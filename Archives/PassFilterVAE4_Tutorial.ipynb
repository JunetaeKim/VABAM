# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import hilbert, chirp
import tensorflow as tf
from tensorflow.keras import backend as K
import pandas as pd
from tensorflow.keras.layers import Input, GRU, Dense,Conv1D, Masking, Reshape, BatchNormalization, Flatten, Conv1DTranspose, RepeatVector, TimeDistributed, Bidirectional, MaxPooling1D,Activation, GaussianNoise, Lambda
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras import Model
import tensorflow_probability as tfp

os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %% [markdown]
# ### Data

# %%
DATA = np.load('./Data/AsanTRSet.npy')

# %% [markdown]
# #### Env setting

# %%
save_path = './Results/'
if not os.path.exists(save_path):
    os.mkdir(save_path)
    
### Model checkpoint
ModelSaveSameName = save_path+'PSVAE3_Mask.hdf5'
ModelSave = ModelCheckpoint(filepath=ModelSaveSameName, monitor='val_mse', verbose=1, save_best_only=True )

### Model Early stop
EarlyStop = EarlyStopping(monitor='val_loss', patience=500)

LatDim = 2
SigDim = DATA.shape[1]
MaskingRate = 0.025
GaussStd1 = 0.002
GaussStd2 = 0.1

def ReName (layer, name):
    return Lambda(lambda x: x, name=name)(layer)

# %%
def MaskingGen ( InpRegul, MaskingRate = 0.025, GaussStd2 = 0.1):
    ## Masking vector generation 1 vs 0
    NBatch = tf.shape(InpRegul)[0]
    
    MaskIDX = tf.random.shuffle(tf.range(NBatch * InpRegul.shape[1] ))
    CutIDX = tf.cast(  tf.cast(tf.shape(MaskIDX)[0], dtype=tf.float32) * (1-MaskingRate), dtype=tf.int32 )
    MaskIDX = tf.cast(MaskIDX < CutIDX, dtype=tf.float32)
    MaskVec = tf.reshape(MaskIDX, (NBatch, -1))[:,:,None]
    
    ## Noise vector generation 1 vs 0
    RevMaskIDX = MaskIDX == 0
    RevMaskIDX = tf.cast(RevMaskIDX, dtype=tf.float32)
    NoisVec = RevMaskIDX * tf.random.normal(tf.shape(RevMaskIDX), stddev=GaussStd2)
    NoisVec = tf.reshape(NoisVec, (NBatch, -1))[:,:,None]
    return MaskVec, NoisVec

def GenLowFilter (LF, BL, N = 401):
    nVec = np.arange(N)
    KaiserBL = tf.signal.kaiser_window(N, beta=BL)

    # A low-pass filter
    X = 2 * LF * (nVec - (N - 1) / 2)
    X = tf.maximum(X , 1e-7)
    LPF = tf.sin(np.pi*X)/(np.pi*X)
    LPF *= KaiserBL
    LPF /= tf.reduce_sum(LPF, axis=-1, keepdims=True)
    
    return LPF[:,None] 


def GenHighFilter (HF, BH, N = 401):
    nVec = np.arange(N)
    KaiserBH = tf.signal.kaiser_window(N, beta=BH)

    # A high-pass filter
    Y = 2 * HF * (nVec - (N - 1) / 2)
    Y = tf.maximum(Y , 1e-7)
    HPF = tf.sin(np.pi*Y)/(np.pi*Y)
    HPF *= KaiserBH
    HPF /= tf.reduce_sum(HPF, axis=-1, keepdims=True)
    HPF = -HPF

    ## HPF[(N - 1) // 2] += 1
    Mask = np.zeros(HPF.shape[1])
    Mask[(N - 1) // 2] += 1
    Mask = tf.constant(Mask, dtype=tf.float32)
    HPF = HPF + Mask
    
    return HPF[:,None]

# %% [markdown]
# ### Encoder

# %%
training = True

InpL = Input(shape=(SigDim,))
InpFrame = tf.signal.frame(InpL, 100, 100)

if training:
    InpRegul = GaussianNoise(stddev=GaussStd1)(InpFrame, training=training)
    MaskVec, NoisVec = MaskingGen(InpRegul, MaskingRate, GaussStd2)
    EncInp = Masking(mask_value=0.)(InpRegul * MaskVec )
    EncOut = InpRegul + NoisVec
else:
    EncInp, EncOut = InpFrame, InpFrame

EncGRUOut = Bidirectional(GRU(50, return_sequences=True))(EncInp)
EncGRUOut = Bidirectional(GRU(20, return_sequences=False))(EncGRUOut)

Zs = Dense(20, activation='relu')(EncGRUOut)
Zs = Dense(10, activation='relu')(Zs)
Z_Mean = Dense(LatDim, activation='linear', name='Z_Mean')(Zs) 
Z_Log_Sigma = Dense(LatDim, activation='softplus', name='Z_Log_Sigma')(Zs)

# Reparameterization Trick for sampling 
Epsilon = K.random_normal(shape=(tf.shape(Z_Mean)[0], Z_Mean.shape[1]), mean=0., stddev=0.1)
#Epsilon = Lambda(lambda x: x, name="Epsilon")(Epsilon)
Epsilon = ReName(Epsilon,'Epsilon')

Z_Sampled = Z_Mean + tf.exp(0.5 * Z_Log_Sigma) * Epsilon
#Z_Sampled = Lambda(lambda x: x, name="Z_Sampled")(Z_Sampled)
Z_Sampled = ReName(Z_Sampled,'Z_Sampled')


EncModel = Model(InpL, [Flatten()(EncOut), Z_Mean, Z_Log_Sigma, Z_Sampled])

# %% [markdown]
# ##### Debugging

# %%
#EncModel.save_weights('./Results/tmp.hdf5')
#EncModel.load_weights('./Results/tmp.hdf5')
tmp = EncModel.predict(DATA[:100])[0]
#tmp = VAEM.predict(DATA[:100])
plt.plot(tmp[9])

# %% [markdown]
# ### Decoder

# %%
InpZ = Input(shape=(LatDim,), name='InpZmean')
EncReInp = Input(shape=(SigDim,))

FiltPar = Dense(4, activation='relu')(InpZ)
FiltPar = Dense(8, activation='relu')(FiltPar)
FiltPar = Dense(4*3, activation='linear')(FiltPar) # Num. of parameters for filtering : 4, Num. of filtering : 3 

LHFs = Activation('sigmoid')(FiltPar[:, :(4*3)//2])
LHFs = Reshape((-1,2), name='LHFs')(LHFs)

LHBs = Activation('softplus')(FiltPar[:, (4*3)//2:])
LHBs = Reshape((-1,2), name='LHBs')(LHBs)



### Filtering level 1
## Filter generation
HPF_11 = GenHighFilter(LHFs[:, 0, 0:1], LHBs[:, 0, 0:1], N=301)
LPF_11 = GenLowFilter(LHFs[:, 0, 1:2],  LHBs[:, 0, 1:2],  N=201)

## Perform signal filtering level 1
InpFrame_11 =  tf.signal.frame(EncReInp, HPF_11.shape[-1], 1)
HpSig_11 = tf.reduce_sum(InpFrame_11*HPF_11[:,:,::-1], axis=-1, keepdims=True)
HpSig_11 = ReName(HpSig_11, 'HpSig_11')
InpFrame_11 =  tf.signal.frame(EncReInp, LPF_11.shape[-1], 1)
LpSig_11 = tf.reduce_sum(InpFrame_11*LPF_11[:,:,::-1], axis=-1, keepdims=True)
LpSig_11 = ReName(LpSig_11, 'LpSig_11')


### Filtering level 21 (from HpSig_11)
## Filter generation
HPF_21 = GenHighFilter(LHFs[:, 1, 0:1], LHBs[:, 1, 0:1], N=401)
LPF_21 = GenLowFilter(LHFs[:, 1, 1:2],  LHBs[:, 1, 1:2],  N=301)

## Perform signal filtering level 2
InpFrame_21 =  tf.signal.frame(HpSig_11[:,:,0], HPF_21.shape[-1], 1)
HpSig_21 = tf.reduce_sum(InpFrame_21*HPF_21[:,:,::-1], axis=-1, keepdims=True)
HpSig_21 = ReName(HpSig_21, 'HpSig_21')
InpFrame_21 =  tf.signal.frame(HpSig_11[:,:,0], LPF_21.shape[-1], 1)
LpSig_21 = tf.reduce_sum(InpFrame_21*LPF_21[:,:,::-1], axis=-1, keepdims=True)
LpSig_21 = ReName(LpSig_21, 'LpSig_21')

### Filtering level 22 (from LpSig_11)
## Filter generation
HPF_22 = GenHighFilter(LHFs[:, 2, 0:1], LHBs[:, 2, 0:1], N=301)
LPF_22 = GenLowFilter(LHFs[:, 2, 1:2],  LHBs[:, 2, 1:2],  N=201)

## Perform signal filtering level 2
InpFrame_22 =  tf.signal.frame(LpSig_11[:,:,0], HPF_22.shape[-1], 1)
HpSig_22 = tf.reduce_sum(InpFrame_22*HPF_22[:,:,::-1], axis=-1, keepdims=True)
HpSig_22 = ReName(HpSig_22, 'HpSig_22')
InpFrame_22 =  tf.signal.frame(LpSig_11[:,:,0], LPF_22.shape[-1], 1)
LpSig_22 = tf.reduce_sum(InpFrame_22*LPF_22[:,:,::-1], axis=-1, keepdims=True)
LpSig_22 = ReName(LpSig_22, 'LpSig_22')

## GRU NET
Dec_HpSig_11 = Reshape((-1, 100))(HpSig_11)
Dec_LpSig_11 = Reshape((-1, 100))(LpSig_11)
Dec_HpSig_21 = Reshape((-1, 100))(HpSig_21)
Dec_LpSig_21 = Reshape((-1, 100))(LpSig_21)
Dec_HpSig_22 = Reshape((-1, 100))(HpSig_22)
Dec_LpSig_22 = Reshape((-1, 100))(LpSig_22)

Dec_HpSig_11 = Bidirectional(GRU(5))(Dec_HpSig_11)
Dec_LpSig_11 = Bidirectional(GRU(5))(Dec_LpSig_11)
Dec_HpSig_21 = Bidirectional(GRU(5))(Dec_HpSig_21)
Dec_LpSig_21 = Bidirectional(GRU(5))(Dec_LpSig_21)
Dec_HpSig_22 = Bidirectional(GRU(5))(Dec_HpSig_22)
Dec_LpSig_22 = Bidirectional(GRU(5))(Dec_LpSig_22)

Decoder = tf.concat([Dec_HpSig_11, Dec_LpSig_11, Dec_HpSig_21, Dec_LpSig_21, Dec_HpSig_22, Dec_LpSig_22], axis=1)
Decoder = RepeatVector((SigDim//100) )(Decoder)
Decoder = Bidirectional(GRU(50, return_sequences=True))(Decoder)
Decoder = TimeDistributed(Dense(100))(Decoder)
#Decoder = Bidirectional(GRU(50, return_sequences=True))(Decoder)
DecOut = Dense(100, activation='sigmoid')(Decoder)
DecOut = Reshape((SigDim,),name='DecOut')(DecOut)


DecModel = Model([EncReInp, InpZ], DecOut)

# %%
DecModel.summary()
# Out:
# Model: "model_13"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# InpZmean (InputLayer)           [(None, 2)]          0
# __________________________________________________________________________________________________
# dense_29 (Dense)                (None, 4)            12          InpZmean[0][0]
# __________________________________________________________________________________________________
# dense_30 (Dense)                (None, 8)            40          dense_29[0][0]
# __________________________________________________________________________________________________
# dense_31 (Dense)                (None, 12)           108         dense_30[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_90 (Sl (None, 6)            0           dense_31[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 6)            0           tf.__operators__.getitem_90[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_91 (Sl (None, 6)            0           dense_31[0][0]
# __________________________________________________________________________________________________
# LHFs (Reshape)                  (None, 3, 2)         0           activation_2[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 6)            0           tf.__operators__.getitem_91[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_92 (Sl (None, 1)            0           LHFs[0][0]
# __________________________________________________________________________________________________
# LHBs (Reshape)                  (None, 3, 2)         0           activation_3[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_122 (TFOpLambd (None, 1)            0           tf.__operators__.getitem_92[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_93 (Sl (None, 1)            0           LHBs[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_123 (TFOpLambd (None, 301)          0           tf.math.multiply_122[0][0]
# __________________________________________________________________________________________________
# tf.cast_54 (TFOpLambda)         (None, 1)            0           tf.__operators__.getitem_93[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_95 (Sl (None, 1)            0           LHFs[0][0]
# __________________________________________________________________________________________________
# tf.math.maximum_6 (TFOpLambda)  (None, 301)          0           tf.math.multiply_123[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_120 (TFOpLambd (None, 301)          0           tf.cast_54[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_129 (TFOpLambd (None, 1)            0           tf.__operators__.getitem_95[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_96 (Sl (None, 1)            0           LHBs[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_124 (TFOpLambd (None, 301)          0           tf.math.maximum_6[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_6 (TFOpLambda) (None, 301)          0           tf.math.multiply_120[0][0]
#                                                                  tf.cast_54[0][0]
# __________________________________________________________________________________________________
# tf.math.bessel_i0e_12 (TFOpLamb (None, 301)          0           tf.math.multiply_120[0][0]
# __________________________________________________________________________________________________
# tf.math.bessel_i0e_13 (TFOpLamb (None, 1)            0           tf.cast_54[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_130 (TFOpLambd (None, 201)          0           tf.math.multiply_129[0][0]
# __________________________________________________________________________________________________
# tf.cast_55 (TFOpLambda)         (None, 1)            0           tf.__operators__.getitem_96[0][0]
# __________________________________________________________________________________________________
# tf.math.sin_6 (TFOpLambda)      (None, 301)          0           tf.math.multiply_124[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_125 (TFOpLambd (None, 301)          0           tf.math.maximum_6[0][0]
# __________________________________________________________________________________________________
# tf.math.exp_18 (TFOpLambda)     (None, 301)          0           tf.math.subtract_6[0][0]
# __________________________________________________________________________________________________
# tf.math.truediv_18 (TFOpLambda) (None, 301)          0           tf.math.bessel_i0e_12[0][0]
#                                                                  tf.math.bessel_i0e_13[0][0]
# __________________________________________________________________________________________________
# tf.math.maximum_7 (TFOpLambda)  (None, 201)          0           tf.math.multiply_130[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_127 (TFOpLambd (None, 201)          0           tf.cast_55[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_100 (S (None, 1)            0           LHFs[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_110 (S (None, 1)            0           LHFs[0][0]
# __________________________________________________________________________________________________
# tf.math.truediv_19 (TFOpLambda) (None, 301)          0           tf.math.sin_6[0][0]
#                                                                  tf.math.multiply_125[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_121 (TFOpLambd (None, 301)          0           tf.math.exp_18[0][0]
#                                                                  tf.math.truediv_18[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_131 (TFOpLambd (None, 201)          0           tf.math.maximum_7[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_7 (TFOpLambda) (None, 201)          0           tf.math.multiply_127[0][0]
#                                                                  tf.cast_55[0][0]
# __________________________________________________________________________________________________
# tf.math.bessel_i0e_14 (TFOpLamb (None, 201)          0           tf.math.multiply_127[0][0]
# __________________________________________________________________________________________________
# tf.math.bessel_i0e_15 (TFOpLamb (None, 1)            0           tf.cast_55[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_138 (TFOpLambd (None, 1)            0           tf.__operators__.getitem_100[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_101 (S (None, 1)            0           LHBs[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_154 (TFOpLambd (None, 1)            0           tf.__operators__.getitem_110[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_111 (S (None, 1)            0           LHBs[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_126 (TFOpLambd (None, 301)          0           tf.math.truediv_19[0][0]
#                                                                  tf.math.multiply_121[0][0]
# __________________________________________________________________________________________________
# tf.math.sin_7 (TFOpLambda)      (None, 201)          0           tf.math.multiply_131[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_132 (TFOpLambd (None, 201)          0           tf.math.maximum_7[0][0]
# __________________________________________________________________________________________________
# tf.math.exp_19 (TFOpLambda)     (None, 201)          0           tf.math.subtract_7[0][0]
# __________________________________________________________________________________________________
# tf.math.truediv_21 (TFOpLambda) (None, 201)          0           tf.math.bessel_i0e_14[0][0]
#                                                                  tf.math.bessel_i0e_15[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_139 (TFOpLambd (None, 401)          0           tf.math.multiply_138[0][0]
# __________________________________________________________________________________________________
# tf.cast_56 (TFOpLambda)         (None, 1)            0           tf.__operators__.getitem_101[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_103 (S (None, 1)            0           LHFs[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_155 (TFOpLambd (None, 301)          0           tf.math.multiply_154[0][0]
# __________________________________________________________________________________________________
# tf.cast_58 (TFOpLambda)         (None, 1)            0           tf.__operators__.getitem_111[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_113 (S (None, 1)            0           LHFs[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_sum_12 (TFOpLamb (None, 1)            0           tf.math.multiply_126[0][0]
# __________________________________________________________________________________________________
# tf.math.truediv_22 (TFOpLambda) (None, 201)          0           tf.math.sin_7[0][0]
#                                                                  tf.math.multiply_132[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_128 (TFOpLambd (None, 201)          0           tf.math.exp_19[0][0]
#                                                                  tf.math.truediv_21[0][0]
# __________________________________________________________________________________________________
# tf.math.maximum_8 (TFOpLambda)  (None, 401)          0           tf.math.multiply_139[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_136 (TFOpLambd (None, 401)          0           tf.cast_56[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_145 (TFOpLambd (None, 1)            0           tf.__operators__.getitem_103[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_104 (S (None, 1)            0           LHBs[0][0]
# __________________________________________________________________________________________________
# tf.math.maximum_10 (TFOpLambda) (None, 301)          0           tf.math.multiply_155[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_152 (TFOpLambd (None, 301)          0           tf.cast_58[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_161 (TFOpLambd (None, 1)            0           tf.__operators__.getitem_113[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_114 (S (None, 1)            0           LHBs[0][0]
# __________________________________________________________________________________________________
# tf.math.truediv_20 (TFOpLambda) (None, 301)          0           tf.math.multiply_126[0][0]
#                                                                  tf.math.reduce_sum_12[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_133 (TFOpLambd (None, 201)          0           tf.math.truediv_22[0][0]
#                                                                  tf.math.multiply_128[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_140 (TFOpLambd (None, 401)          0           tf.math.maximum_8[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_8 (TFOpLambda) (None, 401)          0           tf.math.multiply_136[0][0]
#                                                                  tf.cast_56[0][0]
# __________________________________________________________________________________________________
# tf.math.bessel_i0e_16 (TFOpLamb (None, 401)          0           tf.math.multiply_136[0][0]
# __________________________________________________________________________________________________
# tf.math.bessel_i0e_17 (TFOpLamb (None, 1)            0           tf.cast_56[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_146 (TFOpLambd (None, 301)          0           tf.math.multiply_145[0][0]
# __________________________________________________________________________________________________
# tf.cast_57 (TFOpLambda)         (None, 1)            0           tf.__operators__.getitem_104[0][0
# __________________________________________________________________________________________________
# tf.math.multiply_156 (TFOpLambd (None, 301)          0           tf.math.maximum_10[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_10 (TFOpLambda (None, 301)          0           tf.math.multiply_152[0][0]
#                                                                  tf.cast_58[0][0]
# __________________________________________________________________________________________________
# tf.math.bessel_i0e_20 (TFOpLamb (None, 301)          0           tf.math.multiply_152[0][0]
# __________________________________________________________________________________________________
# tf.math.bessel_i0e_21 (TFOpLamb (None, 1)            0           tf.cast_58[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_162 (TFOpLambd (None, 201)          0           tf.math.multiply_161[0][0]
# __________________________________________________________________________________________________
# tf.cast_59 (TFOpLambda)         (None, 1)            0           tf.__operators__.getitem_114[0][0
# __________________________________________________________________________________________________
# tf.math.negative_3 (TFOpLambda) (None, 301)          0           tf.math.truediv_20[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_sum_13 (TFOpLamb (None, 1)            0           tf.math.multiply_133[0][0]
# __________________________________________________________________________________________________
# tf.math.sin_8 (TFOpLambda)      (None, 401)          0           tf.math.multiply_140[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_141 (TFOpLambd (None, 401)          0           tf.math.maximum_8[0][0]
# __________________________________________________________________________________________________
# tf.math.exp_20 (TFOpLambda)     (None, 401)          0           tf.math.subtract_8[0][0]
# __________________________________________________________________________________________________
# tf.math.truediv_24 (TFOpLambda) (None, 401)          0           tf.math.bessel_i0e_16[0][0]
#                                                                  tf.math.bessel_i0e_17[0][0]
# __________________________________________________________________________________________________
# tf.math.maximum_9 (TFOpLambda)  (None, 301)          0           tf.math.multiply_146[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_143 (TFOpLambd (None, 301)          0           tf.cast_57[0][0]
# __________________________________________________________________________________________________
# tf.math.sin_10 (TFOpLambda)     (None, 301)          0           tf.math.multiply_156[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_157 (TFOpLambd (None, 301)          0           tf.math.maximum_10[0][0]
# __________________________________________________________________________________________________
# tf.math.exp_22 (TFOpLambda)     (None, 301)          0           tf.math.subtract_10[0][0]
# __________________________________________________________________________________________________
# tf.math.truediv_30 (TFOpLambda) (None, 301)          0           tf.math.bessel_i0e_20[0][0]
#                                                                  tf.math.bessel_i0e_21[0][0]
# __________________________________________________________________________________________________
# tf.math.maximum_11 (TFOpLambda) (None, 201)          0           tf.math.multiply_162[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_159 (TFOpLambd (None, 201)          0           tf.cast_59[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_27 (TFOpLa (None, 301)          0           tf.math.negative_3[0][0]
# __________________________________________________________________________________________________
# tf.math.truediv_23 (TFOpLambda) (None, 201)          0           tf.math.multiply_133[0][0]
#                                                                  tf.math.reduce_sum_13[0][0]
# __________________________________________________________________________________________________
# tf.math.truediv_25 (TFOpLambda) (None, 401)          0           tf.math.sin_8[0][0]
#                                                                  tf.math.multiply_141[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_137 (TFOpLambd (None, 401)          0           tf.math.exp_20[0][0]
#                                                                  tf.math.truediv_24[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_147 (TFOpLambd (None, 301)          0           tf.math.maximum_9[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_9 (TFOpLambda) (None, 301)          0           tf.math.multiply_143[0][0]
#                                                                  tf.cast_57[0][0]
# __________________________________________________________________________________________________
# tf.math.bessel_i0e_18 (TFOpLamb (None, 301)          0           tf.math.multiply_143[0][0]
# __________________________________________________________________________________________________
# tf.math.bessel_i0e_19 (TFOpLamb (None, 1)            0           tf.cast_57[0][0]
# __________________________________________________________________________________________________
# tf.math.truediv_31 (TFOpLambda) (None, 301)          0           tf.math.sin_10[0][0]
#                                                                  tf.math.multiply_157[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_153 (TFOpLambd (None, 301)          0           tf.math.exp_22[0][0]
#                                                                  tf.math.truediv_30[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_163 (TFOpLambd (None, 201)          0           tf.math.maximum_11[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_11 (TFOpLambda (None, 201)          0           tf.math.multiply_159[0][0]
#                                                                  tf.cast_59[0][0]
# __________________________________________________________________________________________________
# tf.math.bessel_i0e_22 (TFOpLamb (None, 201)          0           tf.math.multiply_159[0][0]
# __________________________________________________________________________________________________
# tf.math.bessel_i0e_23 (TFOpLamb (None, 1)            0           tf.cast_59[0][0]
# __________________________________________________________________________________________________
# input_14 (InputLayer)           [(None, 1000)]       0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_94 (Sl (None, 1, 301)       0           tf.__operators__.add_27[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_97 (Sl (None, 1, 201)       0           tf.math.truediv_23[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_142 (TFOpLambd (None, 401)          0           tf.math.truediv_25[0][0]
#                                                                  tf.math.multiply_137[0][0]
# __________________________________________________________________________________________________
# tf.math.sin_9 (TFOpLambda)      (None, 301)          0           tf.math.multiply_147[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_148 (TFOpLambd (None, 301)          0           tf.math.maximum_9[0][0]
# __________________________________________________________________________________________________
# tf.math.exp_21 (TFOpLambda)     (None, 301)          0           tf.math.subtract_9[0][0]
# __________________________________________________________________________________________________
# tf.math.truediv_27 (TFOpLambda) (None, 301)          0           tf.math.bessel_i0e_18[0][0]
#                                                                  tf.math.bessel_i0e_19[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_158 (TFOpLambd (None, 301)          0           tf.math.truediv_31[0][0]
#                                                                  tf.math.multiply_153[0][0]
# __________________________________________________________________________________________________
# tf.math.sin_11 (TFOpLambda)     (None, 201)          0           tf.math.multiply_163[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_164 (TFOpLambd (None, 201)          0           tf.math.maximum_11[0][0]
# __________________________________________________________________________________________________
# tf.math.exp_23 (TFOpLambda)     (None, 201)          0           tf.math.subtract_11[0][0]
# __________________________________________________________________________________________________
# tf.math.truediv_33 (TFOpLambda) (None, 201)          0           tf.math.bessel_i0e_22[0][0]
#                                                                  tf.math.bessel_i0e_23[0][0]
# __________________________________________________________________________________________________
# tf.signal.frame_18 (TFOpLambda) (None, 700, 301)     0           input_14[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_98 (Sl (None, 1, 301)       0           tf.__operators__.getitem_94[0][0]
# __________________________________________________________________________________________________
# tf.signal.frame_19 (TFOpLambda) (None, 800, 201)     0           input_14[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_99 (Sl (None, 1, 201)       0           tf.__operators__.getitem_97[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_sum_16 (TFOpLamb (None, 1)            0           tf.math.multiply_142[0][0]
# __________________________________________________________________________________________________
# tf.math.truediv_28 (TFOpLambda) (None, 301)          0           tf.math.sin_9[0][0]
#                                                                  tf.math.multiply_148[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_144 (TFOpLambd (None, 301)          0           tf.math.exp_21[0][0]
#                                                                  tf.math.truediv_27[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_sum_20 (TFOpLamb (None, 1)            0           tf.math.multiply_158[0][0]
# __________________________________________________________________________________________________
# tf.math.truediv_34 (TFOpLambda) (None, 201)          0           tf.math.sin_11[0][0]
#                                                                  tf.math.multiply_164[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_160 (TFOpLambd (None, 201)          0           tf.math.exp_23[0][0]
#                                                                  tf.math.truediv_33[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_134 (TFOpLambd (None, 700, 301)     0           tf.signal.frame_18[0][0]
#                                                                  tf.__operators__.getitem_98[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_135 (TFOpLambd (None, 800, 201)     0           tf.signal.frame_19[0][0]
#                                                                  tf.__operators__.getitem_99[0][0]
# __________________________________________________________________________________________________
# tf.math.truediv_26 (TFOpLambda) (None, 401)          0           tf.math.multiply_142[0][0]
#                                                                  tf.math.reduce_sum_16[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_149 (TFOpLambd (None, 301)          0           tf.math.truediv_28[0][0]
#                                                                  tf.math.multiply_144[0][0]
# __________________________________________________________________________________________________
# tf.math.truediv_32 (TFOpLambda) (None, 301)          0           tf.math.multiply_158[0][0]
#                                                                  tf.math.reduce_sum_20[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_165 (TFOpLambd (None, 201)          0           tf.math.truediv_34[0][0]
#                                                                  tf.math.multiply_160[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_sum_14 (TFOpLamb (None, 700, 1)       0           tf.math.multiply_134[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_sum_15 (TFOpLamb (None, 800, 1)       0           tf.math.multiply_135[0][0]
# __________________________________________________________________________________________________
# tf.math.negative_4 (TFOpLambda) (None, 401)          0           tf.math.truediv_26[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_sum_17 (TFOpLamb (None, 1)            0           tf.math.multiply_149[0][0]
# __________________________________________________________________________________________________
# tf.math.negative_5 (TFOpLambda) (None, 301)          0           tf.math.truediv_32[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_sum_21 (TFOpLamb (None, 1)            0           tf.math.multiply_165[0][0]
# __________________________________________________________________________________________________
# HpSig_11 (Lambda)               (None, 700, 1)       0           tf.math.reduce_sum_14[0][0]
# __________________________________________________________________________________________________
# LpSig_11 (Lambda)               (None, 800, 1)       0           tf.math.reduce_sum_15[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_28 (TFOpLa (None, 401)          0           tf.math.negative_4[0][0]
# __________________________________________________________________________________________________
# tf.math.truediv_29 (TFOpLambda) (None, 301)          0           tf.math.multiply_149[0][0]
#                                                                  tf.math.reduce_sum_17[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_29 (TFOpLa (None, 301)          0           tf.math.negative_5[0][0]
# __________________________________________________________________________________________________
# tf.math.truediv_35 (TFOpLambda) (None, 201)          0           tf.math.multiply_165[0][0]
#                                                                  tf.math.reduce_sum_21[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_106 (S (None, 700)          0           HpSig_11[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_102 (S (None, 1, 401)       0           tf.__operators__.add_28[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_108 (S (None, 700)          0           HpSig_11[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_105 (S (None, 1, 301)       0           tf.math.truediv_29[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_116 (S (None, 800)          0           LpSig_11[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_112 (S (None, 1, 301)       0           tf.__operators__.add_29[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_118 (S (None, 800)          0           LpSig_11[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_115 (S (None, 1, 201)       0           tf.math.truediv_35[0][0]
# __________________________________________________________________________________________________
# tf.signal.frame_20 (TFOpLambda) (None, 300, 401)     0           tf.__operators__.getitem_106[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_107 (S (None, 1, 401)       0           tf.__operators__.getitem_102[0][0
# __________________________________________________________________________________________________
# tf.signal.frame_21 (TFOpLambda) (None, 400, 301)     0           tf.__operators__.getitem_108[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_109 (S (None, 1, 301)       0           tf.__operators__.getitem_105[0][0
# __________________________________________________________________________________________________
# tf.signal.frame_22 (TFOpLambda) (None, 500, 301)     0           tf.__operators__.getitem_116[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_117 (S (None, 1, 301)       0           tf.__operators__.getitem_112[0][0
# __________________________________________________________________________________________________
# tf.signal.frame_23 (TFOpLambda) (None, 600, 201)     0           tf.__operators__.getitem_118[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_119 (S (None, 1, 201)       0           tf.__operators__.getitem_115[0][0
# __________________________________________________________________________________________________
# tf.math.multiply_150 (TFOpLambd (None, 300, 401)     0           tf.signal.frame_20[0][0]
#                                                                  tf.__operators__.getitem_107[0][0
# __________________________________________________________________________________________________
# tf.math.multiply_151 (TFOpLambd (None, 400, 301)     0           tf.signal.frame_21[0][0]
#                                                                  tf.__operators__.getitem_109[0][0
# __________________________________________________________________________________________________
# tf.math.multiply_166 (TFOpLambd (None, 500, 301)     0           tf.signal.frame_22[0][0]
#                                                                  tf.__operators__.getitem_117[0][0
# __________________________________________________________________________________________________
# tf.math.multiply_167 (TFOpLambd (None, 600, 201)     0           tf.signal.frame_23[0][0]
#                                                                  tf.__operators__.getitem_119[0][0
# __________________________________________________________________________________________________
# tf.math.reduce_sum_18 (TFOpLamb (None, 300, 1)       0           tf.math.multiply_150[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_sum_19 (TFOpLamb (None, 400, 1)       0           tf.math.multiply_151[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_sum_22 (TFOpLamb (None, 500, 1)       0           tf.math.multiply_166[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_sum_23 (TFOpLamb (None, 600, 1)       0           tf.math.multiply_167[0][0]
# __________________________________________________________________________________________________
# HpSig_21 (Lambda)               (None, 300, 1)       0           tf.math.reduce_sum_18[0][0]
# __________________________________________________________________________________________________
# LpSig_21 (Lambda)               (None, 400, 1)       0           tf.math.reduce_sum_19[0][0]
# __________________________________________________________________________________________________
# HpSig_22 (Lambda)               (None, 500, 1)       0           tf.math.reduce_sum_22[0][0]
# __________________________________________________________________________________________________
# LpSig_22 (Lambda)               (None, 600, 1)       0           tf.math.reduce_sum_23[0][0]
# __________________________________________________________________________________________________
# reshape_8 (Reshape)             (None, 7, 100)       0           HpSig_11[0][0]
# __________________________________________________________________________________________________
# reshape_9 (Reshape)             (None, 8, 100)       0           LpSig_11[0][0]
# __________________________________________________________________________________________________
# reshape_10 (Reshape)            (None, 3, 100)       0           HpSig_21[0][0]
# __________________________________________________________________________________________________
# reshape_11 (Reshape)            (None, 4, 100)       0           LpSig_21[0][0]
# __________________________________________________________________________________________________
# reshape_12 (Reshape)            (None, 5, 100)       0           HpSig_22[0][0]
# __________________________________________________________________________________________________
# reshape_13 (Reshape)            (None, 6, 100)       0           LpSig_22[0][0]
# __________________________________________________________________________________________________
# bidirectional_31 (Bidirectional (None, 10)           3210        reshape_8[0][0]
# __________________________________________________________________________________________________
# bidirectional_32 (Bidirectional (None, 10)           3210        reshape_9[0][0]
# __________________________________________________________________________________________________
# bidirectional_33 (Bidirectional (None, 10)           3210        reshape_10[0][0]
# __________________________________________________________________________________________________
# bidirectional_34 (Bidirectional (None, 10)           3210        reshape_11[0][0]
# __________________________________________________________________________________________________
# bidirectional_35 (Bidirectional (None, 10)           3210        reshape_12[0][0]
# __________________________________________________________________________________________________
# bidirectional_36 (Bidirectional (None, 10)           3210        reshape_13[0][0]
# __________________________________________________________________________________________________
# tf.concat_1 (TFOpLambda)        (None, 60)           0           bidirectional_31[0][0]
#                                                                  bidirectional_32[0][0]
#                                                                  bidirectional_33[0][0]
#                                                                  bidirectional_34[0][0]
#                                                                  bidirectional_35[0][0]
#                                                                  bidirectional_36[0][0]
# __________________________________________________________________________________________________
# repeat_vector_1 (RepeatVector)  (None, 10, 60)       0           tf.concat_1[0][0]
# __________________________________________________________________________________________________
# bidirectional_37 (Bidirectional (None, 10, 100)      33600       repeat_vector_1[0][0]
# __________________________________________________________________________________________________
# time_distributed_1 (TimeDistrib (None, 10, 100)      10100       bidirectional_37[0][0]
# __________________________________________________________________________________________________
# dense_33 (Dense)                (None, 10, 100)      10100       time_distributed_1[0][0]
# __________________________________________________________________________________________________
# DecOut (Reshape)                (None, 1000)         0           dense_33[0][0]
# ==================================================================================================
# Total params: 73,220
# Trainable params: 73,220
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ### Vae Loss; RecMSE and KL Divergence¶

# %%
# apply beta and capacity
Capacity = 0.01
Beta = 1.0


### Vae Loss; KL Divergence
kl_Loss = 0.5 * tf.reduce_sum( Z_Mean**2  +  tf.exp(Z_Log_Sigma)- Z_Log_Sigma-1, axis=1)    
#kl_Loss = beta *tf.reduce_mean(kl_Loss )

kl_Loss = tf.reduce_mean(kl_Loss )
#kl_Loss = Beta * tf.abs(kl_Loss - Capacity)

def RECMSE (y_true, y_pred):
    
    RecMSE = tf.losses.mse(y_true, y_pred)
    RecMSE *= InpL.shape[1]
    
    return RecMSE

# %%
VAEOut = DecModel([EncModel(InpL)[0], EncModel(InpL)[3]])
VAEOut = Reshape((SigDim,), name='VAEOut')(VAEOut)
VAEM = Model(InpL, VAEOut, name='vae_mlp')

VAEM.compile(optimizer='adam', loss=tf.losses.mean_squared_error, metrics={"VAEOut":'mse'})
#VAEM.compile(optimizer='adam', loss=RECMSE, metrics={"VAEOut":'mse'})
VAEM.add_loss(kl_Loss )
VAEM.add_metric(kl_Loss, 'KL_D')
VAEM.summary()
# Out:
# Model: "vae_mlp"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 1000)]       0
# __________________________________________________________________________________________________
# model_1 (Functional)            [(None, 1000), (None 61314       input_2[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# model_2 (Functional)            (None, 1000)         73220       model_1[0][0]
#                                                                  model_1[1][3]
# __________________________________________________________________________________________________
# VAEOut (Reshape)                (None, 1000)         0           model_2[0][0]
# __________________________________________________________________________________________________
# tf.signal.frame_1 (TFOpLambda)  (None, 10, 100)      0           input_2[0][0]
# __________________________________________________________________________________________________
# gaussian_noise (GaussianNoise)  (None, 10, 100)      0           tf.signal.frame_1[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.shape_1 (TFOpLambd (3,)                 0           gaussian_noise[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1 (Sli ()                   0           tf.compat.v1.shape_1[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_2 (TFOpLambda) ()                   0           tf.__operators__.getitem_1[0][0]
# __________________________________________________________________________________________________
# tf.range (TFOpLambda)           (None,)              0           tf.math.multiply_2[0][0]
# __________________________________________________________________________________________________
# tf.random.shuffle (TFOpLambda)  (None,)              0           tf.range[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.shape_2 (TFOpLambd (1,)                 0           tf.random.shuffle[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_2 (Sli ()                   0           tf.compat.v1.shape_2[0][0]
# __________________________________________________________________________________________________
# tf.cast (TFOpLambda)            ()                   0           tf.__operators__.getitem_2[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_3 (TFOpLambda) ()                   0           tf.cast[0][0]
# __________________________________________________________________________________________________
# tf.cast_1 (TFOpLambda)          ()                   0           tf.math.multiply_3[0][0]
# __________________________________________________________________________________________________
# tf.math.less (TFOpLambda)       (None,)              0           tf.random.shuffle[0][0]
#                                                                  tf.cast_1[0][0]
# __________________________________________________________________________________________________
# tf.cast_2 (TFOpLambda)          (None,)              0           tf.math.less[0][0]
# __________________________________________________________________________________________________
# tf.reshape (TFOpLambda)         (None, None)         0           tf.cast_2[0][0]
#                                                                  tf.__operators__.getitem_1[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_3 (Sli (None, None, 1)      0           tf.reshape[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_5 (TFOpLambda) (None, 10, 100)      0           gaussian_noise[0][0]
#                                                                  tf.__operators__.getitem_3[0][0]
# __________________________________________________________________________________________________
# masking (Masking)               (None, 10, 100)      0           tf.math.multiply_5[0][0]
# __________________________________________________________________________________________________
# bidirectional_2 (Bidirectional) (None, 10, 100)      45600       masking[0][0]
# __________________________________________________________________________________________________
# bidirectional_3 (Bidirectional) (None, 40)           14640       bidirectional_2[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 20)           820         bidirectional_3[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 10)           210         dense_2[0][0]
# __________________________________________________________________________________________________
# Z_Mean (Dense)                  (None, 2)            22          dense_3[0][0]
# __________________________________________________________________________________________________
# Z_Log_Sigma (Dense)             (None, 2)            22          dense_3[0][0]
# __________________________________________________________________________________________________
# tf.math.pow (TFOpLambda)        (None, 2)            0           Z_Mean[0][0]
# __________________________________________________________________________________________________
# tf.math.exp_8 (TFOpLambda)      (None, 2)            0           Z_Log_Sigma[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_6 (TFOpLam (None, 2)            0           tf.math.pow[0][0]
#                                                                  tf.math.exp_8[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_6 (TFOpLambda) (None, 2)            0           tf.__operators__.add_6[0][0]
#                                                                  Z_Log_Sigma[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_7 (TFOpLambda) (None, 2)            0           tf.math.subtract_6[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_sum_12 (TFOpLamb (None,)              0           tf.math.subtract_7[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_56 (TFOpLambda (None,)              0           tf.math.reduce_sum_12[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_mean (TFOpLambda ()                   0           tf.math.multiply_56[0][0]
# __________________________________________________________________________________________________
# add_loss (AddLoss)              ()                   0           tf.math.reduce_mean[0][0]
# __________________________________________________________________________________________________
# add_metric (AddMetric)          ()                   0           tf.math.reduce_mean[0][0]
# ==================================================================================================
# Total params: 134,534
# Trainable params: 134,534
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
#VAEM.load_weights(ModelSaveSameName)
ModelSave = ModelCheckpoint(filepath=ModelSaveSameName, monitor='val_mse', verbose=1, save_best_only=True )

VAEM.fit(DATA[:], DATA[:], batch_size=1000, epochs=500, shuffle=True, validation_split=0.2, callbacks=[ModelSave, EarlyStop])
# Out:
# Epoch 1/500
# 102/320 [========>.....................] - ETA: 57s - loss: 0.0779 - mse: 0.0216 - KL_D: 0.0165
# KeyboardInterrupt

# %%
#VAEM.save_weights('./Results/Masktmp')
#VAEM.load_weights('./Results/Masktmp')

# %% [markdown]
# #### Rec pred by zMean sample

# %%
VAEM.load_weights(ModelSaveSameName)
#Pred =VAEM.predict(DATA[:], batch_size=1000, verbose=1)
VAEM.evaluate(DATA[:], DATA[:], batch_size=2000, verbose=1)
#np.mean((DATA[:]- Pred)**2)
# Out:
# 200/200 [==============================] - 11s 56ms/step - loss: 6.2545e-04 - mse: 6.2535e-04 - KL_D: 1.0242e-07
# [0.0006254484178498387, 0.0006253462051972747, 1.0241907233421443e-07]

# %% [markdown]
# #### Rec pred by zMean

# %%
VAEM.load_weights(ModelSaveSameName)
VAEOut = DecModel([EncModel(InpL)[0], EncModel(InpL)[1]])
VAEOut = Reshape((SigDim,), name='VAEOut')(VAEOut)

RecM = Model(InpL, VAEOut, name='vae_mlp')
Pred = RecM.predict(DATA[:], batch_size=2000, verbose=1 )
RecM.compile(optimizer='adam', loss=tf.losses.mean_squared_error, metrics= {"VAEOut":'mse'}) #{"VAEOut":'mse'}
RecM.evaluate(DATA[:], DATA[:], batch_size=2000, verbose=1)
np.mean((DATA[:]- Pred)**2)
# Out:
# 200/200 [==============================] - 14s 56ms/step
# 200/200 [==============================] - 16s 55ms/step - loss: 6.2412e-04 - mse: 6.2412e-04
# 0.00062535104

# %% [markdown]
# #### Components pred

# %%
VAEM.load_weights(ModelSaveSameName)
LatM = Model([InpL2,InpZ], [HpSig_11, LpSig_11, HpSig_21, LpSig_21, HpSig_22, LpSig_22 ])
ParaM = Model([InpL2,InpZ], [LHFs, LHBs ])


Pred_ZMean = Model(InpL, Z_Mean).predict(DATA[:10])
PredLat = LatM.predict([DATA[:10],Pred_ZMean] )
PredPara = ParaM.predict([DATA[:10],Pred_ZMean] )
#Pred =VAEM.predict(DATA[:10])

# %% [markdown]
# #### Variational pred

# %%
Pred_ZSampled = np.array([np.linspace(-30, 30, 10), np.linspace(-30, 30, 10)]).T
DataSample = np.tile(DATA[1:2].T, 10).T
PredLat = LatM.predict([DataSample,Pred_ZSampled] )

idx = 5
#plt.plot(DATA[idx])
for i in range(9):
    plt.plot(PredLat[idx][i, :1000, 0])
    #print(PredLat[i].shape)

# %%
PredLat[0].shape
# Out:
# (10, 700, 1)

# %%
idx = 0
plt.plot(DATA[idx])
for i in range(6):
    plt.plot(PredLat[i][idx, :1000, 0])
    #print(PredLat[i].shape)

# %%
idx = 0
plt.plot(PredLat[0][idx, :1000, 0])
plt.plot(PredLat[2][idx, :1000, 0])

# %%
plt.plot(PredLat[1][idx, :, 0])
plt.plot(PredLat[3][idx, :, 0])
plt.plot(PredLat[4][idx, :, 0])
plt.plot(PredLat[5][idx, :, 0])

# %%
idx= 5
plt.plot(Pred[idx], c='red')
plt.plot(DATA[idx])

# %%
# Out:
# 100
