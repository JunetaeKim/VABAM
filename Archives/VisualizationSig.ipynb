# %%
import re
import os
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.patches as patches


from Utilities.EvaluationMain import *
from Utilities.Utilities import ReadYaml, SerializeObjects, DeserializeObjects, LoadModelConfigs, LoadParams
from Models.Caller import *
from Utilities.Visualization import VisReconGivenZ_FCA, HeatMapFreqZ_FCA, VisReconGivenFC_ZA, VisReconExtractZ_FC


from Benchmarks.Models.BenchmarkCaller import ModelCall as BMCaller
from Utilities.Visualization import *

# %%
SelIDX= 1
N_Gen = 500
MinFreqR=0.0
MaxFreqR=0.99


YamlPath =  './Benchmarks/Config/EvalConfigII.yml' 
#YamlPath = './Config/EvalConfigART800.yml'
ConfigName = 'ConVAE_II_50' #'SKZFC_ART_50_800' #'BaseVAE_ART_50' #'ConVAE_ART_50'


if 'ConVAE' in ConfigName:
    ModelType = 'ConVAE'
elif 'BaseVAE' in ConfigName:
    ModelType = 'BaseVAE'
elif 'SKZFC' in ConfigName or 'FACFC' in ConfigName or 'TCMIDKZFC' in ConfigName or 'SKZ' in ConfigName:
    ModelType = 'Ours'

EvalConfigs = ReadYaml(YamlPath)
ModelConfigs = ReadYaml(YamlPath)

# Loading the model configurations
if ModelType == 'BaseVAE' or ModelType == 'ConVAE':
    ModelConfigSet, ModelLoadName = LoadModelConfigs(ConfigName, Comp=False, RootDirYaml='./Benchmarks/Config/')
else:
    ModelConfigSet, ModelLoadName = LoadModelConfigs(ConfigName)

# Loading parameters for the evaluation
Params = LoadParams(ModelConfigSet, EvalConfigs[ConfigName])
Params['Common_Info'] = EvalConfigs['Common_Info']


# Loading data
TrData = np.load('./Data/ProcessedData/Tr'+str(Params['SigType'])+'.npy').astype('float32')
VallData = np.load('./Data/ProcessedData/Val'+str(Params['SigType'])+'.npy').astype('float32')

# Intermediate parameters 
SigDim = VallData.shape[1]
DataSize = VallData.shape[0]

# %%
if ModelType == 'Ours':
    
    # Calling Modesl
    SigRepModel, ModelParts = ModelCall (ModelConfigSet, SigDim, DataSize, LoadWeight=True, ReturnModelPart=True, Reparam=False, ReparaStd=Params['ReparaStd'], ModelSaveName=ModelLoadName)
    
    # Setting Model Specifications and Sub-models
    if Params['LossType'] =='Default':
        EncModel, FeatExtModel, FeatGenModel, ReconModel = ModelParts
    elif Params['LossType'] =='FACLosses':
        EncModel, FeatExtModel, FeatGenModel, ReconModel, FacDiscModel = ModelParts
        
    ## The generation model for evaluation
    RecOut = ReconModel(FeatGenModel.output)
    GenModel = Model(FeatGenModel.input, RecOut)
    
    ## The sampling model for evaluation
    Zs_Out = SigRepModel.get_layer('Zs').output
    SampModel = Model(EncModel.input, Zs_Out)

    # Signal generation
    AnalData = VallData
    InpSignal = np.repeat(AnalData[SelIDX:SelIDX+1], N_Gen, axis=0)
    PredZs = SampModel.predict(InpSignal)
    
    FC_Comm = np.tile(np.linspace(MinFreqR, MaxFreqR, N_Gen )[:, None], (1,2))
    FC_Each = np.tile(np.linspace(MinFreqR, MaxFreqR, N_Gen )[:, None], (1,4))
    
    FeatGen = FeatGenModel([FC_Comm,FC_Each, PredZs])
    ReconSignal = ReconModel([FeatGen])
    

elif ModelType == 'BaseVAE':

    # Calling Modesl
    BenchModel, _, AnalData = BMCaller (ModelConfigSet, ConfigName, TrData, VallData, LoadWeight=True, Reparam=False, ReparaStd=Params['ReparaStd'], ModelSaveName='./Benchmarks/' + ModelLoadName[2:]) 
    
    ## The generation model for evaluation
    GenModel = BenchModel.get_layer('ReconModel')
    
    ## The sampling model for evaluation
    Inp_Enc = BenchModel.get_layer('Inp_Enc')
    Zs = BenchModel.get_layer('Zs').output
    
    if Params['SecDataType'] == 'CONDIN':
        Inp_Cond = BenchModel.get_layer('Inp_Cond')
        SampModel = Model([Inp_Enc.input, Inp_Cond.input], Zs)
    else:
        SampModel = Model(Inp_Enc.input, Zs)

    # Signal generation
    InpSignal = np.repeat(VallData[SelIDX:SelIDX+1], N_Gen, axis=0)
    PredZs = SampModel.predict(InpSignal)
    
    VariZs = PredZs  + np.sort(np.random.normal(0, Params['ReparaStd'], N_Gen))[:,None]
    ReconSignal = GenModel.predict(VariZs)


elif ModelType == 'ConVAE':
    
    # Calling Modesl
    BenchModel, _, AnalData = BMCaller (ModelConfigSet, ConfigName, TrData, VallData, LoadWeight=True, Reparam=False, ReparaStd=Params['ReparaStd'], ModelSaveName='./Benchmarks/' + ModelLoadName[2:]) 
            
    ## The generation model for evaluation
    GenModel = BenchModel.get_layer('ReconModel')
    
    ## The sampling model for evaluation
    Inp_Enc = BenchModel.get_layer('Inp_Enc')
    Zs = BenchModel.get_layer('Zs').output
    
    if Params['SecDataType'] == 'CONDIN':
        Inp_Cond = BenchModel.get_layer('Inp_Cond')
        SampModel = Model([Inp_Enc.input, Inp_Cond.input], Zs)
    else:
        SampModel = Model(Inp_Enc.input, Zs)

    # Signal generation
    RawSignal, ConData = AnalData
    CON_Arange = GenConArangeSimple(ConData, N_Gen)
    InpSignal = np.repeat(RawSignal[SelIDX:SelIDX+1], N_Gen, axis=0)
    PredZs = SampModel.predict([InpSignal, CON_Arange])
    ReconSignal = GenModel([PredZs, CON_Arange])
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  Inp_Enc (InputLayer)           [(None, 1000)]       0           []
#
#  tf.signal.frame (TFOpLambda)   (None, 20, 50)       0           ['Inp_Enc[0][0]']
#
#  bidirectional (Bidirectional)  (None, 20, 50)       11550       ['tf.signal.frame[0][0]']
#
#  bidirectional_1 (Bidirectional  (None, 20, 50)      11550       ['bidirectional[0][0]']
#  )
#
#  bidirectional_2 (Bidirectional  (None, 150)         57150       ['bidirectional_1[0][0]']
#  )
#
#  Inp_Cond (InputLayer)          [(None, 50)]         0           []
#
#  concatenate (Concatenate)      (None, 200)          0           ['bidirectional_2[0][0]',
#                                                                   'Inp_Cond[0][0]']
#
#  dense (Dense)                  (None, 100)          20100       ['concatenate[0][0]']
#
#  dense_1 (Dense)                (None, 70)           7070        ['dense[0][0]']
#
#  dense_2 (Dense)                (None, 50)           3550        ['dense_1[0][0]']
#
#  Z_Mu (Dense)                   (None, 50)           2550        ['dense_2[0][0]']
#
#  dense_3 (Dense)                (None, 50)           2550        ['dense_2[0][0]']
#
#  tf.compat.v1.shape (TFOpLambda  (2,)                0           ['Z_Mu[0][0]']
#  )
#
#  Z_Log_Sigma (Lambda)           (None, 50)           0           ['dense_3[0][0]']
#
#  tf.__operators__.getitem (Slic  ()                  0           ['tf.compat.v1.shape[0][0]']
#  ingOpLambda)
#
#  tf.math.multiply_1 (TFOpLambda  (None, 50)          0           ['Z_Log_Sigma[0][0]']
#  )
#
#  tf.random.normal (TFOpLambda)  (None, 50)           0           ['tf.__operators__.getitem[0][0]'
#                                                                  ]
#
#  tf.math.exp (TFOpLambda)       (None, 50)           0           ['tf.math.multiply_1[0][0]']
#
#  tf.math.multiply (TFOpLambda)  (None, 50)           0           ['tf.random.normal[0][0]']
#
#  tf.math.multiply_2 (TFOpLambda  (None, 50)          0           ['tf.math.exp[0][0]',
#  )                                                                'tf.math.multiply[0][0]']
#
#  tf.__operators__.add (TFOpLamb  (None, 50)          0           ['Z_Mu[0][0]',
#  da)                                                              'tf.math.multiply_2[0][0]']
#
#  Zs (Lambda)                    (None, 50)           0           ['tf.__operators__.add[0][0]']
#
#  ReconModel (Functional)        (None, 1000)         54925       ['Zs[0][0]',
#                                                                   'Inp_Cond[0][0]']
#
#  tf.cast_1 (TFOpLambda)         (None, 1000)         0           ['Inp_Enc[0][0]']
#
#  tf.cast (TFOpLambda)           (None, 1000)         0           ['ReconModel[0][0]']
#
#  tf.math.subtract (TFOpLambda)  (None, 1000)         0           ['tf.cast_1[0][0]',
#                                                                   'tf.cast[0][0]']
#
#  tf.math.square (TFOpLambda)    (None, 1000)         0           ['tf.math.subtract[0][0]']
#
#  Beta_Rec (Lossweight)          ()                   1           ['ReconModel[0][0]']
#
#  tf.math.reduce_mean (TFOpLambd  ()                  0           ['tf.math.square[0][0]']
#  a)
#
#  tf.math.multiply_3 (TFOpLambda  ()                  0           ['Beta_Rec[0][0]',
#  )                                                                'tf.math.reduce_mean[0][0]']
#
#  add_loss (AddLoss)             ()                   0           ['tf.math.multiply_3[0][0]']
#
#  add_metric (AddMetric)         ()                   0           ['tf.math.multiply_3[0][0]']
#
#  tf.math.pow (TFOpLambda)       (None, 50)           0           ['Z_Mu[0][0]']
#
#  tf.math.exp_1 (TFOpLambda)     (None, 50)           0           ['Z_Log_Sigma[0][0]']
#
#  tf.__operators__.add_1 (TFOpLa  (None, 50)          0           ['tf.math.pow[0][0]',
#  mbda)                                                            'tf.math.exp_1[0][0]']
#
#  tf.math.subtract_1 (TFOpLambda  (None, 50)          0           ['tf.__operators__.add_1[0][0]',
#  )                                                                'Z_Log_Sigma[0][0]']
#
#  tf.math.subtract_2 (TFOpLambda  (None, 50)          0           ['tf.math.subtract_1[0][0]']
#  )
#
#  tf.math.reduce_sum (TFOpLambda  (None,)             0           ['tf.math.subtract_2[0][0]']
#  )
#
#  tf.math.multiply_4 (TFOpLambda  (None,)             0           ['tf.math.reduce_sum[0][0]']
#  )
#
#  tf.math.reduce_mean_1 (TFOpLam  ()                  0           ['tf.math.multiply_4[0][0]']
#  bda)
#
#  tf.math.subtract_3 (TFOpLambda  ()                  0           ['tf.math.reduce_mean_1[0][0]']
#  )
#
#  Beta_Z (Lossweight)            ()                   1           ['ReconModel[0][0]']
#
#  tf.math.abs (TFOpLambda)       ()                   0           ['tf.math.subtract_3[0][0]']
#
#  tf.math.multiply_5 (TFOpLambda  ()                  0           ['Beta_Z[0][0]',
#  )                                                                'tf.math.abs[0][0]']
#
#  add_loss_1 (AddLoss)           ()                   0           ['tf.math.multiply_5[0][0]']
#
#  add_metric_1 (AddMetric)       ()                   0           ['tf.math.multiply_5[0][0]']
#
# ==================================================================================================
# Total params: 170,997
# Trainable params: 170,995
# Non-trainable params: 2
# __________________________________________________________________________________________________
# Model weights loaded
# 10/10 [==============================] - 2s 5ms/step

# %%
def CustomLinspace(start, end, breakpoints, numbers):
    """
    Generate a series of points within specified intervals and number of points.

    Parameters:
    start (float): The starting value of the sequence.
    end (float): The end value of the sequence.
    breakpoints (list): A list of points where the intervals change.
    numbers (list): A list of integers indicating the number of points in each interval.

    Returns:
    np.array: An array of points including the start, end, and the specified number of points in each interval.
    """

    # Validate input: there should be one more number than there are breakpoints
    if len(breakpoints) + 1 != len(numbers):
        raise ValueError("There must be one more element in 'numbers' than there are in 'breakpoints'.")

    # Combine the start, breakpoints, and end into a single list of points
    points = [start] + breakpoints + [end]
    
    # Initialize an empty array to hold the result
    result = np.array([])

    # Generate points for each interval
    for i in range(len(numbers)):
        # Determine if the endpoint should be included
        endpoint = True if i == len(numbers) - 1 else False  # Include endpoint only for the last interval
        
        # Generate 'numbers[i]' points between 'points[i]' and 'points[i + 1]'
        part = np.linspace(points[i], points[i + 1], numbers[i], endpoint=endpoint)
        result = np.concatenate((result, part))  # Append the new points to the result

    return result


def SigGen (ConfigName, YamlPath, SelIDX= 1, N_Gen = 300, MinFreqR=0.0, MaxFreqR=0.05, GenBP=None, N_GenList = None):
    
    if N_GenList is not None:
            N_Gen = np.sum(N_GenList)
        
    if 'ConVAE' in ConfigName:
        ModelType = 'ConVAE'
    elif 'BaseVAE' in ConfigName or 'TCVAE' in ConfigName or 'FACVAE' in ConfigName:
        ModelType = 'BaseVAE'
    elif 'SKZFC' in ConfigName or 'FACFC' in ConfigName or 'TCMIDKZFC' in ConfigName or 'SKZ' in ConfigName:
        ModelType = 'Ours'
    
    EvalConfigs = ReadYaml(YamlPath)
    ModelConfigs = ReadYaml(YamlPath)
    
    # Loading the model configurations
    if ModelType == 'BaseVAE' or ModelType == 'ConVAE':
        ModelConfigSet, ModelLoadName = LoadModelConfigs(ConfigName, Comp=False, RootDirYaml='./Benchmarks/Config/')
    else:
        ModelConfigSet, ModelLoadName = LoadModelConfigs(ConfigName)
    
    # Loading parameters for the evaluation
    Params = LoadParams(ModelConfigSet, EvalConfigs[ConfigName])
    Params['Common_Info'] = EvalConfigs['Common_Info']
    
    
    # Loading data
    TrData = np.load('./Data/ProcessedData/Tr'+str(Params['SigType'])+'.npy').astype('float32')
    VallData = np.load('./Data/ProcessedData/Val'+str(Params['SigType'])+'.npy').astype('float32')
    
    # Intermediate parameters 
    SigDim = VallData.shape[1]
    DataSize = VallData.shape[0]


    if ModelType == 'Ours':

        if N_GenList is not None:
            FC_Comm = np.tile(CustomLinspace(MinFreqR, MaxFreqR, GenBP, N_GenList)[:, None], (1,2))
            FC_Each = np.tile(CustomLinspace(MinFreqR, MaxFreqR, GenBP, N_GenList)[:, None], (1,4))
        else:
            FC_Comm = np.tile(np.linspace(MinFreqR, MaxFreqR, N_Gen )[:, None], (1,2))
            FC_Each = np.tile(np.linspace(MinFreqR, MaxFreqR, N_Gen )[:, None], (1,4))
            
    
        # Calling Modesl
        SigRepModel, ModelParts = ModelCall (ModelConfigSet, SigDim, DataSize, LoadWeight=True, ReturnModelPart=True, Reparam=False, ReparaStd=Params['ReparaStd'], ModelSaveName=ModelLoadName)
        
        # Setting Model Specifications and Sub-models
        if Params['LossType'] =='Default':
            EncModel, FeatExtModel, FeatGenModel, ReconModel = ModelParts
        elif Params['LossType'] =='FACLosses':
            EncModel, FeatExtModel, FeatGenModel, ReconModel, FacDiscModel = ModelParts
            
        ## The generation model for evaluation
        RecOut = ReconModel(FeatGenModel.output)
        GenModel = Model(FeatGenModel.input, RecOut)
        
        ## The sampling model for evaluation
        Zs_Out = SigRepModel.get_layer('Zs').output
        SampModel = Model(EncModel.input, Zs_Out)
    
        # Signal generation
        AnalData = VallData
        OrginalSig = AnalData[SelIDX:SelIDX+1]
        InpSignal = np.repeat(OrginalSig, N_Gen, axis=0)
        PredZs = SampModel.predict(InpSignal)

        FeatGen = FeatGenModel([FC_Comm,FC_Each, PredZs])
        ReconSignal = ReconModel.predict([FeatGen])
        CON_Arange = None
        
    
    elif ModelType == 'BaseVAE':
    
        # Calling Modesl
        BenchModel, _, AnalData = BMCaller (ModelConfigSet, ConfigName, TrData, VallData, LoadWeight=True, Reparam=False, ReparaStd=Params['ReparaStd'], ModelSaveName='./Benchmarks/' + ModelLoadName[2:]) 
        
        ## The generation model for evaluation
        GenModel = BenchModel.get_layer('ReconModel')
        
        ## The sampling model for evaluation
        Inp_Enc = BenchModel.get_layer('Inp_Enc')
        Zs = BenchModel.get_layer('Zs').output
        
        if Params['SecDataType'] == 'CONDIN':
            Inp_Cond = BenchModel.get_layer('Inp_Cond')
            SampModel = Model([Inp_Enc.input, Inp_Cond.input], Zs)
        else:
            SampModel = Model(Inp_Enc.input, Zs)
    
        # Gignal generation
        OrginalSig = AnalData[SelIDX:SelIDX+1]
        InpSignal = np.repeat(OrginalSig, N_Gen, axis=0)
        PredZs = SampModel.predict(InpSignal)
        
        PredZs = PredZs  + np.sort(np.random.normal(0, Params['ReparaStd'], N_Gen))[:,None]
        ReconSignal = GenModel.predict(PredZs)
        CON_Arange = None
    
    
    elif ModelType == 'ConVAE':
        
        # Calling Modesl
        BenchModel, _, AnalData = BMCaller (ModelConfigSet, ConfigName, TrData, VallData, LoadWeight=True, Reparam=False, ReparaStd=Params['ReparaStd'], ModelSaveName='./Benchmarks/' + ModelLoadName[2:]) 
                
        ## The generation model for evaluation
        GenModel = BenchModel.get_layer('ReconModel')
        
        ## The sampling model for evaluation
        Inp_Enc = BenchModel.get_layer('Inp_Enc')
        Zs = BenchModel.get_layer('Zs').output
        
        if Params['SecDataType'] == 'CONDIN':
            Inp_Cond = BenchModel.get_layer('Inp_Cond')
            SampModel = Model([Inp_Enc.input, Inp_Cond.input], Zs)
        else:
            SampModel = Model(Inp_Enc.input, Zs)
    
        # Signal generation
        RawSignal, ConData = AnalData
        CON_Arange = GenConArangeSimple(ConData, N_Gen)
        '''
        RandSelIDXbdm = np.random.randint(0, ConData.shape[0], N_Gen)
        SelConData = ConData[RandSelIDXbdm]
        CON_Arange = np.sort(SelConData, axis=0)
        '''
        #np.random.seed(0)
        #ConData = np.random.permutation(ConData)[:N_Gen]
        #CON_Arange = np.sort(ConData, axis=0)
        
        OrginalSig = RawSignal[SelIDX:SelIDX+1]
        InpSignal = np.repeat(OrginalSig, N_Gen, axis=0)
        PredZs = SampModel.predict([InpSignal, CON_Arange])
        ReconSignal = GenModel.predict([PredZs, CON_Arange])

    HalfLen = ReconSignal.shape[1]//2
    FFTRes = np.abs(np.fft.fft(ReconSignal, axis=-1)[:, :HalfLen]) 
    Amplitude = FFTRes/HalfLen

    return ReconSignal, Amplitude, OrginalSig, PredZs, CON_Arange

# %%
GenBP=[0.1, 0.5]
N_GenList = [300, 150, 50]

DicConfigYaml = {'SKZFC_ART_50_800': './Config/EvalConfigART800.yml',
                 'ConVAE_ART_50'  : './Benchmarks/Config/EvalConfigART.yml',
                 'BaseVAE_ART_50' : './Benchmarks/Config/EvalConfigART.yml',
                'SKZFC_II_50_800': './Config/EvalConfigII800.yml',
                 'ConVAE_II_50'  : './Benchmarks/Config/EvalConfigII.yml',
                 'BaseVAE_II_50' : './Benchmarks/Config/EvalConfigII.yml', 
                 'TCVAE_ART_50'         : './Benchmarks/Config/EvalConfigART.yml',
                 'FACVAE_ART_50'        : './Benchmarks/Config/EvalConfigART.yml',
                 'TCMIDKZFC_ART_50_800' : './Config/EvalConfigART800.yml',
                 'FACFC_ART_50_800'     : './Config/EvalConfigART800.yml',
                 'TCVAE_II_50'         : './Benchmarks/Config/EvalConfigII.yml',
                 'FACVAE_II_50'        : './Benchmarks/Config/EvalConfigII.yml',
                 'TCMIDKZFC_II_50_800' : './Config/EvalConfigII800.yml',
                 'FACFC_II_50_800'     : './Config/EvalConfigII800.yml'}

#DicConfigYaml = {'TCMIDKZFC_ART_50_800_A' : './Config/EvalConfigART800.yml'}



GeneratedSignals = {}
GeneratedAmplitude = {}
InpSignals = {}
Zs = {}
CON_Aranges = {}

for ConfigYaml in DicConfigYaml.items():
    print(ConfigYaml[0])
    #ReconSignal, Amplitude, InpSignal, PredZs, CON_Arange = SigGen(ConfigYaml[0], ConfigYaml[1], SelIDX= 1100, N_Gen = np.sum(N_GenList), MinFreqR=0.0, MaxFreqR=0.05,  GenBP=GenBP, N_GenList=N_GenList)
    ReconSignal, Amplitude, InpSignal, PredZs, CON_Arange = SigGen(ConfigYaml[0], ConfigYaml[1], SelIDX= 1100, N_Gen = 500, MinFreqR=0.0, MaxFreqR=0.05,  GenBP=GenBP)
    GeneratedSignals[ConfigYaml[0]] = ReconSignal
    GeneratedAmplitude[ConfigYaml[0]] = Amplitude
    InpSignals[ConfigYaml[0]] = InpSignal
    Zs[ConfigYaml[0]] = PredZs
    CON_Aranges[ConfigYaml[0]] = CON_Arange
# Out:
# SKZFC_ART_50_800
# OrigRecLoss added
# FeatRecLoss added
# kl_Loss_SKZ selected
# kl_Loss_Z added
# kl_Loss_FC added
# Model: "model_240"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  Inp_Enc (InputLayer)           [(None, 1000)]       0           []
#
#  tf.signal.frame_351 (TFOpLambd  (None, 20, 50)      0           ['Inp_Enc[0][0]']
#  a)
#
#  bidirectional_1098 (Bidirectio  (None, 20, 50)      11550       ['tf.signal.frame_351[0][0]']
#  nal)
#
#  bidirectional_1099 (Bidirectio  (None, 20, 50)      11550       ['bidirectional_1098[0][0]']
#  nal)
#
#  bidirectional_1100 (Bidirectio  (None, 150)         57150       ['bidirectional_1099[0][0]']
#  nal)
#
#  dense_1983 (Dense)             (None, 100)          15100       ['bidirectional_1100[0][0]']
#
#  dense_1984 (Dense)             (None, 70)           7070        ['dense_1983[0][0]']
#
#  dense_1985 (Dense)             (None, 50)           3550        ['dense_1984[0][0]']
#
#  dense_1987 (Dense)             (None, 6)            306         ['dense_1985[0][0]']
#
#  dense_1988 (Dense)             (None, 6)            42          ['dense_1987[0][0]']
#
#  tf.clip_by_value_182 (TFOpLamb  (None, 6)           0           ['dense_1988[0][0]']
#  da)
#
#  FC_Mu (Lambda)                 (None, 6)            0           ['tf.clip_by_value_182[0][0]']
#
#  tf.compat.v1.shape_198 (TFOpLa  (2,)                0           ['FC_Mu[0][0]']
#  mbda)
#
#  tf.__operators__.getitem_3992   ()                  0           ['tf.compat.v1.shape_198[0][0]']
#  (SlicingOpLambda)
#
#  tf.random.uniform_42 (TFOpLamb  (None, 6)           0           ['tf.__operators__.getitem_3992[0
#  da)                                                             ][0]']
#
#  tf.clip_by_value_183 (TFOpLamb  (None, 6)           0           ['tf.random.uniform_42[0][0]']
#  da)
#
#  tf.math.subtract_1152 (TFOpLam  (None, 6)           0           ['tf.clip_by_value_183[0][0]']
#  bda)
#
#  tf.math.log_308 (TFOpLambda)   (None, 6)            0           ['tf.clip_by_value_183[0][0]']
#
#  tf.math.log_309 (TFOpLambda)   (None, 6)            0           ['tf.math.subtract_1152[0][0]']
#
#  tf.math.subtract_1154 (TFOpLam  (None, 6)           0           ['tf.math.log_308[0][0]',
#  bda)                                                             'tf.math.log_309[0][0]']
#
#  tf.math.log_310 (TFOpLambda)   (None, 6)            0           ['FC_Mu[0][0]']
#
#  tf.math.subtract_1153 (TFOpLam  (None, 6)           0           ['FC_Mu[0][0]']
#  bda)
#
#  tf.__operators__.add_731 (TFOp  (None, 6)           0           ['tf.math.subtract_1154[0][0]',
#  Lambda)                                                          'tf.math.log_310[0][0]']
#
#  tf.math.log_311 (TFOpLambda)   (None, 6)            0           ['tf.math.subtract_1153[0][0]']
#
#  tf.math.subtract_1155 (TFOpLam  (None, 6)           0           ['tf.__operators__.add_731[0][0]'
#  bda)                                                            , 'tf.math.log_311[0][0]']
#
#  Z_Mu (Dense)                   (None, 50)           2550        ['dense_1985[0][0]']
#
#  tf.math.sigmoid_42 (TFOpLambda  (None, 6)           0           ['tf.math.subtract_1155[0][0]']
#  )
#
#  dense_1986 (Dense)             (None, 50)           2550        ['dense_1985[0][0]']
#
#  tf.compat.v1.shape_197 (TFOpLa  (2,)                0           ['Z_Mu[0][0]']
#  mbda)
#
#  tf.math.multiply_2907 (TFOpLam  (None, 6)           0           ['tf.math.sigmoid_42[0][0]']
#  bda)
#
#  tf.math.multiply_2908 (TFOpLam  (None, 6)           0           ['FC_Mu[0][0]']
#  bda)
#
#  Z_Log_Sigma (Lambda)           (None, 50)           0           ['dense_1986[0][0]']
#
#  tf.__operators__.getitem_3991   ()                  0           ['tf.compat.v1.shape_197[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.add_732 (TFOp  (None, 6)           0           ['tf.math.multiply_2907[0][0]',
#  Lambda)                                                          'tf.math.multiply_2908[0][0]']
#
#  tf.math.multiply_2905 (TFOpLam  (None, 50)          0           ['Z_Log_Sigma[0][0]']
#  bda)
#
#  tf.random.normal_99 (TFOpLambd  (None, 50)          0           ['tf.__operators__.getitem_3991[0
#  a)                                                              ][0]']
#
#  tf.math.multiply_2909 (TFOpLam  (None, 6)           0           ['tf.__operators__.add_732[0][0]'
#  bda)                                                            ]
#
#  tf.math.exp_254 (TFOpLambda)   (None, 50)           0           ['tf.math.multiply_2905[0][0]']
#
#  tf.math.multiply_2904 (TFOpLam  (None, 50)          0           ['tf.random.normal_99[0][0]']
#  bda)
#
#  tf.clip_by_value_184 (TFOpLamb  (None, 6)           0           ['tf.math.multiply_2909[0][0]']
#  da)
#
#  tf.math.multiply_2906 (TFOpLam  (None, 50)          0           ['tf.math.exp_254[0][0]',
#  bda)                                                             'tf.math.multiply_2904[0][0]']
#
#  FCs (Lambda)                   (None, 6)            0           ['tf.clip_by_value_184[0][0]']
#
#  tf.__operators__.add_730 (TFOp  (None, 50)          0           ['Z_Mu[0][0]',
#  Lambda)                                                          'tf.math.multiply_2906[0][0]']
#
#  tf.__operators__.getitem_4009   (None, 2)           0           ['FCs[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_4010   (None, 4)           0           ['FCs[0][0]']
#  (SlicingOpLambda)
#
#  Zs (Lambda)                    (None, 50)           0           ['tf.__operators__.add_730[0][0]'
#                                                                  ]
#
#  SigOut (Flatten)               (None, 1000)         0           ['tf.signal.frame_351[0][0]']
#
#  FeatGenModel (Functional)      [(None, 800),        86100       ['tf.__operators__.getitem_4009[0
#                                  (None, 800),                    ][0]',
#                                  (None, 800),                     'tf.__operators__.getitem_4010[0
#                                  (None, 800)]                    ][0]',
#                                                                   'Zs[0][0]']
#
#  FeatExtModel (Functional)      [(None, 800),        0           ['SigOut[0][0]',
#                                  (None, 800),                     'FCs[0][0]']
#                                  (None, 800),
#                                  (None, 800)]
#
#  ReconModel (Functional)        (None, 1000)         191300      ['FeatExtModel[0][0]',
#                                                                   'FeatExtModel[0][1]',
#                                                                   'FeatExtModel[0][2]',
#                                                                   'FeatExtModel[0][3]',
#                                                                   'FeatGenModel[0][0]',
#                                                                   'FeatGenModel[0][1]',
#                                                                   'FeatGenModel[0][2]',
#                                                                   'FeatGenModel[0][3]']
#
#  tf.cast_423 (TFOpLambda)       (None, 1000)         0           ['Inp_Enc[0][0]']
#
#  tf.cast_422 (TFOpLambda)       (None, 1000)         0           ['ReconModel[0][0]']
#
#  tf.math.subtract_1156 (TFOpLam  (None, 1000)        0           ['tf.cast_423[0][0]',
#  bda)                                                             'tf.cast_422[0][0]']
#
#  tf.math.square_141 (TFOpLambda  (None, 1000)        0           ['tf.math.subtract_1156[0][0]']
#  )
#
#  Beta_Orig (Lossweight)         ()                   1           ['Inp_Enc[0][0]']
#
#  tf.math.reduce_mean_450 (TFOpL  ()                  0           ['tf.math.square_141[0][0]']
#  ambda)
#
#  tf.math.multiply_2946 (TFOpLam  ()                  0           ['Beta_Orig[0][0]',
#  bda)                                                             'tf.math.reduce_mean_450[0][0]']
#
#  add_loss_394 (AddLoss)         ()                   0           ['tf.math.multiply_2946[0][0]']
#
#  add_metric_394 (AddMetric)     ()                   0           ['tf.math.multiply_2946[0][0]']
#
#  tf.concat_328 (TFOpLambda)     (None, 3200)         0           ['FeatExtModel[0][0]',
#                                                                   'FeatExtModel[0][1]',
#                                                                   'FeatExtModel[0][2]',
#                                                                   'FeatExtModel[0][3]']
#
#  tf.concat_327 (TFOpLambda)     (None, 3200)         0           ['FeatGenModel[0][0]',
#                                                                   'FeatGenModel[0][1]',
#                                                                   'FeatGenModel[0][2]',
#                                                                   'FeatGenModel[0][3]']
#
#  tf.cast_425 (TFOpLambda)       (None, 3200)         0           ['tf.concat_328[0][0]']
#
#  tf.cast_424 (TFOpLambda)       (None, 3200)         0           ['tf.concat_327[0][0]']
#
#  tf.math.subtract_1157 (TFOpLam  (None, 3200)        0           ['tf.cast_425[0][0]',
#  bda)                                                             'tf.cast_424[0][0]']
#
#  tf.math.square_142 (TFOpLambda  (None, 3200)        0           ['tf.math.subtract_1157[0][0]']
#  )
#
#  Beta_Feat (Lossweight)         ()                   1           ['Inp_Enc[0][0]']
#
#  tf.math.reduce_mean_451 (TFOpL  ()                  0           ['tf.math.square_142[0][0]']
#  ambda)
#
#  tf.math.multiply_2947 (TFOpLam  ()                  0           ['Beta_Feat[0][0]',
#  bda)                                                             'tf.math.reduce_mean_451[0][0]']
#
#  add_loss_395 (AddLoss)         ()                   0           ['tf.math.multiply_2947[0][0]']
#
#  add_metric_395 (AddMetric)     ()                   0           ['tf.math.multiply_2947[0][0]']
#
#  tf.math.pow_71 (TFOpLambda)    (None, 50)           0           ['Z_Mu[0][0]']
#
#  tf.math.exp_257 (TFOpLambda)   (None, 50)           0           ['Z_Log_Sigma[0][0]']
#
#  tf.__operators__.add_743 (TFOp  (None, 50)          0           ['tf.math.pow_71[0][0]',
#  Lambda)                                                          'tf.math.exp_257[0][0]']
#
#  tf.math.subtract_1166 (TFOpLam  (None, 50)          0           ['tf.__operators__.add_743[0][0]'
#  bda)                                                            , 'Z_Log_Sigma[0][0]']
#
#  tf.math.subtract_1167 (TFOpLam  (None, 50)          0           ['tf.math.subtract_1166[0][0]']
#  bda)
#
#  tf.math.reduce_sum_800 (TFOpLa  (None,)             0           ['tf.math.subtract_1167[0][0]']
#  mbda)
#
#  tf.math.multiply_2956 (TFOpLam  (None,)             0           ['tf.math.reduce_sum_800[0][0]']
#  bda)
#
#  tf.math.reduce_mean_455 (TFOpL  ()                  0           ['tf.math.multiply_2956[0][0]']
#  ambda)
#
#  tf.math.subtract_1168 (TFOpLam  ()                  0           ['tf.math.reduce_mean_455[0][0]']
#  bda)
#
#  Beta_Z (Lossweight)            ()                   1           ['Inp_Enc[0][0]']
#
#  tf.math.abs_253 (TFOpLambda)   ()                   0           ['tf.math.subtract_1168[0][0]']
#
#  tf.math.multiply_2957 (TFOpLam  ()                  0           ['Beta_Z[0][0]',
#  bda)                                                             'tf.math.abs_253[0][0]']
#
#  add_loss_396 (AddLoss)         ()                   0           ['tf.math.multiply_2957[0][0]']
#
#  add_metric_396 (AddMetric)     ()                   0           ['tf.math.multiply_2957[0][0]']
#
#  tf.cast_426 (TFOpLambda)       (None, 6)            0           ['FC_Mu[0][0]']
#
#  tf.math.subtract_1164 (TFOpLam  (None, 6)           0           ['tf.cast_426[0][0]']
#  bda)
#
#  tf.math.log_312 (TFOpLambda)   (None, 6)            0           ['tf.cast_426[0][0]']
#
#  tf.math.log_313 (TFOpLambda)   (None, 6)            0           ['tf.math.subtract_1164[0][0]']
#
#  tf.math.subtract_1162 (TFOpLam  (None, 6)           0           ['tf.math.log_312[0][0]']
#  bda)
#
#  tf.math.subtract_1163 (TFOpLam  (None, 6)           0           ['tf.cast_426[0][0]']
#  bda)
#
#  tf.math.subtract_1165 (TFOpLam  (None, 6)           0           ['tf.math.log_313[0][0]']
#  bda)
#
#  tf.math.multiply_2954 (TFOpLam  (None, 6)           0           ['tf.cast_426[0][0]',
#  bda)                                                             'tf.math.subtract_1162[0][0]']
#
#  tf.math.multiply_2955 (TFOpLam  (None, 6)           0           ['tf.math.subtract_1163[0][0]',
#  bda)                                                             'tf.math.subtract_1165[0][0]']
#
#  tf.__operators__.add_742 (TFOp  (None, 6)           0           ['tf.math.multiply_2954[0][0]',
#  Lambda)                                                          'tf.math.multiply_2955[0][0]']
#
#  tf.math.reduce_mean_454 (TFOpL  ()                  0           ['tf.__operators__.add_742[0][0]'
#  ambda)                                                          ]
#
#  tf.math.subtract_1169 (TFOpLam  ()                  0           ['tf.math.reduce_mean_454[0][0]']
#  bda)
#
#  Beta_Fc (Lossweight)           ()                   1           ['Inp_Enc[0][0]']
#
#  tf.math.abs_254 (TFOpLambda)   ()                   0           ['tf.math.subtract_1169[0][0]']
#
#  tf.math.multiply_2958 (TFOpLam  ()                  0           ['Beta_Fc[0][0]',
#  bda)                                                             'tf.math.abs_254[0][0]']
#
#  add_loss_397 (AddLoss)         ()                   0           ['tf.math.multiply_2958[0][0]']
#
#  add_metric_397 (AddMetric)     ()                   0           ['tf.math.multiply_2958[0][0]']
#
# ==================================================================================================
# Total params: 388,822
# Trainable params: 388,818
# Non-trainable params: 4
# __________________________________________________________________________________________________
# Model weights loaded
# 16/16 [==============================] - 1s 13ms/step
# 16/16 [==============================] - 2s 17ms/step
# ConVAE_ART_50
# Model: "model_243"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  Inp_Enc (InputLayer)           [(None, 1000)]       0           []
#
#  tf.signal.frame_358 (TFOpLambd  (None, 20, 50)      0           ['Inp_Enc[0][0]']
#  a)
#
#  bidirectional_1116 (Bidirectio  (None, 20, 50)      11550       ['tf.signal.frame_358[0][0]']
#  nal)
#
#  bidirectional_1117 (Bidirectio  (None, 20, 50)      11550       ['bidirectional_1116[0][0]']
#  nal)
#
#  bidirectional_1118 (Bidirectio  (None, 150)         57150       ['bidirectional_1117[0][0]']
#  nal)
#
#  Inp_Cond (InputLayer)          [(None, 50)]         0           []
#
#  concatenate_30 (Concatenate)   (None, 200)          0           ['bidirectional_1118[0][0]',
#                                                                   'Inp_Cond[0][0]']
#
#  dense_2014 (Dense)             (None, 100)          20100       ['concatenate_30[0][0]']
#
#  dense_2015 (Dense)             (None, 70)           7070        ['dense_2014[0][0]']
#
#  dense_2016 (Dense)             (None, 50)           3550        ['dense_2015[0][0]']
#
#  Z_Mu (Dense)                   (None, 50)           2550        ['dense_2016[0][0]']
#
#  dense_2017 (Dense)             (None, 50)           2550        ['dense_2016[0][0]']
#
#  tf.compat.v1.shape_199 (TFOpLa  (2,)                0           ['Z_Mu[0][0]']
#  mbda)
#
#  Z_Log_Sigma (Lambda)           (None, 50)           0           ['dense_2017[0][0]']
#
#  tf.__operators__.getitem_4014   ()                  0           ['tf.compat.v1.shape_199[0][0]']
#  (SlicingOpLambda)
#
#  tf.math.multiply_2960 (TFOpLam  (None, 50)          0           ['Z_Log_Sigma[0][0]']
#  bda)
#
#  tf.random.normal_100 (TFOpLamb  (None, 50)          0           ['tf.__operators__.getitem_4014[0
#  da)                                                             ][0]']
#
#  tf.math.exp_258 (TFOpLambda)   (None, 50)           0           ['tf.math.multiply_2960[0][0]']
#
#  tf.math.multiply_2959 (TFOpLam  (None, 50)          0           ['tf.random.normal_100[0][0]']
#  bda)
#
#  tf.math.multiply_2961 (TFOpLam  (None, 50)          0           ['tf.math.exp_258[0][0]',
#  bda)                                                             'tf.math.multiply_2959[0][0]']
#
#  tf.__operators__.add_744 (TFOp  (None, 50)          0           ['Z_Mu[0][0]',
#  Lambda)                                                          'tf.math.multiply_2961[0][0]']
#
#  Zs (Lambda)                    (None, 50)           0           ['tf.__operators__.add_744[0][0]'
#                                                                  ]
#
#  ReconModel (Functional)        (None, 1000)         54925       ['Zs[0][0]',
#                                                                   'Inp_Cond[0][0]']
#
#  tf.cast_428 (TFOpLambda)       (None, 1000)         0           ['Inp_Enc[0][0]']
#
#  tf.cast_427 (TFOpLambda)       (None, 1000)         0           ['ReconModel[0][0]']
#
#  tf.math.subtract_1170 (TFOpLam  (None, 1000)        0           ['tf.cast_428[0][0]',
#  bda)                                                             'tf.cast_427[0][0]']
#
#  tf.math.square_143 (TFOpLambda  (None, 1000)        0           ['tf.math.subtract_1170[0][0]']
#  )
#
#  Beta_Rec (Lossweight)          ()                   1           ['ReconModel[0][0]']
#
#  tf.math.reduce_mean_456 (TFOpL  ()                  0           ['tf.math.square_143[0][0]']
#  ambda)
#
#  tf.math.multiply_2962 (TFOpLam  ()                  0           ['Beta_Rec[0][0]',
#  bda)                                                             'tf.math.reduce_mean_456[0][0]']
#
#  add_loss_398 (AddLoss)         ()                   0           ['tf.math.multiply_2962[0][0]']
#
#  add_metric_398 (AddMetric)     ()                   0           ['tf.math.multiply_2962[0][0]']
#
#  tf.math.pow_72 (TFOpLambda)    (None, 50)           0           ['Z_Mu[0][0]']
#
#  tf.math.exp_259 (TFOpLambda)   (None, 50)           0           ['Z_Log_Sigma[0][0]']
#
#  tf.__operators__.add_745 (TFOp  (None, 50)          0           ['tf.math.pow_72[0][0]',
#  Lambda)                                                          'tf.math.exp_259[0][0]']
#
#  tf.math.subtract_1171 (TFOpLam  (None, 50)          0           ['tf.__operators__.add_745[0][0]'
#  bda)                                                            , 'Z_Log_Sigma[0][0]']
#
#  tf.math.subtract_1172 (TFOpLam  (None, 50)          0           ['tf.math.subtract_1171[0][0]']
#  bda)
#
#  tf.math.reduce_sum_801 (TFOpLa  (None,)             0           ['tf.math.subtract_1172[0][0]']
#  mbda)
#
#  tf.math.multiply_2963 (TFOpLam  (None,)             0           ['tf.math.reduce_sum_801[0][0]']
#  bda)
#
#  tf.math.reduce_mean_457 (TFOpL  ()                  0           ['tf.math.multiply_2963[0][0]']
#  ambda)
#
#  tf.math.subtract_1173 (TFOpLam  ()                  0           ['tf.math.reduce_mean_457[0][0]']
#  bda)
#
#  Beta_Z (Lossweight)            ()                   1           ['ReconModel[0][0]']
#
#  tf.math.abs_255 (TFOpLambda)   ()                   0           ['tf.math.subtract_1173[0][0]']
#
#  tf.math.multiply_2964 (TFOpLam  ()                  0           ['Beta_Z[0][0]',
#  bda)                                                             'tf.math.abs_255[0][0]']
#
#  add_loss_399 (AddLoss)         ()                   0           ['tf.math.multiply_2964[0][0]']
#
#  add_metric_399 (AddMetric)     ()                   0           ['tf.math.multiply_2964[0][0]']
#
# ==================================================================================================
# Total params: 170,997
# Trainable params: 170,995
# Non-trainable params: 2
# __________________________________________________________________________________________________
# Model weights loaded
# 16/16 [==============================] - 1s 12ms/step
# 16/16 [==============================] - 1s 6ms/step
# BaseVAE_ART_50
# ReconOutLoss added
# Model: "model_245"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  Inp_Enc (InputLayer)           [(None, 1000)]       0           []
#
#  tf.signal.frame_359 (TFOpLambd  (None, 20, 50)      0           ['Inp_Enc[0][0]']
#  a)
#
#  bidirectional_1122 (Bidirectio  (None, 20, 50)      11550       ['tf.signal.frame_359[0][0]']
#  nal)
#
#  bidirectional_1123 (Bidirectio  (None, 20, 50)      11550       ['bidirectional_1122[0][0]']
#  nal)
#
#  bidirectional_1124 (Bidirectio  (None, 150)         57150       ['bidirectional_1123[0][0]']
#  nal)
#
#  dense_2023 (Dense)             (None, 100)          15100       ['bidirectional_1124[0][0]']
#
#  dense_2024 (Dense)             (None, 70)           7070        ['dense_2023[0][0]']
#
#  dense_2025 (Dense)             (None, 50)           3550        ['dense_2024[0][0]']
#
#  Z_Mu (Dense)                   (None, 50)           2550        ['dense_2025[0][0]']
#
#  dense_2026 (Dense)             (None, 50)           2550        ['dense_2025[0][0]']
#
#  tf.compat.v1.shape_200 (TFOpLa  (2,)                0           ['Z_Mu[0][0]']
#  mbda)
#
#  Z_Log_Sigma (Lambda)           (None, 50)           0           ['dense_2026[0][0]']
#
#  tf.__operators__.getitem_4015   ()                  0           ['tf.compat.v1.shape_200[0][0]']
#  (SlicingOpLambda)
#
#  tf.math.multiply_2966 (TFOpLam  (None, 50)          0           ['Z_Log_Sigma[0][0]']
#  bda)
#
#  tf.random.normal_101 (TFOpLamb  (None, 50)          0           ['tf.__operators__.getitem_4015[0
#  da)                                                             ][0]']
#
#  tf.math.exp_260 (TFOpLambda)   (None, 50)           0           ['tf.math.multiply_2966[0][0]']
#
#  tf.math.multiply_2965 (TFOpLam  (None, 50)          0           ['tf.random.normal_101[0][0]']
#  bda)
#
#  tf.math.multiply_2967 (TFOpLam  (None, 50)          0           ['tf.math.exp_260[0][0]',
#  bda)                                                             'tf.math.multiply_2965[0][0]']
#
#  tf.__operators__.add_746 (TFOp  (None, 50)          0           ['Z_Mu[0][0]',
#  Lambda)                                                          'tf.math.multiply_2967[0][0]']
#
#  Zs (Lambda)                    (None, 50)           0           ['tf.__operators__.add_746[0][0]'
#                                                                  ]
#
#  ReconModel (Functional)        (None, 1000)         52425       ['Zs[0][0]']
#
#  tf.cast_430 (TFOpLambda)       (None, 1000)         0           ['Inp_Enc[0][0]']
#
#  tf.cast_429 (TFOpLambda)       (None, 1000)         0           ['ReconModel[0][0]']
#
#  tf.math.subtract_1174 (TFOpLam  (None, 1000)        0           ['tf.cast_430[0][0]',
#  bda)                                                             'tf.cast_429[0][0]']
#
#  tf.math.square_144 (TFOpLambda  (None, 1000)        0           ['tf.math.subtract_1174[0][0]']
#  )
#
#  Beta_Rec (Lossweight)          ()                   1           ['Inp_Enc[0][0]']
#
#  tf.math.reduce_mean_458 (TFOpL  ()                  0           ['tf.math.square_144[0][0]']
#  ambda)
#
# ...
#                                                                   'tf.compat.v1.nn.embedding_looku
#                                                                  p_1934[0][0]',
#                                                                   'tf.compat.v1.nn.embedding_looku
#                                                                  p_1935[0][0]',
#                                                                   'tf.compat.v1.nn.embedding_looku
#                                                                  p_1936[0][0]',
#                                                                   'tf.compat.v1.nn.embedding_looku
#                                                                  p_1937[0][0]',
#                                                                   'tf.compat.v1.nn.embedding_looku
#                                                                  p_1938[0][0]',
#                                                                   'tf.compat.v1.nn.embedding_looku
#                                                                  p_1939[0][0]',
#                                                                   'tf.compat.v1.nn.embedding_looku
#                                                                  p_1940[0][0]',
#                                                                   'tf.compat.v1.nn.embedding_looku
#                                                                  p_1941[0][0]',
#                                                                   'tf.compat.v1.nn.embedding_looku
#                                                                  p_1942[0][0]',
#                                                                   'tf.compat.v1.nn.embedding_looku
#                                                                  p_1943[0][0]',
#                                                                   'tf.compat.v1.nn.embedding_looku
#                                                                  p_1944[0][0]',
#                                                                   'tf.compat.v1.nn.embedding_looku
#                                                                  p_1945[0][0]',
#                                                                   'tf.compat.v1.nn.embedding_looku
#                                                                  p_1946[0][0]',
#                                                                   'tf.compat.v1.nn.embedding_looku
#                                                                  p_1947[0][0]',
#                                                                   'tf.compat.v1.nn.embedding_looku
#                                                                  p_1948[0][0]',
#                                                                   'tf.compat.v1.nn.embedding_looku
#                                                                  p_1949[0][0]']
#
#  tf.stop_gradient_31 (TFOpLambd  (None, 50)          0           ['tf.concat_367[0][0]']
#  a)
#
#  tf.zeros_like_31 (TFOpLambda)  (None,)              0           ['tf.range_1613[0][0]']
#
#  tf.cast_479 (TFOpLambda)       (None, 2)            0           ['FacDiscModel[0][0]']
#
#  tf.ones_like_31 (TFOpLambda)   (None,)              0           ['tf.range_1612[0][0]']
#
#  tf.cast_481 (TFOpLambda)       (None, 2)            0           ['FacDiscModel[1][0]']
#
#  tf.__operators__.getitem_4560   (None, 1)           0           ['tf.zeros_like_31[0][0]']
#  (SlicingOpLambda)
#
#  tf.clip_by_value_206 (TFOpLamb  (None, 2)           0           ['tf.cast_479[0][0]']
#  da)
#
#  tf.__operators__.getitem_4559   (None, 1)           0           ['tf.ones_like_31[0][0]']
#  (SlicingOpLambda)
#
#  tf.clip_by_value_207 (TFOpLamb  (None, 2)           0           ['tf.cast_481[0][0]']
#  da)
#
#  tf.cast_478 (TFOpLambda)       (None, 1)            0           ['tf.__operators__.getitem_4560[0
#                                                                  ][0]']
#
#  tf.math.log_348 (TFOpLambda)   (None, 2)            0           ['tf.clip_by_value_206[0][0]']
#
#  tf.cast_480 (TFOpLambda)       (None, 1)            0           ['tf.__operators__.getitem_4559[0
#                                                                  ][0]']
#
#  tf.math.log_349 (TFOpLambda)   (None, 2)            0           ['tf.clip_by_value_207[0][0]']
#
#  tf.math.multiply_3311 (TFOpLam  (None, 2)           0           ['tf.cast_478[0][0]',
#  bda)                                                             'tf.math.log_348[0][0]']
#
#  tf.math.multiply_3312 (TFOpLam  (None, 2)           0           ['tf.cast_480[0][0]',
#  bda)                                                             'tf.math.log_349[0][0]']
#
#  tf.math.reduce_sum_895 (TFOpLa  (None,)             0           ['tf.math.multiply_3311[0][0]']
#  mbda)
#
#  tf.math.reduce_sum_896 (TFOpLa  (None,)             0           ['tf.math.multiply_3312[0][0]']
#  mbda)
#
#  tf.math.reduce_mean_511 (TFOpL  ()                  0           ['tf.math.reduce_sum_895[0][0]']
#  ambda)
#
#  tf.math.reduce_mean_512 (TFOpL  ()                  0           ['tf.math.reduce_sum_896[0][0]']
#  ambda)
#
#  tf.math.negative_302 (TFOpLamb  ()                  0           ['tf.math.reduce_mean_511[0][0]']
#  da)
#
#  tf.math.negative_303 (TFOpLamb  ()                  0           ['tf.math.reduce_mean_512[0][0]']
#  da)
#
#  tf.__operators__.add_832 (TFOp  ()                  0           ['tf.math.negative_302[0][0]',
#  Lambda)                                                          'tf.math.negative_303[0][0]']
#
#  tf.math.multiply_3313 (TFOpLam  ()                  0           ['tf.__operators__.add_832[0][0]'
#  bda)                                                            ]
#
#  tf.math.subtract_1310 (TFOpLam  ()                  0           ['tf.math.multiply_3313[0][0]']
#  bda)
#
#  Beta_DTC (Lossweight)          ()                   1           ['Inp_Enc[0][0]']
#
#  tf.math.abs_287 (TFOpLambda)   ()                   0           ['tf.math.subtract_1310[0][0]']
#
#  tf.math.multiply_3314 (TFOpLam  ()                  0           ['Beta_DTC[0][0]',
#  bda)                                                             'tf.math.abs_287[0][0]']
#
#  add_loss_448 (AddLoss)         ()                   0           ['tf.math.multiply_3314[0][0]']
#
#  add_metric_448 (AddMetric)     ()                   0           ['tf.math.multiply_3314[0][0]']
#
#  tf.compat.v1.nn.embedding_look  (None, 6)           0           ['FC_Mu[0][0]',
#  up_1950 (TFOpLambda)                                             'tf.range_1612[0][0]']
#
#  tf.math.subtract_1313 (TFOpLam  (None, 6)           0           ['tf.compat.v1.nn.embedding_looku
#  bda)                                                            p_1950[0][0]']
#
#  tf.math.log_350 (TFOpLambda)   (None, 6)            0           ['tf.compat.v1.nn.embedding_looku
#                                                                  p_1950[0][0]']
#
#  tf.math.log_351 (TFOpLambda)   (None, 6)            0           ['tf.math.subtract_1313[0][0]']
#
#  tf.math.subtract_1311 (TFOpLam  (None, 6)           0           ['tf.math.log_350[0][0]']
#  bda)
#
#  tf.math.subtract_1312 (TFOpLam  (None, 6)           0           ['tf.compat.v1.nn.embedding_looku
#  bda)                                                            p_1950[0][0]']
#
#  tf.math.subtract_1314 (TFOpLam  (None, 6)           0           ['tf.math.log_351[0][0]']
#  bda)
#
#  tf.math.multiply_3315 (TFOpLam  (None, 6)           0           ['tf.compat.v1.nn.embedding_looku
#  bda)                                                            p_1950[0][0]',
#                                                                   'tf.math.subtract_1311[0][0]']
#
#  tf.math.multiply_3316 (TFOpLam  (None, 6)           0           ['tf.math.subtract_1312[0][0]',
#  bda)                                                             'tf.math.subtract_1314[0][0]']
#
#  tf.__operators__.add_833 (TFOp  (None, 6)           0           ['tf.math.multiply_3315[0][0]',
#  Lambda)                                                          'tf.math.multiply_3316[0][0]']
#
#  tf.math.reduce_mean_513 (TFOpL  ()                  0           ['tf.__operators__.add_833[0][0]'
#  ambda)                                                          ]
#
#  tf.math.subtract_1315 (TFOpLam  ()                  0           ['tf.math.reduce_mean_513[0][0]']
#  bda)
#
#  Beta_Fc (Lossweight)           ()                   1           ['Inp_Enc[0][0]']
#
#  tf.math.abs_288 (TFOpLambda)   ()                   0           ['tf.math.subtract_1315[0][0]']
#
#  tf.math.multiply_3317 (TFOpLam  ()                  0           ['Beta_Fc[0][0]',
#  bda)                                                             'tf.math.abs_288[0][0]']
#
#  add_loss_449 (AddLoss)         ()                   0           ['tf.math.multiply_3317[0][0]']
#
#  add_metric_449 (AddMetric)     ()                   0           ['tf.math.multiply_3317[0][0]']
#
# ==================================================================================================
# Total params: 401,676
# Trainable params: 401,670
# Non-trainable params: 6
# __________________________________________________________________________________________________
# Model weights loaded
# 16/16 [==============================] - 1s 15ms/step
# 16/16 [==============================] - 2s 10ms/step

# %%
from matplotlib.gridspec import GridSpec
from mpl_toolkits.axes_grid1 import make_axes_locatable
from matplotlib.ticker import FuncFormatter

MinFreq=1
MaxFreq=50
MinFreqR = 0
MaxFreqR = 1.

# Define the keys for the data you want to plot.
keys = ['BaseVAE_ART_50', 'TCVAE_ART_50', 'FACVAE_ART_50', 'ConVAE_ART_50', 'SKZFC_ART_50_800', 'TCMIDKZFC_ART_50_800', 'FACFC_ART_50_800',  
         'BaseVAE_II_50', 'TCVAE_II_50',  'FACVAE_II_50',  'ConVAE_II_50',  'SKZFC_II_50_800',  'TCMIDKZFC_II_50_800',  'FACFC_II_50_800']

# Set up colormap and normalization.
cmap = plt.get_cmap('viridis')
norm = plt.Normalize(0, N_Gen-1)


# Create a figure with GridSpec layout for a 3x2 grid of line plots and heatmaps.
fig = plt.figure(figsize=(22, 16))
gs = GridSpec(7, 4, figure=fig, width_ratios=[5, 1, 5, 1], hspace=0.5, wspace=0.16)  # Allocate space for color bars

row_idx = -1
col_idx_line = 0
col_idx_heat = 1

# Iterate over the keys and create the corresponding subplots for line plots and heatmaps.
for idx, key in enumerate(keys):
    # Calculate row index for the current subplot.
    row_idx += 1
    col_idx_heat = col_idx_line+1

    if 'SKZFC' in key or 'FACFC' in key or 'TCMIDKZFC' in key or 'SKZ' in key:
        norm2 = plt.Normalize(MinFreqR, MaxFreqR)
        cbarLabel = '$\\acute{\\theta}$ for generation'
    elif 'BaseVAE'in key or 'TCVAE' in key or 'FACVAE' in key:
        MeanZs = np.mean(Zs[key], axis=1)
        norm2 = plt.Normalize(min(MeanZs), max(MeanZs))
        cbarLabel = 'Mean of z for generation'
    elif 'ConVAE'in key:
        FreqIDX = np.argmax(CON_Aranges[key], axis=-1)
        norm2 = plt.Normalize(np.min(FreqIDX), np.max(FreqIDX))
        cbarLabel = '$\\acute{\\theta}$ for generation'
    
    # Create the axis for the line plot.
    ax1 = fig.add_subplot(gs[row_idx, col_idx_line])
    for i in range(0, N_Gen):
        color = cmap(norm(i))
        ax1.plot(GeneratedSignals[key][i], color=color)
    ax1.plot(InpSignals[key][0], color='red', label='Input Signal',linewidth=1)
    
    
    if 'ART' in key:
        SigType = 'ABP'
    elif 'II' in key:
        SigType = 'ECG'
    
    if 'BaseVAE' in key:
        Label = '$B$-VAE'
    elif 'SKZFC' in key:
        Label = 'SKZFC'
    elif 'ConVAE' in key:
        Label = '$C$-VAE'
    elif 'TCVAE' in key:
        Label = '$TC$-VAE'
    elif 'FACVAE' in key:
        Label = '$FAC$-VAE'
    elif 'TCMIDKZFC' in key:
        Label = 'TCMIDKZFC'
    elif 'FACFC' in key:
        Label = 'FACFC'
     
    
    ax1.set_title('A synthesis sample of '+ SigType+' based on ' + Label, fontsize=18)
    
    ax1.set_xticklabels([])  # Hide x-axis tick labels
    ax1.set_yticklabels([])  # Hide y-axis tick labels
    
    # Create an axis for the color bar on the right side of the line plot.
    divider1 = make_axes_locatable(ax1)
    cax1 = divider1.append_axes("right", size="5%", pad=0.02)
    sm1 = plt.cm.ScalarMappable(cmap=cmap, norm=norm2)
    sm1.set_array([])
    cbar1=fig.colorbar(sm1, cax=cax1)
    cbar1.ax.tick_params(labelsize=12)
    #cbar1.set_label(cbarLabel, size=12)

    # Create the axis for the heatmap next to each line plot.
    ax2 = fig.add_subplot(gs[row_idx, col_idx_heat])
    Heatmap = GeneratedAmplitude[key][:, MinFreq:MaxFreq]
    im = ax2.imshow(Heatmap, cmap='viridis', aspect='auto', interpolation='nearest')
    ax2.set_title('PSD degree', fontsize=15)
    ax2.set_xticks([])
    ax2.set_yticks([])
    ax2.set_xlabel('Frequency', fontsize=14)
    ax2.set_ylabel('Synthesis', fontsize=14) #'Index of signals generated with a series of $\\acute{\\theta}$'
    
    
    # Create an axis for the color bar on the right side of the heatmap.
    '''
    divider2 = make_axes_locatable(ax2)
    cax2 = divider2.append_axes("right", size="20%", pad=0.02)
    sm2 = plt.cm.ScalarMappable(cmap=cmap, norm=norm2)
    sm2.set_array([])
    cbar2 =fig.colorbar(im, cax=cax2)
    cbar2.ax.tick_params(labelsize=12)
    cbar2.formatter = FuncFormatter(lambda x, _: f'{x:.3f}')
    '''
    
    if row_idx == 6:
        row_idx = -1
        col_idx_line = 2
    #print(row_idx, col_idx_line)


    pos1 = ax1.get_position()  # get the original position
    pos2 = ax2.get_position()  # get the original position
    ax1.set_position([pos1.x0, pos1.y0, pos1.width, pos1.height])
    ax2.set_position([pos1.x0 + pos1.width + 0.035, pos2.y0, pos2.width, pos2.height])  # Adjust the x position

plt.savefig('./EvalResults/Figures/Synthesis_Samples.png', bbox_inches='tight')
#plt.tight_layout()
#plt.savefig('./EvalResults/Figures/Synthesis_Samples.png')
plt.show()
