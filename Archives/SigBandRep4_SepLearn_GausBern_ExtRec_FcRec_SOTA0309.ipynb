# %%
import os
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.keras import backend as K
from tensorflow.keras.layers import Input, GRU, Dense, Masking, Reshape, Flatten, RepeatVector, TimeDistributed, Bidirectional, Activation, GaussianNoise, Lambda, LSTM
from tensorflow.keras import Model
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from Models.FeatExtModels_NoKaiser import *

os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="0"

TrRate = 0.8

# %% [markdown]
# ### Data

# %%
DATA = np.load('./Data/AsanTRSet.npy')

np.random.seed(7)
PermutedDATA = np.random.permutation(DATA)
TrLen = int(PermutedDATA.shape[0] * TrRate)

TrData = PermutedDATA[:TrLen]
ValData = PermutedDATA[TrLen:]

# %% [markdown]
# #### Env setting

# %%
save_path = './Results/'
if not os.path.exists(save_path):
    os.mkdir(save_path)
    
### Model checkpoint
ModelSaveSameName = save_path+'SigBandRepModel_ExtRec.hdf5'
ModelSave = ModelCheckpoint(filepath=ModelSaveSameName, monitor='val_mse', verbose=1, save_best_only=True )

### Model Early stop
EarlyStop = EarlyStopping(monitor='val_loss', patience=500)

LatDim = 3
SigDim = DATA.shape[1]
MaskingRate = 0.02
NoiseStd = 0.002
MaskStd = 0.1
ReparaStd = 0.1

# %%
'''
class RelLossWeight(tf.keras.callbacks.Callback):
    def __init__(self, LossName1, LossName2, BetaName1, BetaName2, verbose=1):
                
        self.LossName1 = LossName1
        self.LossName2 = LossName2
        self.BetaName1 = BetaName1
        self.BetaName2 = BetaName2
        self.verbose = verbose

    def on_epoch_end(self, epoch, logs={}):
        
        Loss1 = logs[self.LossName1] 
        Loss2 = logs[self.LossName2] 
        
        Beta1_idx = [num for num, i in enumerate(self.model.variables) if self.BetaName1 in i.name][0]
        Beta2_idx = [num for num, i in enumerate(self.model.variables) if self.BetaName2 in i.name][0]
        
        self.model.variables[Beta1_idx].assign(Loss1/Loss2)
        self.model.variables[Beta2_idx].assign(Loss2/Loss1)   

        if self.verbose==1:
            print(self.BetaName1+' : ', self.model.variables[Beta1_idx])
            print(self.BetaName2+' : ', self.model.variables[Beta2_idx])        
 

# Define the KL annealing callback function
class KLCallback(tf.keras.callbacks.Callback):
    def __init__(self, TargetLossName, Threshold, MaxBeta, BetaName, AnnealEpoch=100):
        self.TargetLossName = TargetLossName
        self.Threshold = Threshold
        self.BetaName = BetaName
        self.MaxBeta = MaxBeta
        self.AnnealStart = 0
        self.AnnealEpoch = AnnealEpoch

    def on_epoch_end(self, epoch, logs={}):
        
        TargetLoss = logs['val_'+self.TargetLossName]
        
        if TargetLoss > self.Threshold:
            
            self.AnnealStart = 0
            K.set_value(self.model.get_layer(self.BetaName).variables[0], 0.)
        else: 
            self.AnnealStart += 1
            Beta = (self.AnnealStart) / self.AnnealEpoch * self.MaxBeta
            K.set_value(self.model.get_layer(self.BetaName).variables[0], Beta)
        
        print(self.model.get_layer(self.BetaName).variables[0])
'''

'''
class KLAnneal(tf.keras.callbacks.Callback):
    def __init__(self, TargetLossName, Threshold,  BetaName, MaxBeta=0.1, MinBeta=1e-5, AnnealEpoch=100, UnderLimit=0., verbose=1):
        
        if type(TargetLossName) != list:
            TargetLossName = [TargetLossName]
        
        self.TargetLossName = TargetLossName
        self.Threshold = Threshold
        self.BetaName = BetaName
        self.AnnealIdx = 0
        self.verbose = verbose 
        self.Beta =  np.concatenate([np.array([UnderLimit]), np.linspace(start=MinBeta, stop=MaxBeta, num=AnnealEpoch )])

    def on_epoch_end(self, epoch, logs={}):
        
        TargetLoss = max([logs[i] for i in self.TargetLossName]) 
        
        if TargetLoss > self.Threshold:
            
            #self.AnnealIdx -= 1
            #self.AnnealIdx = np.maximum(self.AnnealIdx, 0)
            K.set_value(self.model.get_layer(self.BetaName).variables[0], self.Beta[self.AnnealIdx])
        else: 
            self.AnnealIdx += 1
            self.AnnealIdx = np.minimum(self.AnnealIdx, len(self.Beta)-1)
            K.set_value(self.model.get_layer(self.BetaName).variables[0], self.Beta[self.AnnealIdx])
        
        if self.verbose==1:
            print(self.BetaName+' : ' ,self.model.get_layer(self.BetaName).variables[0].numpy())
        elif self.verbose==2:
            print('TargetLoss : ', TargetLoss)
            print(self.BetaName+' : ' ,self.model.get_layer(self.BetaName).variables[0].numpy())
'''

'''
class RelLossWeight(tf.keras.callbacks.Callback):
    def __init__(self, LossName1, LossName2, Beta1, Beta2, WeightB1 =1., WeightB2 =1., BetaName1 ='Beta1' , BetaName2 ='Beta2' , verbose=1):
                
        self.LossName1 = LossName1
        self.LossName2 = LossName2
        self.Beta1 = Beta1
        self.Beta2 = Beta2
        self.BetaName1 = BetaName1
        self.BetaName2 = BetaName2
        self.verbose = verbose
        self.WeightB1 = WeightB1
        self.WeightB2 = WeightB2

    def on_epoch_end(self, epoch, logs={}):
        
        Loss1 = logs[self.LossName1] 
        Loss2 = logs[self.LossName2] 
        
        Beta1 = tf.maximum(Loss1/Loss2, 1.) * self.WeightB1
        Beta2 = tf.maximum(Loss2/Loss1, 1.) * self.WeightB2
        
        self.Beta1.assign(Beta1)
        self.Beta2.assign(Beta2)   

        if self.verbose==1:
            print(self.BetaName1+' : ', self.Beta1.numpy())
            print(self.BetaName2+' : ', self.Beta2.numpy())   
'''

# %%
'''
class KLAnneal(tf.keras.callbacks.Callback):
    def __init__(self, TargetLossName, Threshold,  Beta, BetaName ='Beta', MaxBeta=0.1, MinBeta=1e-5, AnnealEpoch=100, UnderLimit=0., verbose=1):
        
        if type(TargetLossName) != list:
            TargetLossName = [TargetLossName]
        
        self.TargetLossName = TargetLossName
        self.Threshold = Threshold
        self.Beta = Beta
        self.BetaName = BetaName
        self.AnnealIdx = 0
        self.verbose = verbose 
        self.BetaValue =  np.concatenate([np.array([UnderLimit]), np.linspace(start=MinBeta, stop=MaxBeta, num=AnnealEpoch )])

    def on_epoch_end(self, epoch, logs={}):
        
        TargetLoss = max([logs[i] for i in self.TargetLossName]) 
        
        if TargetLoss > self.Threshold:
            
            #self.AnnealIdx -= 1
            #self.AnnealIdx = np.maximum(self.AnnealIdx, 0)
            self.Beta.assign(self.BetaValue[self.AnnealIdx])
        else: 
            self.AnnealIdx += 1
            self.AnnealIdx = np.minimum(self.AnnealIdx, len(self.BetaValue)-1)
            self.Beta.assign(self.BetaValue[self.AnnealIdx])
        
        if self.verbose==1:
            print(self.BetaName+' : ' ,self.Beta.numpy())
        elif self.verbose==2:
            print('TargetLoss : ', TargetLoss)
            print(self.BetaName+' : ' ,self.Beta.numpy())
            
            
       
class RelLossWeight(tf.keras.callbacks.Callback):
    def __init__(self, BetaList, BetaWeight, MinLimit , MaxLimit , verbose=1):
                
        self.BetaList = BetaList
        self.BetaWeight = BetaWeight
        self.MinLimit = MinLimit
        self.MaxLimit = MaxLimit
        self.verbose = verbose

        
    def on_epoch_end(self, epoch, logs={}):
        
        Losses = np.array([logs[i] for i in self.BetaList.keys()])
        Losses = np.maximum(1e-7, Losses)
        RelWeights = Losses / np.min(Losses)
        RelWeights = {LossName:RelWeights[num] for num, LossName in enumerate (self.BetaList.keys())}

        for name, beta in self.BetaList.items():
            
            Value = np.clip(RelWeights[name] * self.BetaWeight[name], self.MinLimit[name], self.MaxLimit[name])
            beta.assign(Value)

        if self.verbose==1:
            print(RelWeights)
            for key, beta in self.BetaList.items():
                print(key, ': ', beta.numpy())
                
RelLossDic = {'val_mse':'Beta_Rec', 'val_FeatRecLoss':'Beta_Feat', 'val_kl_Loss_Z':'Beta_Z', 'val_kl_Loss_FC':'Beta_Fc'}
WeightDic = {'val_mse':10., 'val_FeatRecLoss':100., 'val_kl_Loss_Z':1., 'val_kl_Loss_FC':1.}
MinLimit = {'val_mse':1., 'val_FeatRecLoss':1., 'val_kl_Loss_Z':0.01, 'val_kl_Loss_FC':0.01}
MaxLimit = {'val_mse':200., 'val_FeatRecLoss':200., 'val_kl_Loss_Z':0.1, 'val_kl_Loss_FC':0.1}
RelLoss = RelLossWeight(BetaList=RelLossDic, BetaWeight= WeightDic, MinLimit= MinLimit, MaxLimit = MaxLimit )


class RelLossWeight(tf.keras.callbacks.Callback):
    def __init__(self, BetaList, LossScaling, MinLimit , MaxLimit , verbose=1):
                
        self.BetaList = BetaList
        self.LossScaling = LossScaling
        self.MinLimit = MinLimit
        self.MaxLimit = MaxLimit
        self.verbose = verbose

        
    def on_epoch_end(self, epoch, logs={}):
        
        Losses = np.array([logs[i] for i in self.BetaList.keys()])
        Losses = np.maximum(1e-7, Losses)
        RelWeights = Losses / np.min(Losses)
        RelWeights = {loss:RelWeights[num] * self.LossScaling[loss] for num, loss in enumerate (self.BetaList.keys())}

        for loss, beta in self.BetaList.items():
            
            Value = np.clip(RelWeights[loss] , self.MinLimit[beta], self.MaxLimit[beta])
            K.set_value(self.model.get_layer(beta).variables[0], Value)

        if self.verbose==1:
            print('RelWeights')
            print(RelWeights)
                       
            for key, beta in self.BetaList.items():
                print(beta, ': ', self.model.get_layer(beta).variables[0].numpy())

'''

# %%
        
def ReName (layer, name):
    return Lambda(lambda x: x, name=name)(layer)

def ParaFilters (layer, name=''):
    Fc = Dense(1, activation='sigmoid')(layer)
    Fc = tf.clip_by_value(Fc, 1e-7, 1-1e-7)
    
    # Reparameterization Trick for sampling from Uniformly distribution; ϵ∼U(0,1) 
    Epsilon = tf.random.uniform(shape=(tf.shape(Fc)[0], Fc.shape[1]))
    Epsilon = tf.clip_by_value(Epsilon, 1e-7, 1-1e-7)

    LogEps = tf.math.log(Epsilon)
    LogNegEps = tf.math.log(1 - Epsilon)
    
    LogTheta = tf.math.log(Fc)
    LogNegTheta = tf.math.log(1-Fc)

    Fc = tf.math.sigmoid(LogEps - LogNegEps + LogTheta - LogNegTheta)
    Fc = tf.clip_by_value(Fc, 1e-7, 1-1e-7)
    Fc = ReName(Fc, name)
    
    return Fc 


class Lossweight(tf.keras.layers.Layer):
    
    def __init__(self, InitVal = 0., name='Lossweight'):
        super(Lossweight, self).__init__(name=name)
        self.InitVal = InitVal
    
    def build(self, input_shape):
        self.GenVec = tf.Variable(self.InitVal, trainable=False)
    
    def call(self, input):

        return self.GenVec
    
    def get_config(self):
        config = super(Lossweight, self).get_config()
        config.update({ 'InitVal': self.InitVal })
        return config
    

class RandFCs(tf.keras.layers.Layer):
    
    def __init__(self, ):
        super(RandFCs, self).__init__(name='FCs')
        pass
    
    def build(self, input_shape):
        self.GenVec = tf.Variable(tf.random.uniform(shape=(1,6)), trainable=False)
    
    def call(self, input):
        return tf.tile(self.GenVec , (tf.shape(input)[0],1))
    


class KLAnneal(tf.keras.callbacks.Callback):
    def __init__(self, TargetLossName, Threshold,  BetaName, MaxBeta=0.1, MinBeta=1e-5, AnnealEpoch=100, UnderLimit=0., verbose=1):
        
        if type(TargetLossName) != list:
            TargetLossName = [TargetLossName]
        
        self.TargetLossName = TargetLossName
        self.Threshold = Threshold
        self.BetaName = BetaName
        self.AnnealIdx = 0
        self.verbose = verbose 
        self.Beta =  np.concatenate([np.array([UnderLimit]), np.linspace(start=MinBeta, stop=MaxBeta, num=AnnealEpoch )])

    def on_epoch_end(self, epoch, logs={}):
        
        TargetLoss = max([logs[i] for i in self.TargetLossName]) 
        
        if TargetLoss > self.Threshold:
            
            self.AnnealIdx -= 1
            self.AnnealIdx = np.maximum(self.AnnealIdx, 0)
            K.set_value(self.model.get_layer(self.BetaName).variables[0], self.Beta[self.AnnealIdx])
        else: 
            self.AnnealIdx += 1
            self.AnnealIdx = np.minimum(self.AnnealIdx, len(self.Beta)-1)
            K.set_value(self.model.get_layer(self.BetaName).variables[0], self.Beta[self.AnnealIdx])
        
        if self.verbose==1:
            print(self.BetaName+' : ' ,self.model.get_layer(self.BetaName).variables[0].numpy())
        elif self.verbose==2:
            print('TargetLoss : ', TargetLoss)
            print(self.BetaName+' : ' ,self.model.get_layer(self.BetaName).variables[0].numpy())
            
          

class RelLossWeight(tf.keras.callbacks.Callback):
    def __init__(self, BetaList, LossScaling, MinLimit , MaxLimit , verbose=1, ToSaveLoss=None, SavePath=None):
                
        self.BetaList = BetaList
        self.LossScaling = LossScaling
        self.MinLimit = MinLimit
        self.MaxLimit = MaxLimit
        self.verbose = verbose
        self.ToSaveLoss = ToSaveLoss
        self.CheckLoss = np.inf
        self.SavePath = SavePath

        
    def on_epoch_end(self, epoch, logs={}):
        
        Losses = {key:logs[key]/np.maximum(1e-7,self.model.get_layer(beta).variables[0].numpy()) for key, beta in self.BetaList.items()}

        if self.ToSaveLoss is not None:
            beta = self.BetaList[self.ToSaveLoss]
            CurrentLoss = logs[self.ToSaveLoss]/np.maximum(1e-7,self.model.get_layer(beta).variables[0].numpy())
            
            if CurrentLoss <= self.CheckLoss:
                self.model.save(self.SavePath)
                print()
                print('the model has been saved since loss decreased from '+ str(self.CheckLoss)+ ' to ' + str(CurrentLoss))
                print()
                self.CheckLoss = CurrentLoss
            else:
                print('the model has not been saved since the loss did not decreased from '+ str(self.CheckLoss))
                
                
        WeigLosses = np.maximum(1e-7, np.array(list(Losses.values())))
        #print(WeigLosses)
        RelWeights = WeigLosses / np.min(WeigLosses)
        #print(RelWeights)
        RelWeights = {loss:RelWeights[num] * self.LossScaling[loss] for num, loss in enumerate (self.BetaList.keys())}
        #print(RelWeights)

        for loss, beta in self.BetaList.items():
            
            Value = np.clip(RelWeights[loss] , self.MinLimit[beta], self.MaxLimit[beta])
            K.set_value(self.model.get_layer(beta).variables[0], Value)

        if self.verbose==1:

            print('------------------------------------')
            print('Losses')
            for key, value in Losses.items():
                print("%s: %.7f" % (key, value))
            
            print('------------------------------------')
            print('RelWeights')
            for key, value in RelWeights.items():
                print("%s: %.7f" % (key, value))

            print('------------------------------------')
            print('Beta')
            for key, beta in self.BetaList.items():
                print(beta, ': ', self.model.get_layer(beta).variables[0].numpy())
            print('------------------------------------')
            print()

# %%
def Encoder(SigDim, LatDim= 2, Type = '', MaskingRate = 0.025, NoiseStd = 0.002, MaskStd = 0.1, ReparaStd = 0.1 , Reparam = False):

    InpL = Input(shape=(SigDim,))
    InpFrame = tf.signal.frame(InpL, 100, 100)

    if Reparam:
        InpRegul = GaussianNoise(stddev=NoiseStd)(InpFrame, training=Reparam)
        MaskVec, NoisVec = MaskingGen(InpRegul, MaskingRate, MaskStd)
        EncInp = Masking(mask_value=0.)(InpRegul * MaskVec )
        EncOut = InpRegul + NoisVec
    else:
        EncInp, EncOut = InpFrame, InpFrame

    Encoder = Dense(50, activation='relu')(InpFrame)
    Encoder = Bidirectional(GRU(30, return_sequences=True))(Encoder)
    Encoder = Bidirectional(GRU(30, return_sequences=False))(Encoder)
    Encoder = Dense(50, activation='relu')(Encoder)
    Encoder = Dense(30, activation='relu')(Encoder)
    Encoder = Dense(15, activation='relu')(Encoder)

    Z_Mean = Dense(LatDim, activation='linear')(Encoder)
    Z_Log_Sigma = Dense(LatDim, activation='relu')(Encoder)
    Z_Log_Sigma = ReName(Z_Log_Sigma,'Z_Log_Sigma'+Type)

    
    # Reparameterization Trick for sampling from Guassian distribution
    Epsilon = tf.random.normal(shape=(tf.shape(Z_Mean)[0], Z_Mean.shape[1]), mean=0., stddev=ReparaStd)

    if Reparam==False:
        Epsilon = Epsilon * 0

    Z_Mean = Z_Mean + tf.exp(0.5 * Z_Log_Sigma) * Epsilon
    Z_Mean = ReName(Z_Mean,'Z_Mean'+Type)
    
    FCs =   Dense(6, activation='relu')(Encoder)
    FCs =   Dense(6, activation='sigmoid')(FCs)
    
    
    # Reparameterization Trick for sampling from Uniformly distribution; ϵ∼U(0,1) 
    FCs = tf.clip_by_value(FCs, 1e-7, 1-1e-7)
    Epsilon = tf.random.uniform(shape=(tf.shape(FCs)[0], FCs.shape[1]))
    Epsilon = tf.clip_by_value(Epsilon, 1e-7, 1-1e-7)
    
    LogEps = tf.math.log(Epsilon)
    LogNegEps = tf.math.log(1 - Epsilon)
    
    LogTheta = tf.math.log(FCs)
    LogNegTheta = tf.math.log(1-FCs)
    
    if Reparam==True:
        FCs = tf.math.sigmoid(LogEps - LogNegEps + LogTheta - LogNegTheta)
    
    FCs = tf.clip_by_value(FCs, 1e-7, 1-1e-7)
    FCs = ReName(FCs, 'FCs')
    
    return [InpL], [Flatten(name='SigOut')(EncOut), Z_Mean, FCs]



def FeatExtractor(Inps, LatDim= 2, FiltLenList = [301, 301, 301, 301, 301, 301] ):
    
    EncReInp, InpZ, FCs = Inps
    
    H_F, L_F, HH_F, HL_F, LH_F, LL_F = tf.split(FCs, 6, axis=1)
    

    ### Filtering level 1 -------------------------------------------------------------------
    ## Filter generation
    To_H = GenHighFilter(H_F,  N=FiltLenList[0])
    To_L = GenLowFilter(L_F, N=FiltLenList[1])

    ## Perform signal filtering level 1
    InpFrame =  tf.signal.frame(EncReInp, To_H.shape[-1], 1)
    Sig_H = tf.reduce_sum(InpFrame*To_H[:,:,::-1], axis=-1, keepdims=True)
    Sig_H = ReName(Sig_H, 'Sig_H_Ext')

    InpFrame =  tf.signal.frame(EncReInp, To_L.shape[-1], 1)
    Sig_L = tf.reduce_sum(InpFrame*To_L[:,:,::-1], axis=-1, keepdims=True)
    Sig_L = ReName(Sig_L, 'Sig_L_Ext')



    ### Filtering level HH and HL (from Sig_H) -------------------------------------------------------------------
    ## Filter generation
    To_HH = GenHighFilter(HH_F, N=FiltLenList[2])
    To_HL = GenLowFilter(HL_F, N=FiltLenList[3])

    ## Perform signal filtering level 2
    Frame_H =  tf.signal.frame(Sig_H[:,:,0], To_HH.shape[-1], 1)
    Sig_HH = tf.reduce_sum(Frame_H*To_HH[:,:,::-1], axis=-1, keepdims=True)
    #Sig_HH = ReName(Sig_HH, 'Sig_HH_Ext')

    Frame_H =  tf.signal.frame(Sig_H[:,:,0], To_HL.shape[-1], 1)
    Sig_HL = tf.reduce_sum(Frame_H*To_HL[:,:,::-1], axis=-1, keepdims=True)
    #Sig_HL = ReName(Sig_HL, 'Sig_HL_Ext')


    ### Filtering level LH and LL (from Sig_L) -------------------------------------------------------------------
    ## Filter generation
    To_LH = GenHighFilter(LH_F,  N=FiltLenList[4])
    To_LL = GenLowFilter(LL_F,  N=FiltLenList[5])

    ## Perform signal filtering level 2
    Frame_L =  tf.signal.frame(Sig_L[:,:,0], To_LH.shape[-1], 1)
    Sig_LH = tf.reduce_sum(Frame_L*To_LH[:,:,::-1], axis=-1, keepdims=True)
    #Sig_LH = ReName(Sig_LH, 'Sig_LH_Ext')

    Frame_L =  tf.signal.frame(Sig_L[:,:,0], To_LL.shape[-1], 1)
    Sig_LL = tf.reduce_sum(Frame_L*To_LL[:,:,::-1], axis=-1, keepdims=True)
    #Sig_LL = ReName(Sig_LL, 'Sig_LL_Ext')

    
    return [Flatten(name='Sig_HH_Ext')(Sig_HH), Flatten(name='Sig_HL_Ext')(Sig_HL), Flatten(name='Sig_LH_Ext')(Sig_LH), Flatten(name='Sig_LL_Ext')(Sig_LL)]




def FeatGenerator (Inp_lat):
    
    #Inp_lat = tf.concat(Inp_lat, axis=-1)
    Inp_lat = ReName(Inp_lat, 'Inp_lat')
    InpZ, FCCommon, FCEach = Inp_lat
    HH_F, HL_F, LH_F, LL_F = tf.split(FCEach, 4, axis=1)
    
   
    Dec_Sig_HH = Dense(10, activation='relu')(tf.concat([InpZ, FCCommon, HH_F], axis=-1))
    Dec_Sig_HH = Dense(20, activation='relu')(Dec_Sig_HH)
    Dec_Sig_HH = Dense(30, activation='relu')(Dec_Sig_HH)
    Dec_Sig_HH = Dense(50, activation='relu')(Dec_Sig_HH)

    Dec_Sig_HH = RepeatVector(10 )(Dec_Sig_HH)
    Dec_Sig_HH = Bidirectional(GRU(10, return_sequences=True))(Dec_Sig_HH)
    Dec_Sig_HH = Bidirectional(GRU(20, return_sequences=True))(Dec_Sig_HH)
    Dec_Sig_HH = Dense(40,'tanh')(Dec_Sig_HH)
    Sig_HH= Flatten(name='Sig_HH_Gen')(Dec_Sig_HH)
    
    # ---------------------------------------------------------------------- #
    
    Dec_Sig_HL = Dense(10, activation='relu')(tf.concat([InpZ, FCCommon, HL_F], axis=-1))
    Dec_Sig_HL = Dense(20, activation='relu')(Dec_Sig_HL)
    Dec_Sig_HL = Dense(30, activation='relu')(Dec_Sig_HL)
    Dec_Sig_HL = Dense(50, activation='relu')(Dec_Sig_HL)

    Dec_Sig_HL = RepeatVector(10 )(Dec_Sig_HL)
    Dec_Sig_HL = Bidirectional(GRU(10, return_sequences=True))(Dec_Sig_HL)
    Dec_Sig_HL = Bidirectional(GRU(20, return_sequences=True))(Dec_Sig_HL)
    Dec_Sig_HL = Dense(40,'tanh')(Dec_Sig_HL)
    Sig_HL= Flatten(name='Sig_HL_Gen')(Dec_Sig_HL)
    
    # ---------------------------------------------------------------------- #
    
    Dec_Sig_LH = Dense(10, activation='relu')(tf.concat([InpZ, FCCommon, LH_F], axis=-1))
    Dec_Sig_LH = Dense(20, activation='relu')(Dec_Sig_LH)
    Dec_Sig_LH = Dense(30, activation='relu')(Dec_Sig_LH)
    Dec_Sig_LH = Dense(50, activation='relu')(Dec_Sig_LH)

    Dec_Sig_LH = RepeatVector(10 )(Dec_Sig_LH)
    Dec_Sig_LH = Bidirectional(GRU(10, return_sequences=True))(Dec_Sig_LH)
    Dec_Sig_LH = Bidirectional(GRU(20, return_sequences=True))(Dec_Sig_LH)
    Dec_Sig_LH = Dense(40,'tanh')(Dec_Sig_LH)
    Sig_LH= Flatten(name='Sig_LH_Gen')(Dec_Sig_LH)
    
    # ---------------------------------------------------------------------- #
    
    Dec_Sig_LL = Dense(10, activation='relu')(tf.concat([InpZ, FCCommon, LL_F], axis=-1))
    Dec_Sig_LL = Dense(20, activation='relu')(Dec_Sig_LL)
    Dec_Sig_LL = Dense(30, activation='relu')(Dec_Sig_LL)
    Dec_Sig_LL = Dense(50, activation='relu')(Dec_Sig_LL)

    Dec_Sig_LL = RepeatVector(10 )(Dec_Sig_LL)
    Dec_Sig_LL = Bidirectional(GRU(10, return_sequences=True))(Dec_Sig_LL)
    Dec_Sig_LL = Bidirectional(GRU(20, return_sequences=True))(Dec_Sig_LL)
    Dec_Sig_LL = Dense(40,'tanh')(Dec_Sig_LL)
    Sig_LL= Flatten(name='Sig_LL_Gen')(Dec_Sig_LL)
    
    return  Sig_HH, Sig_HL, Sig_LH, Sig_LL




def Reconstructor(Inps ):
    Sig_HH, Sig_HL, Sig_LH, Sig_LL = Inps[0]
    FCs = Inps[1] 

    ## GRU NET -------------------------------------------------------------------
    Dec_Sig_HH = Reshape((-1, 100))(Sig_HH)
    Dec_Sig_HL = Reshape((-1, 100))(Sig_HL)
    Dec_Sig_LH = Reshape((-1, 100))(Sig_LH)
    Dec_Sig_LL = Reshape((-1, 100))(Sig_LL)

    Dec_Sig_HH = Bidirectional(GRU(5), name='Dec_Sig_HH')(Dec_Sig_HH)
    Dec_Sig_HL = Bidirectional(GRU(5), name='Dec_Sig_HL')(Dec_Sig_HL)
    Dec_Sig_LH = Bidirectional(GRU(5), name='Dec_Sig_LH')(Dec_Sig_LH)
    Dec_Sig_LL = Bidirectional(GRU(5), name='Dec_Sig_LL')(Dec_Sig_LL)

    Decoder = tf.concat([ Dec_Sig_HH, Dec_Sig_HL, Dec_Sig_LH, Dec_Sig_LL, FCs], axis=1)
    Decoder = RepeatVector((SigDim//100) )(Decoder)
    Decoder = Bidirectional(GRU(50, return_sequences=True))(Decoder)
    Decoder = Dense(100, activation='relu')(Decoder)
    DecOut = Dense(100, activation='sigmoid')(Decoder)
    DecOut = Reshape((SigDim,),name='Out')(DecOut)

    
    return DecOut

# %%
### Encoder - FeatExtractor
EncInp, EncOut = Encoder(SigDim=SigDim, LatDim= LatDim, Type = '', MaskingRate = MaskingRate, NoiseStd = NoiseStd, MaskStd = MaskStd, ReparaStd = ReparaStd, Reparam=True)
FeatExtOut = FeatExtractor(EncOut)

### Encoder - FeatGenerator - Reconstruction
FeatGenOut = FeatGenerator([EncOut[1],EncOut[2][:, :2], EncOut[2][:, 2:]])
FeatGenOut = ReName(FeatGenOut, 'FeatGenOut')

ReconOut = Reconstructor([FeatExtOut , EncOut[2]])
ReconOut = ReName(ReconOut, 'ReconOut')

### Define the total model
SigBandRepModel = Model(EncInp, ReconOut)

### Weight controller; Apply beta and capacity 
Capacity_Z = 0.1 # 0.1 0.05
Capacity_Fc = 0.6
Beta_Z = Lossweight(name='Beta_Z')(FeatGenOut)
Beta_Fc = Lossweight(name='Beta_Fc')(FeatGenOut)
Beta_Rec = Lossweight(name='Beta_Rec', InitVal=500.)(FeatGenOut)
Beta_Feat = Lossweight(name='Beta_Feat', InitVal=500.)(FeatGenOut)


### Adding the RecLoss; 
MSE = tf.keras.losses.MeanSquaredError()
RecLoss = Beta_Rec * MSE(ReconOut, EncInp)
SigBandRepModel.add_loss(RecLoss)
SigBandRepModel.add_metric(RecLoss, 'RecLoss')


### Adding the FeatRecLoss; It allows connection between the extractor and generator
FeatRecLoss= Beta_Feat * MSE(tf.concat(FeatGenOut, axis=-1), tf.concat(FeatExtOut, axis=-1))
SigBandRepModel.add_loss(FeatRecLoss)
SigBandRepModel.add_metric(FeatRecLoss, 'FeatRecLoss')

### KL Divergence for p(Z) vs q(Z)
Z_Sampled, Z_Log_Sigma = SigBandRepModel.get_layer('Z_Mean').output, SigBandRepModel.get_layer('Z_Log_Sigma').output
kl_Loss_Z = 0.5 * tf.reduce_sum( Z_Sampled**2  +  tf.exp(Z_Log_Sigma)- Z_Log_Sigma-1, axis=1)    
kl_Loss_Z = tf.reduce_mean(kl_Loss_Z )
kl_Loss_Z = Beta_Z * tf.abs(kl_Loss_Z - Capacity_Z)

### KL Divergence for p(FCs) vs q(FCs)
BernP = 0.5 # hyperparameter
FCs = SigBandRepModel.get_layer('FCs').output
kl_Loss_FC = tf.math.log(FCs) - tf.math.log(BernP) + tf.math.log(1-FCs) - tf.math.log(1-BernP) 
kl_Loss_FC = tf.reduce_mean(-kl_Loss_FC )
kl_Loss_FC = Beta_Fc * tf.abs(kl_Loss_FC - Capacity_Fc)

SigBandRepModel.add_loss(kl_Loss_Z )
SigBandRepModel.add_metric(kl_Loss_Z , 'kl_Loss_Z')

SigBandRepModel.add_loss(kl_Loss_FC )
SigBandRepModel.add_metric(kl_Loss_FC , 'kl_Loss_FC')

## Model Compile
SigBandRepModel.compile(optimizer='adam') 

### Loss and KLD_Beta controller
KLD_Beta_Z = KLAnneal(TargetLossName=['val_FeatRecLoss', 'val_RecLoss'], Threshold=0.001, BetaName='Beta_Z',  MaxBeta=0.1 , MinBeta=0.1, AnnealEpoch=1, UnderLimit=1e-7, verbose=2)
KLD_Beta_Fc = KLAnneal(TargetLossName=['val_FeatRecLoss', 'val_RecLoss'], Threshold=0.001, BetaName='Beta_Fc',  MaxBeta=0.005 , MinBeta=0.005, AnnealEpoch=1, UnderLimit=1e-7, verbose=1)

RelLossDic = {'val_RecLoss':'Beta_Rec', 'val_FeatRecLoss':'Beta_Feat', 'val_kl_Loss_Z':'Beta_Z', 'val_kl_Loss_FC':'Beta_Fc'}
ScalingDic = {'val_RecLoss':100., 'val_FeatRecLoss':100., 'val_kl_Loss_Z':0.1, 'val_kl_Loss_FC':0.1}
MinLimit = {'Beta_Rec':1., 'Beta_Feat':1., 'Beta_Z':0.01, 'Beta_Fc':0.01}
MaxLimit = {'Beta_Rec':500., 'Beta_Feat':500., 'Beta_Z':0.05, 'Beta_Fc':0.05}
RelLoss = RelLossWeight(BetaList=RelLossDic, LossScaling= ScalingDic, MinLimit= MinLimit, MaxLimit = MaxLimit, ToSaveLoss='val_FeatRecLoss' ,  SavePath = ModelSaveSameName)

# %%
SigBandRepModel.load_weights(ModelSaveSameName)
#ModelSave = ModelCheckpoint(filepath=ModelSaveSameName, monitor='val_FeatRecLoss', verbose=1, save_best_only=True )

SigBandRepModel.fit(TrData, batch_size=3500, epochs=1000, shuffle=True, validation_data =(ValData, None) , callbacks=[EarlyStop,  RelLoss]) # ModelSave,
# Out:
# Epoch 1/1000
#  6/92 [>.............................] - ETA: 40s - loss: 0.5267 - RecLoss: 0.1085 - FeatRecLoss: 0.3938 - kl_Loss_Z: 0.0013 - kl_Loss_FC: 0.0231WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1439s vs `on_train_batch_end` time: 0.3337s). Check your callbacks.
# 92/92 [==============================] - 51s 554ms/step - loss: 0.5223 - RecLoss: 0.1065 - FeatRecLoss: 0.3918 - kl_Loss_Z: 0.0013 - kl_Loss_FC: 0.0227 - val_loss: 0.5200 - val_RecLoss: 0.1056 - val_FeatRecLoss: 0.3909 - val_kl_Loss_Z: 0.0013 - val_kl_Loss_FC: 0.0223
#
# the model has been saved since loss decreased from inf to 0.00205577841403216
#
# ------------------------------------
# Losses
# val_RecLoss: 0.0010562
# val_FeatRecLoss: 0.0020558
# val_kl_Loss_Z: 0.0254355
# val_kl_Loss_FC: 0.4453034
# ------------------------------------
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 194.6424102
# val_kl_Loss_Z: 2.4082478
# val_kl_Loss_FC: 42.1616121
# ------------------------------------
# Beta
# Beta_Rec :  100.0
# Beta_Feat :  194.64241
# Beta_Z :  0.05
# Beta_Fc :  0.05
# ------------------------------------
#
# Epoch 2/1000
# 92/92 [==============================] - 47s 513ms/step - loss: 0.5305 - RecLoss: 0.1056 - FeatRecLoss: 0.4007 - kl_Loss_Z: 0.0014 - kl_Loss_FC: 0.0229 - val_loss: 0.5306 - val_RecLoss: 0.1063 - val_FeatRecLoss: 0.3986 - val_kl_Loss_Z: 0.0014 - val_kl_Loss_FC: 0.0243
#
# the model has been saved since loss decreased from 0.00205577841403216 to 0.0020477976478970625
#
# ------------------------------------
# Losses
# val_RecLoss: 0.0010627
# val_FeatRecLoss: 0.0020478
# val_kl_Loss_Z: 0.0276690
# val_kl_Loss_FC: 0.4866635
# ------------------------------------
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 192.6992309
# val_kl_Loss_Z: 2.6036686
# val_kl_Loss_FC: 45.7953886
# ------------------------------------
# Beta
# Beta_Rec :  100.0
# Beta_Feat :  192.69923
# Beta_Z :  0.05
# Beta_Fc :  0.05
# ------------------------------------
#
# Epoch 3/1000
# 92/92 [==============================] - 49s 529ms/step - loss: 0.5261 - RecLoss: 0.1054 - FeatRecLoss: 0.3966 - kl_Loss_Z: 0.0014 - kl_Loss_FC: 0.0227 - val_loss: 0.5253 - val_RecLoss: 0.1058 - val_FeatRecLoss: 0.3964 - val_kl_Loss_Z: 0.0012 - val_kl_Loss_FC: 0.0218
# the model has not been saved since the loss did not decreased from 0.0020477976478970625
# ------------------------------------
# Losses
# val_RecLoss: 0.0010581
# val_FeatRecLoss: 0.0020573
# val_kl_Loss_Z: 0.0249477
# val_kl_Loss_FC: 0.4367170
# ------------------------------------
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 194.4344863
# val_kl_Loss_Z: 2.3578029
# val_kl_Loss_FC: 41.2740793
# ------------------------------------
# Beta
# Beta_Rec :  100.0
# Beta_Feat :  194.43448
# Beta_Z :  0.05
# Beta_Fc :  0.05
# ------------------------------------
#
# Epoch 4/1000
# 92/92 [==============================] - 49s 528ms/step - loss: 0.5298 - RecLoss: 0.1054 - FeatRecLoss: 0.4002 - kl_Loss_Z: 0.0014 - kl_Loss_FC: 0.0227 - val_loss: 0.5296 - val_RecLoss: 0.1059 - val_FeatRecLoss: 0.3996 - val_kl_Loss_Z: 0.0015 - val_kl_Loss_FC: 0.0225
# the model has not been saved since the loss did not decreased from 0.0020477976478970625
# ------------------------------------
# Losses
# val_RecLoss: 0.0010591
# val_FeatRecLoss: 0.0020551
# val_kl_Loss_Z: 0.0307642
# val_kl_Loss_FC: 0.4507885
# ------------------------------------
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 194.0365827
# val_kl_Loss_Z: 2.9047107
# val_kl_Loss_FC: 42.5627496
# ------------------------------------
# Beta
# Beta_Rec :  100.0
# Beta_Feat :  194.03658
# Beta_Z :  0.05
# Beta_Fc :  0.05
# ------------------------------------
#
# Epoch 5/1000
# 92/92 [==============================] - 50s 540ms/step - loss: 0.5286 - RecLoss: 0.1053 - FeatRecLoss: 0.3992 - kl_Loss_Z: 0.0014 - kl_Loss_FC: 0.0227 - val_loss: 0.5277 - val_RecLoss: 0.1053 - val_FeatRecLoss: 0.3989 - val_kl_Loss_Z: 0.0013 - val_kl_Loss_FC: 0.0222
# the model has not been saved since the loss did not decreased from 0.0020477976478970625
# ------------------------------------
# Losses
# val_RecLoss: 0.0010529
# val_FeatRecLoss: 0.0020557
# val_kl_Loss_Z: 0.0265901
# val_kl_Loss_FC: 0.4441545
# ------------------------------------
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 195.2456670
# val_kl_Loss_Z: 2.5254943
# val_kl_Loss_FC: 42.1853048
# ------------------------------------
# Beta
# Beta_Rec :  100.0
# Beta_Feat :  195.24567
# Beta_Z :  0.05
# Beta_Fc :  0.05
# ------------------------------------
#
# Epoch 6/1000
# 92/92 [==============================] - 49s 535ms/step - loss: 0.5312 - RecLoss: 0.1051 - FeatRecLoss: 0.4018 - kl_Loss_Z: 0.0014 - kl_Loss_FC: 0.0228 - val_loss: 0.5308 - val_RecLoss: 0.1057 - val_FeatRecLoss: 0.4017 - val_kl_Loss_Z: 0.0015 - val_kl_Loss_FC: 0.0220
# the model has not been saved since the loss did not decreased from 0.0020477976478970625
# ------------------------------------
# Losses
# val_RecLoss: 0.0010571
# val_FeatRecLoss: 0.0020573
# val_kl_Loss_Z: 0.0297050
# val_kl_Loss_FC: 0.4395134
# ------------------------------------
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 194.6047845
# val_kl_Loss_Z: 2.8099276
# val_kl_Loss_FC: 41.5755574
# ------------------------------------
# Beta
# Beta_Rec :  100.0
# Beta_Feat :  194.60478
# Beta_Z :  0.05
# Beta_Fc :  0.05
# ------------------------------------
#
# Epoch 7/1000
# 92/92 [==============================] - 49s 529ms/step - loss: 0.5295 - RecLoss: 0.1052 - FeatRecLoss: 0.4002 - kl_Loss_Z: 0.0013 - kl_Loss_FC: 0.0228 - val_loss: 0.5294 - val_RecLoss: 0.1057 - val_FeatRecLoss: 0.3995 - val_kl_Loss_Z: 0.0013 - val_kl_Loss_FC: 0.0230
# the model has not been saved since the loss did not decreased from 0.0020477976478970625
# ------------------------------------
# Losses
# val_RecLoss: 0.0010566
# val_FeatRecLoss: 0.0020529
# val_kl_Loss_Z: 0.0258742
# val_kl_Loss_FC: 0.4593146
# ------------------------------------
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 194.2983764
# val_kl_Loss_Z: 2.4489197
# val_kl_Loss_FC: 43.4728057
# ------------------------------------
# Beta
# Beta_Rec :  100.0
# Beta_Feat :  194.29837
# Beta_Z :  0.05
# Beta_Fc :  0.05
# ------------------------------------
#
# Epoch 8/1000
# 92/92 [==============================] - 48s 520ms/step - loss: 0.5291 - RecLoss: 0.1050 - FeatRecLoss: 0.3997 - kl_Loss_Z: 0.0014 - kl_Loss_FC: 0.0230 - val_loss: 0.5286 - val_RecLoss: 0.1056 - val_FeatRecLoss: 0.3990 - val_kl_Loss_Z: 0.0014 - val_kl_Loss_FC: 0.0226
# the model has not been saved since the loss did not decreased from 0.0020477976478970625
# ------------------------------------
# Losses
# val_RecLoss: 0.0010559
# val_FeatRecLoss: 0.0020536
# val_kl_Loss_Z: 0.0272185
# val_kl_Loss_FC: 0.4526327
# ------------------------------------
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 194.4803426
# val_kl_Loss_Z: 2.5776875
# val_kl_Loss_FC: 42.8658523
# ------------------------------------
# Beta
# Beta_Rec :  100.0
# Beta_Feat :  194.48035
# Beta_Z :  0.05
# Beta_Fc :  0.05
# ------------------------------------
#
# Epoch 9/1000
# 92/92 [==============================] - 50s 539ms/step - loss: 0.5294 - RecLoss: 0.1050 - FeatRecLoss: 0.4001 - kl_Loss_Z: 0.0014 - kl_Loss_FC: 0.0229 - val_loss: 0.5295 - val_RecLoss: 0.1054 - val_FeatRecLoss: 0.4011 - val_kl_Loss_Z: 0.0015 - val_kl_Loss_FC: 0.0216
# the model has not been saved since the loss did not decreased from 0.0020477976478970625
# ------------------------------------
# Losses
# val_RecLoss: 0.0010537
# val_FeatRecLoss: 0.0020626
# val_kl_Loss_Z: 0.0291692
# val_kl_Loss_FC: 0.4315013
# ------------------------------------
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 195.7502257
# val_kl_Loss_Z: 2.7683351
# val_kl_Loss_FC: 40.9521476
# ------------------------------------
# Beta
# Beta_Rec :  100.0
# Beta_Feat :  195.75023
# Beta_Z :  0.05
# Beta_Fc :  0.05
# ------------------------------------
#
# Epoch 10/1000
# 92/92 [==============================] - 49s 528ms/step - loss: 0.5319 - RecLoss: 0.1049 - FeatRecLoss: 0.4028 - kl_Loss_Z: 0.0014 - kl_Loss_FC: 0.0229 - val_loss: 0.5313 - val_RecLoss: 0.1056 - val_FeatRecLoss: 0.4001 - val_kl_Loss_Z: 0.0014 - val_kl_Loss_FC: 0.0243
#
# the model has been saved since loss decreased from 0.0020477976478970625 to 0.002043722736151798
#
# ------------------------------------
# Losses
# val_RecLoss: 0.0010560
# val_FeatRecLoss: 0.0020437
# val_kl_Loss_Z: 0.0276392
# val_kl_Loss_FC: 0.4850711
# ------------------------------------
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 193.5310876
# val_kl_Loss_Z: 2.6173081
# val_kl_Loss_FC: 45.9339876
# ------------------------------------
# Beta
# Beta_Rec :  100.0
# Beta_Feat :  193.53108
# Beta_Z :  0.05
# Beta_Fc :  0.05
# ------------------------------------
#
# Epoch 11/1000
# 92/92 [==============================] - 48s 525ms/step - loss: 0.5272 - RecLoss: 0.1049 - FeatRecLoss: 0.3982 - kl_Loss_Z: 0.0013 - kl_Loss_FC: 0.0228 - val_loss: 0.5282 - val_RecLoss: 0.1068 - val_FeatRecLoss: 0.3960 - val_kl_Loss_Z: 0.0017 - val_kl_Loss_FC: 0.0237
# the model has not been saved since the loss did not decreased from 0.002043722736151798
# ------------------------------------
# Losses
# val_RecLoss: 0.0010683
# val_FeatRecLoss: 0.0020463
# val_kl_Loss_Z: 0.0334553
# val_kl_Loss_FC: 0.4737917
# ------------------------------------
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 191.5492588
# val_kl_Loss_Z: 3.1316084
# val_kl_Loss_FC: 44.3496856
# ------------------------------------
# Beta
# Beta_Rec :  100.0
# Beta_Feat :  191.54926
# Beta_Z :  0.05
# Beta_Fc :  0.05
# ------------------------------------
#
# Epoch 12/1000
# 92/92 [==============================] - 48s 518ms/step - loss: 0.5229 - RecLoss: 0.1047 - FeatRecLoss: 0.3941 - kl_Loss_Z: 0.0014 - kl_Loss_FC: 0.0228 - val_loss: 0.5230 - val_RecLoss: 0.1050 - val_FeatRecLoss: 0.3939 - val_kl_Loss_Z: 0.0015 - val_kl_Loss_FC: 0.0226
# the model has not been saved since the loss did not decreased from 0.002043722736151798
# ------------------------------------
# Losses
# val_RecLoss: 0.0010503
# val_FeatRecLoss: 0.0020563
# val_kl_Loss_Z: 0.0295325
# val_kl_Loss_FC: 0.4511869
# ------------------------------------
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 195.7881832
# val_kl_Loss_Z: 2.8118706
# val_kl_Loss_FC: 42.9587294
# ------------------------------------
# Beta
# Beta_Rec :  100.0
# Beta_Feat :  195.78818
# Beta_Z :  0.05
# Beta_Fc :  0.05
# ------------------------------------
#
# Epoch 13/1000
# 92/92 [==============================] - 51s 556ms/step - loss: 0.5319 - RecLoss: 0.1047 - FeatRecLoss: 0.4029 - kl_Loss_Z: 0.0014 - kl_Loss_FC: 0.0229 - val_loss: 0.5323 - val_RecLoss: 0.1052 - val_FeatRecLoss: 0.4031 - val_kl_Loss_Z: 0.0014 - val_kl_Loss_FC: 0.0225
# the model has not been saved since the loss did not decreased from 0.002043722736151798
# ------------------------------------
# Losses
# val_RecLoss: 0.0010525
# val_FeatRecLoss: 0.0020587
# val_kl_Loss_Z: 0.0276601
# val_kl_Loss_FC: 0.4509972
# ------------------------------------
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 195.6076902
# val_kl_Loss_Z: 2.6281199
# val_kl_Loss_FC: 42.8514030
# ------------------------------------
# Beta
# Beta_Rec :  100.0
# Beta_Feat :  195.6077
# Beta_Z :  0.05
# Beta_Fc :  0.05
# ------------------------------------
#
# Epoch 14/1000
# 92/92 [==============================] - 48s 522ms/step - loss: 0.5314 - RecLoss: 0.1048 - FeatRecLoss: 0.4023 - kl_Loss_Z: 0.0014 - kl_Loss_FC: 0.0230 - val_loss: 0.5299 - val_RecLoss: 0.1048 - val_FeatRecLoss: 0.4005 - val_kl_Loss_Z: 0.0013 - val_kl_Loss_FC: 0.0233
# the model has not been saved since the loss did not decreased from 0.002043722736151798
# ------------------------------------
# Losses
# val_RecLoss: 0.0010475
# val_FeatRecLoss: 0.0020473
# val_kl_Loss_Z: 0.0259065
# val_kl_Loss_FC: 0.4669512
# ------------------------------------
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 195.4390150
# val_kl_Loss_Z: 2.4731070
# val_kl_Loss_FC: 44.5764535
# ------------------------------------
# Beta
# Beta_Rec :  100.0
# Beta_Feat :  195.43901
# Beta_Z :  0.05
# Beta_Fc :  0.05
# ------------------------------------
#
# Epoch 15/1000
# 92/92 [==============================] - 48s 526ms/step - loss: 0.5309 - RecLoss: 0.1046 - FeatRecLoss: 0.4020 - kl_Loss_Z: 0.0014 - kl_Loss_FC: 0.0229 - val_loss: 0.5299 - val_RecLoss: 0.1050 - val_FeatRecLoss: 0.4010 - val_kl_Loss_Z: 0.0012 - val_kl_Loss_FC: 0.0227
# the model has not been saved since the loss did not decreased from 0.002043722736151798
# ------------------------------------
# Losses
# val_RecLoss: 0.0010496
# val_FeatRecLoss: 0.0020518
# val_kl_Loss_Z: 0.0241117
# val_kl_Loss_FC: 0.4542274
# ------------------------------------
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 195.4745836
# val_kl_Loss_Z: 2.2971215
# val_kl_Loss_FC: 43.2743262
# ------------------------------------
# Beta
# Beta_Rec :  100.0
# Beta_Feat :  195.47458
# Beta_Z :  0.05
# Beta_Fc :  0.05
# ------------------------------------
#
# Epoch 16/1000
# 92/92 [==============================] - 49s 530ms/step - loss: 0.5307 - RecLoss: 0.1043 - FeatRecLoss: 0.4022 - kl_Loss_Z: 0.0014 - kl_Loss_FC: 0.0229 - val_loss: 0.5300 - val_RecLoss: 0.1045 - val_FeatRecLoss: 0.4008 - val_kl_Loss_Z: 0.0012 - val_kl_Loss_FC: 0.0235
# the model has not been saved since the loss did not decreased from 0.002043722736151798
# ------------------------------------
# Losses
# val_RecLoss: 0.0010452
# val_FeatRecLoss: 0.0020501
# val_kl_Loss_Z: 0.0238381
# val_kl_Loss_FC: 0.4704711
# ------------------------------------
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 196.1517097
# val_kl_Loss_Z: 2.2807591
# val_kl_Loss_FC: 45.0132947
# ------------------------------------
# Beta
# Beta_Rec :  100.0
# Beta_Feat :  196.1517
# Beta_Z :  0.05
# Beta_Fc :  0.05
# ------------------------------------
#
# Epoch 17/1000
# 92/92 [==============================] - 50s 540ms/step - loss: 0.5320 - RecLoss: 0.1044 - FeatRecLoss: 0.4033 - kl_Loss_Z: 0.0013 - kl_Loss_FC: 0.0230 - val_loss: 0.5318 - val_RecLoss: 0.1047 - val_FeatRecLoss: 0.4030 - val_kl_Loss_Z: 0.0013 - val_kl_Loss_FC: 0.0228
# the model has not been saved since the loss did not decreased from 0.002043722736151798
# ------------------------------------
# Losses
# val_RecLoss: 0.0010472
# val_FeatRecLoss: 0.0020546
# val_kl_Loss_Z: 0.0253196
# val_kl_Loss_FC: 0.4554070
# ------------------------------------
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 196.2077499
# val_kl_Loss_Z: 2.4179072
# val_kl_Loss_FC: 43.4892296
# ------------------------------------
# Beta
# Beta_Rec :  100.0
# Beta_Feat :  196.20775
# Beta_Z :  0.05
# Beta_Fc :  0.05
# ------------------------------------
#
# Epoch 18/1000
# 92/92 [==============================] - 50s 546ms/step - loss: 0.5325 - RecLoss: 0.1045 - FeatRecLoss: 0.4037 - kl_Loss_Z: 0.0014 - kl_Loss_FC: 0.0229 - val_loss: 0.5320 - val_RecLoss: 0.1051 - val_FeatRecLoss: 0.4024 - val_kl_Loss_Z: 0.0013 - val_kl_Loss_FC: 0.0232
# the model has not been saved since the loss did not decreased from 0.002043722736151798
# ------------------------------------
# Losses
# val_RecLoss: 0.0010510
# val_FeatRecLoss: 0.0020509
# val_kl_Loss_Z: 0.0264615
# val_kl_Loss_FC: 0.4638980
# ------------------------------------
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 195.1333642
# val_kl_Loss_Z: 2.5177272
# val_kl_Loss_FC: 44.1383644
# ------------------------------------
# Beta
# Beta_Rec :  100.0
# Beta_Feat :  195.13336
# Beta_Z :  0.05
# Beta_Fc :  0.05
# ------------------------------------
#
# Epoch 19/1000
# 92/92 [==============================] - 49s 535ms/step - loss: 0.5299 - RecLoss: 0.1041 - FeatRecLoss: 0.4014 - kl_Loss_Z: 0.0014 - kl_Loss_FC: 0.0229 - val_loss: 0.5294 - val_RecLoss: 0.1047 - val_FeatRecLoss: 0.4017 - val_kl_Loss_Z: 0.0013 - val_kl_Loss_FC: 0.0217
# the model has not been saved since the loss did not decreased from 0.002043722736151798
# ------------------------------------
# Losses
# val_RecLoss: 0.0010470
# val_FeatRecLoss: 0.0020586
# val_kl_Loss_Z: 0.0263273
# val_kl_Loss_FC: 0.4340648
# ------------------------------------
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 196.6203641
# val_kl_Loss_Z: 2.5145132
# val_kl_Loss_FC: 41.4573442
# ------------------------------------
# Beta
# Beta_Rec :  100.0
# Beta_Feat :  196.62036
# Beta_Z :  0.05
# Beta_Fc :  0.05
# ------------------------------------
#
# Epoch 20/1000
# 92/92 [==============================] - 50s 538ms/step - loss: 0.5331 - RecLoss: 0.1043 - FeatRecLoss: 0.4044 - kl_Loss_Z: 0.0014 - kl_Loss_FC: 0.0230 - val_loss: 0.5329 - val_RecLoss: 0.1049 - val_FeatRecLoss: 0.4025 - val_kl_Loss_Z: 0.0015 - val_kl_Loss_FC: 0.0240
# the model has not been saved since the loss did not decreased from 0.002043722736151798
# ------------------------------------
# Losses
# val_RecLoss: 0.0010486
# val_FeatRecLoss: 0.0020470
# val_kl_Loss_Z: 0.0307576
# val_kl_Loss_FC: 0.4807925
# ------------------------------------
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 195.2070077
# val_kl_Loss_Z: 2.9330837
# val_kl_Loss_FC: 45.8489203
# ------------------------------------
# Beta
# Beta_Rec :  100.0
# Beta_Feat :  195.207
# Beta_Z :  0.05
# Beta_Fc :  0.05
# ------------------------------------
#
# Epoch 21/1000
# 92/92 [==============================] - 49s 534ms/step - loss: 0.5303 - RecLoss: 0.1044 - FeatRecLoss: 0.4016 - kl_Loss_Z: 0.0013 - kl_Loss_FC: 0.0230 - val_loss: 0.5302 - val_RecLoss: 0.1053 - val_FeatRecLoss: 0.4012 - val_kl_Loss_Z: 0.0012 - val_kl_Loss_FC: 0.0224
# the model has not been saved since the loss did not decreased from 0.002043722736151798
# ------------------------------------
# Losses
# val_RecLoss: 0.0010534
# val_FeatRecLoss: 0.0020555
# val_kl_Loss_Z: 0.0239795
# val_kl_Loss_FC: 0.4479532
# ------------------------------------
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 195.1182184
# val_kl_Loss_Z: 2.2762959
# val_kl_Loss_FC: 42.5228006
# ------------------------------------
# Beta
# Beta_Rec :  100.0
# Beta_Feat :  195.11823
# Beta_Z :  0.05
# Beta_Fc :  0.05
# ------------------------------------
#
# Epoch 22/1000
# 92/92 [==============================] - 50s 547ms/step - loss: 0.5294 - RecLoss: 0.1041 - FeatRecLoss: 0.4010 - kl_Loss_Z: 0.0014 - kl_Loss_FC: 0.0229 - val_loss: 0.5290 - val_RecLoss: 0.1043 - val_FeatRecLoss: 0.3994 - val_kl_Loss_Z: 0.0013 - val_kl_Loss_FC: 0.0240
# the model has not been saved since the loss did not decreased from 0.002043722736151798
# ------------------------------------
# Losses
# val_RecLoss: 0.0010429
# val_FeatRecLoss: 0.0020468
# val_kl_Loss_Z: 0.0268978
# val_kl_Loss_FC: 0.4800260
# ------------------------------------
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 196.2676470
# val_kl_Loss_Z: 2.5792216
# val_kl_Loss_FC: 46.0294751
# ------------------------------------
# Beta
# Beta_Rec :  100.0
# Beta_Feat :  196.26765
# Beta_Z :  0.05
# Beta_Fc :  0.05
# ------------------------------------
#
# Epoch 23/1000
# 92/92 [==============================] - 50s 542ms/step - loss: 0.5321 - RecLoss: 0.1041 - FeatRecLoss: 0.4037 - kl_Loss_Z: 0.0014 - kl_Loss_FC: 0.0230 - val_loss: 0.5326 - val_RecLoss: 0.1051 - val_FeatRecLoss: 0.4035 - val_kl_Loss_Z: 0.0012 - val_kl_Loss_FC: 0.0227
# the model has not been saved since the loss did not decreased from 0.002043722736151798
# ------------------------------------
# Losses
# val_RecLoss: 0.0010512
# val_FeatRecLoss: 0.0020559
# val_kl_Loss_Z: 0.0248539
# val_kl_Loss_FC: 0.4547521
# ------------------------------------
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 195.5825902
# val_kl_Loss_Z: 2.3644387
# val_kl_Loss_FC: 43.2620819
# ------------------------------------
# Beta
# Beta_Rec :  100.0
# Beta_Feat :  195.5826
# Beta_Z :  0.05
# Beta_Fc :  0.05
# ------------------------------------
#
# Epoch 24/1000
# 92/92 [==============================] - 47s 507ms/step - loss: 0.5302 - RecLoss: 0.1038 - FeatRecLoss: 0.4022 - kl_Loss_Z: 0.0014 - kl_Loss_FC: 0.0229 - val_loss: 0.5295 - val_RecLoss: 0.1038 - val_FeatRecLoss: 0.4014 - val_kl_Loss_Z: 0.0015 - val_kl_Loss_FC: 0.0229
# the model has not been saved since the loss did not decreased from 0.002043722736151798
# ------------------------------------
# Losses
# val_RecLoss: 0.0010378
# val_FeatRecLoss: 0.0020522
# val_kl_Loss_Z: 0.0292497
# val_kl_Loss_FC: 0.4575756
# ------------------------------------
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 197.7368059
# val_kl_Loss_Z: 2.8183669
# val_kl_Loss_FC: 44.0899420
# ------------------------------------
# Beta
# Beta_Rec :  100.0
# Beta_Feat :  197.7368
# Beta_Z :  0.05
# Beta_Fc :  0.05
# ------------------------------------
#
# Epoch 25/1000
# 92/92 [==============================] - 49s 536ms/step - loss: 0.5347 - RecLoss: 0.1037 - FeatRecLoss: 0.4065 - kl_Loss_Z: 0.0014 - kl_Loss_FC: 0.0231 - val_loss: 0.5352 - val_RecLoss: 0.1048 - val_FeatRecLoss: 0.4054 - val_kl_Loss_Z: 0.0013 - val_kl_Loss_FC: 0.0236
# the model has not been saved since the loss did not decreased from 0.002043722736151798
# ------------------------------------
# Losses
# val_RecLoss: 0.0010485
# val_FeatRecLoss: 0.0020504
# val_kl_Loss_Z: 0.0255224
# val_kl_Loss_FC: 0.4725574
# ------------------------------------
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 195.5615030
# val_kl_Loss_Z: 2.4342665
# val_kl_Loss_FC: 45.0714550
# ------------------------------------
# Beta
# Beta_Rec :  100.0
# Beta_Feat :  195.56151
# Beta_Z :  0.05
# Beta_Fc :  0.05
# ------------------------------------
#
# Epoch 26/1000
# 92/92 [==============================] - 48s 524ms/step - loss: 0.5302 - RecLoss: 0.1036 - FeatRecLoss: 0.4023 - kl_Loss_Z: 0.0014 - kl_Loss_FC: 0.0230 - val_loss: 0.5308 - val_RecLoss: 0.1045 - val_FeatRecLoss: 0.4025 - val_kl_Loss_Z: 0.0015 - val_kl_Loss_FC: 0.0223
# the model has not been saved since the loss did not decreased from 0.002043722736151798
# ------------------------------------
# Losses
# val_RecLoss: 0.0010452
# val_FeatRecLoss: 0.0020580
# val_kl_Loss_Z: 0.0299238
# val_kl_Loss_FC: 0.4462650
# ------------------------------------
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 196.8958459
# val_kl_Loss_Z: 2.8629476
# val_kl_Loss_FC: 42.6961810
# ------------------------------------
# Beta
# Beta_Rec :  100.0
# Beta_Feat :  196.89584
# Beta_Z :  0.05
# Beta_Fc :  0.05
# ------------------------------------
#
# Epoch 27/1000
# 92/92 [==============================] - 48s 520ms/step - loss: 0.5330 - RecLoss: 0.1036 - FeatRecLoss: 0.4049 - kl_Loss_Z: 0.0014 - kl_Loss_FC: 0.0230 - val_loss: 0.5323 - val_RecLoss: 0.1042 - val_FeatRecLoss: 0.4040 - val_kl_Loss_Z: 0.0016 - val_kl_Loss_FC: 0.0226
# the model has not been saved since the loss did not decreased from 0.002043722736151798
# ------------------------------------
# Losses
# val_RecLoss: 0.0010419
# val_FeatRecLoss: 0.0020516
# val_kl_Loss_Z: 0.0318746
# val_kl_Loss_FC: 0.4520310
# ------------------------------------
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 196.9016504
# val_kl_Loss_Z: 3.0591572
# val_kl_Loss_FC: 43.3835767
# ------------------------------------
# Beta
# Beta_Rec :  100.0
# Beta_Feat :  196.90166
# Beta_Z :  0.05
# Beta_Fc :  0.05
# ------------------------------------
#
# Epoch 28/1000
# 92/92 [==============================] - 48s 521ms/step - loss: 0.5329 - RecLoss: 0.1036 - FeatRecLoss: 0.4049 - kl_Loss_Z: 0.0014 - kl_Loss_FC: 0.0231 - val_loss: 0.5338 - val_RecLoss: 0.1044 - val_FeatRecLoss: 0.4043 - val_kl_Loss_Z: 0.0014 - val_kl_Loss_FC: 0.0237
# the model has not been saved since the loss did not decreased from 0.002043722736151798
# ------------------------------------
# Losses
# val_RecLoss: 0.0010438
# val_FeatRecLoss: 0.0020534
# val_kl_Loss_Z: 0.0283206
# val_kl_Loss_FC: 0.4747349
# ------------------------------------
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 196.7297203
# val_kl_Loss_Z: 2.7133294
# val_kl_Loss_FC: 45.4832460
# ------------------------------------
# Beta
# Beta_Rec :  100.0
# Beta_Feat :  196.72972
# Beta_Z :  0.05
# Beta_Fc :  0.05
# ------------------------------------
#
# Epoch 29/1000
# 92/92 [==============================] - 46s 503ms/step - loss: 0.5324 - RecLoss: 0.1033 - FeatRecLoss: 0.4046 - kl_Loss_Z: 0.0013 - kl_Loss_FC: 0.0231 - val_loss: 0.5318 - val_RecLoss: 0.1037 - val_FeatRecLoss: 0.4046 - val_kl_Loss_Z: 0.0013 - val_kl_Loss_FC: 0.0220
# the model has not been saved since the loss did not decreased from 0.002043722736151798
# ------------------------------------
# Losses
# val_RecLoss: 0.0010374
# val_FeatRecLoss: 0.0020569
# val_kl_Loss_Z: 0.0266022
# val_kl_Loss_FC: 0.4407732
# ------------------------------------
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 198.2755784
# val_kl_Loss_Z: 2.5643840
# val_kl_Loss_FC: 42.4893353
# ------------------------------------
# Beta
# Beta_Rec :  100.0
# Beta_Feat :  198.27557
# Beta_Z :  0.05
# Beta_Fc :  0.05
# ------------------------------------
#
# Epoch 30/1000
# 92/92 [==============================] - 46s 504ms/step - loss: 0.5358 - RecLoss: 0.1035 - FeatRecLoss: 0.4078 - kl_Loss_Z: 0.0014 - kl_Loss_FC: 0.0231 - val_loss: 0.5355 - val_RecLoss: 0.1037 - val_FeatRecLoss: 0.4066 - val_kl_Loss_Z: 0.0014 - val_kl_Loss_FC: 0.0238
# the model has not been saved since the loss did not decreased from 0.002043722736151798
# ------------------------------------
# Losses
# val_RecLoss: 0.0010372
# val_FeatRecLoss: 0.0020506
# val_kl_Loss_Z: 0.0274040
# val_kl_Loss_FC: 0.4762446
# ------------------------------------
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 197.7113188
# val_kl_Loss_Z: 2.6422077
# val_kl_Loss_FC: 45.9180368
# ------------------------------------
# Beta
# Beta_Rec :  100.0
# Beta_Feat :  197.71132
# Beta_Z :  0.05
# Beta_Fc :  0.05
# ------------------------------------
#
# Epoch 31/1000
# 92/92 [==============================] - 47s 515ms/step - loss: 0.5344 - RecLoss: 0.1035 - FeatRecLoss: 0.4063 - kl_Loss_Z: 0.0014 - kl_Loss_FC: 0.0231 - val_loss: 0.5339 - val_RecLoss: 0.1037 - val_FeatRecLoss: 0.4064 - val_kl_Loss_Z: 0.0013 - val_kl_Loss_FC: 0.0225
# the model has not been saved since the loss did not decreased from 0.002043722736151798
# ------------------------------------
# Losses
# val_RecLoss: 0.0010367
# val_FeatRecLoss: 0.0020556
# val_kl_Loss_Z: 0.0263509
# val_kl_Loss_FC: 0.4496634
# ------------------------------------
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 198.2884138
# val_kl_Loss_Z: 2.5418857
# val_kl_Loss_FC: 43.3759009
# ------------------------------------
# Beta
# Beta_Rec :  100.0
# Beta_Feat :  198.2884
# Beta_Z :  0.05
# Beta_Fc :  0.05
# ------------------------------------
#
# Epoch 32/1000
# 92/92 [==============================] - 48s 523ms/step - loss: 0.5356 - RecLoss: 0.1034 - FeatRecLoss: 0.4077 - kl_Loss_Z: 0.0013 - kl_Loss_FC: 0.0232 - val_loss: 0.5355 - val_RecLoss: 0.1038 - val_FeatRecLoss: 0.4057 - val_kl_Loss_Z: 0.0014 - val_kl_Loss_FC: 0.0246
# the model has not been saved since the loss did not decreased from 0.002043722736151798
# ------------------------------------
# Losses
# val_RecLoss: 0.0010384
# val_FeatRecLoss: 0.0020458
# val_kl_Loss_Z: 0.0273398
# val_kl_Loss_FC: 0.4917236
# ------------------------------------
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 197.0212060
# val_kl_Loss_Z: 2.6329412
# val_kl_Loss_FC: 47.3551562
# ------------------------------------
# Beta
# Beta_Rec :  100.0
# Beta_Feat :  197.02121
# Beta_Z :  0.05
# Beta_Fc :  0.05
# ------------------------------------
#
# Epoch 33/1000
# 92/92 [==============================] - 46s 498ms/step - loss: 0.5326 - RecLoss: 0.1029 - FeatRecLoss: 0.4053 - kl_Loss_Z: 0.0014 - kl_Loss_FC: 0.0231 - val_loss: 0.5332 - val_RecLoss: 0.1045 - val_FeatRecLoss: 0.4040 - val_kl_Loss_Z: 0.0015 - val_kl_Loss_FC: 0.0233
# the model has not been saved since the loss did not decreased from 0.002043722736151798
# ------------------------------------
# Losses
# val_RecLoss: 0.0010446
# val_FeatRecLoss: 0.0020508
# val_kl_Loss_Z: 0.0294840
# val_kl_Loss_FC: 0.4654157
# ------------------------------------
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 196.3293764
# val_kl_Loss_Z: 2.8226444
# val_kl_Loss_FC: 44.5564894
# ------------------------------------
# Beta
# Beta_Rec :  100.0
# Beta_Feat :  196.32938
# Beta_Z :  0.05
# Beta_Fc :  0.05
# ------------------------------------
#
# Epoch 34/1000
# 92/92 [==============================] - 46s 497ms/step - loss: 0.5313 - RecLoss: 0.1032 - FeatRecLoss: 0.4038 - kl_Loss_Z: 0.0013 - kl_Loss_FC: 0.0229 - val_loss: 0.5303 - val_RecLoss: 0.1033 - val_FeatRecLoss: 0.4031 - val_kl_Loss_Z: 0.0012 - val_kl_Loss_FC: 0.0227
# the model has not been saved since the loss did not decreased from 0.002043722736151798
# ------------------------------------
# Losses
# val_RecLoss: 0.0010329
# val_FeatRecLoss: 0.0020532
# val_kl_Loss_Z: 0.0243209
# val_kl_Loss_FC: 0.4544339
# ------------------------------------
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 198.7862064
# val_kl_Loss_Z: 2.3546867
# val_kl_Loss_FC: 43.9970623
# ------------------------------------
# Beta
# Beta_Rec :  100.0
# Beta_Feat :  198.78621
# Beta_Z :  0.05
# Beta_Fc :  0.05
# ------------------------------------
#
# Epoch 35/1000
# 92/92 [==============================] - 46s 498ms/step - loss: 0.5364 - RecLoss: 0.1032 - FeatRecLoss: 0.4087 - kl_Loss_Z: 0.0015 - kl_Loss_FC: 0.0230 - val_loss: 0.5363 - val_RecLoss: 0.1039 - val_FeatRecLoss: 0.4063 - val_kl_Loss_Z: 0.0014 - val_kl_Loss_FC: 0.0247
#
# the model has been saved since loss decreased from 0.002043722736151798 to 0.002043686868185313
#
# ------------------------------------
# Losses
# val_RecLoss: 0.0010393
# val_FeatRecLoss: 0.0020437
# val_kl_Loss_Z: 0.0287471
# val_kl_Loss_FC: 0.4934871
# ------------------------------------
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 196.6467191
# val_kl_Loss_Z: 2.7660884
# val_kl_Loss_FC: 47.4840987
# ------------------------------------
# Beta
# Beta_Rec :  100.0
# Beta_Feat :  196.64671
# Beta_Z :  0.05
# Beta_Fc :  0.05
# ------------------------------------
#
# Epoch 36/1000
# 92/92 [==============================] - 46s 497ms/step - loss: 0.5316 - RecLoss: 0.1030 - FeatRecLoss: 0.4043 - kl_Loss_Z: 0.0013 - kl_Loss_FC: 0.0229 - val_loss: 0.5323 - val_RecLoss: 0.1039 - val_FeatRecLoss: 0.4024 - val_kl_Loss_Z: 0.0013 - val_kl_Loss_FC: 0.0247
# the model has not been saved since the loss did not decreased from 0.002043686868185313
# ------------------------------------
# Losses
# val_RecLoss: 0.0010392
# val_FeatRecLoss: 0.0020465
# val_kl_Loss_Z: 0.0250074
# val_kl_Loss_FC: 0.4945917
# ------------------------------------
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 196.9310359
# val_kl_Loss_Z: 2.4064602
# val_kl_Loss_FC: 47.5944948
# ------------------------------------
# Beta
# Beta_Rec :  100.0
# Beta_Feat :  196.93103
# Beta_Z :  0.05
# Beta_Fc :  0.05
# ------------------------------------
#
# Epoch 37/1000
# 92/92 [==============================] - 46s 497ms/step - loss: 0.5324 - RecLoss: 0.1030 - FeatRecLoss: 0.4048 - kl_Loss_Z: 0.0014 - kl_Loss_FC: 0.0231 - val_loss: 0.5322 - val_RecLoss: 0.1030 - val_FeatRecLoss: 0.4045 - val_kl_Loss_Z: 0.0013 - val_kl_Loss_FC: 0.0233
# the model has not been saved since the loss did not decreased from 0.002043686868185313
# ------------------------------------
# Losses
# val_RecLoss: 0.0010304
# val_FeatRecLoss: 0.0020541
# val_kl_Loss_Z: 0.0261785
# val_kl_Loss_FC: 0.4663979
# ------------------------------------
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 199.3411420
# val_kl_Loss_Z: 2.5405115
# val_kl_Loss_FC: 45.2618966
# ------------------------------------
# Beta
# Beta_Rec :  100.0
# Beta_Feat :  199.34114
# Beta_Z :  0.05
# Beta_Fc :  0.05
# ------------------------------------
#
# Epoch 38/1000
# 92/92 [==============================] - 46s 497ms/step - loss: 0.5368 - RecLoss: 0.1026 - FeatRecLoss: 0.4096 - kl_Loss_Z: 0.0014 - kl_Loss_FC: 0.0232 - val_loss: 0.5366 - val_RecLoss: 0.1033 - val_FeatRecLoss: 0.4091 - val_kl_Loss_Z: 0.0013 - val_kl_Loss_FC: 0.0229
# the model has not been saved since the loss did not decreased from 0.002043686868185313
# ------------------------------------
# Losses
# val_RecLoss: 0.0010329
# val_FeatRecLoss: 0.0020522
# val_kl_Loss_Z: 0.0261915
# val_kl_Loss_FC: 0.4581619
# ------------------------------------
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 198.6849601
# val_kl_Loss_Z: 2.5357471
# val_kl_Loss_FC: 44.3571703
# ------------------------------------
# Beta
# Beta_Rec :  100.0
# Beta_Feat :  198.68497
# Beta_Z :  0.05
# Beta_Fc :  0.05
# ------------------------------------
#
# Epoch 39/1000
# 92/92 [==============================] - 46s 497ms/step - loss: 0.5357 - RecLoss: 0.1026 - FeatRecLoss: 0.4085 - kl_Loss_Z: 0.0014 - kl_Loss_FC: 0.0232 - val_loss: 0.5353 - val_RecLoss: 0.1034 - val_FeatRecLoss: 0.4073 - val_kl_Loss_Z: 0.0014 - val_kl_Loss_FC: 0.0231
# the model has not been saved since the loss did not decreased from 0.002043686868185313
# ------------------------------------
# Losses
# val_RecLoss: 0.0010344
# val_FeatRecLoss: 0.0020501
# val_kl_Loss_Z: 0.0272887
# val_kl_Loss_FC: 0.4625611
# ------------------------------------
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 198.1995864
# val_kl_Loss_Z: 2.6381746
# val_kl_Loss_FC: 44.7187398
# ------------------------------------
# Beta
# Beta_Rec :  100.0
# Beta_Feat :  198.19958
# Beta_Z :  0.05
# Beta_Fc :  0.05
# ------------------------------------
#
# Epoch 40/1000
# 92/92 [==============================] - 46s 497ms/step - loss: 0.5352 - RecLoss: 0.1029 - FeatRecLoss: 0.4077 - kl_Loss_Z: 0.0015 - kl_Loss_FC: 0.0231 - val_loss: 0.5341 - val_RecLoss: 0.1027 - val_FeatRecLoss: 0.4079 - val_kl_Loss_Z: 0.0016 - val_kl_Loss_FC: 0.0218
# the model has not been saved since the loss did not decreased from 0.002043686868185313
# ------------------------------------
# Losses
# val_RecLoss: 0.0010268
# val_FeatRecLoss: 0.0020582
# val_kl_Loss_Z: 0.0320971
# val_kl_Loss_FC: 0.4365406
# ------------------------------------
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 200.4435835
# val_kl_Loss_Z: 3.1258273
# val_kl_Loss_FC: 42.5132470
# ------------------------------------
# Beta
# Beta_Rec :  100.0
# Beta_Feat :  200.44359
# Beta_Z :  0.05
# Beta_Fc :  0.05
# ------------------------------------
#
# Epoch 41/1000
# 92/92 [==============================] - 46s 497ms/step - loss: 0.5391 - RecLoss: 0.1024 - FeatRecLoss: 0.4121 - kl_Loss_Z: 0.0014 - kl_Loss_FC: 0.0233 - val_loss: 0.5382 - val_RecLoss: 0.1028 - val_FeatRecLoss: 0.4102 - val_kl_Loss_Z: 0.0017 - val_kl_Loss_FC: 0.0236
# the model has not been saved since the loss did not decreased from 0.002043686868185313
# ------------------------------------
# Losses
# val_RecLoss: 0.0010280
# val_FeatRecLoss: 0.0020466
# val_kl_Loss_Z: 0.0333144
# val_kl_Loss_FC: 0.4710417
# ------------------------------------
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 199.0743427
# val_kl_Loss_Z: 3.2405599
# val_kl_Loss_FC: 45.8192173
# ------------------------------------
# Beta
# Beta_Rec :  100.0
# Beta_Feat :  199.07434
# Beta_Z :  0.05
# Beta_Fc :  0.05
# ------------------------------------
#
# Epoch 42/1000
# 92/92 [==============================] - 46s 495ms/step - loss: 0.5360 - RecLoss: 0.1024 - FeatRecLoss: 0.4090 - kl_Loss_Z: 0.0014 - kl_Loss_FC: 0.0231 - val_loss: 0.5357 - val_RecLoss: 0.1026 - val_FeatRecLoss: 0.4088 - val_kl_Loss_Z: 0.0016 - val_kl_Loss_FC: 0.0226
# the model has not been saved since the loss did not decreased from 0.002043686868185313
# ------------------------------------
# Losses
# val_RecLoss: 0.0010264
# val_FeatRecLoss: 0.0020536
# val_kl_Loss_Z: 0.0319722
# val_kl_Loss_FC: 0.4523880
# ------------------------------------
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 200.0690541
# val_kl_Loss_Z: 3.1148503
# val_kl_Loss_FC: 44.0732928
# ------------------------------------
# Beta
# Beta_Rec :  100.0
# Beta_Feat :  200.06906
# Beta_Z :  0.05
# Beta_Fc :  0.05
# ------------------------------------
#
# Epoch 43/1000
# 92/92 [==============================] - 45s 495ms/step - loss: 0.5385 - RecLoss: 0.1027 - FeatRecLoss: 0.4109 - kl_Loss_Z: 0.0015 - kl_Loss_FC: 0.0234 - val_loss: 0.5381 - val_RecLoss: 0.1031 - val_FeatRecLoss: 0.4089 - val_kl_Loss_Z: 0.0017 - val_kl_Loss_FC: 0.0244
#
# the model has been saved since loss decreased from 0.002043686868185313 to 0.002043682657130724
#
# ------------------------------------
# Losses
# val_RecLoss: 0.0010314
# val_FeatRecLoss: 0.0020437
# val_kl_Loss_Z: 0.0338309
# val_kl_Loss_FC: 0.4886427
# ------------------------------------
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 198.1528574
# val_kl_Loss_Z: 3.2802035
# val_kl_Loss_FC: 47.3781722
# ------------------------------------
# Beta
# Beta_Rec :  100.0
# Beta_Feat :  198.15286
# Beta_Z :  0.05
# Beta_Fc :  0.05
# ------------------------------------
#
# Epoch 44/1000
# 92/92 [==============================] - 46s 495ms/step - loss: 0.5340 - RecLoss: 0.1022 - FeatRecLoss: 0.4073 - kl_Loss_Z: 0.0014 - kl_Loss_FC: 0.0231 - val_loss: 0.5344 - val_RecLoss: 0.1033 - val_FeatRecLoss: 0.4036 - val_kl_Loss_Z: 0.0015 - val_kl_Loss_FC: 0.0260
#
# the model has been saved since loss decreased from 0.002043682657130724 to 0.0020367053570012226
#
# ------------------------------------
# Losses
# val_RecLoss: 0.0010334
# val_FeatRecLoss: 0.0020367
# val_kl_Loss_Z: 0.0305602
# val_kl_Loss_FC: 0.5190995
# ------------------------------------
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 197.0790932
# val_kl_Loss_Z: 2.9571154
# val_kl_Loss_FC: 50.2299737
# ------------------------------------
# Beta
# Beta_Rec :  100.0
# Beta_Feat :  197.07909
# Beta_Z :  0.05
# Beta_Fc :  0.05
# ------------------------------------
#
# Epoch 45/1000
# 92/92 [==============================] - 46s 496ms/step - loss: 0.5321 - RecLoss: 0.1024 - FeatRecLoss: 0.4053 - kl_Loss_Z: 0.0014 - kl_Loss_FC: 0.0230 - val_loss: 0.5321 - val_RecLoss: 0.1031 - val_FeatRecLoss: 0.4054 - val_kl_Loss_Z: 0.0013 - val_kl_Loss_FC: 0.0222
# the model has not been saved since the loss did not decreased from 0.0020367053570012226
# ------------------------------------
# Losses
# val_RecLoss: 0.0010315
# val_FeatRecLoss: 0.0020571
# val_kl_Loss_Z: 0.0264880
# val_kl_Loss_FC: 0.4449447
# ------------------------------------
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 199.4395543
# val_kl_Loss_Z: 2.5680268
# val_kl_Loss_FC: 43.1376369
# ------------------------------------
# Beta
# Beta_Rec :  100.0
# Beta_Feat :  199.43956
# Beta_Z :  0.05
# Beta_Fc :  0.05
# ------------------------------------
#
# Epoch 46/1000
# 92/92 [==============================] - 46s 497ms/step - loss: 0.5364 - RecLoss: 0.1021 - FeatRecLoss: 0.4097 - kl_Loss_Z: 0.0014 - kl_Loss_FC: 0.0232 - val_loss: 0.5369 - val_RecLoss: 0.1032 - val_FeatRecLoss: 0.4105 - val_kl_Loss_Z: 0.0013 - val_kl_Loss_FC: 0.0218
# the model has not been saved since the loss did not decreased from 0.0020367053570012226
# ------------------------------------
# Losses
# val_RecLoss: 0.0010323
# val_FeatRecLoss: 0.0020584
# val_kl_Loss_Z: 0.0257004
# val_kl_Loss_FC: 0.4366150
# ------------------------------------
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 199.4110310
# val_kl_Loss_Z: 2.4897421
# val_kl_Loss_FC: 42.2973139
# ------------------------------------
# Beta
# Beta_Rec :  100.0
# Beta_Feat :  199.41103
# Beta_Z :  0.05
# Beta_Fc :  0.05
# ------------------------------------
#
# Epoch 47/1000
# 92/92 [==============================] - 46s 497ms/step - loss: 0.5368 - RecLoss: 0.1024 - FeatRecLoss: 0.4098 - kl_Loss_Z: 0.0015 - kl_Loss_FC: 0.0232 - val_loss: 0.5361 - val_RecLoss: 0.1024 - val_FeatRecLoss: 0.4095 - val_kl_Loss_Z: 0.0014 - val_kl_Loss_FC: 0.0228
# the model has not been saved since the loss did not decreased from 0.0020367053570012226
# ------------------------------------
# Losses
# val_RecLoss: 0.0010243
# val_FeatRecLoss: 0.0020536
# val_kl_Loss_Z: 0.0284246
# val_kl_Loss_FC: 0.4557705
# ------------------------------------
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 200.4854423
# val_kl_Loss_Z: 2.7750222
# val_kl_Loss_FC: 44.4957909
# ------------------------------------
# Beta
# Beta_Rec :  100.0
# Beta_Feat :  200.48544
# Beta_Z :  0.05
# Beta_Fc :  0.05
# ------------------------------------
#
# Epoch 48/1000
# 92/92 [==============================] - 46s 497ms/step - loss: 0.5388 - RecLoss: 0.1020 - FeatRecLoss: 0.4122 - kl_Loss_Z: 0.0015 - kl_Loss_FC: 0.0232 - val_loss: 0.5383 - val_RecLoss: 0.1021 - val_FeatRecLoss: 0.4116 - val_kl_Loss_Z: 0.0013 - val_kl_Loss_FC: 0.0233
# the model has not been saved since the loss did not decreased from 0.0020367053570012226
# ------------------------------------
# Losses
# val_RecLoss: 0.0010209
# val_FeatRecLoss: 0.0020530
# val_kl_Loss_Z: 0.0266497
# val_kl_Loss_FC: 0.4661449
# ------------------------------------
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 201.1034369
# val_kl_Loss_Z: 2.6104857
# val_kl_Loss_FC: 45.6614276
# ------------------------------------
# Beta
# Beta_Rec :  100.0
# Beta_Feat :  201.10344
# Beta_Z :  0.05
# Beta_Fc :  0.05
# ------------------------------------
#
# Epoch 49/1000
# 92/92 [==============================] - 46s 496ms/step - loss: 0.5399 - RecLoss: 0.1021 - FeatRecLoss: 0.4129 - kl_Loss_Z: 0.0015 - kl_Loss_FC: 0.0234 - val_loss: 0.5413 - val_RecLoss: 0.1047 - val_FeatRecLoss: 0.4124 - val_kl_Loss_Z: 0.0015 - val_kl_Loss_FC: 0.0228
# the model has not been saved since the loss did not decreased from 0.0020367053570012226
# ------------------------------------
# Losses
# val_RecLoss: 0.0010474
# val_FeatRecLoss: 0.0020506
# val_kl_Loss_Z: 0.0293314
# val_kl_Loss_FC: 0.4550416
# ------------------------------------
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 195.7707122
# val_kl_Loss_Z: 2.8002848
# val_kl_Loss_FC: 43.4430060
# ------------------------------------
# Beta
# Beta_Rec :  100.0
# Beta_Feat :  195.7707
# Beta_Z :  0.05
# Beta_Fc :  0.05
# ------------------------------------
#
# Epoch 50/1000
# 92/92 [==============================] - 46s 496ms/step - loss: 0.5292 - RecLoss: 0.1021 - FeatRecLoss: 0.4028 - kl_Loss_Z: 0.0014 - kl_Loss_FC: 0.0230 - val_loss: 0.5283 - val_RecLoss: 0.1019 - val_FeatRecLoss: 0.4014 - val_kl_Loss_Z: 0.0014 - val_kl_Loss_FC: 0.0236
# the model has not been saved since the loss did not decreased from 0.0020367053570012226
# ------------------------------------
# Losses
# val_RecLoss: 0.0010190
# val_FeatRecLoss: 0.0020504
# val_kl_Loss_Z: 0.0275250
# val_kl_Loss_FC: 0.4719568
# ------------------------------------
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 201.2236337
# val_kl_Loss_Z: 2.7012128
# val_kl_Loss_FC: 46.3162052
# ------------------------------------
# Beta
# Beta_Rec :  100.0
# Beta_Feat :  201.22363
# Beta_Z :  0.05
# Beta_Fc :  0.05
# ------------------------------------
#
# Epoch 51/1000
# 92/92 [==============================] - 46s 497ms/step - loss: 0.5402 - RecLoss: 0.1018 - FeatRecLoss: 0.4136 - kl_Loss_Z: 0.0014 - kl_Loss_FC: 0.0233 - val_loss: 0.5387 - val_RecLoss: 0.1018 - val_FeatRecLoss: 0.4134 - val_kl_Loss_Z: 0.0012 - val_kl_Loss_FC: 0.0222
# the model has not been saved since the loss did not decreased from 0.0020367053570012226
# ------------------------------------
# Losses
# val_RecLoss: 0.0010185
# val_FeatRecLoss: 0.0020547
# val_kl_Loss_Z: 0.0244041
# val_kl_Loss_FC: 0.4434412
# ------------------------------------
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 201.7376772
# val_kl_Loss_Z: 2.3961372
# val_kl_Loss_FC: 43.5395795
# ------------------------------------
# Beta
# Beta_Rec :  100.0
# Beta_Feat :  201.73767
# Beta_Z :  0.05
# Beta_Fc :  0.05
# ------------------------------------
#
# Epoch 52/1000
# 92/92 [==============================] - 46s 496ms/step - loss: 0.5407 - RecLoss: 0.1017 - FeatRecLoss: 0.4144 - kl_Loss_Z: 0.0015 - kl_Loss_FC: 0.0231 - val_loss: 0.5421 - val_RecLoss: 0.1032 - val_FeatRecLoss: 0.4138 - val_kl_Loss_Z: 0.0016 - val_kl_Loss_FC: 0.0235
# the model has not been saved since the loss did not decreased from 0.0020367053570012226
# ------------------------------------
# Losses
# val_RecLoss: 0.0010320
# val_FeatRecLoss: 0.0020513
# val_kl_Loss_Z: 0.0314273
# val_kl_Loss_FC: 0.4708099
# ------------------------------------
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 198.7810077
# val_kl_Loss_Z: 3.0453917
# val_kl_Loss_FC: 45.6227889
# ------------------------------------
# Beta
# Beta_Rec :  100.0
# Beta_Feat :  198.781
# Beta_Z :  0.05
# Beta_Fc :  0.05
# ------------------------------------
#
# Epoch 53/1000
# 92/92 [==============================] - 46s 496ms/step - loss: 0.5348 - RecLoss: 0.1018 - FeatRecLoss: 0.4085 - kl_Loss_Z: 0.0014 - kl_Loss_FC: 0.0232 - val_loss: 0.5344 - val_RecLoss: 0.1015 - val_FeatRecLoss: 0.4099 - val_kl_Loss_Z: 0.0012 - val_kl_Loss_FC: 0.0217
# the model has not been saved since the loss did not decreased from 0.0020367053570012226
# ------------------------------------
# Losses
# val_RecLoss: 0.0010153
# val_FeatRecLoss: 0.0020621
# val_kl_Loss_Z: 0.0242453
# val_kl_Loss_FC: 0.4343286
# ------------------------------------
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 203.0960953
# val_kl_Loss_Z: 2.3879173
# val_kl_Loss_FC: 42.7768980
# ------------------------------------
# Beta
# Beta_Rec :  100.0
# Beta_Feat :  203.0961
# Beta_Z :  0.05
# Beta_Fc :  0.05
# ------------------------------------
#
# Epoch 54/1000
# 92/92 [==============================] - 46s 496ms/step - loss: 0.5434 - RecLoss: 0.1015 - FeatRecLoss: 0.4172 - kl_Loss_Z: 0.0014 - kl_Loss_FC: 0.0233 - val_loss: 0.5431 - val_RecLoss: 0.1019 - val_FeatRecLoss: 0.4173 - val_kl_Loss_Z: 0.0015 - val_kl_Loss_FC: 0.0224
# the model has not been saved since the loss did not decreased from 0.0020367053570012226
# ------------------------------------
# Losses
# val_RecLoss: 0.0010192
# val_FeatRecLoss: 0.0020548
# val_kl_Loss_Z: 0.0292095
# val_kl_Loss_FC: 0.4485485
# ------------------------------------
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 201.6088116
# val_kl_Loss_Z: 2.8658646
# val_kl_Loss_FC: 44.0089040
# ------------------------------------
# Beta
# Beta_Rec :  100.0
# Beta_Feat :  201.60881
# Beta_Z :  0.05
# Beta_Fc :  0.05
# ------------------------------------
#
# Epoch 55/1000
# 92/92 [==============================] - 46s 496ms/step - loss: 0.5401 - RecLoss: 0.1016 - FeatRecLoss: 0.4138 - kl_Loss_Z: 0.0014 - kl_Loss_FC: 0.0234 - val_loss: 0.5397 - val_RecLoss: 0.1018 - val_FeatRecLoss: 0.4128 - val_kl_Loss_Z: 0.0014 - val_kl_Loss_FC: 0.0237
# the model has not been saved since the loss did not decreased from 0.0020367053570012226
# ------------------------------------
# Losses
# val_RecLoss: 0.0010177
# val_FeatRecLoss: 0.0020473
# val_kl_Loss_Z: 0.0287462
# val_kl_Loss_FC: 0.4740915
# ------------------------------------
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 201.1787221
# val_kl_Loss_Z: 2.8247212
# val_kl_Loss_FC: 46.5862678
# ------------------------------------
# Beta
# Beta_Rec :  100.0
# Beta_Feat :  201.17873
# Beta_Z :  0.05
# Beta_Fc :  0.05
# ------------------------------------
#
# Epoch 56/1000
# 92/92 [==============================] - 46s 495ms/step - loss: 0.5397 - RecLoss: 0.1016 - FeatRecLoss: 0.4134 - kl_Loss_Z: 0.0014 - kl_Loss_FC: 0.0233 - val_loss: 0.5390 - val_RecLoss: 0.1020 - val_FeatRecLoss: 0.4114 - val_kl_Loss_Z: 0.0015 - val_kl_Loss_FC: 0.0241
# the model has not been saved since the loss did not decreased from 0.0020367053570012226
# ------------------------------------
# Losses
# val_RecLoss: 0.0010201
# val_FeatRecLoss: 0.0020449
# val_kl_Loss_Z: 0.0300829
# val_kl_Loss_FC: 0.4814646
# ------------------------------------
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 200.4668374
# val_kl_Loss_Z: 2.9490920
# val_kl_Loss_FC: 47.1990164
# ------------------------------------
# Beta
# Beta_Rec :  100.0
# Beta_Feat :  200.46684
# Beta_Z :  0.05
# Beta_Fc :  0.05
# ------------------------------------
#
# Epoch 57/1000
# 92/92 [==============================] - 46s 502ms/step - loss: 0.5378 - RecLoss: 0.1013 - FeatRecLoss: 0.4116 - kl_Loss_Z: 0.0015 - kl_Loss_FC: 0.0234 - val_loss: 0.5386 - val_RecLoss: 0.1030 - val_FeatRecLoss: 0.4097 - val_kl_Loss_Z: 0.0013 - val_kl_Loss_FC: 0.0246
# the model has not been saved since the loss did not decreased from 0.0020367053570012226
# ------------------------------------
# Losses
# val_RecLoss: 0.0010301
# val_FeatRecLoss: 0.0020439
# val_kl_Loss_Z: 0.0254809
# val_kl_Loss_FC: 0.4924196
# ------------------------------------
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 198.4171674
# val_kl_Loss_Z: 2.4736466
# val_kl_Loss_FC: 47.8033911
# ------------------------------------
# Beta
# Beta_Rec :  100.0
# Beta_Feat :  198.41716
# Beta_Z :  0.05
# Beta_Fc :  0.05
# ------------------------------------
#
# Epoch 58/1000
# 92/92 [==============================] - 48s 524ms/step - loss: 0.5338 - RecLoss: 0.1014 - FeatRecLoss: 0.4079 - kl_Loss_Z: 0.0014 - kl_Loss_FC: 0.0232 - val_loss: 0.5332 - val_RecLoss: 0.1019 - val_FeatRecLoss: 0.4077 - val_kl_Loss_Z: 0.0013 - val_kl_Loss_FC: 0.0222
# the model has not been saved since the loss did not decreased from 0.0020367053570012226
# ------------------------------------
# Losses
# val_RecLoss: 0.0010191
# val_FeatRecLoss: 0.0020548
# val_kl_Loss_Z: 0.0261623
# val_kl_Loss_FC: 0.4445370
# ------------------------------------
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 201.6404798
# val_kl_Loss_Z: 2.5672813
# val_kl_Loss_FC: 43.6220731
# ------------------------------------
# Beta
# Beta_Rec :  100.0
# Beta_Feat :  201.64047
# Beta_Z :  0.05
# Beta_Fc :  0.05
# ------------------------------------
#
# Epoch 59/1000
# ...
#
# ------------------------------------
# Losses
# val_RecLoss: 0.0009562
# val_FeatRecLoss: 0.0010455
# val_kl_Loss_Z: 0.4428481
# val_kl_Loss_FC: 0.1768357
# ------------------------------------
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 109.3419065
# val_kl_Loss_Z: 46.3126115
# val_kl_Loss_FC: 18.4933022
# ------------------------------------
# Beta
# Beta_Rec :  100.0
# Beta_Feat :  109.3419
# Beta_Z :  0.05
# Beta_Fc :  0.05
# ------------------------------------
#
# Epoch 112/1000
# 92/92 [==============================] - 46s 499ms/step - loss: 0.2394 - RecLoss: 0.0948 - FeatRecLoss: 0.1138 - kl_Loss_Z: 0.0219 - kl_Loss_FC: 0.0089 - val_loss: 0.2383 - val_RecLoss: 0.0948 - val_FeatRecLoss: 0.1124 - val_kl_Loss_Z: 0.0222 - val_kl_Loss_FC: 0.0090
#
# the model has been saved since loss decreased from 0.001045543591111568 to 0.0010277009121046116
#
# ------------------------------------
# Losses
# val_RecLoss: 0.0009479
# val_FeatRecLoss: 0.0010277
# val_kl_Loss_Z: 0.4437039
# val_kl_Loss_FC: 0.1800386
# ------------------------------------
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 108.4171756
# val_kl_Loss_Z: 46.8084818
# val_kl_Loss_FC: 18.9931531
# ------------------------------------
# Beta
# Beta_Rec :  100.0
# Beta_Feat :  108.417175
# Beta_Z :  0.05
# Beta_Fc :  0.05
# ------------------------------------
#
# Epoch 113/1000
# 92/92 [==============================] - 46s 499ms/step - loss: 0.2370 - RecLoss: 0.0950 - FeatRecLoss: 0.1110 - kl_Loss_Z: 0.0222 - kl_Loss_FC: 0.0088 - val_loss: 0.2393 - val_RecLoss: 0.0956 - val_FeatRecLoss: 0.1125 - val_kl_Loss_Z: 0.0219 - val_kl_Loss_FC: 0.0093
# the model has not been saved since the loss did not decreased from 0.0010277009121046116
# ------------------------------------
# Losses
# val_RecLoss: 0.0009563
# val_FeatRecLoss: 0.0010373
# val_kl_Loss_Z: 0.4381364
# val_kl_Loss_FC: 0.1863876
# ------------------------------------
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 108.4799004
# val_kl_Loss_Z: 45.8180880
# val_kl_Loss_FC: 19.4914692
# ------------------------------------
# Beta
# Beta_Rec :  100.0
# Beta_Feat :  108.479904
# Beta_Z :  0.05
# Beta_Fc :  0.05
# ------------------------------------
#
# Epoch 114/1000
# 92/92 [==============================] - 47s 510ms/step - loss: 0.2357 - RecLoss: 0.0946 - FeatRecLoss: 0.1100 - kl_Loss_Z: 0.0225 - kl_Loss_FC: 0.0086 - val_loss: 0.2347 - val_RecLoss: 0.0951 - val_FeatRecLoss: 0.1083 - val_kl_Loss_Z: 0.0228 - val_kl_Loss_FC: 0.0085
#
# the model has been saved since loss decreased from 0.0010277009121046116 to 0.000998151139538957
#
# ------------------------------------
# Losses
# val_RecLoss: 0.0009508
# val_FeatRecLoss: 0.0009982
# val_kl_Loss_Z: 0.4563124
# val_kl_Loss_FC: 0.1709216
# ------------------------------------
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 104.9820089
# val_kl_Loss_Z: 47.9933258
# val_kl_Loss_FC: 17.9769265
# ------------------------------------
# Beta
# Beta_Rec :  100.0
# Beta_Feat :  104.98201
# Beta_Z :  0.05
# Beta_Fc :  0.05
# ------------------------------------
#
# Epoch 115/1000
# 92/92 [==============================] - 46s 499ms/step - loss: 0.2313 - RecLoss: 0.0950 - FeatRecLoss: 0.1054 - kl_Loss_Z: 0.0227 - kl_Loss_FC: 0.0082 - val_loss: 0.2306 - val_RecLoss: 0.0948 - val_FeatRecLoss: 0.1053 - val_kl_Loss_Z: 0.0227 - val_kl_Loss_FC: 0.0078
# the model has not been saved since the loss did not decreased from 0.000998151139538957
# ------------------------------------
# Losses
# val_RecLoss: 0.0009477
# val_FeatRecLoss: 0.0010035
# val_kl_Loss_Z: 0.4534360
# val_kl_Loss_FC: 0.1565475
# ------------------------------------
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 105.8882706
# val_kl_Loss_Z: 47.8476128
# val_kl_Loss_FC: 16.5192535
# ------------------------------------
# Beta
# Beta_Rec :  100.0
# Beta_Feat :  105.88827
# Beta_Z :  0.05
# Beta_Fc :  0.05
# ------------------------------------
#
# Epoch 116/1000
# 92/92 [==============================] - 46s 501ms/step - loss: 0.2312 - RecLoss: 0.0948 - FeatRecLoss: 0.1053 - kl_Loss_Z: 0.0227 - kl_Loss_FC: 0.0084 - val_loss: 0.2317 - val_RecLoss: 0.0959 - val_FeatRecLoss: 0.1046 - val_kl_Loss_Z: 0.0225 - val_kl_Loss_FC: 0.0087
#
# the model has been saved since loss decreased from 0.000998151139538957 to 0.0009875838262502516
#
# ------------------------------------
# Losses
# val_RecLoss: 0.0009593
# val_FeatRecLoss: 0.0009876
# val_kl_Loss_Z: 0.4497070
# val_kl_Loss_FC: 0.1744798
# ------------------------------------
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 102.9531366
# val_kl_Loss_Z: 46.8808285
# val_kl_Loss_FC: 18.1890852
# ------------------------------------
# Beta
# Beta_Rec :  100.0
# Beta_Feat :  102.95314
# Beta_Z :  0.05
# Beta_Fc :  0.05
# ------------------------------------
#
# Epoch 117/1000
# 92/92 [==============================] - 46s 502ms/step - loss: 0.2272 - RecLoss: 0.0945 - FeatRecLoss: 0.1019 - kl_Loss_Z: 0.0227 - kl_Loss_FC: 0.0080 - val_loss: 0.2270 - val_RecLoss: 0.0950 - val_FeatRecLoss: 0.1018 - val_kl_Loss_Z: 0.0226 - val_kl_Loss_FC: 0.0076
# the model has not been saved since the loss did not decreased from 0.0009875838262502516
# ------------------------------------
# Losses
# val_RecLoss: 0.0009502
# val_FeatRecLoss: 0.0009890
# val_kl_Loss_Z: 0.4515217
# val_kl_Loss_FC: 0.1521961
# ------------------------------------
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 104.0861060
# val_kl_Loss_Z: 47.5198108
# val_kl_Loss_FC: 16.0176749
# ------------------------------------
# Beta
# Beta_Rec :  100.0
# Beta_Feat :  104.086105
# Beta_Z :  0.05
# Beta_Fc :  0.05
# ------------------------------------
#
# Epoch 118/1000
# 92/92 [==============================] - 46s 500ms/step - loss: 0.2272 - RecLoss: 0.0943 - FeatRecLoss: 0.1017 - kl_Loss_Z: 0.0231 - kl_Loss_FC: 0.0080 - val_loss: 0.2278 - val_RecLoss: 0.0953 - val_FeatRecLoss: 0.1015 - val_kl_Loss_Z: 0.0230 - val_kl_Loss_FC: 0.0081
#
# the model has been saved since loss decreased from 0.0009875838262502516 to 0.0009746925912712107
#
# ------------------------------------
# Losses
# val_RecLoss: 0.0009532
# val_FeatRecLoss: 0.0009747
# val_kl_Loss_Z: 0.4594186
# val_kl_Loss_FC: 0.1618223
# ------------------------------------
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 102.2565560
# val_kl_Loss_Z: 48.1983337
# val_kl_Loss_FC: 16.9770364
# ------------------------------------
# Beta
# Beta_Rec :  100.0
# Beta_Feat :  102.25655
# Beta_Z :  0.05
# Beta_Fc :  0.05
# ------------------------------------
#
# Epoch 119/1000
# 92/92 [==============================] - 46s 501ms/step - loss: 0.2251 - RecLoss: 0.0943 - FeatRecLoss: 0.1001 - kl_Loss_Z: 0.0230 - kl_Loss_FC: 0.0078 - val_loss: 0.2257 - val_RecLoss: 0.0946 - val_FeatRecLoss: 0.1001 - val_kl_Loss_Z: 0.0230 - val_kl_Loss_FC: 0.0080
# the model has not been saved since the loss did not decreased from 0.0009746925912712107
# ------------------------------------
# Losses
# val_RecLoss: 0.0009456
# val_FeatRecLoss: 0.0009793
# val_kl_Loss_Z: 0.4592922
# val_kl_Loss_FC: 0.1609653
# ------------------------------------
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 103.5611169
# val_kl_Loss_Z: 48.5721572
# val_kl_Loss_FC: 17.0227871
# ------------------------------------
# Beta
# Beta_Rec :  100.0
# Beta_Feat :  103.56112
# Beta_Z :  0.05
# Beta_Fc :  0.05
# ------------------------------------
#
# Epoch 120/1000
# 92/92 [==============================] - 46s 504ms/step - loss: 0.2251 - RecLoss: 0.0941 - FeatRecLoss: 0.0999 - kl_Loss_Z: 0.0232 - kl_Loss_FC: 0.0077 - val_loss: 0.2259 - val_RecLoss: 0.0946 - val_FeatRecLoss: 0.0994 - val_kl_Loss_Z: 0.0237 - val_kl_Loss_FC: 0.0083
#
# the model has been saved since loss decreased from 0.0009746925912712107 to 0.0009593416719476102
#
# ------------------------------------
# Losses
# val_RecLoss: 0.0009457
# val_FeatRecLoss: 0.0009593
# val_kl_Loss_Z: 0.4734983
# val_kl_Loss_FC: 0.1662672
# ------------------------------------
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 101.4392543
# val_kl_Loss_Z: 50.0669554
# val_kl_Loss_FC: 17.5808289
# ------------------------------------
# Beta
# Beta_Rec :  100.0
# Beta_Feat :  101.439255
# Beta_Z :  0.05
# Beta_Fc :  0.05
# ------------------------------------
#
# Epoch 121/1000
# 92/92 [==============================] - 46s 499ms/step - loss: 0.2229 - RecLoss: 0.0940 - FeatRecLoss: 0.0980 - kl_Loss_Z: 0.0232 - kl_Loss_FC: 0.0077 - val_loss: 0.2232 - val_RecLoss: 0.0944 - val_FeatRecLoss: 0.0981 - val_kl_Loss_Z: 0.0231 - val_kl_Loss_FC: 0.0075
# the model has not been saved since the loss did not decreased from 0.0009593416719476102
# ------------------------------------
# Losses
# val_RecLoss: 0.0009439
# val_FeatRecLoss: 0.0009671
# val_kl_Loss_Z: 0.4624341
# val_kl_Loss_FC: 0.1509490
# ------------------------------------
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 102.4660633
# val_kl_Loss_Z: 48.9933120
# val_kl_Loss_FC: 15.9925321
# ------------------------------------
# Beta
# Beta_Rec :  100.0
# Beta_Feat :  102.466064
# Beta_Z :  0.05
# Beta_Fc :  0.05
# ------------------------------------
#
# Epoch 122/1000
# 92/92 [==============================] - 46s 505ms/step - loss: 0.2235 - RecLoss: 0.0940 - FeatRecLoss: 0.0983 - kl_Loss_Z: 0.0233 - kl_Loss_FC: 0.0079 - val_loss: 0.2241 - val_RecLoss: 0.0944 - val_FeatRecLoss: 0.0974 - val_kl_Loss_Z: 0.0250 - val_kl_Loss_FC: 0.0074
#
# the model has been saved since loss decreased from 0.0009593416719476102 to 0.0009504749409773267
#
# ------------------------------------
# Losses
# val_RecLoss: 0.0009437
# val_FeatRecLoss: 0.0009505
# val_kl_Loss_Z: 0.5000899
# val_kl_Loss_FC: 0.1473109
# ------------------------------------
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 100.7231848
# val_kl_Loss_Z: 52.9952389
# val_kl_Loss_FC: 15.6107494
# ------------------------------------
# Beta
# Beta_Rec :  100.0
# Beta_Feat :  100.72318
# Beta_Z :  0.05
# Beta_Fc :  0.05
# ------------------------------------
#
# Epoch 123/1000
# 92/92 [==============================] - 46s 501ms/step - loss: 0.2212 - RecLoss: 0.0939 - FeatRecLoss: 0.0966 - kl_Loss_Z: 0.0232 - kl_Loss_FC: 0.0076 - val_loss: 0.2220 - val_RecLoss: 0.0944 - val_FeatRecLoss: 0.0969 - val_kl_Loss_Z: 0.0232 - val_kl_Loss_FC: 0.0075
# the model has not been saved since the loss did not decreased from 0.0009504749409773267
# ------------------------------------
# Losses
# val_RecLoss: 0.0009436
# val_FeatRecLoss: 0.0009620
# val_kl_Loss_Z: 0.4632735
# val_kl_Loss_FC: 0.1509600
# ------------------------------------
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 101.9554898
# val_kl_Loss_Z: 49.0972713
# val_kl_Loss_FC: 15.9985933
# ------------------------------------
# Beta
# Beta_Rec :  100.0
# Beta_Feat :  101.95549
# Beta_Z :  0.05
# Beta_Fc :  0.05
# ------------------------------------
#
# Epoch 124/1000
# 92/92 [==============================] - 46s 500ms/step - loss: 0.2223 - RecLoss: 0.0942 - FeatRecLoss: 0.0970 - kl_Loss_Z: 0.0234 - kl_Loss_FC: 0.0077 - val_loss: 0.2239 - val_RecLoss: 0.0947 - val_FeatRecLoss: 0.0982 - val_kl_Loss_Z: 0.0224 - val_kl_Loss_FC: 0.0086
# the model has not been saved since the loss did not decreased from 0.0009504749409773267
# ------------------------------------
# Losses
# val_RecLoss: 0.0009470
# val_FeatRecLoss: 0.0009631
# val_kl_Loss_Z: 0.4481247
# val_kl_Loss_FC: 0.1713770
# ------------------------------------
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 101.6950546
# val_kl_Loss_Z: 47.3188934
# val_kl_Loss_FC: 18.0962412
# ------------------------------------
# Beta
# Beta_Rec :  100.0
# Beta_Feat :  101.69505
# Beta_Z :  0.05
# Beta_Fc :  0.05
# ------------------------------------
#
# Epoch 125/1000
# 10/92 [==>...........................] - ETA: 39s - loss: 0.2250 - RecLoss: 0.0941 - FeatRecLoss: 0.0999 - kl_Loss_Z: 0.0222 - kl_Loss_FC: 0.0089
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [8], in <cell line: 4>()
#       1 SigBandRepModel.load_weights(ModelSaveSameName)
#       2 #ModelSave = ModelCheckpoint(filepath=ModelSaveSameName, monitor='val_FeatRecLoss', verbose=1, save_best_only=True )
# ----> 4 SigBandRepModel.fit(TrData, batch_size=3500, epochs=1000, shuffle=True, validation_data =(ValData, None) , callbacks=[EarlyStop,  RelLoss])
#
# File ~\anaconda3\envs\ai\lib\site-packages\tensorflow\python\keras\engine\training.py:1100, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1093 with trace.Trace(
#    1094     'train',
#    1095     epoch_num=epoch,
#    1096     step_num=step,
#    1097     batch_size=batch_size,
#    1098     _r=1):
#    1099   callbacks.on_train_batch_begin(step)
# -> 1100   tmp_logs = self.train_function(iterator)
#    1101   if data_handler.should_sync:
#    1102     context.async_wait()
#
# File ~\anaconda3\envs\ai\lib\site-packages\tensorflow\python\eager\def_function.py:828, in Function.__call__(self, *args, **kwds)
#     826 tracing_count = self.experimental_get_tracing_count()
#     827 with trace.Trace(self._name) as tm:
# --> 828   result = self._call(*args, **kwds)
#     829   compiler = "xla" if self._experimental_compile else "nonXla"
#     830   new_tracing_count = self.experimental_get_tracing_count()
#
# File ~\anaconda3\envs\ai\lib\site-packages\tensorflow\python\eager\def_function.py:855, in Function._call(self, *args, **kwds)
#     852   self._lock.release()
#     853   # In this case we have created variables on the first call, so we run the
#     854   # defunned version which is guaranteed to never create variables.
# --> 855   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     856 elif self._stateful_fn is not None:
#     857   # Release the lock early so that multiple threads can perform the call
#     858   # in parallel.
#     859   self._lock.release()
#
# File ~\anaconda3\envs\ai\lib\site-packages\tensorflow\python\eager\function.py:2942, in Function.__call__(self, *args, **kwargs)
#    2939 with self._lock:
#    2940   (graph_function,
#    2941    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2942 return graph_function._call_flat(
#    2943     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File ~\anaconda3\envs\ai\lib\site-packages\tensorflow\python\eager\function.py:1918, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1914 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1915 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1916     and executing_eagerly):
#    1917   # No tape is watching; skip to running the function.
# -> 1918   return self._build_call_outputs(self._inference_function.call(
#    1919       ctx, args, cancellation_manager=cancellation_manager))
#    1920 forward_backward = self._select_forward_and_backward_functions(
#    1921     args,
#    1922     possible_gradient_type,
#    1923     executing_eagerly)
#    1924 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~\anaconda3\envs\ai\lib\site-packages\tensorflow\python\eager\function.py:555, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     553 with _InterpolateFunctionError(self):
#     554   if cancellation_manager is None:
# --> 555     outputs = execute.execute(
#     556         str(self.signature.name),
#     557         num_outputs=self._num_outputs,
#     558         inputs=args,
#     559         attrs=attrs,
#     560         ctx=ctx)
#     561   else:
#     562     outputs = execute.execute_with_cancellation(
#     563         str(self.signature.name),
#     564         num_outputs=self._num_outputs,
#    (...)
#     567         ctx=ctx,
#     568         cancellation_manager=cancellation_manager)
#
# File ~\anaconda3\envs\ai\lib\site-packages\tensorflow\python\eager\execute.py:59, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57 try:
#      58   ctx.ensure_initialized()
# ---> 59   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                       inputs, attrs, num_outputs)
#      61 except core._NotOkStatusException as e:
#      62   if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# ### Post model

# %%
### Encoder - FeatExtractor
EncInp, EncOut = Encoder(SigDim=SigDim, LatDim= LatDim, Type = '', MaskingRate = MaskingRate, NoiseStd = NoiseStd, MaskStd = MaskStd, ReparaStd = ReparaStd, Reparam=False)
FeatExtOut = FeatExtractor(EncOut)

### Encoder - FeatGenerator - Reconstruction
FeatGenOut = FeatGenerator([EncOut[1],EncOut[2][:, :2], EncOut[2][:, 2:]])
FeatGenOut = ReName(FeatGenOut, 'FeatGenOut')

ReconOut = Reconstructor([FeatExtOut , EncOut[2]])
ReconOut = ReName(ReconOut, 'ReconOut')

### Define the total model
SigBandRepModel = Model(EncInp, ReconOut)

### Weight controller; Apply beta and capacity 
Capacity_Z = 0.1 # 0.1 0.05
Capacity_Fc = 0.6
Beta_Z = Lossweight(name='Beta_Z')(FeatGenOut)
Beta_Fc = Lossweight(name='Beta_Fc')(FeatGenOut)
Beta_Rec = Lossweight(name='Beta_Rec', InitVal=500.)(FeatGenOut)
Beta_Feat = Lossweight(name='Beta_Feat', InitVal=500.)(FeatGenOut)


### Adding the RecLoss; 
MSE = tf.keras.losses.MeanSquaredError()
RecLoss = Beta_Rec * MSE(ReconOut, EncInp)
SigBandRepModel.add_loss(RecLoss)
SigBandRepModel.add_metric(RecLoss, 'RecLoss')


### Adding the FeatRecLoss; It allows connection between the extractor and generator
FeatRecLoss= Beta_Feat * MSE(tf.concat(FeatGenOut, axis=-1), tf.concat(FeatExtOut, axis=-1))
SigBandRepModel.add_loss(FeatRecLoss)
SigBandRepModel.add_metric(FeatRecLoss, 'FeatRecLoss')

### KL Divergence for p(Z) vs q(Z)
Z_Sampled, Z_Log_Sigma = SigBandRepModel.get_layer('Z_Mean').output, SigBandRepModel.get_layer('Z_Log_Sigma').output
kl_Loss_Z = 0.5 * tf.reduce_sum( Z_Sampled**2  +  tf.exp(Z_Log_Sigma)- Z_Log_Sigma-1, axis=1)    
kl_Loss_Z = tf.reduce_mean(kl_Loss_Z )
kl_Loss_Z = Beta_Z * tf.abs(kl_Loss_Z - Capacity_Z)

### KL Divergence for p(FCs) vs q(FCs)
BernP = 0.5 # hyperparameter
FCs = SigBandRepModel.get_layer('FCs').output
kl_Loss_FC = tf.math.log(FCs) - tf.math.log(BernP) + tf.math.log(1-FCs) - tf.math.log(1-BernP) 
kl_Loss_FC = tf.reduce_mean(-kl_Loss_FC )
kl_Loss_FC = Beta_Fc * tf.abs(kl_Loss_FC - Capacity_Fc)

SigBandRepModel.add_loss(kl_Loss_Z )
SigBandRepModel.add_metric(kl_Loss_Z , 'kl_Loss_Z')

SigBandRepModel.add_loss(kl_Loss_FC )
SigBandRepModel.add_metric(kl_Loss_FC , 'kl_Loss_FC')

### Load weights
SigBandRepModel.load_weights(ModelSaveSameName)


### Regularizer resetting
for i in SigBandRepModel.weights:
    if i.name.split('/')[0] in ['Beta_Z','Beta_Fc','Beta_Rec','Beta_Feat']:
        i.assign(1.)


## Model Compile
SigBandRepModel.compile(optimizer='adam')

# %% [markdown]
# #### Model evaluation

# %%
SigBandRepModel.evaluate(ValData,  batch_size=3500, verbose=1)
# Out:
# 23/23 [==============================] - 6s 91ms/step - loss: 0.8998 - RecLoss: 8.7579e-04 - FeatRecLoss: 5.3856e-04 - kl_Loss_Z: 0.4842 - kl_Loss_FC: 0.4172
# [0.902769923210144,
#  0.0008757853647693992,
#  0.0005385619006119668,
#  0.48419347405433655,
#  0.4171620309352875]

# %%
def LayerExtractor(Backborn, Subtractor):
    
    SelectLayers = [i for i in Backborn if i not in Subtractor]
    
    SelectWeights = []
    for i in SelectLayers:
        SelectWeights.extend(i.get_weights())
    
    return SelectWeights



EncOut = [SigBandRepModel.get_layer('SigOut').output,
          SigBandRepModel.get_layer('Z_Mean').output,
          SigBandRepModel.get_layer('FCs').output ]


FeatExtOut = [SigBandRepModel.get_layer('Sig_HH_Ext').output,
              SigBandRepModel.get_layer('Sig_HL_Ext').output,
              SigBandRepModel.get_layer('Sig_LH_Ext').output,
              SigBandRepModel.get_layer('Sig_LL_Ext').output]

FeatGenOut = [SigBandRepModel.get_layer('Sig_HH_Gen').output,
              SigBandRepModel.get_layer('Sig_HL_Gen').output,
              SigBandRepModel.get_layer('Sig_LH_Gen').output,
              SigBandRepModel.get_layer('Sig_LL_Gen').output]

FCs = SigBandRepModel.get_layer('FCs').output

EncoderLayers = Model(SigBandRepModel.input, EncOut).layers
Enc2FeatExtLayers = Model(SigBandRepModel.input, FeatExtOut).layers
Enc2FeatGenLayers = Model(SigBandRepModel.input, FeatGenOut).layers
Enc2ReconLayers = Model(SigBandRepModel.input, SigBandRepModel.output).layers
len(EncoderLayers), len(Enc2FeatExtLayers), len(Enc2FeatGenLayers), len(Enc2ReconLayers), len(SigBandRepModel.layers)
# Out:
# (26, 121, 69, 136, 257)

# %%
### Feat Generator Reconstruction and Load Weights
Post_InpZ = Input((LatDim,))
Post_FCCommon = Input((2,))
Post_FCEach =Input((4,))
Post_FeatGenOut = FeatGenerator([Post_InpZ,Post_FCCommon,Post_FCEach])
Post_FeatGenModel = Model([Post_InpZ, Post_FCCommon, Post_FCEach], Post_FeatGenOut)

# Weight updating 
Pre_FeatGenWeights = LayerExtractor(Enc2FeatGenLayers, EncoderLayers)
Post_FeatGenModel.set_weights(Pre_FeatGenWeights)


### Reconstructor Reconstruction and Load Weights
Sig_HH_Gen = Input((400,))
Sig_HL_Gen = Input((400,))
Sig_LH_Gen = Input((400,))
Sig_LL_Gen = Input((400,))
FCs = Input((6,))
ReconOut =  Reconstructor([[Sig_HH_Gen, Sig_HL_Gen, Sig_LH_Gen, Sig_LL_Gen], FCs])
Post_ReconModel = Model([Sig_HH_Gen, Sig_HL_Gen, Sig_LH_Gen, Sig_LL_Gen, FCs], ReconOut)

# Weight updating 
Pre_ReconWeights = LayerExtractor(Enc2ReconLayers, Enc2FeatExtLayers)
Post_ReconModel.set_weights(Pre_ReconWeights)

### Incorporating two parts into one model
Post_ReconOut = Post_ReconModel([Post_FeatGenModel.output, FCs])
SigGenerator = Model([Post_FeatGenModel.input, FCs], Post_ReconOut)

# %%
N_Exp = 100
#Z_pred = np.tile(np.zeros(LatDim), (N_Exp,1))
Z_pred = np.linspace(-0.5, 0.5, N_Exp*LatDim).reshape(N_Exp, -1)

#FC_Comm = np.random.uniform(0,1, N_Exp * 2).reshape(N_Exp, -1)
#FC_Comm = np.linspace(0,1, N_Exp * 2).reshape(N_Exp, -1)
FC_Comm = np.tile(np.ones(2) * 1., (N_Exp,1))

#FC_Each = np.random.uniform(0,1, N_Exp * 4).reshape(N_Exp, -1)
#FC_Each = np.linspace(0,1, N_Exp * 4).reshape(N_Exp, -1)
FC_Each = np.tile(np.ones(4) * 1.0, (N_Exp,1))

# %%
FeatGen = Post_FeatGenModel.predict([Z_pred,FC_Comm,FC_Each], batch_size=1000)
SigGen = SigGenerator.predict([Z_pred,FC_Comm,FC_Each, np.concatenate([FC_Comm,FC_Each], axis=-1)], batch_size=1000)

# %%
plt.plot(SigGen[4])

# %%
for i in range(N_Exp):
    plt.plot(FeatGen[0][i])

# %%
for i in range(4):
    plt.plot(FeatGen[i][8])

# %%
TotalLayers = SigBandRepModel.layers
print(len(TotalLayers))

TotalLayers, Tr_EncoderLayers = LayerExtractor(TotalLayers, EncoderLayers)
print(len(Tr_EncoderLayers), len(EncoderLayers))

TotalLayers, Tr_FeatExtLayers = LayerExtractor(TotalLayers, Enc2FeatExtLayers)
print(len(Tr_FeatExtLayers), len(Enc2FeatExtLayers))

TotalLayers, Tr_FeatGenLayers = LayerExtractor(TotalLayers, Enc2FeatGenLayers)
print(len(Tr_FeatGenLayers), len(Enc2FeatGenLayers))
# Out:
# 257
# 14 26
# 57 121
# 27 69

# %%
FeatGenOut = FeatGenerator([EncOut[1],EncOut[2][:, :2], EncOut[2][:, 2:]])

# %%
### Define total model again
ModelInp, Z_Mean = Encoder()
LatGenOut = Decoder(Z_Mean[0])
LatGenOut = ReName(LatGenOut, 'Out')
SigGenModel = Model(ModelInp[0], LatGenOut)
SigGenModel.load_weights(ModelSaveSameName)

### Load trained layers
EncoderLayers = Model(ModelInp, Z_Mean).layers
DecoderStartIDX = len(EncoderLayers)
DecoderLayers = SigGenModel.layers[DecoderStartIDX:]


### Define a sub-model
New_DecInp = Input((2,))
New_DecOut = Decoder(New_DecInp)
New_DecModel = Model(New_DecInp, New_DecOut)

### Weight update
DecoderLayersWeights = []
for i in DecoderLayers:
    DecoderLayersWeights.extend(i.get_weights())
    
New_DecModel.set_weights(DecoderLayersWeights)
