# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import hilbert, chirp
import tensorflow as tf
from tensorflow.keras import backend as K
import pandas as pd
from tensorflow.keras.layers import Input, GRU, Dense, Masking, Reshape, BatchNormalization, Flatten, Conv1DTranspose, RepeatVector, TimeDistributed, Bidirectional, Activation, GaussianNoise, Lambda
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras import Model
import tensorflow_probability as tfp

os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %% [markdown]
# ### Data

# %%
DATA = np.load('./Data/AsanTRSet.npy')

# %% [markdown]
# #### Env setting

# %%
save_path = './Results/'
if not os.path.exists(save_path):
    os.mkdir(save_path)
    
### Model checkpoint
ModelSaveSameName = save_path+'VaeSFModel.hdf5'
ModelSave = ModelCheckpoint(filepath=ModelSaveSameName, monitor='val_mse', verbose=1, save_best_only=True )

### Model Early stop
EarlyStop = EarlyStopping(monitor='val_loss', patience=500)

LatDim = 2
SigDim = DATA.shape[1]
MaskingRate = 0.025
GaussStd1 = 0.002
GaussStd2 = 0.1

# %%
def MaskingGen ( InpRegul, MaskingRate = 0.025, GaussStd2 = 0.1):
    ## Masking vector generation 1 vs 0
    NBatch = tf.shape(InpRegul)[0]
    
    MaskIDX = tf.random.shuffle(tf.range(NBatch * InpRegul.shape[1] ))
    CutIDX = tf.cast(  tf.cast(tf.shape(MaskIDX)[0], dtype=tf.float32) * (1-MaskingRate), dtype=tf.int32 )
    MaskIDX = tf.cast(MaskIDX < CutIDX, dtype=tf.float32)
    MaskVec = tf.reshape(MaskIDX, (NBatch, -1))[:,:,None]
    
    ## Noise vector generation 1 vs 0
    RevMaskIDX = MaskIDX == 0
    RevMaskIDX = tf.cast(RevMaskIDX, dtype=tf.float32)
    NoisVec = RevMaskIDX * tf.random.normal(tf.shape(RevMaskIDX), stddev=GaussStd2)
    NoisVec = tf.reshape(NoisVec, (NBatch, -1))[:,:,None]
    return MaskVec, NoisVec

def GenLowFilter (LF, BL, N = 401):
    nVec = np.arange(N)
    KaiserBL = tf.signal.kaiser_window(N, beta=BL)

    # A low-pass filter
    X = 2 * LF * (nVec - (N - 1) / 2)
    X = tf.maximum(X , 1e-7)
    LPF = tf.sin(np.pi*X)/(np.pi*X)
    LPF *= KaiserBL
    LPF /= tf.reduce_sum(LPF, axis=-1, keepdims=True)
    
    return LPF[:,None] 


def GenHighFilter (HF, BH, N = 401):
    nVec = np.arange(N)
    KaiserBH = tf.signal.kaiser_window(N, beta=BH)

    # A high-pass filter
    Y = 2 * HF * (nVec - (N - 1) / 2)
    Y = tf.maximum(Y , 1e-7)
    HPF = tf.sin(np.pi*Y)/(np.pi*Y)
    HPF *= KaiserBH
    HPF /= tf.reduce_sum(HPF, axis=-1, keepdims=True)
    HPF = -HPF

    ## HPF[(N - 1) // 2] += 1
    Mask = np.zeros(HPF.shape[1])
    Mask[(N - 1) // 2] += 1
    Mask = tf.constant(Mask, dtype=tf.float32)
    HPF = HPF + Mask
    
    return HPF[:,None] 

def ReName (layer, name):
    return Lambda(lambda x: x, name=name)(layer)

# %% [markdown]
# ### Encoder

# %%
def EncoderModel (training = False):

    InpL = Input(shape=(SigDim,))
    InpFrame = tf.signal.frame(InpL, 100, 100)

    if training:
        InpRegul = GaussianNoise(stddev=GaussStd1)(InpFrame, training=training)
        MaskVec, NoisVec = MaskingGen(InpRegul, MaskingRate, GaussStd2)
        EncInp = Masking(mask_value=0.)(InpRegul * MaskVec )
        EncOut = InpRegul + NoisVec
    else:
        EncInp, EncOut = InpFrame, InpFrame

    EncGRUOut = Bidirectional(GRU(50, return_sequences=True))(EncInp)
    EncGRUOut = Bidirectional(GRU(20, return_sequences=False))(EncGRUOut)

    Zs = Dense(20, activation='relu')(EncGRUOut)
    Zs = Dense(10, activation='relu')(Zs)
    Z_Mean = Dense(LatDim, activation='linear', name='Z_Mean')(Zs) 
    Z_Log_Sigma = Dense(LatDim, activation='softplus', name='Z_Log_Sigma')(Zs)

    if training:
        # Reparameterization Trick for sampling 
        Epsilon = K.random_normal(shape=(tf.shape(Z_Mean)[0], Z_Mean.shape[1]), mean=0., stddev=0.1)
        Epsilon = ReName(Epsilon,'Epsilon')
        Z_Mean = Z_Mean + tf.exp(0.5 * Z_Log_Sigma) * Epsilon
        Z_Mean = ReName(Z_Mean,'Z_Sampled')
    
    EncModel = Model(InpL, [Flatten()(EncOut), Z_Mean, Z_Log_Sigma], name='EncoderModel')
    
    return EncModel

# %% [markdown]
# ##### Debugging

# %%
#EncModel.save_weights('./Results/tmp.hdf5')
#EncModel.load_weights('./Results/tmp.hdf5')
#tmp = EncModel.predict(DATA[:100])[0]
#tmp = VAEM.predict(DATA[:100])
#plt.plot(tmp[0])

# %% [markdown]
# ### Decoder

# %%
def DecoderModel():

    InpZ = Input(shape=(LatDim,), name='InpZmean')
    EncReInp = Input(shape=(SigDim,))

    FiltPar = Dense(4, activation='relu')(InpZ)
    FiltPar = Dense(8, activation='relu')(FiltPar)
    FiltPar = Dense(4*3, activation='linear')(FiltPar) # Num. of parameters for filtering : 4, Num. of filtering : 3 

    LHFs = Activation('sigmoid')(FiltPar[:, :(4*3)//2])
    LHFs = Reshape((-1,2), name='LHFs')(LHFs)

    LHBs = Activation('softplus')(FiltPar[:, (4*3)//2:])
    LHBs = Reshape((-1,2), name='LHBs')(LHBs)


    
    ### Filtering level 1 -------------------------------------------------------------------
    ## Filter generation
    HPF_11 = GenHighFilter(LHFs[:, 0, 0:1], LHBs[:, 0, 0:1], N=301)
    LPF_11 = GenLowFilter(LHFs[:, 0, 1:2],  LHBs[:, 0, 1:2],  N=201)

    ## Perform signal filtering level 1
    InpFrame_11 =  tf.signal.frame(EncReInp, HPF_11.shape[-1], 1)
    HpSig_11 = tf.reduce_sum(InpFrame_11*HPF_11[:,:,::-1], axis=-1, keepdims=True)
    HpSig_11 = ReName(HpSig_11, 'HpSig_11')
    InpFrame_11 =  tf.signal.frame(EncReInp, LPF_11.shape[-1], 1)
    LpSig_11 = tf.reduce_sum(InpFrame_11*LPF_11[:,:,::-1], axis=-1, keepdims=True)
    LpSig_11 = ReName(LpSig_11, 'LpSig_11')


    ### Filtering level 21 (from HpSig_11) -------------------------------------------------------------------
    ## Filter generation
    HPF_21 = GenHighFilter(LHFs[:, 1, 0:1], LHBs[:, 1, 0:1], N=401)
    LPF_21 = GenLowFilter(LHFs[:, 1, 1:2],  LHBs[:, 1, 1:2],  N=301)

    ## Perform signal filtering level 2
    InpFrame_21 =  tf.signal.frame(HpSig_11[:,:,0], HPF_21.shape[-1], 1)
    HpSig_21 = tf.reduce_sum(InpFrame_21*HPF_21[:,:,::-1], axis=-1, keepdims=True)
    HpSig_21 = ReName(HpSig_21, 'HpSig_21')
    InpFrame_21 =  tf.signal.frame(HpSig_11[:,:,0], LPF_21.shape[-1], 1)
    LpSig_21 = tf.reduce_sum(InpFrame_21*LPF_21[:,:,::-1], axis=-1, keepdims=True)
    LpSig_21 = ReName(LpSig_21, 'LpSig_21')

    

    ### Filtering level 22 (from LpSig_11) -------------------------------------------------------------------
    ## Filter generation
    HPF_22 = GenHighFilter(LHFs[:, 2, 0:1], LHBs[:, 2, 0:1], N=301)
    LPF_22 = GenLowFilter(LHFs[:, 2, 1:2],  LHBs[:, 2, 1:2],  N=201)

    ## Perform signal filtering level 2
    InpFrame_22 =  tf.signal.frame(LpSig_11[:,:,0], HPF_22.shape[-1], 1)
    HpSig_22 = tf.reduce_sum(InpFrame_22*HPF_22[:,:,::-1], axis=-1, keepdims=True)
    HpSig_22 = ReName(HpSig_22, 'HpSig_22')

    InpFrame_22 =  tf.signal.frame(LpSig_11[:,:,0], LPF_22.shape[-1], 1)
    LpSig_22 = tf.reduce_sum(InpFrame_22*LPF_22[:,:,::-1], axis=-1, keepdims=True)
    LpSig_22 = ReName(LpSig_22, 'LpSig_22')
    
    

    ## GRU NET -------------------------------------------------------------------
    Dec_HpSig_11 = Reshape((-1, 100))(HpSig_11)
    Dec_LpSig_11 = Reshape((-1, 100))(LpSig_11)
    Dec_HpSig_21 = Reshape((-1, 100))(HpSig_21)
    Dec_LpSig_21 = Reshape((-1, 100))(LpSig_21)
    Dec_HpSig_22 = Reshape((-1, 100))(HpSig_22)
    Dec_LpSig_22 = Reshape((-1, 100))(LpSig_22)

    Dec_HpSig_11 = Bidirectional(GRU(5))(Dec_HpSig_11)
    Dec_LpSig_11 = Bidirectional(GRU(5))(Dec_LpSig_11)
    Dec_HpSig_21 = Bidirectional(GRU(5))(Dec_HpSig_21)
    Dec_LpSig_21 = Bidirectional(GRU(5))(Dec_LpSig_21)
    Dec_HpSig_22 = Bidirectional(GRU(5))(Dec_HpSig_22)
    Dec_LpSig_22 = Bidirectional(GRU(5))(Dec_LpSig_22)

    Decoder = tf.concat([Dec_HpSig_11, Dec_LpSig_11, Dec_HpSig_21, Dec_LpSig_21, Dec_HpSig_22, Dec_LpSig_22], axis=1)
    Decoder = RepeatVector((SigDim//100) )(Decoder)
    Decoder = Bidirectional(GRU(50, return_sequences=True))(Decoder)
    Decoder = TimeDistributed(Dense(100))(Decoder)
    #Decoder = Bidirectional(GRU(50, return_sequences=True))(Decoder)
    DecOut = Dense(100, activation='sigmoid')(Decoder)
    DecOut = Reshape((SigDim,),name='DecOut')(DecOut)
    DecModel = Model([EncReInp, InpZ], DecOut, name='DecoderModel')
    
    return DecModel

# %% [markdown]
# ### Vae Loss; RecMSE and KL Divergence¶

# %%
def VaeModel (EncModel, DecModel):
    
    VaeSFOut = DecModel([EncModel(EncModel.input)[0], EncModel(EncModel.input)[1]])
    VaeSFOut = Reshape((SigDim,), name='Out')(VaeSFOut)
    VaeSFModel = Model(EncModel.input, VaeSFOut, name='VaeSFModel')
    
    return VaeSFModel


EncModel = EncoderModel(training=True)
DecModel = DecoderModel()

### Vae Loss; KL Divergence
Z_Sampled, Z_Log_Sigma = EncModel.get_layer('Z_Sampled').output,EncModel.get_layer('Z_Log_Sigma').output
kl_Loss = 0.5 * tf.reduce_sum( Z_Sampled**2  +  tf.exp(Z_Log_Sigma)- Z_Log_Sigma-1, axis=1)    
kl_Loss = tf.reduce_mean(kl_Loss )

VaeSFModel = VaeModel(EncModel,DecModel )
VaeSFModel.compile(optimizer='adam', loss=tf.losses.mean_squared_error, metrics={"Out":'mse'})
#VaeSFModel.compile(optimizer='adam', loss=RECMSE, metrics={"VAEOut":'mse'})
VaeSFModel.add_loss(kl_Loss )
VaeSFModel.add_metric(kl_Loss, 'KL_D')

VaeSFModel.summary()
# Out:
# Model: "VaeSFModel"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 1000)]       0
# __________________________________________________________________________________________________
# EncoderModel (Functional)       [(None, 1000), (None 61314       input_1[0][0]
#                                                                  input_1[0][0]
# __________________________________________________________________________________________________
# DecoderModel (Functional)       (None, 1000)         73220       EncoderModel[0][0]
#                                                                  EncoderModel[1][1]
# __________________________________________________________________________________________________
# Out (Reshape)                   (None, 1000)         0           DecoderModel[0][0]
# __________________________________________________________________________________________________
# tf.signal.frame (TFOpLambda)    (None, 10, 100)      0           input_1[0][0]
# __________________________________________________________________________________________________
# gaussian_noise (GaussianNoise)  (None, 10, 100)      0           tf.signal.frame[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.shape (TFOpLambda) (3,)                 0           gaussian_noise[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem (Slici ()                   0           tf.compat.v1.shape[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply (TFOpLambda)   ()                   0           tf.__operators__.getitem[0][0]
# __________________________________________________________________________________________________
# tf.range (TFOpLambda)           (None,)              0           tf.math.multiply[0][0]
# __________________________________________________________________________________________________
# tf.random.shuffle (TFOpLambda)  (None,)              0           tf.range[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.shape_1 (TFOpLambd (1,)                 0           tf.random.shuffle[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1 (Sli ()                   0           tf.compat.v1.shape_1[0][0]
# __________________________________________________________________________________________________
# tf.cast (TFOpLambda)            ()                   0           tf.__operators__.getitem_1[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_1 (TFOpLambda) ()                   0           tf.cast[0][0]
# __________________________________________________________________________________________________
# tf.cast_1 (TFOpLambda)          ()                   0           tf.math.multiply_1[0][0]
# __________________________________________________________________________________________________
# tf.math.less (TFOpLambda)       (None,)              0           tf.random.shuffle[0][0]
#                                                                  tf.cast_1[0][0]
# __________________________________________________________________________________________________
# tf.cast_2 (TFOpLambda)          (None,)              0           tf.math.less[0][0]
# __________________________________________________________________________________________________
# tf.reshape (TFOpLambda)         (None, None)         0           tf.cast_2[0][0]
#                                                                  tf.__operators__.getitem[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_2 (Sli (None, None, 1)      0           tf.reshape[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_3 (TFOpLambda) (None, 10, 100)      0           gaussian_noise[0][0]
#                                                                  tf.__operators__.getitem_2[0][0]
# __________________________________________________________________________________________________
# masking (Masking)               (None, 10, 100)      0           tf.math.multiply_3[0][0]
# __________________________________________________________________________________________________
# bidirectional (Bidirectional)   (None, 10, 100)      45600       masking[0][0]
# __________________________________________________________________________________________________
# bidirectional_1 (Bidirectional) (None, 40)           14640       bidirectional[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 20)           820         bidirectional_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 10)           210         dense[0][0]
# __________________________________________________________________________________________________
# Z_Mean (Dense)                  (None, 2)            22          dense_1[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.shape_3 (TFOpLambd (2,)                 0           Z_Mean[0][0]
# __________________________________________________________________________________________________
# Z_Log_Sigma (Dense)             (None, 2)            22          dense_1[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_4 (Sli ()                   0           tf.compat.v1.shape_3[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_4 (TFOpLambda) (None, 2)            0           Z_Log_Sigma[0][0]
# __________________________________________________________________________________________________
# tf.random.normal_1 (TFOpLambda) (None, 2)            0           tf.__operators__.getitem_4[0][0]
# __________________________________________________________________________________________________
# tf.math.exp (TFOpLambda)        (None, 2)            0           tf.math.multiply_4[0][0]
# __________________________________________________________________________________________________
# Epsilon (Lambda)                (None, 2)            0           tf.random.normal_1[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_5 (TFOpLambda) (None, 2)            0           tf.math.exp[0][0]
#                                                                  Epsilon[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_1 (TFOpLam (None, 2)            0           Z_Mean[0][0]
#                                                                  tf.math.multiply_5[0][0]
# __________________________________________________________________________________________________
# Z_Sampled (Lambda)              (None, 2)            0           tf.__operators__.add_1[0][0]
# __________________________________________________________________________________________________
# tf.math.pow (TFOpLambda)        (None, 2)            0           Z_Sampled[0][0]
# __________________________________________________________________________________________________
# tf.math.exp_7 (TFOpLambda)      (None, 2)            0           Z_Log_Sigma[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_5 (TFOpLam (None, 2)            0           tf.math.pow[0][0]
#                                                                  tf.math.exp_7[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_6 (TFOpLambda) (None, 2)            0           tf.__operators__.add_5[0][0]
#                                                                  Z_Log_Sigma[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_7 (TFOpLambda) (None, 2)            0           tf.math.subtract_6[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_sum_12 (TFOpLamb (None,)              0           tf.math.subtract_7[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_54 (TFOpLambda (None,)              0           tf.math.reduce_sum_12[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_mean (TFOpLambda ()                   0           tf.math.multiply_54[0][0]
# __________________________________________________________________________________________________
# add_loss (AddLoss)              ()                   0           tf.math.reduce_mean[0][0]
# __________________________________________________________________________________________________
# add_metric (AddMetric)          ()                   0           tf.math.reduce_mean[0][0]
# ==================================================================================================
# Total params: 134,534
# Trainable params: 134,534
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
#VaeSFModel.load_weights(ModelSaveSameName)
ModelSave = ModelCheckpoint(filepath=ModelSaveSameName, monitor='val_mse', verbose=1, save_best_only=True )

VaeSFModel.fit(DATA[:], DATA[:], batch_size=1000, epochs=500, shuffle=True, validation_split=0.2, callbacks=[ModelSave, EarlyStop])
# Out:
# Epoch 1/500
# 320/320 [==============================] - 107s 276ms/step - loss: 0.1528 - mse: 0.0144 - KL_D: 0.0622 - val_loss: 0.0179 - val_mse: 0.0074 - val_KL_D: 0.0105
#
# Epoch 00001: val_mse improved from inf to 0.00739, saving model to ./Results\VaeSFModel.hdf5
# WARNING:tensorflow:Found duplicated `Variable`s in Model's `weights`. This is usually caused by `Variable`s being shared by Layers in the Model. These `Variable`s will be treated as separate `Variable`s when the Model is restored. To avoid this, please save with `save_format="tf"`.
# Epoch 2/500
# 320/320 [==============================] - 86s 269ms/step - loss: 0.0174 - mse: 0.0070 - KL_D: 0.0103 - val_loss: 0.0158 - val_mse: 0.0057 - val_KL_D: 0.0101
#
# Epoch 00002: val_mse improved from 0.00739 to 0.00570, saving model to ./Results\VaeSFModel.hdf5
# WARNING:tensorflow:Found duplicated `Variable`s in Model's `weights`. This is usually caused by `Variable`s being shared by Layers in the Model. These `Variable`s will be treated as separate `Variable`s when the Model is restored. To avoid this, please save with `save_format="tf"`.
# Epoch 3/500
# 320/320 [==============================] - 86s 268ms/step - loss: 0.0156 - mse: 0.0054 - KL_D: 0.0102 - val_loss: 0.0146 - val_mse: 0.0045 - val_KL_D: 0.0102
#
# Epoch 00003: val_mse improved from 0.00570 to 0.00447, saving model to ./Results\VaeSFModel.hdf5
# WARNING:tensorflow:Found duplicated `Variable`s in Model's `weights`. This is usually caused by `Variable`s being shared by Layers in the Model. These `Variable`s will be treated as separate `Variable`s when the Model is restored. To avoid this, please save with `save_format="tf"`.
# Epoch 4/500
# 320/320 [==============================] - 85s 264ms/step - loss: 0.0144 - mse: 0.0043 - KL_D: 0.0102 - val_loss: 0.0137 - val_mse: 0.0036 - val_KL_D: 0.0101
#
# Epoch 00004: val_mse improved from 0.00447 to 0.00363, saving model to ./Results\VaeSFModel.hdf5
# WARNING:tensorflow:Found duplicated `Variable`s in Model's `weights`. This is usually caused by `Variable`s being shared by Layers in the Model. These `Variable`s will be treated as separate `Variable`s when the Model is restored. To avoid this, please save with `save_format="tf"`.
# Epoch 5/500
# 320/320 [==============================] - 85s 265ms/step - loss: 0.0135 - mse: 0.0034 - KL_D: 0.0101 - val_loss: 0.0129 - val_mse: 0.0029 - val_KL_D: 0.0100
#
# Epoch 00005: val_mse improved from 0.00363 to 0.00286, saving model to ./Results\VaeSFModel.hdf5
# WARNING:tensorflow:Found duplicated `Variable`s in Model's `weights`. This is usually caused by `Variable`s being shared by Layers in the Model. These `Variable`s will be treated as separate `Variable`s when the Model is restored. To avoid this, please save with `save_format="tf"`.
# Epoch 6/500
# 320/320 [==============================] - 82s 256ms/step - loss: 0.0128 - mse: 0.0027 - KL_D: 0.0101 - val_loss: 0.0125 - val_mse: 0.0024 - val_KL_D: 0.0101
#
# Epoch 00006: val_mse improved from 0.00286 to 0.00244, saving model to ./Results\VaeSFModel.hdf5
# WARNING:tensorflow:Found duplicated `Variable`s in Model's `weights`. This is usually caused by `Variable`s being shared by Layers in the Model. These `Variable`s will be treated as separate `Variable`s when the Model is restored. To avoid this, please save with `save_format="tf"`.
# Epoch 7/500
# 320/320 [==============================] - 82s 256ms/step - loss: 0.0125 - mse: 0.0024 - KL_D: 0.0101 - val_loss: 0.0122 - val_mse: 0.0022 - val_KL_D: 0.0101
#
# Epoch 00007: val_mse improved from 0.00244 to 0.00216, saving model to ./Results\VaeSFModel.hdf5
# WARNING:tensorflow:Found duplicated `Variable`s in Model's `weights`. This is usually caused by `Variable`s being shared by Layers in the Model. These `Variable`s will be treated as separate `Variable`s when the Model is restored. To avoid this, please save with `save_format="tf"`.
# Epoch 8/500
# 320/320 [==============================] - 88s 275ms/step - loss: 0.0123 - mse: 0.0021 - KL_D: 0.0101 - val_loss: 0.0121 - val_mse: 0.0019 - val_KL_D: 0.0101
#
# Epoch 00008: val_mse improved from 0.00216 to 0.00195, saving model to ./Results\VaeSFModel.hdf5
# WARNING:tensorflow:Found duplicated `Variable`s in Model's `weights`. This is usually caused by `Variable`s being shared by Layers in the Model. These `Variable`s will be treated as separate `Variable`s when the Model is restored. To avoid this, please save with `save_format="tf"`.
# Epoch 9/500
# 320/320 [==============================] - 87s 271ms/step - loss: 0.0120 - mse: 0.0019 - KL_D: 0.0101 - val_loss: 0.0118 - val_mse: 0.0018 - val_KL_D: 0.0101
#
# Epoch 00009: val_mse improved from 0.00195 to 0.00177, saving model to ./Results\VaeSFModel.hdf5
# WARNING:tensorflow:Found duplicated `Variable`s in Model's `weights`. This is usually caused by `Variable`s being shared by Layers in the Model. These `Variable`s will be treated as separate `Variable`s when the Model is restored. To avoid this, please save with `save_format="tf"`.
# Epoch 10/500
# 229/320 [====================>.........] - ETA: 22s - loss: 0.0118 - mse: 0.0017 - KL_D: 0.0101

# %% [markdown]
# ### Post analysis

# %%
EncModel = EncoderModel(training=False)
DecModel = DecoderModel()

### Vae Loss; KL Divergence
Z_Mean, Z_Log_Sigma = EncModel.get_layer('Z_Mean').output,EncModel.get_layer('Z_Log_Sigma').output

kl_Loss = 0.5 * tf.reduce_sum( Z_Mean**2  +  tf.exp(Z_Log_Sigma)- Z_Log_Sigma-1, axis=1)    
kl_Loss = tf.reduce_mean(kl_Loss )

VaeSFModel = VaeModel(EncModel,DecModel )
VaeSFModel.add_loss(kl_Loss )
VaeSFModel.add_metric(kl_Loss, 'KL_D')

# %% [markdown]
# #### Rec pred by zMean

# %%
VaeSFModel.load_weights(ModelSaveSameName)
VaeSFModel.compile(optimizer='adam', loss=tf.losses.mean_squared_error, metrics={"Out":'mse'})

#Pred =VAEM.predict(DATA[:], batch_size=1000, verbose=1)
VaeSFModel.evaluate(DATA[:], DATA[:], batch_size=2000, verbose=1)
#np.mean((DATA[:]- Pred)**2)
# Out:
# 200/200 [==============================] - 18s 57ms/step - loss: 0.0010 - mse: 0.0010 - KL_D: 1.5386e-05
# [0.0010230086045339704, 0.0010076225735247135, 1.5386229279101826e-05]

# %% [markdown]
# #### Components pred

# %%
VaeSFModel.load_weights(ModelSaveSameName)

HpSig_11 = DecModel.get_layer('HpSig_11').output
LpSig_11 = DecModel.get_layer('LpSig_11').output
HpSig_21 = DecModel.get_layer('HpSig_21').output
LpSig_21 = DecModel.get_layer('LpSig_21').output
HpSig_22 = DecModel.get_layer('HpSig_22').output
LpSig_22 = DecModel.get_layer('LpSig_22').output

LHFs = DecModel.get_layer('LHFs').output
LHBs = DecModel.get_layer('LHBs').output

LatM = Model(DecModel.input, [HpSig_11, LpSig_11, HpSig_21, LpSig_21, HpSig_22, LpSig_22 ])
ParaM = Model(DecModel.input, [LHFs, LHBs ])


Pred_ZMean = Model(EncModel.input, EncModel.get_layer('Z_Mean').output).predict(DATA[:10])
PredLat = LatM.predict([DATA[:10],Pred_ZMean] )
PredPara = ParaM.predict([DATA[:10],Pred_ZMean] )
Pred =VaeSFModel.predict(DATA[:10])
# Out:
# WARNING:tensorflow:5 out of the last 12 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001D3E2C0BEE0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %% [markdown]
# #### Variational pred

# %%
Pred_ZSampled = np.array([np.linspace(-30, 30, 10), np.linspace(-30, 30, 10)]).T
DataSample = np.tile(DATA[1:2].T, 10).T
PredLat = LatM.predict([DataSample,Pred_ZSampled] )

idx = 4
#plt.plot(DATA[idx])
for i in range(9):
    plt.plot(PredLat[idx][i, :1000, 0])
    #print(PredLat[i].shape)

# %%
PredLat[0].shape
# Out:
# (10, 700, 1)

# %%
idx = 0
plt.plot(DATA[idx])
for i in range(6):
    plt.plot(PredLat[i][idx, :1000, 0])
    #print(PredLat[i].shape)

# %%
idx = 0
plt.plot(PredLat[0][idx, :1000, 0])
plt.plot(PredLat[2][idx, :1000, 0])

# %%
plt.plot(PredLat[1][idx, :, 0])
plt.plot(PredLat[3][idx, :, 0])
plt.plot(PredLat[4][idx, :, 0])
plt.plot(PredLat[5][idx, :, 0])

# %%
idx= 0
plt.plot(Pred[idx], c='red')
plt.plot(DATA[idx])

# %%
# Out:
# 100
