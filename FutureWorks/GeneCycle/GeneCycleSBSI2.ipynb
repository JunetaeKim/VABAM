# %%
import sys
# setting path
sys.path.append('../../')

import os
import re
import numpy as np
import matplotlib.pyplot as plt
import copy
from argparse import ArgumentParser

from Models.MainModel import *
from Models.Losses import *

from Utilities.Utilities import ReadYaml, SerializeObjects, DeserializeObjects, LoadModelConfigs, LoadParams
from tqdm import trange, tqdm
import itertools
from scipy.stats import mode
import pandas as pd
import matplotlib.pyplot as plt

## GPU selection
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]= "1"

# TensorFlow wizardry
config = tf.compat.v1.ConfigProto()
# Don't pre-allocate memory; allocate as-needed
config.gpu_options.allow_growth = True
# Only allow a total of half the GPU memory to be allocated
config.gpu_options.per_process_gpu_memory_fraction = 1.0
# Create a session with the above options specified.
tf.compat.v1.keras.backend.set_session(tf.compat.v1.Session(config=config))
# Out:
# WARNING:tensorflow:From C:\Users\USER\AppData\Local\Temp\ipykernel_572\2724155336.py:33: The name tf.keras.backend.set_session is deprecated. Please use tf.compat.v1.keras.backend.set_session instead.

# %%
Test1 = pd.read_excel('./Data/data.xlsx', sheet_name='test1').values[:,1]
Test2 = pd.read_excel('./Data/data.xlsx', sheet_name='test2').values[:,1]
Test3 = pd.read_excel('./Data/data.xlsx', sheet_name='test3').values[:,1]
Test4 = pd.read_excel('./Data/data.xlsx', sheet_name='test4').values[:,1]

RhythmicData = pd.read_csv('./Data/RhythmicData.csv').values
DataSize=len(RhythmicData) 

'''
SigDim = len(Test4)
CompSize = 130
FiltLen = (SigDim - CompSize)//2 + 1
'''
# Out:
# '\nSigDim = len(Test4)\nCompSize = 130\nFiltLen = (SigDim - CompSize)//2 + 1\n'

# %%
plt.plot(Test1)
plt.plot(Test2)
plt.plot(Test3)
plt.plot(Test4)

# %%
idx = 2
plt.plot(RhythmicData[idx])

# %%
def MaskingGen ( InpRegul, MaskingRate, MaskStd):
    ## Masking vector generation 1 vs 0
    NBatch = tf.shape(InpRegul)[0]
    
    MaskIDX = tf.random.shuffle(tf.range(NBatch * InpRegul.shape[1] ))
    CutIDX = tf.cast(  tf.cast(tf.shape(MaskIDX)[0], dtype=tf.float32) * (1-MaskingRate), dtype=tf.int32 )
    MaskIDX = tf.cast(MaskIDX < CutIDX, dtype=tf.float32)
    MaskVec = tf.reshape(MaskIDX, (NBatch, -1))[:,:,None]
    
    ## Noise vector generation 1 vs 0; Enocder 에서는 masking {0 vs 1}을 통해 BP가 되지 않도록 제어; Filtering (feature extracting) part에서는 encoder에서 masking 된 부분에 noise를 추가해줌
    RevMaskIDX = MaskIDX == 0
    RevMaskIDX = tf.cast(RevMaskIDX, dtype=tf.float32)
    NoisVec = RevMaskIDX * tf.random.normal(tf.shape(RevMaskIDX), stddev=MaskStd)
    NoisVec = tf.reshape(NoisVec, (NBatch, -1))[:,:,None]
    return MaskVec, NoisVec


def GenLowFilter (LF, N, Decay=0.):
    nVec = np.arange(N, dtype=np.float32)
    Window = tf.signal.hamming_window(N)

    # A low-pass filter
    X = 2 * LF * (nVec - (N - 1) / 2)
    X = tf.where(X == 0, 1e-7, X)
    LPF = tf.sin(np.pi*X)/(np.pi*X)
    LPF *= Window
    LPF /= tf.reduce_sum(LPF, axis=-1, keepdims=True)
    
    # Freq cutoff Decay effect
    if Decay != 0:
        LPF *= tf.exp(-Decay * nVec) 
        #LPF *= tf.exp(-LF * Decay * nVec) 
        
    
    return LPF[:,None] 


def GenHighFilter (HF, N, Decay=0.):
    nVec = np.arange(N, dtype=np.float32)
    Window = tf.signal.hamming_window(N)

    # A high-pass filter
    Y = 2 * HF * (nVec - (N - 1) / 2)
    Y = tf.where(Y == 0, 1e-7, Y)
    HPF = tf.sin(np.pi*Y)/(np.pi*Y)
    HPF *= Window
    HPF /= tf.reduce_sum(HPF, axis=-1, keepdims=True)
    HPF = -HPF

    ## To make HPF[(N - 1) // 2] += 1
    Mask = np.zeros(HPF.shape[1])
    Mask[(N - 1) // 2] += 1
    Mask = tf.constant(Mask, dtype=tf.float32)
    HPF = HPF + Mask
    
    # Freq cutoff Decay effect
    if Decay != 0:
        HPF *= tf.exp(-Decay * nVec) 
        #HPF *= tf.exp(-HF * Decay * nVec) 
    
    return HPF[:,None]

# %%
def Encoder(SigDim, SlidingSize = 50, LatDim= 2, Type = '', ReparaStd = 0.1 , Reparam = False, FcLimit=0.05):

    InpL = Input(shape=(SigDim,), name='Inp_Enc')
    InpFrame = tf.signal.frame(InpL, SlidingSize, SlidingSize)

   
    Encoder = Bidirectional(GRU(5, return_sequences=True))(InpFrame)
    Encoder = Bidirectional(GRU(10, return_sequences=False))(Encoder)
    Encoder = Dense(10, activation='relu')(Encoder)
    Encoder = Dense(10, activation='relu')(Encoder)
    
    Z_Mu = Dense(LatDim, activation='linear', name='Z_Mu')(Encoder)
    Z_Log_Sigma = Dense(LatDim, activation='softplus')(Encoder)
    Z_Log_Sigma = ReName(Z_Log_Sigma,'Z_Log_Sigma')
    
    
    # Reparameterization Trick for sampling from Guassian distribution
    Epsilon = tf.random.normal(shape=(tf.shape(Z_Mu)[0], Z_Mu.shape[1]), mean=0., stddev=ReparaStd)
    
    if Reparam==False:
        Epsilon = Epsilon * 0
    
    Zs = Z_Mu + tf.exp(0.5 * Z_Log_Sigma) * Epsilon
    Zs = ReName(Zs,'Zs')
    
    FC_Mu =   Dense(6, activation='relu')(Encoder)
    FC_Mu =   Dense(6, activation='sigmoid')(FC_Mu)
    FC_Mu = tf.clip_by_value(FC_Mu, 1e-7, 1-1e-7)
    FC_Mu = ReName(FC_Mu,'FC_Mu')
    
    # Reparameterization Trick for sampling from Uniformly distribution; ϵ∼U(0,1) 
    Epsilon = tf.random.uniform(shape=(tf.shape(FC_Mu)[0], FC_Mu.shape[1]))
    Epsilon = tf.clip_by_value(Epsilon, 1e-7, 1-1e-7)
    
    LogEps = tf.math.log(Epsilon)
    LogNegEps = tf.math.log(1 - Epsilon)
    
    LogTheta = tf.math.log(FC_Mu)
    LogNegTheta = tf.math.log(1-FC_Mu)
    
    if Reparam==True:
        FCs = tf.math.sigmoid(LogEps - LogNegEps + LogTheta - LogNegTheta) * 1. + FC_Mu * 0.
    else:
        FCs = tf.math.sigmoid(LogEps - LogNegEps + LogTheta - LogNegTheta) * 0. + FC_Mu * 1.
    
    FCs = FCs * FcLimit
    FCs = tf.clip_by_value(FCs, 1e-7, FcLimit-1e-7)
    FCs = ReName(FCs, 'FCs')
    
    return Model(InpL, [Flatten()(InpFrame), FCs, Zs], name='EncModel')

# %%
## --------------------------------------------------   FeatExtractor  -------------------------------------------------------------
def FeatExtractor(SigDim, LatDim= 2, CompSize = 600, DecayH = 0. , DecayL = 0. ):
    
    FiltLen = (SigDim - CompSize)//2 + 1
    
    EncReInp = Input(shape=(SigDim,), name='Inp_EncRe')
    FCs = Input(shape=(6,), name='Inp_FCs')
    
    H_F, L_F, HH_F, HL_F, LH_F, LL_F = tf.split(FCs, 6, axis=1)
    

    ### Filtering level 1 -------------------------------------------------------------------
    ## Filter generation
    To_H = GenHighFilter(H_F,  N=FiltLen, Decay=DecayH)
    To_L = GenLowFilter(L_F, N=FiltLen, Decay=DecayL)

    ## Perform signal filtering level 1
    InpFrame =  tf.signal.frame(EncReInp, To_H.shape[-1], 1)
    Sig_H = tf.reduce_sum(InpFrame*To_H[:,:,::-1], axis=-1, keepdims=True)
    Sig_H = ReName(Sig_H, 'Sig_H_Ext')

    InpFrame =  tf.signal.frame(EncReInp, To_L.shape[-1], 1)
    Sig_L = tf.reduce_sum(InpFrame*To_L[:,:,::-1], axis=-1, keepdims=True)
    Sig_L = ReName(Sig_L, 'Sig_L_Ext')



    ### Filtering level HH and HL (from Sig_H) -------------------------------------------------------------------
    ## Filter generation
    To_HH = GenHighFilter(HH_F, N=FiltLen, Decay=DecayH)
    To_HL = GenLowFilter(HL_F, N=FiltLen, Decay=DecayL)

    ## Perform signal filtering level 2
    Frame_H =  tf.signal.frame(Sig_H[:,:,0], To_HH.shape[-1], 1)
    Sig_HH = tf.reduce_sum(Frame_H*To_HH[:,:,::-1], axis=-1, keepdims=True)
    Sig_HH = Flatten(name='Sig_HH_Ext')(Sig_HH)

    Frame_H =  tf.signal.frame(Sig_H[:,:,0], To_HL.shape[-1], 1)
    Sig_HL = tf.reduce_sum(Frame_H*To_HL[:,:,::-1], axis=-1, keepdims=True)
    Sig_HL = Flatten(name='Sig_HL_Ext')(Sig_HL)


    ### Filtering level LH and LL (from Sig_L) -------------------------------------------------------------------
    ## Filter generation
    To_LH = GenHighFilter(LH_F,  N=FiltLen, Decay=DecayH)
    To_LL = GenLowFilter(LL_F,  N=FiltLen, Decay=DecayL)

    ## Perform signal filtering level 2
    Frame_L =  tf.signal.frame(Sig_L[:,:,0], To_LH.shape[-1], 1)
    Sig_LH = tf.reduce_sum(Frame_L*To_LH[:,:,::-1], axis=-1, keepdims=True)
    Sig_LH = Flatten(name='Sig_LH_Ext')(Sig_LH)

    Frame_L =  tf.signal.frame(Sig_L[:,:,0], To_LL.shape[-1], 1)
    Sig_LL = tf.reduce_sum(Frame_L*To_LL[:,:,::-1], axis=-1, keepdims=True)
    Sig_LL = Flatten(name='Sig_LL_Ext')(Sig_LL)

    
    return Model([EncReInp, FCs], [Sig_HH, Sig_HL, Sig_LH, Sig_LL], name='FeatExtModel')

# %%
## --------------------------------------------------   FeatGenerator  -------------------------------------------------------------
def FeatGenerator (SigDim, CompSize, LatDim= 2, SlidingSize= 50):
    
    InpZ = Input(shape=(LatDim,), name='Inp_Z')
    FCCommon = Input(shape=(2,), name='Inp_FCCommon')
    FCEach = Input(shape=(4,), name='Inp_FCEach')
    
    HH_F, HL_F, LH_F, LL_F = tf.split(FCEach, 4, axis=1)
    
    
    Dec_Sig_HH = Dense(10, activation='relu')(tf.concat([InpZ, FCCommon, HH_F], axis=-1))
    Dec_Sig_HH = Dense(10, activation='relu')(Dec_Sig_HH)
    Dec_Sig_HH = RepeatVector(SigDim//SlidingSize )(Dec_Sig_HH)
    Dec_Sig_HH = Bidirectional(GRU(5, return_sequences=True))(Dec_Sig_HH)
    Dec_Sig_HH = Bidirectional(GRU(5, return_sequences=False))(Dec_Sig_HH)
    Dec_Sig_HH = Dense(CompSize,'tanh')(Dec_Sig_HH)
    Sig_HH= Flatten(name='Sig_HH_Gen')(Dec_Sig_HH)
    
    
    Dec_Sig_HL = Dense(10, activation='relu')(tf.concat([InpZ, FCCommon, HL_F], axis=-1))
    Dec_Sig_HL = Dense(10, activation='relu')(Dec_Sig_HL)
    Dec_Sig_HL = RepeatVector(SigDim//SlidingSize )(Dec_Sig_HL)
    Dec_Sig_HL = Bidirectional(GRU(5, return_sequences=True))(Dec_Sig_HL)
    Dec_Sig_HL = Bidirectional(GRU(5, return_sequences=False))(Dec_Sig_HL)
    Dec_Sig_HL = Dense(CompSize,'tanh')(Dec_Sig_HL)
    Sig_HL= Flatten(name='Sig_HL_Gen')(Dec_Sig_HL)
    
    
    Dec_Sig_LH = Dense(10, activation='relu')(tf.concat([InpZ, FCCommon, LH_F], axis=-1))
    Dec_Sig_LH = Dense(10, activation='relu')(Dec_Sig_LH)
    Dec_Sig_LH = RepeatVector(SigDim//SlidingSize )(Dec_Sig_LH)
    Dec_Sig_LH = Bidirectional(GRU(5, return_sequences=True))(Dec_Sig_LH)
    Dec_Sig_LH = Bidirectional(GRU(5, return_sequences=False))(Dec_Sig_LH)
    Dec_Sig_LH = Dense(CompSize,'tanh')(Dec_Sig_LH)
    Sig_LH= Flatten(name='Sig_LH_Gen')(Dec_Sig_LH)
    
    
    Dec_Sig_LL = Dense(10, activation='relu')(tf.concat([InpZ, FCCommon, LL_F], axis=-1))
    Dec_Sig_LL = Dense(10, activation='relu')(Dec_Sig_LL)
    Dec_Sig_LL = RepeatVector(SigDim//SlidingSize )(Dec_Sig_LL)
    Dec_Sig_LL = Bidirectional(GRU(5, return_sequences=True))(Dec_Sig_LL)
    Dec_Sig_LL = Bidirectional(GRU(5, return_sequences=False))(Dec_Sig_LL)
    Dec_Sig_LL = Dense(CompSize,'tanh')(Dec_Sig_LL)
    Sig_LL = Flatten(name='Sig_LL_Gen')(Dec_Sig_LL)
        
    return  Model([FCCommon, FCEach, InpZ], [Sig_HH, Sig_HL, Sig_LH, Sig_LL], name='FeatGenModel')

# %%
def Reconstructor(SigDim , SlidingSize = 50, CompSize=600 ):
    
    Sig_HH = Input(shape=(CompSize,), name='Inp_Sig_HH')
    Sig_HL = Input(shape=(CompSize,), name='Inp_Sig_HL')
    Sig_LH = Input(shape=(CompSize,), name='Inp_Sig_LH')
    Sig_LL = Input(shape=(CompSize,), name='Inp_Sig_LL')
    

    ## GRU NET -------------------------------------------------------------------
    Dec_Sig_HH = Reshape((-1, SlidingSize))(Sig_HH)
    Dec_Sig_HL = Reshape((-1, SlidingSize))(Sig_HL)
    Dec_Sig_LH = Reshape((-1, SlidingSize))(Sig_LH)
    Dec_Sig_LL = Reshape((-1, SlidingSize))(Sig_LL)

    Dec_Sig_HH = Bidirectional(GRU(5), name='Dec_Sig_HH')(Dec_Sig_HH)
    Dec_Sig_HL = Bidirectional(GRU(5), name='Dec_Sig_HL')(Dec_Sig_HL)
    Dec_Sig_LH = Bidirectional(GRU(5), name='Dec_Sig_LH')(Dec_Sig_LH)
    Dec_Sig_LL = Bidirectional(GRU(5), name='Dec_Sig_LL')(Dec_Sig_LL)

    Decoder = tf.concat([ Dec_Sig_HH, Dec_Sig_HL, Dec_Sig_LH, Dec_Sig_LL], axis=1)
    Decoder = Dense(Decoder.shape[-1], activation='relu')(Decoder)
    Decoder = Dense(Decoder.shape[-1], activation='relu')(Decoder)
    Decoder = Dense(Decoder.shape[-1], activation='relu')(Decoder)
    Decoder = Dense(Decoder.shape[-1], activation='relu')(Decoder)
    Decoder = RepeatVector((SigDim//SlidingSize) )(Decoder)
    Decoder = Bidirectional(GRU(5, return_sequences=True))(Decoder)
    Decoder = Bidirectional(GRU(5, return_sequences=True))(Decoder)
    DecOut = Dense(SlidingSize,'sigmoid')(Decoder)
    DecOut = Reshape((SigDim,),name='Out')(DecOut)

    return Model([Sig_HH, Sig_HL, Sig_LH, Sig_LL], DecOut, name='ReconModel')

# %%
def CustMSE_NLL(y_true, y_pred, Type='MSE', Sigma=1., HybRate = 0.85, NLLScale= 1e-7):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)

    if Type =='MSE':
        return tf.reduce_mean(tf.square(y_pred - y_true))
    elif Type =='NLL':
        # mu : y_true
        # x : y_pred
        nll = 0.5 * tf.math.log(2 * tf.constant(np.pi) * Sigma**2) + ((y_pred - y_true)**2 / (2 * Sigma**2))
        return  tf.reduce_sum(nll) * NLLScale

    elif Type =='MSENLL':
        MSE = tf.reduce_mean(tf.square(y_pred - y_true))
        nll = 0.5 * tf.math.log(2 * tf.constant(np.pi) * Sigma**2) + ((y_pred - y_true)**2 / (2 * Sigma**2))
        return HybRate*MSE  + (1-HybRate)*tf.reduce_sum(nll) * NLLScale

# %%
def DefLosses (Models, Beta_Z=1, Beta_Fc=1, Beta_Orig=1, Beta_Feat=1, Capacity_Z=0.05, Capacity_Fc=0.005):
    
    ###-------------------------------- Model structuring -------------------------------------------- ###
    ## Model core parts
    EncModel,FeatExtModel,FeatGenModel,ReconModel =  Models
    EncInp =EncModel.input
    InpZ = EncModel.output[2]
    InpFCCommon = EncModel.output[1][:, :2]
    InpFCEach = EncModel.output[1][:, 2:]

    ## Each output of each model
    FeatExtOut = FeatExtModel(EncModel.output[:2])
    FeatGenOut = FeatGenModel([InpFCCommon, InpFCEach, InpZ])
    ReconExtOut = ReconModel(FeatExtOut)
    ReconGenOut = ReconModel(FeatGenOut)
    
    ### Define the total model
    SigRepModel = Model(EncInp, [FeatGenOut, ReconExtOut, ReconGenOut])
    
    
    ###-------------------------------- Common losses -------------------------------------------- ###
    ### Adding the RecLoss; 
    ReconOut_ext = Beta_Orig * CustMSE_NLL(ReconExtOut, EncInp)

    SigRepModel.add_loss(ReconOut_ext)
    SigRepModel.add_metric(ReconOut_ext, 'OrigRecLoss')
    print('OrigRecLoss added')

    ### Adding the FeatRecLoss; It allows connection between the extractor and generator
    FeatRecLoss= Beta_Feat * CustMSE_NLL(tf.concat(FeatGenOut, axis=-1), tf.concat(FeatExtOut, axis=-1))

    SigRepModel.add_loss(FeatRecLoss)
    SigRepModel.add_metric(FeatRecLoss, 'FeatRecLoss')
    print('FeatRecLoss added')


    ###-------------------------------- Specific losses -------------------------------------------- ###
    ### KL Divergence for p(Z) vs q(Z)
    Z_Mu, Z_Log_Sigma, Zs = SigRepModel.get_layer('Z_Mu').output, SigRepModel.get_layer('Z_Log_Sigma').output, SigRepModel.get_layer('Zs').output
    kl_Loss_Z = 0.5 * tf.reduce_sum( Z_Mu**2  +  tf.exp(Z_Log_Sigma)- Z_Log_Sigma-1, axis=1)    
    kl_Loss_Z = tf.reduce_mean(kl_Loss_Z )
    kl_Loss_Z = Beta_Z * tf.abs(kl_Loss_Z - Capacity_Z)
    SigRepModel.add_loss(kl_Loss_Z )
    SigRepModel.add_metric(kl_Loss_Z , 'kl_Loss_Z')
    print('kl_Loss_Z added')
    
    ### KL Divergence for p(FC) vs q(FC)
    BernP = tf.cast(0.5, tf.float32) # hyperparameter
    FC_Mu = SigRepModel.get_layer('FC_Mu').output 
    FC_Mu = tf.cast(FC_Mu, tf.float32)
    kl_Loss_FC = FC_Mu*(tf.math.log(FC_Mu) - tf.math.log(BernP)) + (1-FC_Mu)*(tf.math.log(1-FC_Mu) - tf.math.log(1-BernP))
    kl_Loss_FC = tf.reduce_mean(kl_Loss_FC )
    kl_Loss_FC = Beta_Fc * tf.abs(kl_Loss_FC - Capacity_Fc)
    SigRepModel.add_loss(kl_Loss_FC )
    SigRepModel.add_metric(kl_Loss_FC , 'kl_Loss_FC')
    print('kl_Loss_FC added')
    
        
    return SigRepModel

# %%
SigDim = RhythmicData.shape[-1]
CompSize = 10
FiltLen = (SigDim - CompSize)//2 + 1

LatDim = 10
MaskingRate = 0
FcLimit = 1.
SlidingSize= 1
ReparaStd = 0.1 
Reparam = True
LossType = 'Default'
SelConfigSet = {'SpecLosses':['SKZ','FC'], 'Capacity_Z':0.05, 'Capacity_Fc':0.005}

# %%
# Defining Modesl
EncModel = Encoder(SigDim=SigDim, LatDim= LatDim,  Reparam=Reparam, FcLimit=FcLimit, SlidingSize=SlidingSize)
FeatExtModel = FeatExtractor(SigDim=SigDim, CompSize = CompSize)
FeatGenModel = FeatGenerator(SigDim=SigDim,CompSize= FeatExtModel.output[0].shape[-1], LatDim= LatDim, SlidingSize=SlidingSize)
ReconModel = Reconstructor(SigDim=SigDim, CompSize= FeatExtModel.output[0].shape[-1], SlidingSize=SlidingSize)



Models = [EncModel,FeatExtModel,FeatGenModel,ReconModel] 
SigRepModel = DefLosses(Models, Beta_Z=0.001, Beta_Fc=1, Beta_Orig=1, Beta_Feat=2, Capacity_Z=0.05, Capacity_Fc=0.005)
ModelParts = [EncModel, FeatExtModel, FeatGenModel, ReconModel]

# Model Compile
SigRepModel.compile(optimizer='adam') 
SigRepModel.summary()
# Out:
# OrigRecLoss added
# FeatRecLoss added
# kl_Loss_Z added
# kl_Loss_FC added
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  Inp_Enc (InputLayer)           [(None, 13)]         0           []
#
#  tf.signal.frame_7 (TFOpLambda)  (None, 13, 1)       0           ['Inp_Enc[0][0]']
#
#  bidirectional_12 (Bidirectiona  (None, 13, 10)      240         ['tf.signal.frame_7[0][0]']
#  l)
#
#  bidirectional_13 (Bidirectiona  (None, 20)          1320        ['bidirectional_12[0][0]']
#  l)
#
#  dense_22 (Dense)               (None, 10)           210         ['bidirectional_13[0][0]']
#
#  dense_23 (Dense)               (None, 10)           110         ['dense_22[0][0]']
#
#  dense_25 (Dense)               (None, 6)            66          ['dense_23[0][0]']
#
#  dense_26 (Dense)               (None, 6)            42          ['dense_25[0][0]']
#
#  tf.clip_by_value_3 (TFOpLambda  (None, 6)           0           ['dense_26[0][0]']
#  )
#
#  FC_Mu (Lambda)                 (None, 6)            0           ['tf.clip_by_value_3[0][0]']
#
#  tf.compat.v1.shape_3 (TFOpLamb  (2,)                0           ['FC_Mu[0][0]']
#  da)
#
#  tf.__operators__.getitem_21 (S  ()                  0           ['tf.compat.v1.shape_3[0][0]']
#  licingOpLambda)
#
#  tf.random.uniform_1 (TFOpLambd  (None, 6)           0           ['tf.__operators__.getitem_21[0][
#  a)                                                              0]']
#
#  tf.clip_by_value_4 (TFOpLambda  (None, 6)           0           ['tf.random.uniform_1[0][0]']
#  )
#
#  tf.math.subtract_14 (TFOpLambd  (None, 6)           0           ['tf.clip_by_value_4[0][0]']
#  a)
#
#  tf.math.log_6 (TFOpLambda)     (None, 6)            0           ['tf.clip_by_value_4[0][0]']
#
#  tf.math.log_7 (TFOpLambda)     (None, 6)            0           ['tf.math.subtract_14[0][0]']
#
#  tf.math.subtract_16 (TFOpLambd  (None, 6)           0           ['tf.math.log_6[0][0]',
#  a)                                                               'tf.math.log_7[0][0]']
#
#  tf.math.log_8 (TFOpLambda)     (None, 6)            0           ['FC_Mu[0][0]']
#
#  tf.math.subtract_15 (TFOpLambd  (None, 6)           0           ['FC_Mu[0][0]']
#  a)
#
#  tf.__operators__.add_9 (TFOpLa  (None, 6)           0           ['tf.math.subtract_16[0][0]',
#  mbda)                                                            'tf.math.log_8[0][0]']
#
#  tf.math.log_9 (TFOpLambda)     (None, 6)            0           ['tf.math.subtract_15[0][0]']
#
#  tf.math.subtract_17 (TFOpLambd  (None, 6)           0           ['tf.__operators__.add_9[0][0]',
#  a)                                                               'tf.math.log_9[0][0]']
#
#  tf.math.sigmoid_1 (TFOpLambda)  (None, 6)           0           ['tf.math.subtract_17[0][0]']
#
#  Z_Mu (Dense)                   (None, 10)           110         ['dense_23[0][0]']
#
#  dense_24 (Dense)               (None, 10)           110         ['dense_23[0][0]']
#
#  tf.math.multiply_50 (TFOpLambd  (None, 6)           0           ['tf.math.sigmoid_1[0][0]']
#  a)
#
#  tf.math.multiply_51 (TFOpLambd  (None, 6)           0           ['FC_Mu[0][0]']
#  a)
#
#  Z_Log_Sigma (Lambda)           (None, 10)           0           ['dense_24[0][0]']
#
#  tf.compat.v1.shape_2 (TFOpLamb  (2,)                0           ['Z_Mu[0][0]']
#  da)
#
#  tf.__operators__.add_10 (TFOpL  (None, 6)           0           ['tf.math.multiply_50[0][0]',
#  ambda)                                                           'tf.math.multiply_51[0][0]']
#
#  tf.math.multiply_48 (TFOpLambd  (None, 10)          0           ['Z_Log_Sigma[0][0]']
#  a)
#
#  tf.__operators__.getitem_20 (S  ()                  0           ['tf.compat.v1.shape_2[0][0]']
#  licingOpLambda)
#
#  tf.math.multiply_52 (TFOpLambd  (None, 6)           0           ['tf.__operators__.add_10[0][0]']
#  a)
#
#  tf.math.exp_2 (TFOpLambda)     (None, 10)           0           ['tf.math.multiply_48[0][0]']
#
#  tf.random.normal_1 (TFOpLambda  (None, 10)          0           ['tf.__operators__.getitem_20[0][
#  )                                                               0]']
#
#  tf.clip_by_value_5 (TFOpLambda  (None, 6)           0           ['tf.math.multiply_52[0][0]']
#  )
#
#  tf.math.multiply_49 (TFOpLambd  (None, 10)          0           ['tf.math.exp_2[0][0]',
#  a)                                                               'tf.random.normal_1[0][0]']
#
#  FCs (Lambda)                   (None, 6)            0           ['tf.clip_by_value_5[0][0]']
#
#  tf.__operators__.add_8 (TFOpLa  (None, 10)          0           ['Z_Mu[0][0]',
#  mbda)                                                            'tf.math.multiply_49[0][0]']
#
#  tf.__operators__.getitem_38 (S  (None, 2)           0           ['FCs[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_39 (S  (None, 4)           0           ['FCs[0][0]']
#  licingOpLambda)
#
#  Zs (Lambda)                    (None, 10)           0           ['tf.__operators__.add_8[0][0]']
#
#  flatten_1 (Flatten)            (None, 13)           0           ['tf.signal.frame_7[0][0]']
#
#  FeatGenModel (Functional)      [(None, 11),         5564        ['tf.__operators__.getitem_38[0][
#                                  (None, 11),                     0]',
#                                  (None, 11),                      'tf.__operators__.getitem_39[0][
#                                  (None, 11)]                     0]',
#                                                                   'Zs[0][0]']
#
#  FeatExtModel (Functional)      [(None, 11),         0           ['flatten_1[0][0]',
#                                  (None, 11),                      'FCs[0][0]']
#                                  (None, 11),
#                                  (None, 11)]
#
#  ReconModel (Functional)        (None, 13)           9451        ['FeatExtModel[0][0]',
#                                                                   'FeatExtModel[0][1]',
#                                                                   'FeatExtModel[0][2]',
#                                                                   'FeatExtModel[0][3]',
#                                                                   'FeatGenModel[0][0]',
#                                                                   'FeatGenModel[0][1]',
#                                                                   'FeatGenModel[0][2]',
#                                                                   'FeatGenModel[0][3]']
#
#  tf.cast_6 (TFOpLambda)         (None, 13)           0           ['Inp_Enc[0][0]']
#
#  tf.cast_5 (TFOpLambda)         (None, 13)           0           ['ReconModel[0][0]']
#
#  tf.math.subtract_18 (TFOpLambd  (None, 13)          0           ['tf.cast_6[0][0]',
#  a)                                                               'tf.cast_5[0][0]']
#
#  tf.math.square_2 (TFOpLambda)  (None, 13)           0           ['tf.math.subtract_18[0][0]']
#
#  tf.math.reduce_mean_4 (TFOpLam  ()                  0           ['tf.math.square_2[0][0]']
#  bda)
#
#  tf.math.multiply_89 (TFOpLambd  ()                  0           ['tf.math.reduce_mean_4[0][0]']
#  a)
#
#  add_loss_4 (AddLoss)           ()                   0           ['tf.math.multiply_89[0][0]']
#
#  add_metric_4 (AddMetric)       ()                   0           ['tf.math.multiply_89[0][0]']
#
#  tf.concat_13 (TFOpLambda)      (None, 44)           0           ['FeatExtModel[0][0]',
#                                                                   'FeatExtModel[0][1]',
#                                                                   'FeatExtModel[0][2]',
#                                                                   'FeatExtModel[0][3]']
#
#  tf.concat_12 (TFOpLambda)      (None, 44)           0           ['FeatGenModel[0][0]',
#                                                                   'FeatGenModel[0][1]',
#                                                                   'FeatGenModel[0][2]',
#                                                                   'FeatGenModel[0][3]']
#
#  tf.cast_8 (TFOpLambda)         (None, 44)           0           ['tf.concat_13[0][0]']
#
#  tf.cast_7 (TFOpLambda)         (None, 44)           0           ['tf.concat_12[0][0]']
#
#  tf.math.subtract_19 (TFOpLambd  (None, 44)          0           ['tf.cast_8[0][0]',
#  a)                                                               'tf.cast_7[0][0]']
#
#  tf.math.square_3 (TFOpLambda)  (None, 44)           0           ['tf.math.subtract_19[0][0]']
#
#  tf.math.reduce_mean_5 (TFOpLam  ()                  0           ['tf.math.square_3[0][0]']
#  bda)
#
#  tf.math.multiply_90 (TFOpLambd  ()                  0           ['tf.math.reduce_mean_5[0][0]']
#  a)
#
#  add_loss_5 (AddLoss)           ()                   0           ['tf.math.multiply_90[0][0]']
#
#  add_metric_5 (AddMetric)       ()                   0           ['tf.math.multiply_90[0][0]']
#
#  tf.math.pow_1 (TFOpLambda)     (None, 10)           0           ['Z_Mu[0][0]']
#
#  tf.math.exp_3 (TFOpLambda)     (None, 10)           0           ['Z_Log_Sigma[0][0]']
#
#  tf.__operators__.add_14 (TFOpL  (None, 10)          0           ['tf.math.pow_1[0][0]',
#  ambda)                                                           'tf.math.exp_3[0][0]']
#
#  tf.math.subtract_20 (TFOpLambd  (None, 10)          0           ['tf.__operators__.add_14[0][0]',
#  a)                                                               'Z_Log_Sigma[0][0]']
#
#  tf.math.subtract_21 (TFOpLambd  (None, 10)          0           ['tf.math.subtract_20[0][0]']
#  a)
#
#  tf.math.reduce_sum_25 (TFOpLam  (None,)             0           ['tf.math.subtract_21[0][0]']
#  bda)
#
#  tf.math.multiply_91 (TFOpLambd  (None,)             0           ['tf.math.reduce_sum_25[0][0]']
#  a)
#
#  tf.math.reduce_mean_6 (TFOpLam  ()                  0           ['tf.math.multiply_91[0][0]']
#  bda)
#
#  tf.math.subtract_22 (TFOpLambd  ()                  0           ['tf.math.reduce_mean_6[0][0]']
#  a)
#
#  tf.math.abs_2 (TFOpLambda)     ()                   0           ['tf.math.subtract_22[0][0]']
#
#  tf.math.multiply_92 (TFOpLambd  ()                  0           ['tf.math.abs_2[0][0]']
#  a)
#
#  add_loss_6 (AddLoss)           ()                   0           ['tf.math.multiply_92[0][0]']
#
#  add_metric_6 (AddMetric)       ()                   0           ['tf.math.multiply_92[0][0]']
#
#  tf.cast_9 (TFOpLambda)         (None, 6)            0           ['FC_Mu[0][0]']
#
#  tf.math.subtract_25 (TFOpLambd  (None, 6)           0           ['tf.cast_9[0][0]']
#  a)
#
#  tf.math.log_10 (TFOpLambda)    (None, 6)            0           ['tf.cast_9[0][0]']
#
#  tf.math.log_11 (TFOpLambda)    (None, 6)            0           ['tf.math.subtract_25[0][0]']
#
#  tf.math.subtract_23 (TFOpLambd  (None, 6)           0           ['tf.math.log_10[0][0]']
#  a)
#
#  tf.math.subtract_24 (TFOpLambd  (None, 6)           0           ['tf.cast_9[0][0]']
#  a)
#
#  tf.math.subtract_26 (TFOpLambd  (None, 6)           0           ['tf.math.log_11[0][0]']
#  a)
#
#  tf.math.multiply_93 (TFOpLambd  (None, 6)           0           ['tf.cast_9[0][0]',
#  a)                                                               'tf.math.subtract_23[0][0]']
#
#  tf.math.multiply_94 (TFOpLambd  (None, 6)           0           ['tf.math.subtract_24[0][0]',
#  a)                                                               'tf.math.subtract_26[0][0]']
#
#  tf.__operators__.add_15 (TFOpL  (None, 6)           0           ['tf.math.multiply_93[0][0]',
#  ambda)                                                           'tf.math.multiply_94[0][0]']
#
#  tf.math.reduce_mean_7 (TFOpLam  ()                  0           ['tf.__operators__.add_15[0][0]']
#  bda)
#
#  tf.math.subtract_27 (TFOpLambd  ()                  0           ['tf.math.reduce_mean_7[0][0]']
#  a)
#
#  tf.math.abs_3 (TFOpLambda)     ()                   0           ['tf.math.subtract_27[0][0]']
#
#  tf.math.multiply_95 (TFOpLambd  ()                  0           ['tf.math.abs_3[0][0]']
#  a)
#
#  add_loss_7 (AddLoss)           ()                   0           ['tf.math.multiply_95[0][0]']
#
#  add_metric_7 (AddMetric)       ()                   0           ['tf.math.multiply_95[0][0]']
#
# ==================================================================================================
# Total params: 17,223
# Trainable params: 17,223
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
TrSize = int(DataSize * 0.8)
np.random.seed(1)
PerRhythmicData = np.random.permutation(RhythmicData)

TrData = PerRhythmicData[:TrSize]
ValData = PerRhythmicData[TrSize:]

# %%
SigRepModel.fit(TrData, batch_size=1000, epochs=1000, shuffle=True, validation_data =(ValData, None), verbose=1 )
# Out:
# Epoch 1/1000
# 19/19 [==============================] - 27s 325ms/step - loss: 1.0155 - OrigRecLoss: 0.2901 - FeatRecLoss: 0.7199 - kl_Loss_Z: 0.0016 - kl_Loss_FC: 0.0040 - val_loss: 0.9119 - val_OrigRecLoss: 0.2113 - val_FeatRecLoss: 0.6979 - val_kl_Loss_Z: 0.0016 - val_kl_Loss_FC: 9.9514e-04
# Epoch 2/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.7629 - OrigRecLoss: 0.1402 - FeatRecLoss: 0.6206 - kl_Loss_Z: 0.0016 - kl_Loss_FC: 4.1535e-04 - val_loss: 0.7117 - val_OrigRecLoss: 0.1333 - val_FeatRecLoss: 0.5765 - val_kl_Loss_Z: 0.0016 - val_kl_Loss_FC: 2.6048e-04
# Epoch 3/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.6009 - OrigRecLoss: 0.1105 - FeatRecLoss: 0.4884 - kl_Loss_Z: 0.0018 - kl_Loss_FC: 2.0421e-04 - val_loss: 0.5421 - val_OrigRecLoss: 0.1233 - val_FeatRecLoss: 0.4167 - val_kl_Loss_Z: 0.0021 - val_kl_Loss_FC: 1.4253e-05
# Epoch 4/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.4441 - OrigRecLoss: 0.1021 - FeatRecLoss: 0.3394 - kl_Loss_Z: 0.0025 - kl_Loss_FC: 6.0763e-05 - val_loss: 0.4411 - val_OrigRecLoss: 0.1202 - val_FeatRecLoss: 0.3176 - val_kl_Loss_Z: 0.0031 - val_kl_Loss_FC: 1.0567e-04
# Epoch 5/1000
# 19/19 [==============================] - 1s 45ms/step - loss: 0.3849 - OrigRecLoss: 0.1016 - FeatRecLoss: 0.2797 - kl_Loss_Z: 0.0035 - kl_Loss_FC: 7.7787e-05 - val_loss: 0.4030 - val_OrigRecLoss: 0.1186 - val_FeatRecLoss: 0.2806 - val_kl_Loss_Z: 0.0037 - val_kl_Loss_FC: 9.5766e-05
# Epoch 6/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.3563 - OrigRecLoss: 0.1001 - FeatRecLoss: 0.2526 - kl_Loss_Z: 0.0036 - kl_Loss_FC: 6.2695e-05 - val_loss: 0.3849 - val_OrigRecLoss: 0.1176 - val_FeatRecLoss: 0.2638 - val_kl_Loss_Z: 0.0034 - val_kl_Loss_FC: 9.2116e-05
# Epoch 7/1000
# 19/19 [==============================] - 1s 45ms/step - loss: 0.3432 - OrigRecLoss: 0.0988 - FeatRecLoss: 0.2411 - kl_Loss_Z: 0.0032 - kl_Loss_FC: 5.0527e-05 - val_loss: 0.3745 - val_OrigRecLoss: 0.1168 - val_FeatRecLoss: 0.2546 - val_kl_Loss_Z: 0.0030 - val_kl_Loss_FC: 1.3405e-04
# Epoch 8/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.3332 - OrigRecLoss: 0.0977 - FeatRecLoss: 0.2326 - kl_Loss_Z: 0.0028 - kl_Loss_FC: 1.4480e-04 - val_loss: 0.3678 - val_OrigRecLoss: 0.1162 - val_FeatRecLoss: 0.2490 - val_kl_Loss_Z: 0.0026 - val_kl_Loss_FC: 5.4326e-05
# Epoch 9/1000
# 19/19 [==============================] - 1s 45ms/step - loss: 0.3268 - OrigRecLoss: 0.0973 - FeatRecLoss: 0.2269 - kl_Loss_Z: 0.0024 - kl_Loss_FC: 1.1406e-04 - val_loss: 0.3634 - val_OrigRecLoss: 0.1157 - val_FeatRecLoss: 0.2453 - val_kl_Loss_Z: 0.0023 - val_kl_Loss_FC: 1.0555e-04
# Epoch 10/1000
# 19/19 [==============================] - 1s 45ms/step - loss: 0.3180 - OrigRecLoss: 0.0949 - FeatRecLoss: 0.2208 - kl_Loss_Z: 0.0022 - kl_Loss_FC: 8.3129e-05 - val_loss: 0.3600 - val_OrigRecLoss: 0.1153 - val_FeatRecLoss: 0.2427 - val_kl_Loss_Z: 0.0021 - val_kl_Loss_FC: 2.3768e-05
# Epoch 11/1000
# 19/19 [==============================] - 1s 45ms/step - loss: 0.3155 - OrigRecLoss: 0.0948 - FeatRecLoss: 0.2187 - kl_Loss_Z: 0.0020 - kl_Loss_FC: 6.0964e-05 - val_loss: 0.3577 - val_OrigRecLoss: 0.1149 - val_FeatRecLoss: 0.2409 - val_kl_Loss_Z: 0.0018 - val_kl_Loss_FC: 7.6496e-05
# Epoch 12/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.3156 - OrigRecLoss: 0.0960 - FeatRecLoss: 0.2178 - kl_Loss_Z: 0.0018 - kl_Loss_FC: 5.2374e-05 - val_loss: 0.3559 - val_OrigRecLoss: 0.1146 - val_FeatRecLoss: 0.2394 - val_kl_Loss_Z: 0.0017 - val_kl_Loss_FC: 1.4056e-04
# Epoch 13/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.3109 - OrigRecLoss: 0.0940 - FeatRecLoss: 0.2151 - kl_Loss_Z: 0.0016 - kl_Loss_FC: 1.0442e-04 - val_loss: 0.3544 - val_OrigRecLoss: 0.1144 - val_FeatRecLoss: 0.2384 - val_kl_Loss_Z: 0.0015 - val_kl_Loss_FC: 8.7417e-05
# Epoch 14/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.3175 - OrigRecLoss: 0.0986 - FeatRecLoss: 0.2173 - kl_Loss_Z: 0.0015 - kl_Loss_FC: 6.2737e-05 - val_loss: 0.3531 - val_OrigRecLoss: 0.1142 - val_FeatRecLoss: 0.2375 - val_kl_Loss_Z: 0.0014 - val_kl_Loss_FC: 1.1363e-05
# Epoch 15/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.3111 - OrigRecLoss: 0.0948 - FeatRecLoss: 0.2148 - kl_Loss_Z: 0.0014 - kl_Loss_FC: 8.2144e-05 - val_loss: 0.3521 - val_OrigRecLoss: 0.1140 - val_FeatRecLoss: 0.2367 - val_kl_Loss_Z: 0.0013 - val_kl_Loss_FC: 4.4490e-05
# Epoch 16/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.3352 - OrigRecLoss: 0.1007 - FeatRecLoss: 0.2331 - kl_Loss_Z: 0.0013 - kl_Loss_FC: 9.1886e-05 - val_loss: 0.3512 - val_OrigRecLoss: 0.1138 - val_FeatRecLoss: 0.2361 - val_kl_Loss_Z: 0.0012 - val_kl_Loss_FC: 1.0885e-05
# Epoch 17/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.3074 - OrigRecLoss: 0.0933 - FeatRecLoss: 0.2130 - kl_Loss_Z: 0.0012 - kl_Loss_FC: 4.3633e-05 - val_loss: 0.3505 - val_OrigRecLoss: 0.1137 - val_FeatRecLoss: 0.2356 - val_kl_Loss_Z: 0.0011 - val_kl_Loss_FC: 3.1651e-05
# Epoch 18/1000
# 19/19 [==============================] - 1s 45ms/step - loss: 0.3061 - OrigRecLoss: 0.0931 - FeatRecLoss: 0.2118 - kl_Loss_Z: 0.0011 - kl_Loss_FC: 5.5386e-05 - val_loss: 0.3501 - val_OrigRecLoss: 0.1135 - val_FeatRecLoss: 0.2353 - val_kl_Loss_Z: 0.0010 - val_kl_Loss_FC: 2.4407e-04
# Epoch 19/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.3150 - OrigRecLoss: 0.0987 - FeatRecLoss: 0.2152 - kl_Loss_Z: 9.9412e-04 - kl_Loss_FC: 9.4626e-05 - val_loss: 0.3494 - val_OrigRecLoss: 0.1134 - val_FeatRecLoss: 0.2349 - val_kl_Loss_Z: 9.5493e-04 - val_kl_Loss_FC: 6.5693e-05
# Epoch 20/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.3142 - OrigRecLoss: 0.0958 - FeatRecLoss: 0.2173 - kl_Loss_Z: 9.2447e-04 - kl_Loss_FC: 1.1463e-04 - val_loss: 0.3490 - val_OrigRecLoss: 0.1133 - val_FeatRecLoss: 0.2346 - val_kl_Loss_Z: 8.9397e-04 - val_kl_Loss_FC: 1.9521e-04
# Epoch 21/1000
# 19/19 [==============================] - 1s 43ms/step - loss: 0.3063 - OrigRecLoss: 0.0936 - FeatRecLoss: 0.2118 - kl_Loss_Z: 8.6238e-04 - kl_Loss_FC: 1.2029e-04 - val_loss: 0.3485 - val_OrigRecLoss: 0.1132 - val_FeatRecLoss: 0.2343 - val_kl_Loss_Z: 8.3078e-04 - val_kl_Loss_FC: 1.2140e-04
# Epoch 22/1000
# 19/19 [==============================] - 1s 45ms/step - loss: 0.3306 - OrigRecLoss: 0.0994 - FeatRecLoss: 0.2303 - kl_Loss_Z: 8.0809e-04 - kl_Loss_FC: 1.5938e-04 - val_loss: 0.3481 - val_OrigRecLoss: 0.1131 - val_FeatRecLoss: 0.2342 - val_kl_Loss_Z: 7.8019e-04 - val_kl_Loss_FC: 1.1254e-05
# Epoch 23/1000
# 19/19 [==============================] - 1s 43ms/step - loss: 0.3180 - OrigRecLoss: 0.0975 - FeatRecLoss: 0.2196 - kl_Loss_Z: 7.5644e-04 - kl_Loss_FC: 8.5834e-05 - val_loss: 0.3479 - val_OrigRecLoss: 0.1131 - val_FeatRecLoss: 0.2340 - val_kl_Loss_Z: 7.3313e-04 - val_kl_Loss_FC: 1.2000e-04
# Epoch 24/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.3096 - OrigRecLoss: 0.0947 - FeatRecLoss: 0.2142 - kl_Loss_Z: 7.0864e-04 - kl_Loss_FC: 7.0199e-05 - val_loss: 0.3475 - val_OrigRecLoss: 0.1130 - val_FeatRecLoss: 0.2338 - val_kl_Loss_Z: 6.8675e-04 - val_kl_Loss_FC: 2.6622e-05
# Epoch 25/1000
# 19/19 [==============================] - 1s 45ms/step - loss: 0.3038 - OrigRecLoss: 0.0925 - FeatRecLoss: 0.2106 - kl_Loss_Z: 6.6835e-04 - kl_Loss_FC: 5.9805e-05 - val_loss: 0.3473 - val_OrigRecLoss: 0.1129 - val_FeatRecLoss: 0.2336 - val_kl_Loss_Z: 6.4694e-04 - val_kl_Loss_FC: 9.4454e-05
# Epoch 26/1000
# 19/19 [==============================] - 1s 45ms/step - loss: 0.3065 - OrigRecLoss: 0.0935 - FeatRecLoss: 0.2122 - kl_Loss_Z: 6.3235e-04 - kl_Loss_FC: 1.0431e-04 - val_loss: 0.3471 - val_OrigRecLoss: 0.1129 - val_FeatRecLoss: 0.2335 - val_kl_Loss_Z: 6.1230e-04 - val_kl_Loss_FC: 1.2991e-04
# Epoch 27/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.3701 - OrigRecLoss: 0.1081 - FeatRecLoss: 0.2612 - kl_Loss_Z: 5.9912e-04 - kl_Loss_FC: 6.6246e-05 - val_loss: 0.3468 - val_OrigRecLoss: 0.1128 - val_FeatRecLoss: 0.2334 - val_kl_Loss_Z: 5.8376e-04 - val_kl_Loss_FC: 8.9485e-05
# Epoch 28/1000
# 19/19 [==============================] - 1s 43ms/step - loss: 0.3040 - OrigRecLoss: 0.0924 - FeatRecLoss: 0.2110 - kl_Loss_Z: 5.6782e-04 - kl_Loss_FC: 6.2165e-05 - val_loss: 0.3466 - val_OrigRecLoss: 0.1128 - val_FeatRecLoss: 0.2332 - val_kl_Loss_Z: 5.5334e-04 - val_kl_Loss_FC: 7.5450e-05
# Epoch 29/1000
# 19/19 [==============================] - 1s 46ms/step - loss: 0.3071 - OrigRecLoss: 0.0938 - FeatRecLoss: 0.2128 - kl_Loss_Z: 5.3857e-04 - kl_Loss_FC: 4.3635e-05 - val_loss: 0.3464 - val_OrigRecLoss: 0.1127 - val_FeatRecLoss: 0.2331 - val_kl_Loss_Z: 5.2431e-04 - val_kl_Loss_FC: 6.2695e-05
# Epoch 30/1000
# 19/19 [==============================] - 1s 43ms/step - loss: 0.3049 - OrigRecLoss: 0.0931 - FeatRecLoss: 0.2112 - kl_Loss_Z: 5.1099e-04 - kl_Loss_FC: 7.0146e-05 - val_loss: 0.3463 - val_OrigRecLoss: 0.1127 - val_FeatRecLoss: 0.2330 - val_kl_Loss_Z: 4.9557e-04 - val_kl_Loss_FC: 1.0742e-04
# Epoch 31/1000
# 19/19 [==============================] - 1s 43ms/step - loss: 0.3068 - OrigRecLoss: 0.0938 - FeatRecLoss: 0.2125 - kl_Loss_Z: 4.8498e-04 - kl_Loss_FC: 4.7193e-05 - val_loss: 0.3462 - val_OrigRecLoss: 0.1126 - val_FeatRecLoss: 0.2330 - val_kl_Loss_Z: 4.7279e-04 - val_kl_Loss_FC: 8.1735e-05
# Epoch 32/1000
# 19/19 [==============================] - 1s 43ms/step - loss: 0.3051 - OrigRecLoss: 0.0931 - FeatRecLoss: 0.2114 - kl_Loss_Z: 4.6051e-04 - kl_Loss_FC: 4.5748e-05 - val_loss: 0.3460 - val_OrigRecLoss: 0.1126 - val_FeatRecLoss: 0.2329 - val_kl_Loss_Z: 4.4746e-04 - val_kl_Loss_FC: 5.5317e-05
# Epoch 33/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.3053 - OrigRecLoss: 0.0933 - FeatRecLoss: 0.2114 - kl_Loss_Z: 4.3721e-04 - kl_Loss_FC: 1.2995e-04 - val_loss: 0.3459 - val_OrigRecLoss: 0.1125 - val_FeatRecLoss: 0.2328 - val_kl_Loss_Z: 4.2615e-04 - val_kl_Loss_FC: 1.3461e-04
# Epoch 34/1000
# 19/19 [==============================] - 1s 43ms/step - loss: 0.3044 - OrigRecLoss: 0.0934 - FeatRecLoss: 0.2104 - kl_Loss_Z: 4.1417e-04 - kl_Loss_FC: 1.2604e-04 - val_loss: 0.3458 - val_OrigRecLoss: 0.1125 - val_FeatRecLoss: 0.2327 - val_kl_Loss_Z: 4.0425e-04 - val_kl_Loss_FC: 1.3653e-04
# Epoch 35/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.3035 - OrigRecLoss: 0.0928 - FeatRecLoss: 0.2103 - kl_Loss_Z: 3.9393e-04 - kl_Loss_FC: 4.8893e-05 - val_loss: 0.3456 - val_OrigRecLoss: 0.1125 - val_FeatRecLoss: 0.2327 - val_kl_Loss_Z: 3.8286e-04 - val_kl_Loss_FC: 6.7101e-05
# Epoch 36/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.3345 - OrigRecLoss: 0.1014 - FeatRecLoss: 0.2327 - kl_Loss_Z: 3.7443e-04 - kl_Loss_FC: 7.9422e-05 - val_loss: 0.3454 - val_OrigRecLoss: 0.1124 - val_FeatRecLoss: 0.2326 - val_kl_Loss_Z: 3.6429e-04 - val_kl_Loss_FC: 2.4350e-05
# Epoch 37/1000
# 19/19 [==============================] - 1s 45ms/step - loss: 0.3034 - OrigRecLoss: 0.0928 - FeatRecLoss: 0.2102 - kl_Loss_Z: 3.5587e-04 - kl_Loss_FC: 5.3275e-05 - val_loss: 0.3454 - val_OrigRecLoss: 0.1124 - val_FeatRecLoss: 0.2326 - val_kl_Loss_Z: 3.4678e-04 - val_kl_Loss_FC: 6.6084e-05
# Epoch 38/1000
# 19/19 [==============================] - 1s 46ms/step - loss: 0.3008 - OrigRecLoss: 0.0918 - FeatRecLoss: 0.2087 - kl_Loss_Z: 3.3827e-04 - kl_Loss_FC: 4.5683e-05 - val_loss: 0.3452 - val_OrigRecLoss: 0.1124 - val_FeatRecLoss: 0.2325 - val_kl_Loss_Z: 3.2888e-04 - val_kl_Loss_FC: 1.0613e-05
# Epoch 39/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.3111 - OrigRecLoss: 0.0946 - FeatRecLoss: 0.2162 - kl_Loss_Z: 3.2097e-04 - kl_Loss_FC: 4.2394e-05 - val_loss: 0.3452 - val_OrigRecLoss: 0.1124 - val_FeatRecLoss: 0.2325 - val_kl_Loss_Z: 3.1184e-04 - val_kl_Loss_FC: 6.6689e-05
# Epoch 40/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.3077 - OrigRecLoss: 0.0940 - FeatRecLoss: 0.2134 - kl_Loss_Z: 3.0420e-04 - kl_Loss_FC: 4.1233e-05 - val_loss: 0.3451 - val_OrigRecLoss: 0.1123 - val_FeatRecLoss: 0.2324 - val_kl_Loss_Z: 2.9569e-04 - val_kl_Loss_FC: 6.2650e-05
# Epoch 41/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.3025 - OrigRecLoss: 0.0924 - FeatRecLoss: 0.2098 - kl_Loss_Z: 2.8860e-04 - kl_Loss_FC: 4.2635e-05 - val_loss: 0.3450 - val_OrigRecLoss: 0.1123 - val_FeatRecLoss: 0.2324 - val_kl_Loss_Z: 2.8041e-04 - val_kl_Loss_FC: 3.8398e-05
# Epoch 42/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.3062 - OrigRecLoss: 0.0936 - FeatRecLoss: 0.2123 - kl_Loss_Z: 2.7354e-04 - kl_Loss_FC: 2.6722e-05 - val_loss: 0.3450 - val_OrigRecLoss: 0.1123 - val_FeatRecLoss: 0.2324 - val_kl_Loss_Z: 2.6562e-04 - val_kl_Loss_FC: 9.5809e-05
# Epoch 43/1000
# 19/19 [==============================] - 1s 43ms/step - loss: 0.3044 - OrigRecLoss: 0.0931 - FeatRecLoss: 0.2110 - kl_Loss_Z: 2.5909e-04 - kl_Loss_FC: 8.1398e-05 - val_loss: 0.3449 - val_OrigRecLoss: 0.1123 - val_FeatRecLoss: 0.2323 - val_kl_Loss_Z: 2.5167e-04 - val_kl_Loss_FC: 7.1808e-05
# Epoch 44/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.3002 - OrigRecLoss: 0.0914 - FeatRecLoss: 0.2084 - kl_Loss_Z: 2.4537e-04 - kl_Loss_FC: 5.8307e-05 - val_loss: 0.3448 - val_OrigRecLoss: 0.1122 - val_FeatRecLoss: 0.2323 - val_kl_Loss_Z: 2.3822e-04 - val_kl_Loss_FC: 8.1132e-06
# Epoch 45/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.3041 - OrigRecLoss: 0.0924 - FeatRecLoss: 0.2113 - kl_Loss_Z: 2.3237e-04 - kl_Loss_FC: 1.1529e-04 - val_loss: 0.3448 - val_OrigRecLoss: 0.1122 - val_FeatRecLoss: 0.2322 - val_kl_Loss_Z: 2.2590e-04 - val_kl_Loss_FC: 1.0666e-04
# Epoch 46/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.3022 - OrigRecLoss: 0.0923 - FeatRecLoss: 0.2095 - kl_Loss_Z: 2.1973e-04 - kl_Loss_FC: 1.4020e-04 - val_loss: 0.3447 - val_OrigRecLoss: 0.1122 - val_FeatRecLoss: 0.2322 - val_kl_Loss_Z: 2.1334e-04 - val_kl_Loss_FC: 7.2855e-05
# Epoch 47/1000
# 19/19 [==============================] - 1s 43ms/step - loss: 0.3051 - OrigRecLoss: 0.0929 - FeatRecLoss: 0.2119 - kl_Loss_Z: 2.0770e-04 - kl_Loss_FC: 1.0288e-04 - val_loss: 0.3446 - val_OrigRecLoss: 0.1122 - val_FeatRecLoss: 0.2322 - val_kl_Loss_Z: 2.0157e-04 - val_kl_Loss_FC: 8.5893e-06
# Epoch 48/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.3008 - OrigRecLoss: 0.0918 - FeatRecLoss: 0.2087 - kl_Loss_Z: 1.9619e-04 - kl_Loss_FC: 5.0107e-05 - val_loss: 0.3446 - val_OrigRecLoss: 0.1122 - val_FeatRecLoss: 0.2322 - val_kl_Loss_Z: 1.9030e-04 - val_kl_Loss_FC: 9.7824e-05
# Epoch 49/1000
# 19/19 [==============================] - 1s 43ms/step - loss: 0.3116 - OrigRecLoss: 0.0947 - FeatRecLoss: 0.2167 - kl_Loss_Z: 1.8466e-04 - kl_Loss_FC: 4.4556e-05 - val_loss: 0.3445 - val_OrigRecLoss: 0.1121 - val_FeatRecLoss: 0.2321 - val_kl_Loss_Z: 1.7914e-04 - val_kl_Loss_FC: 1.1640e-04
# Epoch 50/1000
# 19/19 [==============================] - 1s 43ms/step - loss: 0.3066 - OrigRecLoss: 0.0937 - FeatRecLoss: 0.2126 - kl_Loss_Z: 1.7392e-04 - kl_Loss_FC: 1.1295e-04 - val_loss: 0.3444 - val_OrigRecLoss: 0.1121 - val_FeatRecLoss: 0.2321 - val_kl_Loss_Z: 1.6841e-04 - val_kl_Loss_FC: 1.1676e-05
# Epoch 51/1000
# 19/19 [==============================] - 1s 43ms/step - loss: 0.3164 - OrigRecLoss: 0.0969 - FeatRecLoss: 0.2193 - kl_Loss_Z: 1.6376e-04 - kl_Loss_FC: 3.5127e-05 - val_loss: 0.3444 - val_OrigRecLoss: 0.1121 - val_FeatRecLoss: 0.2321 - val_kl_Loss_Z: 1.5883e-04 - val_kl_Loss_FC: 8.7348e-05
# Epoch 52/1000
# 19/19 [==============================] - 1s 43ms/step - loss: 0.3060 - OrigRecLoss: 0.0931 - FeatRecLoss: 0.2128 - kl_Loss_Z: 1.5393e-04 - kl_Loss_FC: 5.3041e-05 - val_loss: 0.3444 - val_OrigRecLoss: 0.1121 - val_FeatRecLoss: 0.2321 - val_kl_Loss_Z: 1.4936e-04 - val_kl_Loss_FC: 7.5237e-05
# Epoch 53/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.3024 - OrigRecLoss: 0.0922 - FeatRecLoss: 0.2100 - kl_Loss_Z: 1.4485e-04 - kl_Loss_FC: 5.6488e-05 - val_loss: 0.3443 - val_OrigRecLoss: 0.1121 - val_FeatRecLoss: 0.2320 - val_kl_Loss_Z: 1.4007e-04 - val_kl_Loss_FC: 5.1629e-05
# Epoch 54/1000
# 19/19 [==============================] - 1s 43ms/step - loss: 0.3021 - OrigRecLoss: 0.0920 - FeatRecLoss: 0.2098 - kl_Loss_Z: 1.3625e-04 - kl_Loss_FC: 7.0601e-05 - val_loss: 0.3443 - val_OrigRecLoss: 0.1121 - val_FeatRecLoss: 0.2320 - val_kl_Loss_Z: 1.3214e-04 - val_kl_Loss_FC: 5.2594e-05
# Epoch 55/1000
# 19/19 [==============================] - 1s 45ms/step - loss: 0.3034 - OrigRecLoss: 0.0923 - FeatRecLoss: 0.2109 - kl_Loss_Z: 1.2804e-04 - kl_Loss_FC: 7.3171e-05 - val_loss: 0.3443 - val_OrigRecLoss: 0.1121 - val_FeatRecLoss: 0.2320 - val_kl_Loss_Z: 1.2400e-04 - val_kl_Loss_FC: 6.5081e-05
# Epoch 56/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.3094 - OrigRecLoss: 0.0937 - FeatRecLoss: 0.2156 - kl_Loss_Z: 1.2014e-04 - kl_Loss_FC: 5.0158e-05 - val_loss: 0.3442 - val_OrigRecLoss: 0.1121 - val_FeatRecLoss: 0.2319 - val_kl_Loss_Z: 1.1565e-04 - val_kl_Loss_FC: 7.4852e-05
# Epoch 57/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.3175 - OrigRecLoss: 0.1024 - FeatRecLoss: 0.2149 - kl_Loss_Z: 1.1256e-04 - kl_Loss_FC: 5.5858e-05 - val_loss: 0.3441 - val_OrigRecLoss: 0.1120 - val_FeatRecLoss: 0.2320 - val_kl_Loss_Z: 1.0865e-04 - val_kl_Loss_FC: 1.3372e-05
# Epoch 58/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.3008 - OrigRecLoss: 0.0917 - FeatRecLoss: 0.2089 - kl_Loss_Z: 1.0517e-04 - kl_Loss_FC: 6.7783e-05 - val_loss: 0.3442 - val_OrigRecLoss: 0.1120 - val_FeatRecLoss: 0.2319 - val_kl_Loss_Z: 1.0053e-04 - val_kl_Loss_FC: 1.8104e-04
# Epoch 59/1000
# 19/19 [==============================] - 1s 45ms/step - loss: 0.3023 - OrigRecLoss: 0.0925 - FeatRecLoss: 0.2096 - kl_Loss_Z: 9.8105e-05 - kl_Loss_FC: 1.1252e-04 - val_loss: 0.3441 - val_OrigRecLoss: 0.1120 - val_FeatRecLoss: 0.2319 - val_kl_Loss_Z: 9.4338e-05 - val_kl_Loss_FC: 9.1896e-05
# Epoch 60/1000
# 19/19 [==============================] - 1s 43ms/step - loss: 0.3038 - OrigRecLoss: 0.0934 - FeatRecLoss: 0.2102 - kl_Loss_Z: 9.1655e-05 - kl_Loss_FC: 8.8175e-05 - val_loss: 0.3440 - val_OrigRecLoss: 0.1120 - val_FeatRecLoss: 0.2319 - val_kl_Loss_Z: 8.8101e-05 - val_kl_Loss_FC: 8.6119e-06
# Epoch 61/1000
# 19/19 [==============================] - 1s 45ms/step - loss: 0.3026 - OrigRecLoss: 0.0923 - FeatRecLoss: 0.2101 - kl_Loss_Z: 8.5117e-05 - kl_Loss_FC: 1.1936e-04 - val_loss: 0.3442 - val_OrigRecLoss: 0.1120 - val_FeatRecLoss: 0.2319 - val_kl_Loss_Z: 8.0582e-05 - val_kl_Loss_FC: 2.2806e-04
# Epoch 62/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.3181 - OrigRecLoss: 0.0995 - FeatRecLoss: 0.2183 - kl_Loss_Z: 7.9012e-05 - kl_Loss_FC: 1.5766e-04 - val_loss: 0.3441 - val_OrigRecLoss: 0.1120 - val_FeatRecLoss: 0.2319 - val_kl_Loss_Z: 7.6783e-05 - val_kl_Loss_FC: 2.0022e-04
# Epoch 63/1000
# 19/19 [==============================] - 1s 45ms/step - loss: 0.3267 - OrigRecLoss: 0.1077 - FeatRecLoss: 0.2188 - kl_Loss_Z: 7.2781e-05 - kl_Loss_FC: 1.0375e-04 - val_loss: 0.3440 - val_OrigRecLoss: 0.1120 - val_FeatRecLoss: 0.2318 - val_kl_Loss_Z: 7.0092e-05 - val_kl_Loss_FC: 1.3561e-04
# Epoch 64/1000
# 19/19 [==============================] - 1s 43ms/step - loss: 0.3145 - OrigRecLoss: 0.0962 - FeatRecLoss: 0.2181 - kl_Loss_Z: 6.7025e-05 - kl_Loss_FC: 9.3976e-05 - val_loss: 0.3439 - val_OrigRecLoss: 0.1120 - val_FeatRecLoss: 0.2319 - val_kl_Loss_Z: 6.4434e-05 - val_kl_Loss_FC: 3.2151e-05
# Epoch 65/1000
# 19/19 [==============================] - 1s 43ms/step - loss: 0.3026 - OrigRecLoss: 0.0923 - FeatRecLoss: 0.2102 - kl_Loss_Z: 6.1910e-05 - kl_Loss_FC: 2.8132e-05 - val_loss: 0.3439 - val_OrigRecLoss: 0.1120 - val_FeatRecLoss: 0.2318 - val_kl_Loss_Z: 5.9185e-05 - val_kl_Loss_FC: 4.2065e-05
# Epoch 66/1000
# 19/19 [==============================] - 1s 43ms/step - loss: 0.3296 - OrigRecLoss: 0.0997 - FeatRecLoss: 0.2297 - kl_Loss_Z: 5.7158e-05 - kl_Loss_FC: 9.0790e-05 - val_loss: 0.3440 - val_OrigRecLoss: 0.1119 - val_FeatRecLoss: 0.2318 - val_kl_Loss_Z: 5.3641e-05 - val_kl_Loss_FC: 2.2335e-04
# Epoch 67/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.3064 - OrigRecLoss: 0.0936 - FeatRecLoss: 0.2126 - kl_Loss_Z: 5.2242e-05 - kl_Loss_FC: 1.3443e-04 - val_loss: 0.3438 - val_OrigRecLoss: 0.1119 - val_FeatRecLoss: 0.2318 - val_kl_Loss_Z: 5.0109e-05 - val_kl_Loss_FC: 1.5401e-05
# Epoch 68/1000
# 19/19 [==============================] - 1s 45ms/step - loss: 0.3178 - OrigRecLoss: 0.0977 - FeatRecLoss: 0.2200 - kl_Loss_Z: 4.7908e-05 - kl_Loss_FC: 5.8588e-05 - val_loss: 0.3438 - val_OrigRecLoss: 0.1119 - val_FeatRecLoss: 0.2318 - val_kl_Loss_Z: 4.6030e-05 - val_kl_Loss_FC: 8.3173e-05
# Epoch 69/1000
# 19/19 [==============================] - 1s 45ms/step - loss: 0.3015 - OrigRecLoss: 0.0921 - FeatRecLoss: 0.2093 - kl_Loss_Z: 4.3965e-05 - kl_Loss_FC: 7.2619e-05 - val_loss: 0.3438 - val_OrigRecLoss: 0.1119 - val_FeatRecLoss: 0.2318 - val_kl_Loss_Z: 4.1219e-05 - val_kl_Loss_FC: 9.3010e-05
# Epoch 70/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.3271 - OrigRecLoss: 0.0985 - FeatRecLoss: 0.2285 - kl_Loss_Z: 3.9586e-05 - kl_Loss_FC: 1.0708e-04 - val_loss: 0.3438 - val_OrigRecLoss: 0.1119 - val_FeatRecLoss: 0.2318 - val_kl_Loss_Z: 3.7646e-05 - val_kl_Loss_FC: 4.5675e-05
# Epoch 71/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.3013 - OrigRecLoss: 0.0921 - FeatRecLoss: 0.2091 - kl_Loss_Z: 3.5514e-05 - kl_Loss_FC: 4.7490e-05 - val_loss: 0.3438 - val_OrigRecLoss: 0.1119 - val_FeatRecLoss: 0.2318 - val_kl_Loss_Z: 3.3271e-05 - val_kl_Loss_FC: 7.6606e-05
# Epoch 72/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.3126 - OrigRecLoss: 0.0945 - FeatRecLoss: 0.2180 - kl_Loss_Z: 3.1935e-05 - kl_Loss_FC: 6.8665e-05 - val_loss: 0.3439 - val_OrigRecLoss: 0.1119 - val_FeatRecLoss: 0.2317 - val_kl_Loss_Z: 3.1033e-05 - val_kl_Loss_FC: 1.9078e-04
# Epoch 73/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.2992 - OrigRecLoss: 0.0912 - FeatRecLoss: 0.2079 - kl_Loss_Z: 2.8538e-05 - kl_Loss_FC: 6.8984e-05 - val_loss: 0.3438 - val_OrigRecLoss: 0.1119 - val_FeatRecLoss: 0.2317 - val_kl_Loss_Z: 2.6230e-05 - val_kl_Loss_FC: 1.0282e-04
# Epoch 74/1000
# 19/19 [==============================] - 1s 46ms/step - loss: 0.3011 - OrigRecLoss: 0.0917 - FeatRecLoss: 0.2093 - kl_Loss_Z: 2.5069e-05 - kl_Loss_FC: 4.2814e-05 - val_loss: 0.3437 - val_OrigRecLoss: 0.1119 - val_FeatRecLoss: 0.2317 - val_kl_Loss_Z: 2.3248e-05 - val_kl_Loss_FC: 5.1579e-05
# Epoch 75/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.3042 - OrigRecLoss: 0.0930 - FeatRecLoss: 0.2112 - kl_Loss_Z: 2.1866e-05 - kl_Loss_FC: 2.5575e-05 - val_loss: 0.3437 - val_OrigRecLoss: 0.1119 - val_FeatRecLoss: 0.2317 - val_kl_Loss_Z: 2.0397e-05 - val_kl_Loss_FC: 2.3314e-05
# Epoch 76/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.3017 - OrigRecLoss: 0.0920 - FeatRecLoss: 0.2097 - kl_Loss_Z: 1.8912e-05 - kl_Loss_FC: 5.4024e-05 - val_loss: 0.3436 - val_OrigRecLoss: 0.1119 - val_FeatRecLoss: 0.2317 - val_kl_Loss_Z: 1.7466e-05 - val_kl_Loss_FC: 1.5435e-05
# Epoch 77/1000
# 19/19 [==============================] - 1s 43ms/step - loss: 0.3013 - OrigRecLoss: 0.0919 - FeatRecLoss: 0.2093 - kl_Loss_Z: 1.5963e-05 - kl_Loss_FC: 6.5270e-05 - val_loss: 0.3437 - val_OrigRecLoss: 0.1119 - val_FeatRecLoss: 0.2317 - val_kl_Loss_Z: 1.4149e-05 - val_kl_Loss_FC: 8.7632e-05
# Epoch 78/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.3109 - OrigRecLoss: 0.0947 - FeatRecLoss: 0.2160 - kl_Loss_Z: 1.3327e-05 - kl_Loss_FC: 6.3103e-05 - val_loss: 0.3436 - val_OrigRecLoss: 0.1119 - val_FeatRecLoss: 0.2317 - val_kl_Loss_Z: 1.2136e-05 - val_kl_Loss_FC: 6.4163e-05
# Epoch 79/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.3020 - OrigRecLoss: 0.0922 - FeatRecLoss: 0.2097 - kl_Loss_Z: 1.0635e-05 - kl_Loss_FC: 5.2265e-05 - val_loss: 0.3436 - val_OrigRecLoss: 0.1119 - val_FeatRecLoss: 0.2317 - val_kl_Loss_Z: 9.1456e-06 - val_kl_Loss_FC: 2.6628e-05
# Epoch 80/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.3051 - OrigRecLoss: 0.0930 - FeatRecLoss: 0.2121 - kl_Loss_Z: 8.0470e-06 - kl_Loss_FC: 2.2800e-05 - val_loss: 0.3435 - val_OrigRecLoss: 0.1119 - val_FeatRecLoss: 0.2317 - val_kl_Loss_Z: 6.7467e-06 - val_kl_Loss_FC: 1.7361e-05
# Epoch 81/1000
# 19/19 [==============================] - 1s 43ms/step - loss: 0.3041 - OrigRecLoss: 0.0931 - FeatRecLoss: 0.2110 - kl_Loss_Z: 5.5946e-06 - kl_Loss_FC: 4.8011e-05 - val_loss: 0.3435 - val_OrigRecLoss: 0.1118 - val_FeatRecLoss: 0.2317 - val_kl_Loss_Z: 4.5885e-06 - val_kl_Loss_FC: 4.5363e-05
# Epoch 82/1000
# 19/19 [==============================] - 1s 46ms/step - loss: 0.3097 - OrigRecLoss: 0.0950 - FeatRecLoss: 0.2146 - kl_Loss_Z: 3.1898e-06 - kl_Loss_FC: 9.3765e-05 - val_loss: 0.3436 - val_OrigRecLoss: 0.1118 - val_FeatRecLoss: 0.2317 - val_kl_Loss_Z: 2.4212e-06 - val_kl_Loss_FC: 5.8888e-05
# Epoch 83/1000
# 19/19 [==============================] - 1s 46ms/step - loss: 0.3106 - OrigRecLoss: 0.0948 - FeatRecLoss: 0.2158 - kl_Loss_Z: 1.1292e-06 - kl_Loss_FC: 4.0574e-05 - val_loss: 0.3435 - val_OrigRecLoss: 0.1118 - val_FeatRecLoss: 0.2316 - val_kl_Loss_Z: 1.9511e-07 - val_kl_Loss_FC: 6.9643e-05
# Epoch 84/1000
# 19/19 [==============================] - 1s 46ms/step - loss: 0.3014 - OrigRecLoss: 0.0920 - FeatRecLoss: 0.2093 - kl_Loss_Z: 2.4114e-07 - kl_Loss_FC: 4.6321e-05 - val_loss: 0.3435 - val_OrigRecLoss: 0.1118 - val_FeatRecLoss: 0.2316 - val_kl_Loss_Z: 1.0146e-07 - val_kl_Loss_FC: 4.6951e-05
# Epoch 85/1000
# 19/19 [==============================] - 1s 46ms/step - loss: 0.3100 - OrigRecLoss: 0.0943 - FeatRecLoss: 0.2155 - kl_Loss_Z: 3.6404e-07 - kl_Loss_FC: 7.0462e-05 - val_loss: 0.3437 - val_OrigRecLoss: 0.1118 - val_FeatRecLoss: 0.2316 - val_kl_Loss_Z: 9.4646e-07 - val_kl_Loss_FC: 1.8625e-04
# Epoch 86/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.2997 - OrigRecLoss: 0.0914 - FeatRecLoss: 0.2082 - kl_Loss_Z: 4.1483e-07 - kl_Loss_FC: 7.4954e-05 - val_loss: 0.3435 - val_OrigRecLoss: 0.1118 - val_FeatRecLoss: 0.2316 - val_kl_Loss_Z: 1.1004e-07 - val_kl_Loss_FC: 7.5573e-05
# Epoch 87/1000
# 19/19 [==============================] - 1s 43ms/step - loss: 0.3047 - OrigRecLoss: 0.0933 - FeatRecLoss: 0.2113 - kl_Loss_Z: 3.7157e-07 - kl_Loss_FC: 7.0933e-05 - val_loss: 0.3434 - val_OrigRecLoss: 0.1118 - val_FeatRecLoss: 0.2316 - val_kl_Loss_Z: 1.0138e-07 - val_kl_Loss_FC: 8.1249e-06
# Epoch 88/1000
# 19/19 [==============================] - 1s 45ms/step - loss: 0.3045 - OrigRecLoss: 0.0935 - FeatRecLoss: 0.2109 - kl_Loss_Z: 2.5270e-07 - kl_Loss_FC: 4.6462e-05 - val_loss: 0.3435 - val_OrigRecLoss: 0.1118 - val_FeatRecLoss: 0.2316 - val_kl_Loss_Z: 1.7912e-07 - val_kl_Loss_FC: 6.5297e-05
# Epoch 89/1000
# 19/19 [==============================] - 1s 43ms/step - loss: 0.3091 - OrigRecLoss: 0.0943 - FeatRecLoss: 0.2148 - kl_Loss_Z: 2.6430e-07 - kl_Loss_FC: 4.2889e-05 - val_loss: 0.3436 - val_OrigRecLoss: 0.1118 - val_FeatRecLoss: 0.2316 - val_kl_Loss_Z: 8.3796e-07 - val_kl_Loss_FC: 1.5470e-04
# Epoch 90/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.3099 - OrigRecLoss: 0.0938 - FeatRecLoss: 0.2160 - kl_Loss_Z: 5.1013e-07 - kl_Loss_FC: 9.9987e-05 - val_loss: 0.3434 - val_OrigRecLoss: 0.1118 - val_FeatRecLoss: 0.2316 - val_kl_Loss_Z: 4.0263e-07 - val_kl_Loss_FC: 4.0131e-05
# Epoch 91/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.3004 - OrigRecLoss: 0.0916 - FeatRecLoss: 0.2088 - kl_Loss_Z: 2.8910e-07 - kl_Loss_FC: 5.2129e-05 - val_loss: 0.3434 - val_OrigRecLoss: 0.1118 - val_FeatRecLoss: 0.2316 - val_kl_Loss_Z: 6.2566e-08 - val_kl_Loss_FC: 7.1066e-06
# Epoch 92/1000
# 19/19 [==============================] - 1s 43ms/step - loss: 0.3002 - OrigRecLoss: 0.0920 - FeatRecLoss: 0.2082 - kl_Loss_Z: 3.2250e-07 - kl_Loss_FC: 6.5363e-05 - val_loss: 0.3434 - val_OrigRecLoss: 0.1118 - val_FeatRecLoss: 0.2316 - val_kl_Loss_Z: 9.1231e-08 - val_kl_Loss_FC: 4.5727e-05
# Epoch 93/1000
# 19/19 [==============================] - 1s 45ms/step - loss: 0.3198 - OrigRecLoss: 0.1032 - FeatRecLoss: 0.2166 - kl_Loss_Z: 3.4390e-07 - kl_Loss_FC: 6.0046e-05 - val_loss: 0.3434 - val_OrigRecLoss: 0.1118 - val_FeatRecLoss: 0.2316 - val_kl_Loss_Z: 5.9696e-08 - val_kl_Loss_FC: 7.0090e-06
# Epoch 94/1000
# 19/19 [==============================] - 1s 47ms/step - loss: 0.2993 - OrigRecLoss: 0.0913 - FeatRecLoss: 0.2080 - kl_Loss_Z: 3.0092e-07 - kl_Loss_FC: 5.2159e-05 - val_loss: 0.3435 - val_OrigRecLoss: 0.1118 - val_FeatRecLoss: 0.2316 - val_kl_Loss_Z: 4.5926e-07 - val_kl_Loss_FC: 1.1205e-04
# Epoch 95/1000
# 19/19 [==============================] - 1s 48ms/step - loss: 0.3022 - OrigRecLoss: 0.0921 - FeatRecLoss: 0.2100 - kl_Loss_Z: 6.0211e-07 - kl_Loss_FC: 1.1300e-04 - val_loss: 0.3434 - val_OrigRecLoss: 0.1118 - val_FeatRecLoss: 0.2316 - val_kl_Loss_Z: 4.2823e-07 - val_kl_Loss_FC: 4.8041e-05
# Epoch 96/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.3088 - OrigRecLoss: 0.0941 - FeatRecLoss: 0.2146 - kl_Loss_Z: 3.5136e-07 - kl_Loss_FC: 6.6078e-05 - val_loss: 0.3433 - val_OrigRecLoss: 0.1118 - val_FeatRecLoss: 0.2316 - val_kl_Loss_Z: 1.0868e-07 - val_kl_Loss_FC: 1.2577e-05
# Epoch 97/1000
# 19/19 [==============================] - 1s 45ms/step - loss: 0.3038 - OrigRecLoss: 0.0928 - FeatRecLoss: 0.2111 - kl_Loss_Z: 1.5419e-07 - kl_Loss_FC: 2.5756e-05 - val_loss: 0.3433 - val_OrigRecLoss: 0.1118 - val_FeatRecLoss: 0.2316 - val_kl_Loss_Z: 6.1933e-08 - val_kl_Loss_FC: 8.0645e-06
# Epoch 98/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.3112 - OrigRecLoss: 0.0951 - FeatRecLoss: 0.2161 - kl_Loss_Z: 1.3554e-07 - kl_Loss_FC: 2.2706e-05 - val_loss: 0.3434 - val_OrigRecLoss: 0.1118 - val_FeatRecLoss: 0.2315 - val_kl_Loss_Z: 7.5619e-07 - val_kl_Loss_FC: 9.5948e-05
# Epoch 99/1000
# 19/19 [==============================] - 1s 43ms/step - loss: 0.3035 - OrigRecLoss: 0.0923 - FeatRecLoss: 0.2111 - kl_Loss_Z: 3.9278e-07 - kl_Loss_FC: 6.6359e-05 - val_loss: 0.3433 - val_OrigRecLoss: 0.1118 - val_FeatRecLoss: 0.2315 - val_kl_Loss_Z: 7.2423e-08 - val_kl_Loss_FC: 1.7752e-05
# Epoch 100/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.3017 - OrigRecLoss: 0.0921 - FeatRecLoss: 0.2096 - kl_Loss_Z: 3.1769e-07 - kl_Loss_FC: 5.7204e-05 - val_loss: 0.3433 - val_OrigRecLoss: 0.1118 - val_FeatRecLoss: 0.2315 - val_kl_Loss_Z: 1.2128e-07 - val_kl_Loss_FC: 1.0893e-05
# Epoch 101/1000
# 19/19 [==============================] - 1s 43ms/step - loss: 0.3042 - OrigRecLoss: 0.0928 - FeatRecLoss: 0.2113 - kl_Loss_Z: 1.9620e-07 - kl_Loss_FC: 3.6248e-05 - val_loss: 0.3433 - val_OrigRecLoss: 0.1118 - val_FeatRecLoss: 0.2315 - val_kl_Loss_Z: 5.8458e-08 - val_kl_Loss_FC: 1.6630e-05
# Epoch 102/1000
# 19/19 [==============================] - 1s 43ms/step - loss: 0.3039 - OrigRecLoss: 0.0926 - FeatRecLoss: 0.2113 - kl_Loss_Z: 2.2910e-07 - kl_Loss_FC: 3.9218e-05 - val_loss: 0.3433 - val_OrigRecLoss: 0.1118 - val_FeatRecLoss: 0.2315 - val_kl_Loss_Z: 6.7882e-08 - val_kl_Loss_FC: 3.9220e-05
# Epoch 103/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.3002 - OrigRecLoss: 0.0915 - FeatRecLoss: 0.2087 - kl_Loss_Z: 1.9643e-07 - kl_Loss_FC: 4.2814e-05 - val_loss: 0.3434 - val_OrigRecLoss: 0.1118 - val_FeatRecLoss: 0.2315 - val_kl_Loss_Z: 4.3789e-07 - val_kl_Loss_FC: 1.1059e-04
# Epoch 104/1000
# 19/19 [==============================] - 1s 43ms/step - loss: 0.3055 - OrigRecLoss: 0.0929 - FeatRecLoss: 0.2125 - kl_Loss_Z: 5.0418e-07 - kl_Loss_FC: 9.4643e-05 - val_loss: 0.3434 - val_OrigRecLoss: 0.1118 - val_FeatRecLoss: 0.2315 - val_kl_Loss_Z: 4.6188e-07 - val_kl_Loss_FC: 1.1517e-04
# Epoch 105/1000
# 19/19 [==============================] - 1s 43ms/step - loss: 0.3068 - OrigRecLoss: 0.0937 - FeatRecLoss: 0.2130 - kl_Loss_Z: 3.5737e-07 - kl_Loss_FC: 6.9888e-05 - val_loss: 0.3433 - val_OrigRecLoss: 0.1117 - val_FeatRecLoss: 0.2315 - val_kl_Loss_Z: 3.6396e-07 - val_kl_Loss_FC: 7.5575e-05
# Epoch 106/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.3131 - OrigRecLoss: 0.0955 - FeatRecLoss: 0.2175 - kl_Loss_Z: 3.4123e-07 - kl_Loss_FC: 5.2611e-05 - val_loss: 0.3433 - val_OrigRecLoss: 0.1117 - val_FeatRecLoss: 0.2315 - val_kl_Loss_Z: 8.6194e-07 - val_kl_Loss_FC: 1.2939e-04
# Epoch 107/1000
# 19/19 [==============================] - 1s 45ms/step - loss: 0.3288 - OrigRecLoss: 0.0989 - FeatRecLoss: 0.2299 - kl_Loss_Z: 4.3962e-07 - kl_Loss_FC: 4.4310e-05 - val_loss: 0.3433 - val_OrigRecLoss: 0.1117 - val_FeatRecLoss: 0.2315 - val_kl_Loss_Z: 1.3491e-06 - val_kl_Loss_FC: 6.5919e-05
# Epoch 108/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.3043 - OrigRecLoss: 0.0928 - FeatRecLoss: 0.2114 - kl_Loss_Z: 7.0885e-07 - kl_Loss_FC: 4.8119e-05 - val_loss: 0.3432 - val_OrigRecLoss: 0.1117 - val_FeatRecLoss: 0.2315 - val_kl_Loss_Z: 2.2937e-07 - val_kl_Loss_FC: 9.0756e-06
# Epoch 109/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.3027 - OrigRecLoss: 0.0923 - FeatRecLoss: 0.2103 - kl_Loss_Z: 1.3434e-06 - kl_Loss_FC: 5.0695e-05 - val_loss: 0.3432 - val_OrigRecLoss: 0.1117 - val_FeatRecLoss: 0.2314 - val_kl_Loss_Z: 1.0272e-06 - val_kl_Loss_FC: 7.1240e-06
# Epoch 110/1000
# 19/19 [==============================] - 1s 43ms/step - loss: 0.3142 - OrigRecLoss: 0.0952 - FeatRecLoss: 0.2190 - kl_Loss_Z: 4.6826e-07 - kl_Loss_FC: 9.9889e-05 - val_loss: 0.3432 - val_OrigRecLoss: 0.1117 - val_FeatRecLoss: 0.2314 - val_kl_Loss_Z: 9.5656e-08 - val_kl_Loss_FC: 7.7575e-05
# Epoch 111/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.3012 - OrigRecLoss: 0.0918 - FeatRecLoss: 0.2094 - kl_Loss_Z: 4.7662e-07 - kl_Loss_FC: 7.7115e-05 - val_loss: 0.3431 - val_OrigRecLoss: 0.1117 - val_FeatRecLoss: 0.2314 - val_kl_Loss_Z: 4.1965e-07 - val_kl_Loss_FC: 3.3257e-05
# Epoch 112/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.3005 - OrigRecLoss: 0.0916 - FeatRecLoss: 0.2087 - kl_Loss_Z: 8.0357e-07 - kl_Loss_FC: 1.0044e-04 - val_loss: 0.3432 - val_OrigRecLoss: 0.1117 - val_FeatRecLoss: 0.2313 - val_kl_Loss_Z: 3.2379e-06 - val_kl_Loss_FC: 1.5458e-04
# Epoch 113/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.3022 - OrigRecLoss: 0.0920 - FeatRecLoss: 0.2101 - kl_Loss_Z: 2.9924e-06 - kl_Loss_FC: 1.0569e-04 - val_loss: 0.3428 - val_OrigRecLoss: 0.1117 - val_FeatRecLoss: 0.2311 - val_kl_Loss_Z: 4.4588e-06 - val_kl_Loss_FC: 4.8575e-05
# Epoch 114/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.3061 - OrigRecLoss: 0.0959 - FeatRecLoss: 0.2102 - kl_Loss_Z: 5.6907e-06 - kl_Loss_FC: 7.4684e-05 - val_loss: 0.3422 - val_OrigRecLoss: 0.1117 - val_FeatRecLoss: 0.2302 - val_kl_Loss_Z: 1.8383e-05 - val_kl_Loss_FC: 2.2193e-04
# Epoch 115/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.3129 - OrigRecLoss: 0.1019 - FeatRecLoss: 0.2108 - kl_Loss_Z: 2.5296e-05 - kl_Loss_FC: 1.0690e-04 - val_loss: 0.3410 - val_OrigRecLoss: 0.1117 - val_FeatRecLoss: 0.2291 - val_kl_Loss_Z: 3.7983e-05 - val_kl_Loss_FC: 1.5680e-04
# Epoch 116/1000
# 19/19 [==============================] - 1s 45ms/step - loss: 0.3010 - OrigRecLoss: 0.0926 - FeatRecLoss: 0.2083 - kl_Loss_Z: 4.9099e-05 - kl_Loss_FC: 5.4481e-05 - val_loss: 0.3398 - val_OrigRecLoss: 0.1117 - val_FeatRecLoss: 0.2280 - val_kl_Loss_Z: 7.1993e-05 - val_kl_Loss_FC: 1.2429e-05
# Epoch 117/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.2984 - OrigRecLoss: 0.0920 - FeatRecLoss: 0.2063 - kl_Loss_Z: 6.6305e-05 - kl_Loss_FC: 5.5286e-05 - val_loss: 0.3390 - val_OrigRecLoss: 0.1117 - val_FeatRecLoss: 0.2272 - val_kl_Loss_Z: 5.5906e-05 - val_kl_Loss_FC: 9.3453e-05
# Epoch 118/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.2996 - OrigRecLoss: 0.0930 - FeatRecLoss: 0.2064 - kl_Loss_Z: 8.5277e-05 - kl_Loss_FC: 7.1328e-05 - val_loss: 0.3369 - val_OrigRecLoss: 0.1117 - val_FeatRecLoss: 0.2249 - val_kl_Loss_Z: 9.0176e-05 - val_kl_Loss_FC: 1.1248e-04
# Epoch 119/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.2961 - OrigRecLoss: 0.0926 - FeatRecLoss: 0.2033 - kl_Loss_Z: 9.4746e-05 - kl_Loss_FC: 5.7254e-05 - val_loss: 0.3358 - val_OrigRecLoss: 0.1117 - val_FeatRecLoss: 0.2240 - val_kl_Loss_Z: 1.2184e-04 - val_kl_Loss_FC: 2.8202e-05
# Epoch 120/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.2923 - OrigRecLoss: 0.0914 - FeatRecLoss: 0.2007 - kl_Loss_Z: 1.0519e-04 - kl_Loss_FC: 4.9580e-05 - val_loss: 0.3343 - val_OrigRecLoss: 0.1117 - val_FeatRecLoss: 0.2224 - val_kl_Loss_Z: 1.1378e-04 - val_kl_Loss_FC: 2.9618e-05
# Epoch 121/1000
# 19/19 [==============================] - 1s 45ms/step - loss: 0.2945 - OrigRecLoss: 0.0924 - FeatRecLoss: 0.2020 - kl_Loss_Z: 1.0523e-04 - kl_Loss_FC: 4.1281e-05 - val_loss: 0.3334 - val_OrigRecLoss: 0.1117 - val_FeatRecLoss: 0.2215 - val_kl_Loss_Z: 1.0138e-04 - val_kl_Loss_FC: 3.4638e-05
# Epoch 122/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.2925 - OrigRecLoss: 0.0919 - FeatRecLoss: 0.2005 - kl_Loss_Z: 1.1153e-04 - kl_Loss_FC: 5.1465e-05 - val_loss: 0.3329 - val_OrigRecLoss: 0.1117 - val_FeatRecLoss: 0.2210 - val_kl_Loss_Z: 1.2375e-04 - val_kl_Loss_FC: 5.6986e-05
# Epoch 123/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.2951 - OrigRecLoss: 0.0929 - FeatRecLoss: 0.2020 - kl_Loss_Z: 1.2551e-04 - kl_Loss_FC: 8.5583e-05 - val_loss: 0.3319 - val_OrigRecLoss: 0.1117 - val_FeatRecLoss: 0.2201 - val_kl_Loss_Z: 1.3387e-04 - val_kl_Loss_FC: 2.1540e-05
# Epoch 124/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.3050 - OrigRecLoss: 0.0955 - FeatRecLoss: 0.2093 - kl_Loss_Z: 1.4595e-04 - kl_Loss_FC: 6.0842e-05 - val_loss: 0.3310 - val_OrigRecLoss: 0.1117 - val_FeatRecLoss: 0.2191 - val_kl_Loss_Z: 1.3887e-04 - val_kl_Loss_FC: 7.7206e-05
# Epoch 125/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.2867 - OrigRecLoss: 0.0909 - FeatRecLoss: 0.1956 - kl_Loss_Z: 1.5201e-04 - kl_Loss_FC: 4.4968e-05 - val_loss: 0.3293 - val_OrigRecLoss: 0.1117 - val_FeatRecLoss: 0.2173 - val_kl_Loss_Z: 1.5540e-04 - val_kl_Loss_FC: 1.7029e-04
# Epoch 126/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.2864 - OrigRecLoss: 0.0912 - FeatRecLoss: 0.1950 - kl_Loss_Z: 1.6187e-04 - kl_Loss_FC: 9.9385e-05 - val_loss: 0.3271 - val_OrigRecLoss: 0.1117 - val_FeatRecLoss: 0.2152 - val_kl_Loss_Z: 1.6116e-04 - val_kl_Loss_FC: 6.1944e-05
# Epoch 127/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.2865 - OrigRecLoss: 0.0919 - FeatRecLoss: 0.1944 - kl_Loss_Z: 1.6517e-04 - kl_Loss_FC: 4.8789e-05 - val_loss: 0.3242 - val_OrigRecLoss: 0.1117 - val_FeatRecLoss: 0.2122 - val_kl_Loss_Z: 1.7115e-04 - val_kl_Loss_FC: 1.2868e-04
# Epoch 128/1000
# 19/19 [==============================] - 1s 43ms/step - loss: 0.2853 - OrigRecLoss: 0.0921 - FeatRecLoss: 0.1929 - kl_Loss_Z: 1.7225e-04 - kl_Loss_FC: 6.0347e-05 - val_loss: 0.3219 - val_OrigRecLoss: 0.1117 - val_FeatRecLoss: 0.2099 - val_kl_Loss_Z: 1.7782e-04 - val_kl_Loss_FC: 8.6697e-05
# Epoch 129/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.2825 - OrigRecLoss: 0.0917 - FeatRecLoss: 0.1905 - kl_Loss_Z: 1.7002e-04 - kl_Loss_FC: 8.7183e-05 - val_loss: 0.3203 - val_OrigRecLoss: 0.1117 - val_FeatRecLoss: 0.2083 - val_kl_Loss_Z: 1.9790e-04 - val_kl_Loss_FC: 9.8959e-05
# Epoch 130/1000
# 19/19 [==============================] - 1s 47ms/step - loss: 0.2861 - OrigRecLoss: 0.0937 - FeatRecLoss: 0.1922 - kl_Loss_Z: 1.5692e-04 - kl_Loss_FC: 7.5151e-05 - val_loss: 0.3185 - val_OrigRecLoss: 0.1117 - val_FeatRecLoss: 0.2066 - val_kl_Loss_Z: 1.7232e-04 - val_kl_Loss_FC: 9.0821e-05
# Epoch 131/1000
# 19/19 [==============================] - 1s 45ms/step - loss: 0.2849 - OrigRecLoss: 0.0931 - FeatRecLoss: 0.1916 - kl_Loss_Z: 1.6566e-04 - kl_Loss_FC: 9.0969e-05 - val_loss: 0.3177 - val_OrigRecLoss: 0.1117 - val_FeatRecLoss: 0.2058 - val_kl_Loss_Z: 1.8841e-04 - val_kl_Loss_FC: 5.2107e-05
# Epoch 132/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.2843 - OrigRecLoss: 0.0933 - FeatRecLoss: 0.1907 - kl_Loss_Z: 1.7482e-04 - kl_Loss_FC: 1.3384e-04 - val_loss: 0.3171 - val_OrigRecLoss: 0.1117 - val_FeatRecLoss: 0.2051 - val_kl_Loss_Z: 1.9624e-04 - val_kl_Loss_FC: 9.5177e-05
# Epoch 133/1000
# 19/19 [==============================] - 1s 45ms/step - loss: 0.2781 - OrigRecLoss: 0.0912 - FeatRecLoss: 0.1866 - kl_Loss_Z: 1.6999e-04 - kl_Loss_FC: 1.4642e-04 - val_loss: 0.3168 - val_OrigRecLoss: 0.1117 - val_FeatRecLoss: 0.2048 - val_kl_Loss_Z: 1.5687e-04 - val_kl_Loss_FC: 1.4817e-04
# Epoch 134/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.2791 - OrigRecLoss: 0.0920 - FeatRecLoss: 0.1867 - kl_Loss_Z: 1.7572e-04 - kl_Loss_FC: 1.7558e-04 - val_loss: 0.3155 - val_OrigRecLoss: 0.1117 - val_FeatRecLoss: 0.2035 - val_kl_Loss_Z: 1.7948e-04 - val_kl_Loss_FC: 8.2080e-05
# Epoch 135/1000
# 19/19 [==============================] - 1s 43ms/step - loss: 0.2841 - OrigRecLoss: 0.0945 - FeatRecLoss: 0.1893 - kl_Loss_Z: 1.8081e-04 - kl_Loss_FC: 1.3872e-04 - val_loss: 0.3146 - val_OrigRecLoss: 0.1117 - val_FeatRecLoss: 0.2027 - val_kl_Loss_Z: 1.7517e-04 - val_kl_Loss_FC: 7.2635e-05
# Epoch 136/1000
# 19/19 [==============================] - 1s 43ms/step - loss: 0.2760 - OrigRecLoss: 0.0919 - FeatRecLoss: 0.1839 - kl_Loss_Z: 1.8969e-04 - kl_Loss_FC: 7.0289e-05 - val_loss: 0.3135 - val_OrigRecLoss: 0.1117 - val_FeatRecLoss: 0.2015 - val_kl_Loss_Z: 2.1469e-04 - val_kl_Loss_FC: 1.1843e-04
# Epoch 137/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.2750 - OrigRecLoss: 0.0919 - FeatRecLoss: 0.1828 - kl_Loss_Z: 2.1094e-04 - kl_Loss_FC: 7.5574e-05 - val_loss: 0.3121 - val_OrigRecLoss: 0.1117 - val_FeatRecLoss: 0.2000 - val_kl_Loss_Z: 2.5800e-04 - val_kl_Loss_FC: 9.9622e-05
# Epoch 138/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.2797 - OrigRecLoss: 0.0931 - FeatRecLoss: 0.1862 - kl_Loss_Z: 2.4907e-04 - kl_Loss_FC: 9.5619e-05 - val_loss: 0.3107 - val_OrigRecLoss: 0.1117 - val_FeatRecLoss: 0.1987 - val_kl_Loss_Z: 2.7701e-04 - val_kl_Loss_FC: 7.2590e-05
# Epoch 139/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.2782 - OrigRecLoss: 0.0929 - FeatRecLoss: 0.1850 - kl_Loss_Z: 3.0108e-04 - kl_Loss_FC: 7.8548e-05 - val_loss: 0.3090 - val_OrigRecLoss: 0.1117 - val_FeatRecLoss: 0.1969 - val_kl_Loss_Z: 3.1682e-04 - val_kl_Loss_FC: 1.1246e-04
# Epoch 140/1000
# 19/19 [==============================] - 1s 43ms/step - loss: 0.2774 - OrigRecLoss: 0.0952 - FeatRecLoss: 0.1818 - kl_Loss_Z: 3.5846e-04 - kl_Loss_FC: 7.8486e-05 - val_loss: 0.3063 - val_OrigRecLoss: 0.1117 - val_FeatRecLoss: 0.1941 - val_kl_Loss_Z: 4.2673e-04 - val_kl_Loss_FC: 9.5634e-05
# Epoch 141/1000
# 19/19 [==============================] - 1s 43ms/step - loss: 0.2836 - OrigRecLoss: 0.1035 - FeatRecLoss: 0.1794 - kl_Loss_Z: 4.4381e-04 - kl_Loss_FC: 1.5940e-04 - val_loss: 0.3015 - val_OrigRecLoss: 0.1117 - val_FeatRecLoss: 0.1890 - val_kl_Loss_Z: 4.9969e-04 - val_kl_Loss_FC: 2.8781e-04
# Epoch 142/1000
# 19/19 [==============================] - 1s 45ms/step - loss: 0.2638 - OrigRecLoss: 0.0920 - FeatRecLoss: 0.1711 - kl_Loss_Z: 6.5150e-04 - kl_Loss_FC: 1.2542e-04 - val_loss: 0.2958 - val_OrigRecLoss: 0.1117 - val_FeatRecLoss: 0.1832 - val_kl_Loss_Z: 7.8860e-04 - val_kl_Loss_FC: 1.1452e-04
# Epoch 143/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.2636 - OrigRecLoss: 0.0964 - FeatRecLoss: 0.1663 - kl_Loss_Z: 8.5593e-04 - kl_Loss_FC: 9.2380e-05 - val_loss: 0.2927 - val_OrigRecLoss: 0.1117 - val_FeatRecLoss: 0.1800 - val_kl_Loss_Z: 9.0264e-04 - val_kl_Loss_FC: 1.2648e-04
# Epoch 144/1000
# 19/19 [==============================] - 1s 45ms/step - loss: 0.2570 - OrigRecLoss: 0.0927 - FeatRecLoss: 0.1633 - kl_Loss_Z: 9.4023e-04 - kl_Loss_FC: 1.1530e-04 - val_loss: 0.2906 - val_OrigRecLoss: 0.1117 - val_FeatRecLoss: 0.1777 - val_kl_Loss_Z: 9.8627e-04 - val_kl_Loss_FC: 2.6688e-04
# Epoch 145/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.2578 - OrigRecLoss: 0.0934 - FeatRecLoss: 0.1633 - kl_Loss_Z: 0.0010 - kl_Loss_FC: 1.6151e-04 - val_loss: 0.2889 - val_OrigRecLoss: 0.1117 - val_FeatRecLoss: 0.1761 - val_kl_Loss_Z: 0.0010 - val_kl_Loss_FC: 1.0224e-04
# Epoch 146/1000
# 19/19 [==============================] - 1s 45ms/step - loss: 0.2504 - OrigRecLoss: 0.0912 - FeatRecLoss: 0.1580 - kl_Loss_Z: 9.8478e-04 - kl_Loss_FC: 1.4842e-04 - val_loss: 0.2873 - val_OrigRecLoss: 0.1117 - val_FeatRecLoss: 0.1745 - val_kl_Loss_Z: 9.9008e-04 - val_kl_Loss_FC: 1.2774e-04
# Epoch 147/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.2519 - OrigRecLoss: 0.0926 - FeatRecLoss: 0.1581 - kl_Loss_Z: 9.8516e-04 - kl_Loss_FC: 2.0571e-04 - val_loss: 0.2858 - val_OrigRecLoss: 0.1117 - val_FeatRecLoss: 0.1730 - val_kl_Loss_Z: 9.8260e-04 - val_kl_Loss_FC: 1.0326e-04
# Epoch 148/1000
# 19/19 [==============================] - 1s 45ms/step - loss: 0.2528 - OrigRecLoss: 0.0928 - FeatRecLoss: 0.1589 - kl_Loss_Z: 9.9643e-04 - kl_Loss_FC: 1.0037e-04 - val_loss: 0.2846 - val_OrigRecLoss: 0.1117 - val_FeatRecLoss: 0.1719 - val_kl_Loss_Z: 9.8810e-04 - val_kl_Loss_FC: 9.8395e-05
# Epoch 149/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.2535 - OrigRecLoss: 0.0961 - FeatRecLoss: 0.1563 - kl_Loss_Z: 0.0010 - kl_Loss_FC: 5.8094e-05 - val_loss: 0.2833 - val_OrigRecLoss: 0.1117 - val_FeatRecLoss: 0.1705 - val_kl_Loss_Z: 0.0010 - val_kl_Loss_FC: 1.3549e-04
# Epoch 150/1000
# 19/19 [==============================] - 1s 43ms/step - loss: 0.2542 - OrigRecLoss: 0.0950 - FeatRecLoss: 0.1581 - kl_Loss_Z: 0.0010 - kl_Loss_FC: 1.1839e-04 - val_loss: 0.2824 - val_OrigRecLoss: 0.1117 - val_FeatRecLoss: 0.1696 - val_kl_Loss_Z: 9.8433e-04 - val_kl_Loss_FC: 1.3952e-04
# Epoch 151/1000
# 19/19 [==============================] - 1s 43ms/step - loss: 0.2460 - OrigRecLoss: 0.0920 - FeatRecLoss: 0.1529 - kl_Loss_Z: 9.7635e-04 - kl_Loss_FC: 1.1768e-04 - val_loss: 0.2814 - val_OrigRecLoss: 0.1117 - val_FeatRecLoss: 0.1686 - val_kl_Loss_Z: 0.0010 - val_kl_Loss_FC: 1.2902e-04
# Epoch 152/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.2481 - OrigRecLoss: 0.0927 - FeatRecLoss: 0.1543 - kl_Loss_Z: 9.8769e-04 - kl_Loss_FC: 1.6351e-04 - val_loss: 0.2806 - val_OrigRecLoss: 0.1117 - val_FeatRecLoss: 0.1679 - val_kl_Loss_Z: 9.8229e-04 - val_kl_Loss_FC: 8.4522e-05
# Epoch 153/1000
# 19/19 [==============================] - 1s 45ms/step - loss: 0.2438 - OrigRecLoss: 0.0918 - FeatRecLoss: 0.1509 - kl_Loss_Z: 9.6087e-04 - kl_Loss_FC: 1.0164e-04 - val_loss: 0.2802 - val_OrigRecLoss: 0.1117 - val_FeatRecLoss: 0.1674 - val_kl_Loss_Z: 9.7402e-04 - val_kl_Loss_FC: 2.1960e-04
# Epoch 154/1000
# 19/19 [==============================] - 1s 46ms/step - loss: 0.2540 - OrigRecLoss: 0.0947 - FeatRecLoss: 0.1582 - kl_Loss_Z: 9.5908e-04 - kl_Loss_FC: 9.3642e-05 - val_loss: 0.2798 - val_OrigRecLoss: 0.1117 - val_FeatRecLoss: 0.1670 - val_kl_Loss_Z: 9.5401e-04 - val_kl_Loss_FC: 1.6144e-04
# Epoch 155/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.2577 - OrigRecLoss: 0.1021 - FeatRecLoss: 0.1544 - kl_Loss_Z: 9.3213e-04 - kl_Loss_FC: 2.2932e-04 - val_loss: 0.2793 - val_OrigRecLoss: 0.1117 - val_FeatRecLoss: 0.1666 - val_kl_Loss_Z: 9.1765e-04 - val_kl_Loss_FC: 8.0044e-05
# Epoch 156/1000
# 19/19 [==============================] - 1s 45ms/step - loss: 0.2419 - OrigRecLoss: 0.0914 - FeatRecLoss: 0.1495 - kl_Loss_Z: 9.2118e-04 - kl_Loss_FC: 8.7837e-05 - val_loss: 0.2787 - val_OrigRecLoss: 0.1117 - val_FeatRecLoss: 0.1661 - val_kl_Loss_Z: 9.0995e-04 - val_kl_Loss_FC: 1.1432e-04
# Epoch 157/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.2435 - OrigRecLoss: 0.0919 - FeatRecLoss: 0.1506 - kl_Loss_Z: 9.2195e-04 - kl_Loss_FC: 1.2642e-04 - val_loss: 0.2784 - val_OrigRecLoss: 0.1117 - val_FeatRecLoss: 0.1657 - val_kl_Loss_Z: 9.3110e-04 - val_kl_Loss_FC: 7.6573e-05
# Epoch 158/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.2516 - OrigRecLoss: 0.0949 - FeatRecLoss: 0.1556 - kl_Loss_Z: 9.2132e-04 - kl_Loss_FC: 1.3040e-04 - val_loss: 0.2783 - val_OrigRecLoss: 0.1116 - val_FeatRecLoss: 0.1656 - val_kl_Loss_Z: 8.7344e-04 - val_kl_Loss_FC: 2.2685e-04
# Epoch 159/1000
# ...
# Epoch 664/1000
# 19/19 [==============================] - 1s 45ms/step - loss: 0.2073 - OrigRecLoss: 0.0923 - FeatRecLoss: 0.1137 - kl_Loss_Z: 0.0013 - kl_Loss_FC: 9.7006e-05 - val_loss: 0.2420 - val_OrigRecLoss: 0.1116 - val_FeatRecLoss: 0.1290 - val_kl_Loss_Z: 0.0013 - val_kl_Loss_FC: 1.3214e-04
# Epoch 665/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.2253 - OrigRecLoss: 0.1043 - FeatRecLoss: 0.1196 - kl_Loss_Z: 0.0013 - kl_Loss_FC: 1.4752e-04 - val_loss: 0.2420 - val_OrigRecLoss: 0.1116 - val_FeatRecLoss: 0.1289 - val_kl_Loss_Z: 0.0013 - val_kl_Loss_FC: 2.1751e-04
# Epoch 666/1000
# 19/19 [==============================] - 1s 45ms/step - loss: 0.2067 - OrigRecLoss: 0.0916 - FeatRecLoss: 0.1136 - kl_Loss_Z: 0.0013 - kl_Loss_FC: 2.0200e-04 - val_loss: 0.2420 - val_OrigRecLoss: 0.1116 - val_FeatRecLoss: 0.1290 - val_kl_Loss_Z: 0.0013 - val_kl_Loss_FC: 1.2001e-04
# Epoch 667/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.2067 - OrigRecLoss: 0.0914 - FeatRecLoss: 0.1139 - kl_Loss_Z: 0.0013 - kl_Loss_FC: 1.0627e-04 - val_loss: 0.2419 - val_OrigRecLoss: 0.1116 - val_FeatRecLoss: 0.1289 - val_kl_Loss_Z: 0.0013 - val_kl_Loss_FC: 1.2259e-04
# Epoch 668/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.2079 - OrigRecLoss: 0.0921 - FeatRecLoss: 0.1143 - kl_Loss_Z: 0.0013 - kl_Loss_FC: 1.7639e-04 - val_loss: 0.2420 - val_OrigRecLoss: 0.1116 - val_FeatRecLoss: 0.1290 - val_kl_Loss_Z: 0.0013 - val_kl_Loss_FC: 1.1275e-04
# Epoch 669/1000
# 19/19 [==============================] - 1s 43ms/step - loss: 0.2088 - OrigRecLoss: 0.0923 - FeatRecLoss: 0.1150 - kl_Loss_Z: 0.0013 - kl_Loss_FC: 1.2828e-04 - val_loss: 0.2420 - val_OrigRecLoss: 0.1116 - val_FeatRecLoss: 0.1289 - val_kl_Loss_Z: 0.0013 - val_kl_Loss_FC: 1.6412e-04
# Epoch 670/1000
# 19/19 [==============================] - 1s 45ms/step - loss: 0.2118 - OrigRecLoss: 0.0934 - FeatRecLoss: 0.1170 - kl_Loss_Z: 0.0013 - kl_Loss_FC: 1.6776e-04 - val_loss: 0.2421 - val_OrigRecLoss: 0.1116 - val_FeatRecLoss: 0.1291 - val_kl_Loss_Z: 0.0013 - val_kl_Loss_FC: 1.2028e-04
# Epoch 671/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.2083 - OrigRecLoss: 0.0925 - FeatRecLoss: 0.1144 - kl_Loss_Z: 0.0013 - kl_Loss_FC: 1.5262e-04 - val_loss: 0.2419 - val_OrigRecLoss: 0.1116 - val_FeatRecLoss: 0.1289 - val_kl_Loss_Z: 0.0013 - val_kl_Loss_FC: 1.6314e-04
# Epoch 672/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.2083 - OrigRecLoss: 0.0923 - FeatRecLoss: 0.1147 - kl_Loss_Z: 0.0013 - kl_Loss_FC: 1.2653e-04 - val_loss: 0.2421 - val_OrigRecLoss: 0.1116 - val_FeatRecLoss: 0.1290 - val_kl_Loss_Z: 0.0013 - val_kl_Loss_FC: 2.3227e-04
# Epoch 673/1000
# 19/19 [==============================] - 1s 45ms/step - loss: 0.2067 - OrigRecLoss: 0.0916 - FeatRecLoss: 0.1136 - kl_Loss_Z: 0.0013 - kl_Loss_FC: 1.4186e-04 - val_loss: 0.2420 - val_OrigRecLoss: 0.1116 - val_FeatRecLoss: 0.1290 - val_kl_Loss_Z: 0.0013 - val_kl_Loss_FC: 1.4092e-04
# Epoch 674/1000
# 19/19 [==============================] - 1s 45ms/step - loss: 0.2209 - OrigRecLoss: 0.1020 - FeatRecLoss: 0.1175 - kl_Loss_Z: 0.0013 - kl_Loss_FC: 1.5000e-04 - val_loss: 0.2419 - val_OrigRecLoss: 0.1116 - val_FeatRecLoss: 0.1289 - val_kl_Loss_Z: 0.0013 - val_kl_Loss_FC: 1.4109e-04
# Epoch 675/1000
# 19/19 [==============================] - 1s 45ms/step - loss: 0.2071 - OrigRecLoss: 0.0918 - FeatRecLoss: 0.1139 - kl_Loss_Z: 0.0013 - kl_Loss_FC: 1.1541e-04 - val_loss: 0.2421 - val_OrigRecLoss: 0.1116 - val_FeatRecLoss: 0.1291 - val_kl_Loss_Z: 0.0013 - val_kl_Loss_FC: 1.3795e-04
# Epoch 676/1000
# 19/19 [==============================] - 1s 45ms/step - loss: 0.2064 - OrigRecLoss: 0.0915 - FeatRecLoss: 0.1135 - kl_Loss_Z: 0.0013 - kl_Loss_FC: 1.1441e-04 - val_loss: 0.2417 - val_OrigRecLoss: 0.1116 - val_FeatRecLoss: 0.1287 - val_kl_Loss_Z: 0.0013 - val_kl_Loss_FC: 1.2171e-04
# Epoch 677/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.2074 - OrigRecLoss: 0.0919 - FeatRecLoss: 0.1141 - kl_Loss_Z: 0.0013 - kl_Loss_FC: 1.2218e-04 - val_loss: 0.2418 - val_OrigRecLoss: 0.1116 - val_FeatRecLoss: 0.1289 - val_kl_Loss_Z: 0.0013 - val_kl_Loss_FC: 1.0822e-04
# Epoch 678/1000
# 19/19 [==============================] - 1s 45ms/step - loss: 0.2055 - OrigRecLoss: 0.0911 - FeatRecLoss: 0.1130 - kl_Loss_Z: 0.0013 - kl_Loss_FC: 1.4002e-04 - val_loss: 0.2418 - val_OrigRecLoss: 0.1116 - val_FeatRecLoss: 0.1288 - val_kl_Loss_Z: 0.0013 - val_kl_Loss_FC: 1.4592e-04
# Epoch 679/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.2100 - OrigRecLoss: 0.0930 - FeatRecLoss: 0.1156 - kl_Loss_Z: 0.0013 - kl_Loss_FC: 1.2769e-04 - val_loss: 0.2418 - val_OrigRecLoss: 0.1116 - val_FeatRecLoss: 0.1289 - val_kl_Loss_Z: 0.0013 - val_kl_Loss_FC: 1.0799e-04
# Epoch 680/1000
# 19/19 [==============================] - 1s 45ms/step - loss: 0.2097 - OrigRecLoss: 0.0926 - FeatRecLoss: 0.1157 - kl_Loss_Z: 0.0013 - kl_Loss_FC: 1.0893e-04 - val_loss: 0.2418 - val_OrigRecLoss: 0.1116 - val_FeatRecLoss: 0.1288 - val_kl_Loss_Z: 0.0013 - val_kl_Loss_FC: 1.0815e-04
# Epoch 681/1000
# 19/19 [==============================] - 1s 46ms/step - loss: 0.2126 - OrigRecLoss: 0.0930 - FeatRecLoss: 0.1182 - kl_Loss_Z: 0.0013 - kl_Loss_FC: 8.5755e-05 - val_loss: 0.2418 - val_OrigRecLoss: 0.1116 - val_FeatRecLoss: 0.1288 - val_kl_Loss_Z: 0.0013 - val_kl_Loss_FC: 1.4244e-04
# Epoch 682/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.2106 - OrigRecLoss: 0.0931 - FeatRecLoss: 0.1161 - kl_Loss_Z: 0.0013 - kl_Loss_FC: 1.1665e-04 - val_loss: 0.2417 - val_OrigRecLoss: 0.1116 - val_FeatRecLoss: 0.1288 - val_kl_Loss_Z: 0.0013 - val_kl_Loss_FC: 1.1445e-04
# Epoch 683/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.2091 - OrigRecLoss: 0.0926 - FeatRecLoss: 0.1151 - kl_Loss_Z: 0.0013 - kl_Loss_FC: 8.7032e-05 - val_loss: 0.2418 - val_OrigRecLoss: 0.1116 - val_FeatRecLoss: 0.1289 - val_kl_Loss_Z: 0.0013 - val_kl_Loss_FC: 1.1355e-04
# Epoch 684/1000
# 19/19 [==============================] - 1s 47ms/step - loss: 0.2111 - OrigRecLoss: 0.0937 - FeatRecLoss: 0.1160 - kl_Loss_Z: 0.0013 - kl_Loss_FC: 1.1955e-04 - val_loss: 0.2418 - val_OrigRecLoss: 0.1116 - val_FeatRecLoss: 0.1288 - val_kl_Loss_Z: 0.0013 - val_kl_Loss_FC: 1.6044e-04
# Epoch 685/1000
# 19/19 [==============================] - 1s 46ms/step - loss: 0.2055 - OrigRecLoss: 0.0911 - FeatRecLoss: 0.1131 - kl_Loss_Z: 0.0013 - kl_Loss_FC: 8.6404e-05 - val_loss: 0.2418 - val_OrigRecLoss: 0.1116 - val_FeatRecLoss: 0.1288 - val_kl_Loss_Z: 0.0013 - val_kl_Loss_FC: 1.2173e-04
# Epoch 686/1000
# 19/19 [==============================] - 1s 46ms/step - loss: 0.2069 - OrigRecLoss: 0.0918 - FeatRecLoss: 0.1137 - kl_Loss_Z: 0.0013 - kl_Loss_FC: 7.2979e-05 - val_loss: 0.2417 - val_OrigRecLoss: 0.1116 - val_FeatRecLoss: 0.1287 - val_kl_Loss_Z: 0.0013 - val_kl_Loss_FC: 1.0600e-04
# Epoch 687/1000
# 19/19 [==============================] - 1s 45ms/step - loss: 0.2074 - OrigRecLoss: 0.0916 - FeatRecLoss: 0.1145 - kl_Loss_Z: 0.0013 - kl_Loss_FC: 1.0601e-04 - val_loss: 0.2417 - val_OrigRecLoss: 0.1116 - val_FeatRecLoss: 0.1287 - val_kl_Loss_Z: 0.0013 - val_kl_Loss_FC: 2.0331e-04
# Epoch 688/1000
# 19/19 [==============================] - 1s 45ms/step - loss: 0.2102 - OrigRecLoss: 0.0932 - FeatRecLoss: 0.1155 - kl_Loss_Z: 0.0013 - kl_Loss_FC: 1.2025e-04 - val_loss: 0.2416 - val_OrigRecLoss: 0.1116 - val_FeatRecLoss: 0.1286 - val_kl_Loss_Z: 0.0013 - val_kl_Loss_FC: 1.5057e-04
# Epoch 689/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.2326 - OrigRecLoss: 0.1090 - FeatRecLoss: 0.1222 - kl_Loss_Z: 0.0013 - kl_Loss_FC: 1.4775e-04 - val_loss: 0.2418 - val_OrigRecLoss: 0.1116 - val_FeatRecLoss: 0.1288 - val_kl_Loss_Z: 0.0013 - val_kl_Loss_FC: 1.0809e-04
# Epoch 690/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.2131 - OrigRecLoss: 0.0957 - FeatRecLoss: 0.1160 - kl_Loss_Z: 0.0013 - kl_Loss_FC: 1.3205e-04 - val_loss: 0.2417 - val_OrigRecLoss: 0.1116 - val_FeatRecLoss: 0.1287 - val_kl_Loss_Z: 0.0013 - val_kl_Loss_FC: 1.1583e-04
# Epoch 691/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.2135 - OrigRecLoss: 0.0938 - FeatRecLoss: 0.1184 - kl_Loss_Z: 0.0013 - kl_Loss_FC: 7.9744e-05 - val_loss: 0.2417 - val_OrigRecLoss: 0.1116 - val_FeatRecLoss: 0.1287 - val_kl_Loss_Z: 0.0013 - val_kl_Loss_FC: 1.2852e-04
# Epoch 692/1000
# 19/19 [==============================] - 1s 45ms/step - loss: 0.2058 - OrigRecLoss: 0.0911 - FeatRecLoss: 0.1133 - kl_Loss_Z: 0.0013 - kl_Loss_FC: 1.1669e-04 - val_loss: 0.2417 - val_OrigRecLoss: 0.1116 - val_FeatRecLoss: 0.1287 - val_kl_Loss_Z: 0.0013 - val_kl_Loss_FC: 1.3296e-04
# Epoch 693/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.2068 - OrigRecLoss: 0.0917 - FeatRecLoss: 0.1137 - kl_Loss_Z: 0.0013 - kl_Loss_FC: 1.4593e-04 - val_loss: 0.2417 - val_OrigRecLoss: 0.1116 - val_FeatRecLoss: 0.1287 - val_kl_Loss_Z: 0.0013 - val_kl_Loss_FC: 1.0805e-04
# Epoch 694/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.2051 - OrigRecLoss: 0.0909 - FeatRecLoss: 0.1128 - kl_Loss_Z: 0.0013 - kl_Loss_FC: 1.1584e-04 - val_loss: 0.2418 - val_OrigRecLoss: 0.1116 - val_FeatRecLoss: 0.1288 - val_kl_Loss_Z: 0.0013 - val_kl_Loss_FC: 1.2348e-04
# Epoch 695/1000
# 19/19 [==============================] - 1s 45ms/step - loss: 0.2068 - OrigRecLoss: 0.0916 - FeatRecLoss: 0.1138 - kl_Loss_Z: 0.0013 - kl_Loss_FC: 1.0701e-04 - val_loss: 0.2419 - val_OrigRecLoss: 0.1116 - val_FeatRecLoss: 0.1288 - val_kl_Loss_Z: 0.0013 - val_kl_Loss_FC: 1.6782e-04
# Epoch 696/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.2134 - OrigRecLoss: 0.0947 - FeatRecLoss: 0.1173 - kl_Loss_Z: 0.0013 - kl_Loss_FC: 1.7134e-04 - val_loss: 0.2418 - val_OrigRecLoss: 0.1116 - val_FeatRecLoss: 0.1287 - val_kl_Loss_Z: 0.0013 - val_kl_Loss_FC: 1.9393e-04
# Epoch 697/1000
# 19/19 [==============================] - 1s 45ms/step - loss: 0.2218 - OrigRecLoss: 0.0967 - FeatRecLoss: 0.1238 - kl_Loss_Z: 0.0013 - kl_Loss_FC: 9.9772e-05 - val_loss: 0.2417 - val_OrigRecLoss: 0.1116 - val_FeatRecLoss: 0.1287 - val_kl_Loss_Z: 0.0013 - val_kl_Loss_FC: 1.5432e-04
# Epoch 698/1000
# 19/19 [==============================] - 1s 45ms/step - loss: 0.2122 - OrigRecLoss: 0.0959 - FeatRecLoss: 0.1149 - kl_Loss_Z: 0.0013 - kl_Loss_FC: 1.1397e-04 - val_loss: 0.2418 - val_OrigRecLoss: 0.1116 - val_FeatRecLoss: 0.1288 - val_kl_Loss_Z: 0.0013 - val_kl_Loss_FC: 1.4703e-04
# Epoch 699/1000
# 19/19 [==============================] - 1s 45ms/step - loss: 0.2072 - OrigRecLoss: 0.0919 - FeatRecLoss: 0.1140 - kl_Loss_Z: 0.0013 - kl_Loss_FC: 1.2921e-04 - val_loss: 0.2416 - val_OrigRecLoss: 0.1116 - val_FeatRecLoss: 0.1286 - val_kl_Loss_Z: 0.0013 - val_kl_Loss_FC: 1.2270e-04
# Epoch 700/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.2071 - OrigRecLoss: 0.0923 - FeatRecLoss: 0.1134 - kl_Loss_Z: 0.0013 - kl_Loss_FC: 7.5626e-05 - val_loss: 0.2417 - val_OrigRecLoss: 0.1116 - val_FeatRecLoss: 0.1287 - val_kl_Loss_Z: 0.0013 - val_kl_Loss_FC: 1.6077e-04
# Epoch 701/1000
# 19/19 [==============================] - 1s 46ms/step - loss: 0.2068 - OrigRecLoss: 0.0916 - FeatRecLoss: 0.1138 - kl_Loss_Z: 0.0013 - kl_Loss_FC: 1.1476e-04 - val_loss: 0.2416 - val_OrigRecLoss: 0.1116 - val_FeatRecLoss: 0.1287 - val_kl_Loss_Z: 0.0013 - val_kl_Loss_FC: 1.1210e-04
# Epoch 702/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.2227 - OrigRecLoss: 0.0968 - FeatRecLoss: 0.1245 - kl_Loss_Z: 0.0013 - kl_Loss_FC: 1.2101e-04 - val_loss: 0.2417 - val_OrigRecLoss: 0.1116 - val_FeatRecLoss: 0.1287 - val_kl_Loss_Z: 0.0013 - val_kl_Loss_FC: 1.0993e-04
# Epoch 703/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.2076 - OrigRecLoss: 0.0922 - FeatRecLoss: 0.1140 - kl_Loss_Z: 0.0013 - kl_Loss_FC: 1.2266e-04 - val_loss: 0.2417 - val_OrigRecLoss: 0.1116 - val_FeatRecLoss: 0.1287 - val_kl_Loss_Z: 0.0013 - val_kl_Loss_FC: 1.3597e-04
# Epoch 704/1000
# 19/19 [==============================] - 1s 45ms/step - loss: 0.2072 - OrigRecLoss: 0.0918 - FeatRecLoss: 0.1141 - kl_Loss_Z: 0.0013 - kl_Loss_FC: 1.0917e-04 - val_loss: 0.2418 - val_OrigRecLoss: 0.1116 - val_FeatRecLoss: 0.1288 - val_kl_Loss_Z: 0.0013 - val_kl_Loss_FC: 1.4723e-04
# Epoch 705/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.2208 - OrigRecLoss: 0.0969 - FeatRecLoss: 0.1226 - kl_Loss_Z: 0.0013 - kl_Loss_FC: 1.1892e-04 - val_loss: 0.2417 - val_OrigRecLoss: 0.1116 - val_FeatRecLoss: 0.1286 - val_kl_Loss_Z: 0.0013 - val_kl_Loss_FC: 1.4630e-04
# Epoch 706/1000
# 19/19 [==============================] - 1s 45ms/step - loss: 0.2096 - OrigRecLoss: 0.0935 - FeatRecLoss: 0.1148 - kl_Loss_Z: 0.0013 - kl_Loss_FC: 1.1859e-04 - val_loss: 0.2418 - val_OrigRecLoss: 0.1116 - val_FeatRecLoss: 0.1289 - val_kl_Loss_Z: 0.0013 - val_kl_Loss_FC: 1.0188e-04
# Epoch 707/1000
# 19/19 [==============================] - 1s 46ms/step - loss: 0.2138 - OrigRecLoss: 0.0938 - FeatRecLoss: 0.1186 - kl_Loss_Z: 0.0013 - kl_Loss_FC: 1.2121e-04 - val_loss: 0.2417 - val_OrigRecLoss: 0.1116 - val_FeatRecLoss: 0.1287 - val_kl_Loss_Z: 0.0013 - val_kl_Loss_FC: 1.1626e-04
# Epoch 708/1000
# 19/19 [==============================] - 1s 46ms/step - loss: 0.2108 - OrigRecLoss: 0.0930 - FeatRecLoss: 0.1165 - kl_Loss_Z: 0.0013 - kl_Loss_FC: 1.0638e-04 - val_loss: 0.2416 - val_OrigRecLoss: 0.1116 - val_FeatRecLoss: 0.1287 - val_kl_Loss_Z: 0.0013 - val_kl_Loss_FC: 1.0439e-04
# Epoch 709/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.2261 - OrigRecLoss: 0.1038 - FeatRecLoss: 0.1209 - kl_Loss_Z: 0.0013 - kl_Loss_FC: 1.0831e-04 - val_loss: 0.2418 - val_OrigRecLoss: 0.1116 - val_FeatRecLoss: 0.1288 - val_kl_Loss_Z: 0.0013 - val_kl_Loss_FC: 1.1709e-04
# Epoch 710/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.2052 - OrigRecLoss: 0.0910 - FeatRecLoss: 0.1127 - kl_Loss_Z: 0.0013 - kl_Loss_FC: 1.7914e-04 - val_loss: 0.2416 - val_OrigRecLoss: 0.1116 - val_FeatRecLoss: 0.1287 - val_kl_Loss_Z: 0.0013 - val_kl_Loss_FC: 1.0870e-04
# Epoch 711/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.2147 - OrigRecLoss: 0.0945 - FeatRecLoss: 0.1187 - kl_Loss_Z: 0.0013 - kl_Loss_FC: 1.1905e-04 - val_loss: 0.2417 - val_OrigRecLoss: 0.1116 - val_FeatRecLoss: 0.1288 - val_kl_Loss_Z: 0.0013 - val_kl_Loss_FC: 1.0496e-04
# Epoch 712/1000
# 19/19 [==============================] - 1s 46ms/step - loss: 0.2087 - OrigRecLoss: 0.0926 - FeatRecLoss: 0.1148 - kl_Loss_Z: 0.0013 - kl_Loss_FC: 7.3214e-05 - val_loss: 0.2416 - val_OrigRecLoss: 0.1116 - val_FeatRecLoss: 0.1286 - val_kl_Loss_Z: 0.0013 - val_kl_Loss_FC: 1.2784e-04
# Epoch 713/1000
# 19/19 [==============================] - 1s 46ms/step - loss: 0.2119 - OrigRecLoss: 0.0934 - FeatRecLoss: 0.1171 - kl_Loss_Z: 0.0013 - kl_Loss_FC: 1.1737e-04 - val_loss: 0.2417 - val_OrigRecLoss: 0.1116 - val_FeatRecLoss: 0.1287 - val_kl_Loss_Z: 0.0013 - val_kl_Loss_FC: 1.5073e-04
# Epoch 714/1000
# 19/19 [==============================] - 1s 46ms/step - loss: 0.2134 - OrigRecLoss: 0.0938 - FeatRecLoss: 0.1183 - kl_Loss_Z: 0.0013 - kl_Loss_FC: 1.1731e-04 - val_loss: 0.2416 - val_OrigRecLoss: 0.1116 - val_FeatRecLoss: 0.1286 - val_kl_Loss_Z: 0.0013 - val_kl_Loss_FC: 1.0609e-04
# Epoch 715/1000
# 19/19 [==============================] - 1s 44ms/step - loss: 0.2152 - OrigRecLoss: 0.0959 - FeatRecLoss: 0.1179 - kl_Loss_Z: 0.0013 - kl_Loss_FC: 1.0229e-04 - val_loss: 0.2416 - val_OrigRecLoss: 0.1116 - val_FeatRecLoss: 0.1287 - val_kl_Loss_Z: 0.0013 - val_kl_Loss_FC: 1.0598e-04
# Epoch 716/1000
# 19/19 [==============================] - 1s 45ms/step - loss: 0.2066 - OrigRecLoss: 0.0915 - FeatRecLoss: 0.1137 - kl_Loss_Z: 0.0013 - kl_Loss_FC: 1.2207e-04 - val_loss: 0.2416 - val_OrigRecLoss: 0.1116 - val_FeatRecLoss: 0.1287 - val_kl_Loss_Z: 0.0013 - val_kl_Loss_FC: 1.0681e-04
# Epoch 717/1000
#  3/19 [===>..........................] - ETA: 0s - loss: 0.1286 - OrigRecLoss: 0.0625 - FeatRecLoss: 0.0647 - kl_Loss_Z: 0.0012 - kl_Loss_FC: 5.3103e-05
