# %%
import os
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.keras import backend as K
from tensorflow.keras.layers import Input, GRU, Dense, Masking, Reshape, Flatten, RepeatVector, TimeDistributed, Bidirectional, Activation, GaussianNoise, Lambda, LSTM
from tensorflow.keras import Model
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from Models.FeatExtModels_NoKaiser import *

os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %% [markdown]
# ### Data

# %%
DATA = np.load('./Data/AsanTRSet.npy')

# %% [markdown]
# #### Env setting

# %%
save_path = './Results/'
if not os.path.exists(save_path):
    os.mkdir(save_path)
    
### Model checkpoint
ModelSaveSameName = save_path+'SigBandRepModel1.hdf5'
ModelSave = ModelCheckpoint(filepath=ModelSaveSameName, monitor='val_mse', verbose=1, save_best_only=True )

### Model Early stop
EarlyStop = EarlyStopping(monitor='val_loss', patience=500)

LatDim = 3
SigDim = DATA.shape[1]
MaskingRate = 0.02
NoiseStd = 0.002
MaskStd = 0.1
ReparaStd = 0.1

# %%
def ParaFilters (layer, name=''):
    Fc = Dense(1, activation='sigmoid')(layer)
    Fc = tf.clip_by_value(Fc, 1e-7, 1-1e-7)
    
    # Reparameterization Trick for sampling from Uniformly distribution; ϵ∼U(0,1) 
    Epsilon = tf.random.uniform(shape=(tf.shape(Fc)[0], Fc.shape[1]))
    Epsilon = tf.clip_by_value(Epsilon, 1e-7, 1-1e-7)

    LogEps = tf.math.log(Epsilon)
    LogNegEps = tf.math.log(1 - Epsilon)
    
    LogTheta = tf.math.log(Fc)
    LogNegTheta = tf.math.log(1-Fc)

    Fc = tf.math.sigmoid(LogEps - LogNegEps + LogTheta - LogNegTheta)
    Fc = tf.clip_by_value(Fc, 1e-7, 1-1e-7)
    Fc = ReName(Fc, name)
    
    return Fc 


class Lossweight(tf.keras.layers.Layer):
    
    def __init__(self, name='Lossweight'):
        super(Lossweight, self).__init__(name=name)
        pass
    
    def build(self, input_shape):
        self.GenVec = tf.Variable(0., trainable=False)
    
    def call(self, input):

        return self.GenVec
    

class RandFCs(tf.keras.layers.Layer):
    
    def __init__(self, ):
        super(RandFCs, self).__init__(name='FCs')
        pass
    
    def build(self, input_shape):
        self.GenVec = tf.Variable(tf.random.uniform(shape=(1,6)), trainable=False)
    
    def call(self, input):
        return tf.tile(self.GenVec , (tf.shape(input)[0],1))
    
      
'''
# Define the KL annealing callback function
class KLCallback(tf.keras.callbacks.Callback):
    def __init__(self, TargetLossName, Threshold, MaxBeta, BetaName, AnnealEpoch=100):
        self.TargetLossName = TargetLossName
        self.Threshold = Threshold
        self.BetaName = BetaName
        self.MaxBeta = MaxBeta
        self.AnnealStart = 0
        self.AnnealEpoch = AnnealEpoch

    def on_epoch_end(self, epoch, logs={}):
        
        TargetLoss = logs['val_'+self.TargetLossName]
        
        if TargetLoss > self.Threshold:
            
            self.AnnealStart = 0
            K.set_value(self.model.get_layer(self.BetaName).variables[0], 0.)
        else: 
            self.AnnealStart += 1
            Beta = (self.AnnealStart) / self.AnnealEpoch * self.MaxBeta
            K.set_value(self.model.get_layer(self.BetaName).variables[0], Beta)
        
        print(self.model.get_layer(self.BetaName).variables[0])
'''

class KLCallback(tf.keras.callbacks.Callback):
    def __init__(self, TargetLossName, Threshold, MaxBeta, BetaName, AnnealEpoch=100, verbose=1):
        
        if type(TargetLossName) != list:
            TargetLossName = [TargetLossName]
        
        self.TargetLossName = TargetLossName
        self.Threshold = Threshold
        self.BetaName = BetaName
        self.MaxBeta = MaxBeta
        self.AnnealStart = 0
        self.AnnealEpoch = AnnealEpoch
        self.verbose = verbose 

    def on_epoch_end(self, epoch, logs={}):
        
        TargetLoss = max([logs[i] for i in self.TargetLossName]) 
        
        if TargetLoss > self.Threshold:
            
            self.AnnealStart = 0
            K.set_value(self.model.get_layer(self.BetaName).variables[0], 0.)
        else: 
            self.AnnealStart += 1
            Beta = (self.AnnealStart) / self.AnnealEpoch * self.MaxBeta
            K.set_value(self.model.get_layer(self.BetaName).variables[0], Beta)
        
        if self.verbose==1:
            print(self.BetaName+' : ' ,self.model.get_layer(self.BetaName).variables[0].numpy())
        elif self.verbose==2:
            print('TargetLoss : ', TargetLoss)
            print(self.BetaName+' : ' ,self.model.get_layer(self.BetaName).variables[0].numpy())
            
        
        
        
def ReName (layer, name):
    return Lambda(lambda x: x, name=name)(layer)

# %%
def Encoder(SigDim, LatDim= 2, Type = '', MaskingRate = 0.025, NoiseStd = 0.002, MaskStd = 0.1, ReparaStd = 0.1 , Reparam = False):

    InpL = Input(shape=(SigDim,))
    InpFrame = tf.signal.frame(InpL, 100, 100)

    if Reparam:
        InpRegul = GaussianNoise(stddev=NoiseStd)(InpFrame, training=Reparam)
        MaskVec, NoisVec = MaskingGen(InpRegul, MaskingRate, MaskStd)
        EncInp = Masking(mask_value=0.)(InpRegul * MaskVec )
        EncOut = InpRegul + NoisVec
    else:
        EncInp, EncOut = InpFrame, InpFrame

    Encoder = Dense(50, activation='relu')(InpFrame)
    Encoder = Bidirectional(GRU(30, return_sequences=True))(Encoder)
    Encoder = Bidirectional(GRU(30, return_sequences=False))(Encoder)
    Encoder = Dense(50, activation='relu')(Encoder)
    Encoder = Dense(30, activation='relu')(Encoder)
    Encoder = Dense(15, activation='relu')(Encoder)

    Z_Mean = Dense(LatDim, activation='linear')(Encoder)
    Z_Log_Sigma = Dense(LatDim, activation='relu')(Encoder)
    Z_Log_Sigma = ReName(Z_Log_Sigma,'Z_Log_Sigma_'+Type)

    
    # Reparameterization Trick for sampling from Guassian distribution
    Epsilon = tf.random.normal(shape=(tf.shape(Z_Mean)[0], Z_Mean.shape[1]), mean=0., stddev=ReparaStd)

    if Reparam==False:
        Epsilon = Epsilon * 0

    Z_Mean = Z_Mean + tf.exp(0.5 * Z_Log_Sigma) * Epsilon
    Z_Mean = ReName(Z_Mean,'Z_Mean_'+Type)
    
    FCs =   Dense(6, activation='relu')(Z_Mean)
    FCs =   Dense(6, activation='sigmoid')(FCs)
    
    
    # Reparameterization Trick for sampling from Uniformly distribution; ϵ∼U(0,1) 
    FCs = tf.clip_by_value(FCs, 1e-7, 1-1e-7)
    Epsilon = tf.random.uniform(shape=(tf.shape(FCs)[0], FCs.shape[1]))
    Epsilon = tf.clip_by_value(Epsilon, 1e-7, 1-1e-7)
    
    LogEps = tf.math.log(Epsilon)
    LogNegEps = tf.math.log(1 - Epsilon)
    
    LogTheta = tf.math.log(FCs)
    LogNegTheta = tf.math.log(1-FCs)
    
    
    FCs = tf.math.sigmoid(LogEps - LogNegEps + LogTheta - LogNegTheta)
    FCs = tf.clip_by_value(FCs, 1e-7, 1-1e-7)
    FCs = ReName(FCs, 'FCs')
    
    return [InpL], [Flatten()(EncOut), Z_Mean, FCs]



def FeatExtractor(Inps, LatDim= 2, FiltLenList = [301, 301, 301, 301, 301, 301] ):
    
    EncReInp, InpZ, FCs = Inps
    
    H_F, L_F, HH_F, HL_F, LH_F, LL_F = tf.split(FCs, 6, axis=1)
    

    ### Filtering level 1 -------------------------------------------------------------------
    ## Filter generation
    To_H = GenHighFilter(H_F,  N=FiltLenList[0])
    To_L = GenLowFilter(L_F, N=FiltLenList[1])

    ## Perform signal filtering level 1
    InpFrame =  tf.signal.frame(EncReInp, To_H.shape[-1], 1)
    Sig_H = tf.reduce_sum(InpFrame*To_H[:,:,::-1], axis=-1, keepdims=True)
    Sig_H = ReName(Sig_H, 'Sig_H_Ext')

    InpFrame =  tf.signal.frame(EncReInp, To_L.shape[-1], 1)
    Sig_L = tf.reduce_sum(InpFrame*To_L[:,:,::-1], axis=-1, keepdims=True)
    Sig_L = ReName(Sig_L, 'Sig_L_Ext')



    ### Filtering level HH and HL (from Sig_H) -------------------------------------------------------------------
    ## Filter generation
    To_HH = GenHighFilter(HH_F, N=FiltLenList[2])
    To_HL = GenLowFilter(HL_F, N=FiltLenList[3])

    ## Perform signal filtering level 2
    Frame_H =  tf.signal.frame(Sig_H[:,:,0], To_HH.shape[-1], 1)
    Sig_HH = tf.reduce_sum(Frame_H*To_HH[:,:,::-1], axis=-1, keepdims=True)
    Sig_HH = ReName(Sig_HH, 'Sig_HH_Ext')

    Frame_H =  tf.signal.frame(Sig_H[:,:,0], To_HL.shape[-1], 1)
    Sig_HL = tf.reduce_sum(Frame_H*To_HL[:,:,::-1], axis=-1, keepdims=True)
    Sig_HL = ReName(Sig_HL, 'Sig_HL_Ext')


    ### Filtering level LH and LL (from Sig_L) -------------------------------------------------------------------
    ## Filter generation
    To_LH = GenHighFilter(LH_F,  N=FiltLenList[4])
    To_LL = GenLowFilter(LL_F,  N=FiltLenList[5])

    ## Perform signal filtering level 2
    Frame_L =  tf.signal.frame(Sig_L[:,:,0], To_LH.shape[-1], 1)
    Sig_LH = tf.reduce_sum(Frame_L*To_LH[:,:,::-1], axis=-1, keepdims=True)
    Sig_LH = ReName(Sig_LH, 'Sig_LH_Ext')

    Frame_L =  tf.signal.frame(Sig_L[:,:,0], To_LL.shape[-1], 1)
    Sig_LL = tf.reduce_sum(Frame_L*To_LL[:,:,::-1], axis=-1, keepdims=True)
    Sig_LL = ReName(Sig_LL, 'Sig_LL_Ext')

    
    return [Flatten()(Sig_HH), Flatten()(Sig_HL), Flatten()(Sig_LH), Flatten()(Sig_LL)]




def FeatGenerator (Inp_lat):
    
    Inp_lat = tf.concat(Inp_lat, axis=-1)
   
    Dec_Sig_HH = Dense(10, activation='relu')(Inp_lat)
    Dec_Sig_HH = Dense(20, activation='relu')(Dec_Sig_HH)
    Dec_Sig_HH = Dense(30, activation='relu')(Dec_Sig_HH)
    Dec_Sig_HH = Dense(50, activation='relu')(Dec_Sig_HH)

    Dec_Sig_HH = RepeatVector(10 )(Dec_Sig_HH)
    Dec_Sig_HH = Bidirectional(GRU(10, return_sequences=True))(Dec_Sig_HH)
    Dec_Sig_HH = Bidirectional(GRU(20, return_sequences=True))(Dec_Sig_HH)
    Dec_Sig_HH = Dense(40,'tanh')(Dec_Sig_HH)
    Sig_HH= Flatten(name='Sig_HH_Gen')(Dec_Sig_HH)
    
    # ---------------------------------------------------------------------- #
    
    Dec_Sig_HL = Dense(10, activation='relu')(Inp_lat)
    Dec_Sig_HL = Dense(20, activation='relu')(Dec_Sig_HL)
    Dec_Sig_HL = Dense(30, activation='relu')(Dec_Sig_HL)
    Dec_Sig_HL = Dense(50, activation='relu')(Dec_Sig_HL)

    Dec_Sig_HL = RepeatVector(10 )(Dec_Sig_HL)
    Dec_Sig_HL = Bidirectional(GRU(10, return_sequences=True))(Dec_Sig_HL)
    Dec_Sig_HL = Bidirectional(GRU(20, return_sequences=True))(Dec_Sig_HL)
    Dec_Sig_HL = Dense(40,'tanh')(Dec_Sig_HL)
    Sig_HL= Flatten(name='Sig_HL_Gen')(Dec_Sig_HL)
    
    # ---------------------------------------------------------------------- #
    
    Dec_Sig_LH = Dense(10, activation='relu')(Inp_lat)
    Dec_Sig_LH = Dense(20, activation='relu')(Dec_Sig_LH)
    Dec_Sig_LH = Dense(30, activation='relu')(Dec_Sig_LH)
    Dec_Sig_LH = Dense(50, activation='relu')(Dec_Sig_LH)

    Dec_Sig_LH = RepeatVector(10 )(Dec_Sig_LH)
    Dec_Sig_LH = Bidirectional(GRU(10, return_sequences=True))(Dec_Sig_LH)
    Dec_Sig_LH = Bidirectional(GRU(20, return_sequences=True))(Dec_Sig_LH)
    Dec_Sig_LH = Dense(40,'tanh')(Dec_Sig_LH)
    Sig_LH= Flatten(name='Sig_LH_Gen')(Dec_Sig_LH)
    
    # ---------------------------------------------------------------------- #
    
    Dec_Sig_LL = Dense(10, activation='relu')(Inp_lat)
    Dec_Sig_LL = Dense(20, activation='relu')(Dec_Sig_LL)
    Dec_Sig_LL = Dense(30, activation='relu')(Dec_Sig_LL)
    Dec_Sig_LL = Dense(50, activation='relu')(Dec_Sig_LL)

    Dec_Sig_LL = RepeatVector(10 )(Dec_Sig_LL)
    Dec_Sig_LL = Bidirectional(GRU(10, return_sequences=True))(Dec_Sig_LL)
    Dec_Sig_LL = Bidirectional(GRU(20, return_sequences=True))(Dec_Sig_LL)
    Dec_Sig_LL = Dense(40,'tanh')(Dec_Sig_LL)
    Sig_LL= Flatten(name='Sig_LL_Gen')(Dec_Sig_LL)
    
    return  Sig_HH, Sig_HL, Sig_LH, Sig_LL




def Reconstructor(Inps ):
    Sigs, FCs = Inps
    Sig_HH, Sig_HL, Sig_LH, Sig_LL = Sigs

    ## GRU NET -------------------------------------------------------------------
    Dec_Sig_HH = Reshape((-1, 100))(Sig_HH)
    Dec_Sig_HL = Reshape((-1, 100))(Sig_HL)
    Dec_Sig_LH = Reshape((-1, 100))(Sig_LH)
    Dec_Sig_LL = Reshape((-1, 100))(Sig_LL)

    Dec_Sig_HH = Bidirectional(GRU(5), name='Dec_Sig_HH')(Dec_Sig_HH)
    Dec_Sig_HL = Bidirectional(GRU(5), name='Dec_Sig_HL')(Dec_Sig_HL)
    Dec_Sig_LH = Bidirectional(GRU(5), name='Dec_Sig_LH')(Dec_Sig_LH)
    Dec_Sig_LL = Bidirectional(GRU(5), name='Dec_Sig_LL')(Dec_Sig_LL)

    Decoder = tf.concat([ Dec_Sig_HH, Dec_Sig_HL, Dec_Sig_LH, Dec_Sig_LL, FCs], axis=1)
    Decoder = RepeatVector((SigDim//100) )(Decoder)
    Decoder = Bidirectional(GRU(50, return_sequences=True))(Decoder)
    Decoder = Dense(100, activation='relu')(Decoder)
    DecOut = Dense(100, activation='sigmoid')(Decoder)
    DecOut = Reshape((SigDim,),name='Out')(DecOut)

    
    return DecOut

# %%
### Encoder - FeatExtractor
EncInp, EncOut = Encoder(SigDim=SigDim, LatDim= LatDim, Type = 'Tr', MaskingRate = MaskingRate, NoiseStd = NoiseStd, MaskStd = MaskStd, ReparaStd = ReparaStd, Reparam=True)
FeatExtOut = FeatExtractor(EncOut)

### Encoder - FeatGenerator - Reconstruction
FeatGenOut = FeatGenerator(EncOut[1:])
FeatGenOut = ReName(FeatGenOut, 'FeatGenOut')

ReconOut = Reconstructor([FeatGenOut, EncOut[2]])
ReconOut = ReName(ReconOut, 'ReconOut')

### Define the total model
SigBandRepModel = Model(EncInp, ReconOut)



### Weight controller; Apply beta and capacity 
Capacity = 0.1 # 0.1 0.05
Beta_Z = Lossweight(name='Beta_Z')(FeatGenOut)
Beta_Fc = Lossweight(name='Beta_Fc')(FeatGenOut)



### Adding the FeatRecLoss; It allows connection between the extractor and generator
MSE = tf.keras.losses.MeanSquaredError()
FeatRecLoss= MSE(tf.concat(FeatGenOut, axis=-1), tf.concat(FeatExtOut, axis=-1))
BetaFeatRec = 1

SigBandRepModel.add_loss(FeatRecLoss * BetaFeatRec )
SigBandRepModel.add_metric(FeatRecLoss, 'FeatRecLoss')

### KL Divergence for p(Z) vs q(Z)
Z_Sampled, Z_Log_Sigma = SigBandRepModel.get_layer('Z_Mean_Tr').output, SigBandRepModel.get_layer('Z_Log_Sigma_Tr').output
kl_Loss_Z = 0.5 * tf.reduce_sum( Z_Sampled**2  +  tf.exp(Z_Log_Sigma)- Z_Log_Sigma-1, axis=1)    
kl_Loss_Z = tf.reduce_mean(kl_Loss_Z )
kl_Loss_Z = Beta_Z * tf.abs(kl_Loss_Z - Capacity)

### KL Divergence for p(FCs) vs q(FCs)
BernP = 0.5 # hyperparameter
FCs = SigBandRepModel.get_layer('FCs').output
kl_Loss_FC = tf.math.log(FCs) - tf.math.log(BernP) + tf.math.log(1-FCs) - tf.math.log(1-BernP) 
kl_Loss_FC = tf.reduce_mean(-kl_Loss_FC )
kl_Loss_FC = Beta_Fc * tf.abs(kl_Loss_FC - 0.6)

SigBandRepModel.add_loss(kl_Loss_Z )
SigBandRepModel.add_metric(kl_Loss_Z, 'kl_Loss_Z')

SigBandRepModel.add_loss(kl_Loss_FC )
SigBandRepModel.add_metric(kl_Loss_FC, 'kl_Loss_FC')



SigBandRepModel.compile(loss='mse', optimizer='adam', metrics={"ReconOut":'mse'}, loss_weights=[5.]) 

### KLD_Beta controller
KLD_Beta_Z = KLCallback(TargetLossName=['val_FeatRecLoss', 'val_mse'], Threshold=0.0015, MaxBeta=0.5 , BetaName='Beta_Z', AnnealEpoch=500, verbose=2)
KLD_Beta_Fc = KLCallback(TargetLossName=['val_FeatRecLoss', 'val_mse'], Threshold=0.0015, MaxBeta=0.5 , BetaName='Beta_Fc', AnnealEpoch=500, verbose=1)

# %%
#SigBandRepModel.load_weights(ModelSaveSameName)
SigBandRepModel.fit(DATA[:], DATA[:], batch_size=3500, epochs=700, shuffle=True, validation_split=0.2, callbacks=[EarlyStop, ModelSave, KLD_Beta_Z, KLD_Beta_Fc])
# Out:
# Epoch 1/700
# 92/92 [==============================] - 67s 536ms/step - loss: 0.1417 - mse: 0.0248 - FeatRecLoss: 0.0100 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0475 - val_mse: 0.0088 - val_FeatRecLoss: 0.0033 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00001: val_mse did not improve from 0.00222
# TargetLoss :  0.008836403489112854
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 2/700
# 92/92 [==============================] - 45s 495ms/step - loss: 0.0465 - mse: 0.0087 - FeatRecLoss: 0.0029 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0454 - val_mse: 0.0085 - val_FeatRecLoss: 0.0027 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00002: val_mse did not improve from 0.00222
# TargetLoss :  0.008535756729543209
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 3/700
# 92/92 [==============================] - 45s 494ms/step - loss: 0.0451 - mse: 0.0085 - FeatRecLoss: 0.0026 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0449 - val_mse: 0.0085 - val_FeatRecLoss: 0.0025 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00003: val_mse did not improve from 0.00222
# TargetLoss :  0.008478592149913311
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 4/700
# 92/92 [==============================] - 47s 514ms/step - loss: 0.0446 - mse: 0.0084 - FeatRecLoss: 0.0024 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0446 - val_mse: 0.0084 - val_FeatRecLoss: 0.0023 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00004: val_mse did not improve from 0.00222
# TargetLoss :  0.00844855047762394
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 5/700
# 92/92 [==============================] - 47s 508ms/step - loss: 0.0444 - mse: 0.0084 - FeatRecLoss: 0.0023 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0446 - val_mse: 0.0085 - val_FeatRecLoss: 0.0022 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00005: val_mse did not improve from 0.00222
# TargetLoss :  0.00846285093575716
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 6/700
# 92/92 [==============================] - 45s 494ms/step - loss: 0.0443 - mse: 0.0084 - FeatRecLoss: 0.0022 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0442 - val_mse: 0.0084 - val_FeatRecLoss: 0.0021 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00006: val_mse did not improve from 0.00222
# TargetLoss :  0.008424028754234314
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 7/700
# 92/92 [==============================] - 46s 499ms/step - loss: 0.0441 - mse: 0.0084 - FeatRecLoss: 0.0021 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0442 - val_mse: 0.0084 - val_FeatRecLoss: 0.0021 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00007: val_mse did not improve from 0.00222
# TargetLoss :  0.008426445536315441
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 8/700
# 92/92 [==============================] - 46s 501ms/step - loss: 0.0442 - mse: 0.0084 - FeatRecLoss: 0.0021 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0443 - val_mse: 0.0084 - val_FeatRecLoss: 0.0021 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00008: val_mse did not improve from 0.00222
# TargetLoss :  0.008448506705462933
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 9/700
# 92/92 [==============================] - 45s 493ms/step - loss: 0.0441 - mse: 0.0084 - FeatRecLoss: 0.0021 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0442 - val_mse: 0.0084 - val_FeatRecLoss: 0.0021 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00009: val_mse did not improve from 0.00222
# TargetLoss :  0.008420455269515514
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 10/700
# 92/92 [==============================] - 45s 494ms/step - loss: 0.0440 - mse: 0.0084 - FeatRecLoss: 0.0020 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0443 - val_mse: 0.0085 - val_FeatRecLoss: 0.0020 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00010: val_mse did not improve from 0.00222
# TargetLoss :  0.00845128670334816
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 11/700
# 92/92 [==============================] - 45s 494ms/step - loss: 0.0441 - mse: 0.0084 - FeatRecLoss: 0.0020 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0442 - val_mse: 0.0084 - val_FeatRecLoss: 0.0020 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00011: val_mse did not improve from 0.00222
# TargetLoss :  0.008428767323493958
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 12/700
# 92/92 [==============================] - 45s 494ms/step - loss: 0.0441 - mse: 0.0084 - FeatRecLoss: 0.0020 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0442 - val_mse: 0.0084 - val_FeatRecLoss: 0.0020 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00012: val_mse did not improve from 0.00222
# TargetLoss :  0.008442390710115433
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 13/700
# 92/92 [==============================] - 45s 494ms/step - loss: 0.0441 - mse: 0.0084 - FeatRecLoss: 0.0020 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0440 - val_mse: 0.0084 - val_FeatRecLoss: 0.0020 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00013: val_mse did not improve from 0.00222
# TargetLoss :  0.008410287089645863
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 14/700
# 92/92 [==============================] - 45s 495ms/step - loss: 0.0439 - mse: 0.0084 - FeatRecLoss: 0.0019 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0446 - val_mse: 0.0085 - val_FeatRecLoss: 0.0020 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00014: val_mse did not improve from 0.00222
# TargetLoss :  0.008518865332007408
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 15/700
# 92/92 [==============================] - 46s 495ms/step - loss: 0.0440 - mse: 0.0084 - FeatRecLoss: 0.0019 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0440 - val_mse: 0.0084 - val_FeatRecLoss: 0.0019 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00015: val_mse did not improve from 0.00222
# TargetLoss :  0.008409499190747738
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 16/700
# 92/92 [==============================] - 45s 495ms/step - loss: 0.0439 - mse: 0.0084 - FeatRecLoss: 0.0019 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0440 - val_mse: 0.0084 - val_FeatRecLoss: 0.0019 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00016: val_mse did not improve from 0.00222
# TargetLoss :  0.00841065589338541
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 17/700
# 92/92 [==============================] - 45s 494ms/step - loss: 0.0439 - mse: 0.0084 - FeatRecLoss: 0.0019 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0440 - val_mse: 0.0084 - val_FeatRecLoss: 0.0019 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00017: val_mse did not improve from 0.00222
# TargetLoss :  0.008418154902756214
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 18/700
# 92/92 [==============================] - 45s 494ms/step - loss: 0.0439 - mse: 0.0084 - FeatRecLoss: 0.0019 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0441 - val_mse: 0.0084 - val_FeatRecLoss: 0.0019 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00018: val_mse did not improve from 0.00222
# TargetLoss :  0.008443962782621384
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 19/700
# 92/92 [==============================] - 45s 494ms/step - loss: 0.0439 - mse: 0.0084 - FeatRecLoss: 0.0019 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0439 - val_mse: 0.0084 - val_FeatRecLoss: 0.0019 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00019: val_mse did not improve from 0.00222
# TargetLoss :  0.008410695008933544
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 20/700
# 92/92 [==============================] - 45s 494ms/step - loss: 0.0440 - mse: 0.0084 - FeatRecLoss: 0.0019 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0439 - val_mse: 0.0084 - val_FeatRecLoss: 0.0019 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00020: val_mse did not improve from 0.00222
# TargetLoss :  0.008406389504671097
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 21/700
# 92/92 [==============================] - 45s 494ms/step - loss: 0.0439 - mse: 0.0084 - FeatRecLoss: 0.0019 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0440 - val_mse: 0.0084 - val_FeatRecLoss: 0.0019 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00021: val_mse did not improve from 0.00222
# TargetLoss :  0.00842052511870861
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 22/700
# 92/92 [==============================] - 46s 495ms/step - loss: 0.0438 - mse: 0.0084 - FeatRecLoss: 0.0019 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0439 - val_mse: 0.0084 - val_FeatRecLoss: 0.0019 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00022: val_mse did not improve from 0.00222
# TargetLoss :  0.008407928980886936
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 23/700
# 92/92 [==============================] - 45s 493ms/step - loss: 0.0439 - mse: 0.0084 - FeatRecLoss: 0.0019 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0439 - val_mse: 0.0084 - val_FeatRecLoss: 0.0019 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00023: val_mse did not improve from 0.00222
# TargetLoss :  0.00840457621961832
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 24/700
# 92/92 [==============================] - 45s 494ms/step - loss: 0.0439 - mse: 0.0084 - FeatRecLoss: 0.0019 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0440 - val_mse: 0.0084 - val_FeatRecLoss: 0.0019 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00024: val_mse did not improve from 0.00222
# TargetLoss :  0.00841339398175478
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 25/700
# 92/92 [==============================] - 45s 494ms/step - loss: 0.0439 - mse: 0.0084 - FeatRecLoss: 0.0019 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0439 - val_mse: 0.0084 - val_FeatRecLoss: 0.0019 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00025: val_mse did not improve from 0.00222
# TargetLoss :  0.008403906598687172
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 26/700
# 92/92 [==============================] - 45s 494ms/step - loss: 0.0438 - mse: 0.0084 - FeatRecLoss: 0.0019 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0439 - val_mse: 0.0084 - val_FeatRecLoss: 0.0019 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00026: val_mse did not improve from 0.00222
# TargetLoss :  0.008403303101658821
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 27/700
# 92/92 [==============================] - 45s 494ms/step - loss: 0.0439 - mse: 0.0084 - FeatRecLoss: 0.0019 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0439 - val_mse: 0.0084 - val_FeatRecLoss: 0.0019 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00027: val_mse did not improve from 0.00222
# TargetLoss :  0.008403057232499123
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 28/700
# 92/92 [==============================] - 45s 494ms/step - loss: 0.0437 - mse: 0.0084 - FeatRecLoss: 0.0019 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0440 - val_mse: 0.0084 - val_FeatRecLoss: 0.0019 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00028: val_mse did not improve from 0.00222
# TargetLoss :  0.008420011028647423
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 29/700
# 92/92 [==============================] - 45s 493ms/step - loss: 0.0438 - mse: 0.0084 - FeatRecLoss: 0.0019 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0440 - val_mse: 0.0084 - val_FeatRecLoss: 0.0019 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00029: val_mse did not improve from 0.00222
# TargetLoss :  0.008415836840867996
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 30/700
# 92/92 [==============================] - 45s 493ms/step - loss: 0.0439 - mse: 0.0084 - FeatRecLoss: 0.0019 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0439 - val_mse: 0.0084 - val_FeatRecLoss: 0.0019 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00030: val_mse did not improve from 0.00222
# TargetLoss :  0.008402412757277489
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 31/700
# 92/92 [==============================] - 45s 493ms/step - loss: 0.0439 - mse: 0.0084 - FeatRecLoss: 0.0019 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0439 - val_mse: 0.0084 - val_FeatRecLoss: 0.0019 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00031: val_mse did not improve from 0.00222
# TargetLoss :  0.008402194827795029
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 32/700
# 92/92 [==============================] - 45s 492ms/step - loss: 0.0438 - mse: 0.0084 - FeatRecLoss: 0.0019 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0439 - val_mse: 0.0084 - val_FeatRecLoss: 0.0019 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00032: val_mse did not improve from 0.00222
# TargetLoss :  0.008410480804741383
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 33/700
# 92/92 [==============================] - 45s 494ms/step - loss: 0.0438 - mse: 0.0084 - FeatRecLoss: 0.0019 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0439 - val_mse: 0.0084 - val_FeatRecLoss: 0.0019 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00033: val_mse did not improve from 0.00222
# TargetLoss :  0.008402155712246895
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 34/700
# 92/92 [==============================] - 45s 494ms/step - loss: 0.0439 - mse: 0.0084 - FeatRecLoss: 0.0019 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0439 - val_mse: 0.0084 - val_FeatRecLoss: 0.0019 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00034: val_mse did not improve from 0.00222
# TargetLoss :  0.008405215106904507
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 35/700
# 92/92 [==============================] - 45s 494ms/step - loss: 0.0438 - mse: 0.0084 - FeatRecLoss: 0.0019 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0439 - val_mse: 0.0084 - val_FeatRecLoss: 0.0019 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00035: val_mse did not improve from 0.00222
# TargetLoss :  0.00840145256370306
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 36/700
# 92/92 [==============================] - 45s 494ms/step - loss: 0.0438 - mse: 0.0084 - FeatRecLoss: 0.0019 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0439 - val_mse: 0.0084 - val_FeatRecLoss: 0.0019 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00036: val_mse did not improve from 0.00222
# TargetLoss :  0.008401398546993732
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 37/700
# 92/92 [==============================] - 45s 494ms/step - loss: 0.0438 - mse: 0.0084 - FeatRecLoss: 0.0019 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0439 - val_mse: 0.0084 - val_FeatRecLoss: 0.0019 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00037: val_mse did not improve from 0.00222
# TargetLoss :  0.008405324071645737
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 38/700
# 92/92 [==============================] - 45s 494ms/step - loss: 0.0437 - mse: 0.0084 - FeatRecLoss: 0.0019 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0439 - val_mse: 0.0084 - val_FeatRecLoss: 0.0019 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00038: val_mse did not improve from 0.00222
# TargetLoss :  0.00840240903198719
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 39/700
# 92/92 [==============================] - 45s 494ms/step - loss: 0.0438 - mse: 0.0084 - FeatRecLoss: 0.0019 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0442 - val_mse: 0.0085 - val_FeatRecLoss: 0.0019 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00039: val_mse did not improve from 0.00222
# TargetLoss :  0.008454610593616962
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 40/700
# 92/92 [==============================] - 45s 494ms/step - loss: 0.0431 - mse: 0.0082 - FeatRecLoss: 0.0019 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0422 - val_mse: 0.0080 - val_FeatRecLoss: 0.0019 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00040: val_mse did not improve from 0.00222
# TargetLoss :  0.008047660812735558
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 41/700
# 92/92 [==============================] - 45s 495ms/step - loss: 0.0420 - mse: 0.0080 - FeatRecLoss: 0.0019 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0420 - val_mse: 0.0080 - val_FeatRecLoss: 0.0019 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00041: val_mse did not improve from 0.00222
# TargetLoss :  0.00802676659077406
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 42/700
# 92/92 [==============================] - 45s 494ms/step - loss: 0.0419 - mse: 0.0080 - FeatRecLoss: 0.0019 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0420 - val_mse: 0.0080 - val_FeatRecLoss: 0.0019 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00042: val_mse did not improve from 0.00222
# TargetLoss :  0.008022883906960487
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 43/700
# 92/92 [==============================] - 45s 494ms/step - loss: 0.0421 - mse: 0.0080 - FeatRecLoss: 0.0019 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0420 - val_mse: 0.0080 - val_FeatRecLoss: 0.0019 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00043: val_mse did not improve from 0.00222
# TargetLoss :  0.00801756326109171
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 44/700
# 92/92 [==============================] - 45s 494ms/step - loss: 0.0419 - mse: 0.0080 - FeatRecLoss: 0.0019 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0420 - val_mse: 0.0080 - val_FeatRecLoss: 0.0019 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00044: val_mse did not improve from 0.00222
# TargetLoss :  0.008014732971787453
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 45/700
# 92/92 [==============================] - 45s 494ms/step - loss: 0.0419 - mse: 0.0080 - FeatRecLoss: 0.0019 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0423 - val_mse: 0.0081 - val_FeatRecLoss: 0.0019 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00045: val_mse did not improve from 0.00222
# TargetLoss :  0.008075227029621601
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 46/700
# 92/92 [==============================] - 45s 494ms/step - loss: 0.0420 - mse: 0.0080 - FeatRecLoss: 0.0019 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0419 - val_mse: 0.0080 - val_FeatRecLoss: 0.0019 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00046: val_mse did not improve from 0.00222
# TargetLoss :  0.008006078191101551
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 47/700
# 92/92 [==============================] - 45s 494ms/step - loss: 0.0419 - mse: 0.0080 - FeatRecLoss: 0.0019 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0420 - val_mse: 0.0080 - val_FeatRecLoss: 0.0019 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00047: val_mse did not improve from 0.00222
# TargetLoss :  0.008012653328478336
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 48/700
# 92/92 [==============================] - 45s 494ms/step - loss: 0.0419 - mse: 0.0080 - FeatRecLoss: 0.0019 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0419 - val_mse: 0.0080 - val_FeatRecLoss: 0.0019 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00048: val_mse did not improve from 0.00222
# TargetLoss :  0.007998802699148655
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 49/700
# 92/92 [==============================] - 45s 494ms/step - loss: 0.0418 - mse: 0.0080 - FeatRecLoss: 0.0019 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0418 - val_mse: 0.0080 - val_FeatRecLoss: 0.0019 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00049: val_mse did not improve from 0.00222
# TargetLoss :  0.007979239337146282
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 50/700
# 92/92 [==============================] - 45s 494ms/step - loss: 0.0419 - mse: 0.0080 - FeatRecLoss: 0.0019 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0414 - val_mse: 0.0079 - val_FeatRecLoss: 0.0019 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00050: val_mse did not improve from 0.00222
# TargetLoss :  0.007898353040218353
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 51/700
# 92/92 [==============================] - 45s 494ms/step - loss: 0.0412 - mse: 0.0079 - FeatRecLoss: 0.0019 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0409 - val_mse: 0.0078 - val_FeatRecLoss: 0.0019 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00051: val_mse did not improve from 0.00222
# TargetLoss :  0.007782012224197388
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 52/700
# 92/92 [==============================] - 45s 494ms/step - loss: 0.0405 - mse: 0.0077 - FeatRecLoss: 0.0020 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0399 - val_mse: 0.0076 - val_FeatRecLoss: 0.0020 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00052: val_mse did not improve from 0.00222
# TargetLoss :  0.007569996640086174
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 53/700
# 92/92 [==============================] - 45s 493ms/step - loss: 0.0396 - mse: 0.0075 - FeatRecLoss: 0.0020 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0389 - val_mse: 0.0074 - val_FeatRecLoss: 0.0020 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00053: val_mse did not improve from 0.00222
# TargetLoss :  0.007372052874416113
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 54/700
# 92/92 [==============================] - 45s 492ms/step - loss: 0.0386 - mse: 0.0073 - FeatRecLoss: 0.0020 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0373 - val_mse: 0.0070 - val_FeatRecLoss: 0.0021 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00054: val_mse did not improve from 0.00222
# TargetLoss :  0.007041433826088905
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 55/700
# 92/92 [==============================] - 45s 492ms/step - loss: 0.0369 - mse: 0.0070 - FeatRecLoss: 0.0020 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0360 - val_mse: 0.0068 - val_FeatRecLoss: 0.0021 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00055: val_mse did not improve from 0.00222
# TargetLoss :  0.006788803730159998
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 56/700
# 92/92 [==============================] - 45s 493ms/step - loss: 0.0358 - mse: 0.0067 - FeatRecLoss: 0.0021 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0356 - val_mse: 0.0067 - val_FeatRecLoss: 0.0021 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00056: val_mse did not improve from 0.00222
# TargetLoss :  0.00670938566327095
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 57/700
# 92/92 [==============================] - 45s 494ms/step - loss: 0.0349 - mse: 0.0066 - FeatRecLoss: 0.0021 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0343 - val_mse: 0.0064 - val_FeatRecLoss: 0.0021 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00057: val_mse did not improve from 0.00222
# TargetLoss :  0.006443193182349205
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 58/700
# 92/92 [==============================] - 45s 494ms/step - loss: 0.0340 - mse: 0.0064 - FeatRecLoss: 0.0021 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0340 - val_mse: 0.0064 - val_FeatRecLoss: 0.0021 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00058: val_mse did not improve from 0.00222
# TargetLoss :  0.006380743347108364
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 59/700
# 92/92 [==============================] - 45s 494ms/step - loss: 0.0336 - mse: 0.0063 - FeatRecLoss: 0.0021 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0331 - val_mse: 0.0062 - val_FeatRecLoss: 0.0021 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00059: val_mse did not improve from 0.00222
# TargetLoss :  0.00620339484885335
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 60/700
# 92/92 [==============================] - 45s 494ms/step - loss: 0.0329 - mse: 0.0062 - FeatRecLoss: 0.0021 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0326 - val_mse: 0.0061 - val_FeatRecLoss: 0.0020 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00060: val_mse did not improve from 0.00222
# TargetLoss :  0.006107178051024675
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 61/700
# 92/92 [==============================] - 45s 495ms/step - loss: 0.0323 - mse: 0.0061 - FeatRecLoss: 0.0021 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0320 - val_mse: 0.0060 - val_FeatRecLoss: 0.0021 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00061: val_mse did not improve from 0.00222
# TargetLoss :  0.005995842628180981
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 62/700
# 92/92 [==============================] - 46s 495ms/step - loss: 0.0320 - mse: 0.0060 - FeatRecLoss: 0.0021 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0310 - val_mse: 0.0058 - val_FeatRecLoss: 0.0021 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00062: val_mse did not improve from 0.00222
# TargetLoss :  0.005789062473922968
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 63/700
# 92/92 [==============================] - 45s 494ms/step - loss: 0.0310 - mse: 0.0058 - FeatRecLoss: 0.0021 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0314 - val_mse: 0.0059 - val_FeatRecLoss: 0.0021 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00063: val_mse did not improve from 0.00222
# TargetLoss :  0.005877221468836069
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 64/700
# 92/92 [==============================] - 45s 494ms/step - loss: 0.0304 - mse: 0.0057 - FeatRecLoss: 0.0021 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0296 - val_mse: 0.0055 - val_FeatRecLoss: 0.0021 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00064: val_mse did not improve from 0.00222
# TargetLoss :  0.005512965377420187
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 65/700
# 92/92 [==============================] - 45s 494ms/step - loss: 0.0292 - mse: 0.0054 - FeatRecLoss: 0.0021 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0282 - val_mse: 0.0052 - val_FeatRecLoss: 0.0021 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00065: val_mse did not improve from 0.00222
# TargetLoss :  0.005228227935731411
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 66/700
# 92/92 [==============================] - 45s 494ms/step - loss: 0.0279 - mse: 0.0052 - FeatRecLoss: 0.0021 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0266 - val_mse: 0.0049 - val_FeatRecLoss: 0.0021 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00066: val_mse did not improve from 0.00222
# TargetLoss :  0.004904793109744787
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 67/700
# 92/92 [==============================] - 45s 494ms/step - loss: 0.0264 - mse: 0.0049 - FeatRecLoss: 0.0021 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0250 - val_mse: 0.0046 - val_FeatRecLoss: 0.0021 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00067: val_mse did not improve from 0.00222
# TargetLoss :  0.004575939849019051
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 68/700
# 92/92 [==============================] - 45s 495ms/step - loss: 0.0244 - mse: 0.0045 - FeatRecLoss: 0.0021 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0229 - val_mse: 0.0042 - val_FeatRecLoss: 0.0021 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00068: val_mse did not improve from 0.00222
# TargetLoss :  0.004150623921304941
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 69/700
# 92/92 [==============================] - 45s 495ms/step - loss: 0.0227 - mse: 0.0041 - FeatRecLoss: 0.0021 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0216 - val_mse: 0.0039 - val_FeatRecLoss: 0.0022 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00069: val_mse did not improve from 0.00222
# TargetLoss :  0.0038882659282535315
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 70/700
# 92/92 [==============================] - 45s 494ms/step - loss: 0.0210 - mse: 0.0038 - FeatRecLoss: 0.0021 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0203 - val_mse: 0.0036 - val_FeatRecLoss: 0.0022 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00070: val_mse did not improve from 0.00222
# TargetLoss :  0.003631473984569311
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 71/700
# 92/92 [==============================] - 45s 494ms/step - loss: 0.0200 - mse: 0.0036 - FeatRecLoss: 0.0021 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0190 - val_mse: 0.0034 - val_FeatRecLoss: 0.0021 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00071: val_mse did not improve from 0.00222
# TargetLoss :  0.0033641392365098
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 72/700
# 92/92 [==============================] - 45s 494ms/step - loss: 0.0194 - mse: 0.0035 - FeatRecLoss: 0.0021 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0186 - val_mse: 0.0033 - val_FeatRecLoss: 0.0021 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00072: val_mse did not improve from 0.00222
# TargetLoss :  0.003300504758954048
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 73/700
# 92/92 [==============================] - 45s 494ms/step - loss: 0.0185 - mse: 0.0033 - FeatRecLoss: 0.0021 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0179 - val_mse: 0.0032 - val_FeatRecLoss: 0.0021 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00073: val_mse did not improve from 0.00222
# TargetLoss :  0.0031513154972344637
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 74/700
# 92/92 [==============================] - 45s 494ms/step - loss: 0.0179 - mse: 0.0032 - FeatRecLoss: 0.0021 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0171 - val_mse: 0.0030 - val_FeatRecLoss: 0.0021 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00074: val_mse did not improve from 0.00222
# TargetLoss :  0.0030016284435987473
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 75/700
# 92/92 [==============================] - 45s 494ms/step - loss: 0.0173 - mse: 0.0030 - FeatRecLoss: 0.0021 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0176 - val_mse: 0.0031 - val_FeatRecLoss: 0.0021 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00075: val_mse did not improve from 0.00222
# TargetLoss :  0.0030853208154439926
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 76/700
# 92/92 [==============================] - 45s 494ms/step - loss: 0.0169 - mse: 0.0030 - FeatRecLoss: 0.0021 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0161 - val_mse: 0.0028 - val_FeatRecLoss: 0.0021 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00076: val_mse did not improve from 0.00222
# TargetLoss :  0.002801798051223159
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 77/700
# 92/92 [==============================] - 45s 493ms/step - loss: 0.0165 - mse: 0.0029 - FeatRecLoss: 0.0021 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0165 - val_mse: 0.0029 - val_FeatRecLoss: 0.0021 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00077: val_mse did not improve from 0.00222
# TargetLoss :  0.0028708484023809433
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 78/700
# 92/92 [==============================] - 45s 492ms/step - loss: 0.0162 - mse: 0.0028 - FeatRecLoss: 0.0021 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0160 - val_mse: 0.0028 - val_FeatRecLoss: 0.0021 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00078: val_mse did not improve from 0.00222
# TargetLoss :  0.0027885399758815765
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 79/700
# 92/92 [==============================] - 45s 492ms/step - loss: 0.0158 - mse: 0.0027 - FeatRecLoss: 0.0021 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0160 - val_mse: 0.0028 - val_FeatRecLoss: 0.0021 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00079: val_mse did not improve from 0.00222
# TargetLoss :  0.0027777827344834805
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 80/700
# 92/92 [==============================] - 45s 494ms/step - loss: 0.0156 - mse: 0.0027 - FeatRecLoss: 0.0021 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0154 - val_mse: 0.0027 - val_FeatRecLoss: 0.0021 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00080: val_mse did not improve from 0.00222
# TargetLoss :  0.002657317090779543
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 81/700
# 92/92 [==============================] - 45s 495ms/step - loss: 0.0153 - mse: 0.0026 - FeatRecLoss: 0.0021 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0166 - val_mse: 0.0029 - val_FeatRecLoss: 0.0021 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00081: val_mse did not improve from 0.00222
# TargetLoss :  0.002911502728238702
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 82/700
# 92/92 [==============================] - 45s 494ms/step - loss: 0.0152 - mse: 0.0026 - FeatRecLoss: 0.0021 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0145 - val_mse: 0.0025 - val_FeatRecLoss: 0.0021 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00082: val_mse did not improve from 0.00222
# TargetLoss :  0.002486181678250432
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 83/700
# 92/92 [==============================] - 45s 493ms/step - loss: 0.0150 - mse: 0.0026 - FeatRecLoss: 0.0021 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0150 - val_mse: 0.0026 - val_FeatRecLoss: 0.0021 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00083: val_mse did not improve from 0.00222
# TargetLoss :  0.002584960078820586
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 84/700
# 92/92 [==============================] - 45s 494ms/step - loss: 0.0146 - mse: 0.0025 - FeatRecLoss: 0.0021 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0143 - val_mse: 0.0024 - val_FeatRecLoss: 0.0021 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00084: val_mse did not improve from 0.00222
# TargetLoss :  0.0024439897388219833
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 85/700
# 92/92 [==============================] - 45s 494ms/step - loss: 0.0142 - mse: 0.0024 - FeatRecLoss: 0.0021 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0143 - val_mse: 0.0024 - val_FeatRecLoss: 0.0021 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00085: val_mse did not improve from 0.00222
# TargetLoss :  0.0024369112215936184
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 86/700
# 92/92 [==============================] - 45s 495ms/step - loss: 0.0143 - mse: 0.0024 - FeatRecLoss: 0.0021 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0137 - val_mse: 0.0023 - val_FeatRecLoss: 0.0021 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00086: val_mse did not improve from 0.00222
# TargetLoss :  0.0023260375019162893
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 87/700
# 92/92 [==============================] - 45s 494ms/step - loss: 0.0142 - mse: 0.0024 - FeatRecLoss: 0.0021 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0140 - val_mse: 0.0024 - val_FeatRecLoss: 0.0021 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00087: val_mse did not improve from 0.00222
# TargetLoss :  0.0023844174575060606
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 88/700
# 92/92 [==============================] - 45s 494ms/step - loss: 0.0139 - mse: 0.0024 - FeatRecLoss: 0.0021 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0136 - val_mse: 0.0023 - val_FeatRecLoss: 0.0021 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00088: val_mse did not improve from 0.00222
# TargetLoss :  0.002316418569535017
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 89/700
# 92/92 [==============================] - 45s 494ms/step - loss: 0.0138 - mse: 0.0023 - FeatRecLoss: 0.0021 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0136 - val_mse: 0.0023 - val_FeatRecLoss: 0.0021 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00089: val_mse did not improve from 0.00222
# TargetLoss :  0.0023054766934365034
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 90/700
# 92/92 [==============================] - 46s 502ms/step - loss: 0.0138 - mse: 0.0024 - FeatRecLoss: 0.0021 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0136 - val_mse: 0.0023 - val_FeatRecLoss: 0.0021 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00090: val_mse did not improve from 0.00222
# TargetLoss :  0.002301084343343973
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 91/700
# 92/92 [==============================] - 45s 495ms/step - loss: 0.0138 - mse: 0.0023 - FeatRecLoss: 0.0021 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0133 - val_mse: 0.0022 - val_FeatRecLoss: 0.0021 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00091: val_mse did not improve from 0.00222
# TargetLoss :  0.0022484050132334232
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 92/700
# 92/92 [==============================] - 45s 494ms/step - loss: 0.0135 - mse: 0.0023 - FeatRecLoss: 0.0021 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0134 - val_mse: 0.0023 - val_FeatRecLoss: 0.0021 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00092: val_mse did not improve from 0.00222
# TargetLoss :  0.0022682445123791695
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 93/700
# 92/92 [==============================] - 45s 494ms/step - loss: 0.0134 - mse: 0.0023 - FeatRecLoss: 0.0020 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0130 - val_mse: 0.0022 - val_FeatRecLoss: 0.0021 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00093: val_mse improved from 0.00222 to 0.00219, saving model to ./Results\SigBandRepModel1.hdf5
# TargetLoss :  0.002187135862186551
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 94/700
# 92/92 [==============================] - 45s 494ms/step - loss: 0.0132 - mse: 0.0022 - FeatRecLoss: 0.0020 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0129 - val_mse: 0.0022 - val_FeatRecLoss: 0.0020 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00094: val_mse improved from 0.00219 to 0.00217, saving model to ./Results\SigBandRepModel1.hdf5
# TargetLoss :  0.0021721101365983486
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 95/700
# 92/92 [==============================] - 45s 494ms/step - loss: 0.0132 - mse: 0.0022 - FeatRecLoss: 0.0020 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0133 - val_mse: 0.0022 - val_FeatRecLoss: 0.0020 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00095: val_mse did not improve from 0.00217
# TargetLoss :  0.002247632248327136
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 96/700
# 92/92 [==============================] - 45s 494ms/step - loss: 0.0132 - mse: 0.0022 - FeatRecLoss: 0.0020 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0132 - val_mse: 0.0022 - val_FeatRecLoss: 0.0020 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00096: val_mse did not improve from 0.00217
# TargetLoss :  0.002233634004369378
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 97/700
# 92/92 [==============================] - 45s 494ms/step - loss: 0.0131 - mse: 0.0022 - FeatRecLoss: 0.0020 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0129 - val_mse: 0.0022 - val_FeatRecLoss: 0.0020 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00097: val_mse did not improve from 0.00217
# TargetLoss :  0.0021732733584940434
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 98/700
# 92/92 [==============================] - 45s 494ms/step - loss: 0.0128 - mse: 0.0022 - FeatRecLoss: 0.0020 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0123 - val_mse: 0.0021 - val_FeatRecLoss: 0.0020 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00098: val_mse improved from 0.00217 to 0.00206, saving model to ./Results\SigBandRepModel1.hdf5
# TargetLoss :  0.002061021514236927
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 99/700
# 92/92 [==============================] - 45s 492ms/step - loss: 0.0127 - mse: 0.0021 - FeatRecLoss: 0.0020 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0127 - val_mse: 0.0021 - val_FeatRecLoss: 0.0020 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00099: val_mse did not improve from 0.00206
# TargetLoss :  0.0021399797406047583
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 100/700
# 92/92 [==============================] - 45s 492ms/step - loss: 0.0126 - mse: 0.0021 - FeatRecLoss: 0.0020 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0124 - val_mse: 0.0021 - val_FeatRecLoss: 0.0020 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00100: val_mse did not improve from 0.00206
# TargetLoss :  0.002064862521365285
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 101/700
# 92/92 [==============================] - 45s 492ms/step - loss: 0.0127 - mse: 0.0021 - FeatRecLoss: 0.0020 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0125 - val_mse: 0.0021 - val_FeatRecLoss: 0.0020 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00101: val_mse did not improve from 0.00206
# TargetLoss :  0.0020922778639942408
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 102/700
# 92/92 [==============================] - 45s 492ms/step - loss: 0.0126 - mse: 0.0021 - FeatRecLoss: 0.0020 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0130 - val_mse: 0.0022 - val_FeatRecLoss: 0.0020 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00102: val_mse did not improve from 0.00206
# TargetLoss :  0.0021916902624070644
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 103/700
# 92/92 [==============================] - 45s 493ms/step - loss: 0.0129 - mse: 0.0022 - FeatRecLoss: 0.0020 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0124 - val_mse: 0.0021 - val_FeatRecLoss: 0.0020 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00103: val_mse did not improve from 0.00206
# TargetLoss :  0.0020722064655274153
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 104/700
# 92/92 [==============================] - 45s 494ms/step - loss: 0.0124 - mse: 0.0021 - FeatRecLoss: 0.0020 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0130 - val_mse: 0.0022 - val_FeatRecLoss: 0.0020 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00104: val_mse did not improve from 0.00206
# TargetLoss :  0.0021832548081874847
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 105/700
# 92/92 [==============================] - 45s 494ms/step - loss: 0.0127 - mse: 0.0021 - FeatRecLoss: 0.0020 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0120 - val_mse: 0.0020 - val_FeatRecLoss: 0.0020 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00105: val_mse improved from 0.00206 to 0.00199, saving model to ./Results\SigBandRepModel1.hdf5
# TargetLoss :  0.0020235388074070215
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 106/700
# 92/92 [==============================] - 45s 494ms/step - loss: 0.0121 - mse: 0.0020 - FeatRecLoss: 0.0020 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0129 - val_mse: 0.0022 - val_FeatRecLoss: 0.0020 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00106: val_mse did not improve from 0.00199
# TargetLoss :  0.0021703860256820917
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 107/700
# 92/92 [==============================] - 45s 494ms/step - loss: 0.0123 - mse: 0.0020 - FeatRecLoss: 0.0020 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0120 - val_mse: 0.0020 - val_FeatRecLoss: 0.0020 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00107: val_mse did not improve from 0.00199
# TargetLoss :  0.0020192789379507303
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 108/700
# 92/92 [==============================] - 45s 494ms/step - loss: 0.0121 - mse: 0.0020 - FeatRecLoss: 0.0020 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0121 - val_mse: 0.0020 - val_FeatRecLoss: 0.0020 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00108: val_mse did not improve from 0.00199
# TargetLoss :  0.002024094806984067
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 109/700
# 92/92 [==============================] - 45s 494ms/step - loss: 0.0120 - mse: 0.0020 - FeatRecLoss: 0.0020 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0124 - val_mse: 0.0021 - val_FeatRecLoss: 0.0020 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00109: val_mse did not improve from 0.00199
# TargetLoss :  0.0020731533877551556
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 110/700
# 92/92 [==============================] - 45s 494ms/step - loss: 0.0122 - mse: 0.0020 - FeatRecLoss: 0.0020 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0117 - val_mse: 0.0019 - val_FeatRecLoss: 0.0020 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00110: val_mse improved from 0.00199 to 0.00194, saving model to ./Results\SigBandRepModel1.hdf5
# TargetLoss :  0.002023519715294242
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 111/700
# 92/92 [==============================] - 45s 494ms/step - loss: 0.0118 - mse: 0.0020 - FeatRecLoss: 0.0020 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0124 - val_mse: 0.0021 - val_FeatRecLoss: 0.0020 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00111: val_mse did not improve from 0.00194
# TargetLoss :  0.0020817213226109743
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 112/700
# 92/92 [==============================] - 45s 494ms/step - loss: 0.0120 - mse: 0.0020 - FeatRecLoss: 0.0020 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0116 - val_mse: 0.0019 - val_FeatRecLoss: 0.0020 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00112: val_mse improved from 0.00194 to 0.00193, saving model to ./Results\SigBandRepModel1.hdf5
# TargetLoss :  0.0020130062475800514
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 113/700
# 92/92 [==============================] - 45s 494ms/step - loss: 0.0119 - mse: 0.0020 - FeatRecLoss: 0.0020 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0120 - val_mse: 0.0020 - val_FeatRecLoss: 0.0020 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00113: val_mse did not improve from 0.00193
# TargetLoss :  0.0020287286024540663
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 114/700
# 92/92 [==============================] - 45s 494ms/step - loss: 0.0119 - mse: 0.0020 - FeatRecLoss: 0.0020 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0117 - val_mse: 0.0019 - val_FeatRecLoss: 0.0020 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00114: val_mse did not improve from 0.00193
# TargetLoss :  0.0020182630978524685
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 115/700
# 92/92 [==============================] - 45s 493ms/step - loss: 0.0117 - mse: 0.0019 - FeatRecLoss: 0.0020 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0115 - val_mse: 0.0019 - val_FeatRecLoss: 0.0020 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00115: val_mse improved from 0.00193 to 0.00190, saving model to ./Results\SigBandRepModel1.hdf5
# TargetLoss :  0.0020128143951296806
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 116/700
# 92/92 [==============================] - 45s 494ms/step - loss: 0.0117 - mse: 0.0019 - FeatRecLoss: 0.0020 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0127 - val_mse: 0.0021 - val_FeatRecLoss: 0.0020 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00116: val_mse did not improve from 0.00190
# TargetLoss :  0.0021416135132312775
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 117/700
# 92/92 [==============================] - 46s 501ms/step - loss: 0.0121 - mse: 0.0020 - FeatRecLoss: 0.0020 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0119 - val_mse: 0.0020 - val_FeatRecLoss: 0.0020 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00117: val_mse did not improve from 0.00190
# TargetLoss :  0.002014396246522665
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 118/700
# 92/92 [==============================] - 45s 493ms/step - loss: 0.0120 - mse: 0.0020 - FeatRecLoss: 0.0020 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0114 - val_mse: 0.0019 - val_FeatRecLoss: 0.0020 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# ...
#
# Epoch 00197: val_mse did not improve from 0.00140
# TargetLoss :  0.001959641231223941
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 198/700
# 92/92 [==============================] - 46s 500ms/step - loss: 0.0094 - mse: 0.0015 - FeatRecLoss: 0.0020 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0101 - val_mse: 0.0016 - val_FeatRecLoss: 0.0020 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00198: val_mse did not improve from 0.00140
# TargetLoss :  0.0019638126250356436
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 199/700
# 92/92 [==============================] - 46s 499ms/step - loss: 0.0096 - mse: 0.0015 - FeatRecLoss: 0.0020 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0092 - val_mse: 0.0015 - val_FeatRecLoss: 0.0020 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00199: val_mse did not improve from 0.00140
# TargetLoss :  0.001961564179509878
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 200/700
# 92/92 [==============================] - 46s 505ms/step - loss: 0.0091 - mse: 0.0014 - FeatRecLoss: 0.0020 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0095 - val_mse: 0.0015 - val_FeatRecLoss: 0.0020 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00200: val_mse did not improve from 0.00140
# TargetLoss :  0.001962832408025861
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 201/700
# 92/92 [==============================] - 46s 505ms/step - loss: 0.0094 - mse: 0.0015 - FeatRecLoss: 0.0020 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0092 - val_mse: 0.0014 - val_FeatRecLoss: 0.0020 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00201: val_mse did not improve from 0.00140
# TargetLoss :  0.0019612459000200033
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 202/700
# 92/92 [==============================] - 46s 496ms/step - loss: 0.0092 - mse: 0.0014 - FeatRecLoss: 0.0020 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0099 - val_mse: 0.0016 - val_FeatRecLoss: 0.0020 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00202: val_mse did not improve from 0.00140
# TargetLoss :  0.001960678258910775
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 203/700
# 92/92 [==============================] - 46s 497ms/step - loss: 0.0097 - mse: 0.0015 - FeatRecLoss: 0.0020 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0090 - val_mse: 0.0014 - val_FeatRecLoss: 0.0020 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00203: val_mse did not improve from 0.00140
# TargetLoss :  0.001960745546966791
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 204/700
# 92/92 [==============================] - 46s 502ms/step - loss: 0.0091 - mse: 0.0014 - FeatRecLoss: 0.0020 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0091 - val_mse: 0.0014 - val_FeatRecLoss: 0.0020 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00204: val_mse did not improve from 0.00140
# TargetLoss :  0.001959743443876505
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 205/700
# 92/92 [==============================] - 46s 497ms/step - loss: 0.0091 - mse: 0.0014 - FeatRecLoss: 0.0020 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0094 - val_mse: 0.0015 - val_FeatRecLoss: 0.0020 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00205: val_mse did not improve from 0.00140
# TargetLoss :  0.001958811189979315
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 206/700
# 92/92 [==============================] - 45s 494ms/step - loss: 0.0091 - mse: 0.0014 - FeatRecLoss: 0.0020 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0091 - val_mse: 0.0014 - val_FeatRecLoss: 0.0020 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00206: val_mse did not improve from 0.00140
# TargetLoss :  0.0019600875675678253
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 207/700
# 92/92 [==============================] - 46s 505ms/step - loss: 0.0092 - mse: 0.0014 - FeatRecLoss: 0.0020 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0088 - val_mse: 0.0014 - val_FeatRecLoss: 0.0020 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00207: val_mse improved from 0.00140 to 0.00136, saving model to ./Results\SigBandRepModel1.hdf5
# TargetLoss :  0.0019592803437262774
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 208/700
# 92/92 [==============================] - 46s 495ms/step - loss: 0.0091 - mse: 0.0014 - FeatRecLoss: 0.0020 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0095 - val_mse: 0.0015 - val_FeatRecLoss: 0.0020 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00208: val_mse did not improve from 0.00136
# TargetLoss :  0.001959695713594556
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 209/700
# 92/92 [==============================] - 46s 503ms/step - loss: 0.0092 - mse: 0.0014 - FeatRecLoss: 0.0020 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0089 - val_mse: 0.0014 - val_FeatRecLoss: 0.0020 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00209: val_mse did not improve from 0.00136
# TargetLoss :  0.0019585383124649525
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 210/700
# 92/92 [==============================] - 46s 499ms/step - loss: 0.0090 - mse: 0.0014 - FeatRecLoss: 0.0020 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0093 - val_mse: 0.0015 - val_FeatRecLoss: 0.0020 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00210: val_mse did not improve from 0.00136
# TargetLoss :  0.0019547489937394857
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 211/700
# 92/92 [==============================] - 46s 498ms/step - loss: 0.0094 - mse: 0.0015 - FeatRecLoss: 0.0020 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0088 - val_mse: 0.0014 - val_FeatRecLoss: 0.0020 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00211: val_mse did not improve from 0.00136
# TargetLoss :  0.001956069143489003
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 212/700
# 92/92 [==============================] - 46s 495ms/step - loss: 0.0088 - mse: 0.0014 - FeatRecLoss: 0.0020 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0089 - val_mse: 0.0014 - val_FeatRecLoss: 0.0020 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00212: val_mse did not improve from 0.00136
# TargetLoss :  0.001956329448148608
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 213/700
# 92/92 [==============================] - 46s 503ms/step - loss: 0.0096 - mse: 0.0015 - FeatRecLoss: 0.0020 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0090 - val_mse: 0.0014 - val_FeatRecLoss: 0.0020 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00213: val_mse did not improve from 0.00136
# TargetLoss :  0.0019567415583878756
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 214/700
# 92/92 [==============================] - 46s 499ms/step - loss: 0.0106 - mse: 0.0017 - FeatRecLoss: 0.0020 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0102 - val_mse: 0.0016 - val_FeatRecLoss: 0.0020 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00214: val_mse did not improve from 0.00136
# TargetLoss :  0.0019636913202703
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 215/700
# 92/92 [==============================] - 46s 495ms/step - loss: 0.0101 - mse: 0.0016 - FeatRecLoss: 0.0020 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0115 - val_mse: 0.0019 - val_FeatRecLoss: 0.0020 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00215: val_mse did not improve from 0.00136
# TargetLoss :  0.001967190532013774
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 216/700
# 92/92 [==============================] - 46s 495ms/step - loss: 0.0101 - mse: 0.0016 - FeatRecLoss: 0.0020 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0090 - val_mse: 0.0014 - val_FeatRecLoss: 0.0020 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00216: val_mse did not improve from 0.00136
# TargetLoss :  0.001957249827682972
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 217/700
# 92/92 [==============================] - 45s 493ms/step - loss: 0.0090 - mse: 0.0014 - FeatRecLoss: 0.0020 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0092 - val_mse: 0.0014 - val_FeatRecLoss: 0.0020 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00217: val_mse did not improve from 0.00136
# TargetLoss :  0.0019621881656348705
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 218/700
# 92/92 [==============================] - 46s 498ms/step - loss: 0.0090 - mse: 0.0014 - FeatRecLoss: 0.0020 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0089 - val_mse: 0.0014 - val_FeatRecLoss: 0.0020 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00218: val_mse did not improve from 0.00136
# TargetLoss :  0.001954738749191165
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 219/700
# 92/92 [==============================] - 46s 499ms/step - loss: 0.0092 - mse: 0.0014 - FeatRecLoss: 0.0020 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0092 - val_mse: 0.0014 - val_FeatRecLoss: 0.0020 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00219: val_mse did not improve from 0.00136
# TargetLoss :  0.001954797888174653
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 220/700
# 92/92 [==============================] - 46s 505ms/step - loss: 0.0090 - mse: 0.0014 - FeatRecLoss: 0.0019 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0094 - val_mse: 0.0015 - val_FeatRecLoss: 0.0020 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00220: val_mse did not improve from 0.00136
# TargetLoss :  0.001956469612196088
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 221/700
# 92/92 [==============================] - 47s 507ms/step - loss: 0.0090 - mse: 0.0014 - FeatRecLoss: 0.0019 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0091 - val_mse: 0.0014 - val_FeatRecLoss: 0.0020 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00221: val_mse did not improve from 0.00136
# TargetLoss :  0.0019504782976582646
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 222/700
# 92/92 [==============================] - 46s 500ms/step - loss: 0.0090 - mse: 0.0014 - FeatRecLoss: 0.0019 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0089 - val_mse: 0.0014 - val_FeatRecLoss: 0.0020 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00222: val_mse did not improve from 0.00136
# TargetLoss :  0.001953821862116456
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 223/700
# 92/92 [==============================] - 46s 503ms/step - loss: 0.0094 - mse: 0.0015 - FeatRecLoss: 0.0020 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0087 - val_mse: 0.0014 - val_FeatRecLoss: 0.0020 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00223: val_mse improved from 0.00136 to 0.00135, saving model to ./Results\SigBandRepModel1.hdf5
# TargetLoss :  0.0019521110225468874
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 224/700
# 92/92 [==============================] - 46s 496ms/step - loss: 0.0090 - mse: 0.0014 - FeatRecLoss: 0.0019 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0091 - val_mse: 0.0014 - val_FeatRecLoss: 0.0019 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00224: val_mse did not improve from 0.00135
# TargetLoss :  0.0019488235702738166
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 225/700
# 92/92 [==============================] - 46s 497ms/step - loss: 0.0091 - mse: 0.0014 - FeatRecLoss: 0.0019 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0090 - val_mse: 0.0014 - val_FeatRecLoss: 0.0020 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00225: val_mse did not improve from 0.00135
# TargetLoss :  0.0019544262904673815
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 226/700
# 92/92 [==============================] - 46s 501ms/step - loss: 0.0089 - mse: 0.0014 - FeatRecLoss: 0.0019 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0087 - val_mse: 0.0013 - val_FeatRecLoss: 0.0019 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00226: val_mse improved from 0.00135 to 0.00134, saving model to ./Results\SigBandRepModel1.hdf5
# TargetLoss :  0.0019482396310195327
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 227/700
# 92/92 [==============================] - 46s 502ms/step - loss: 0.0088 - mse: 0.0014 - FeatRecLoss: 0.0019 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0095 - val_mse: 0.0015 - val_FeatRecLoss: 0.0020 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00227: val_mse did not improve from 0.00134
# TargetLoss :  0.0019506214885041118
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 228/700
# 92/92 [==============================] - 47s 510ms/step - loss: 0.0095 - mse: 0.0015 - FeatRecLoss: 0.0019 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0092 - val_mse: 0.0015 - val_FeatRecLoss: 0.0019 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00228: val_mse did not improve from 0.00134
# TargetLoss :  0.0019495189189910889
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 229/700
# 92/92 [==============================] - 46s 496ms/step - loss: 0.0096 - mse: 0.0015 - FeatRecLoss: 0.0019 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0090 - val_mse: 0.0014 - val_FeatRecLoss: 0.0019 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00229: val_mse did not improve from 0.00134
# TargetLoss :  0.001949095050804317
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 230/700
# 92/92 [==============================] - 47s 506ms/step - loss: 0.0092 - mse: 0.0015 - FeatRecLoss: 0.0019 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0092 - val_mse: 0.0015 - val_FeatRecLoss: 0.0019 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00230: val_mse did not improve from 0.00134
# TargetLoss :  0.0019489112310111523
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 231/700
# 92/92 [==============================] - 46s 496ms/step - loss: 0.0097 - mse: 0.0016 - FeatRecLoss: 0.0019 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0091 - val_mse: 0.0014 - val_FeatRecLoss: 0.0019 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00231: val_mse did not improve from 0.00134
# TargetLoss :  0.001948827994056046
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 232/700
# 92/92 [==============================] - 46s 496ms/step - loss: 0.0090 - mse: 0.0014 - FeatRecLoss: 0.0019 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0087 - val_mse: 0.0013 - val_FeatRecLoss: 0.0020 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00232: val_mse did not improve from 0.00134
# TargetLoss :  0.0019509588601067662
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 233/700
# 92/92 [==============================] - 47s 507ms/step - loss: 0.0088 - mse: 0.0014 - FeatRecLoss: 0.0019 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0090 - val_mse: 0.0014 - val_FeatRecLoss: 0.0019 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00233: val_mse did not improve from 0.00134
# TargetLoss :  0.0019478655885905027
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 234/700
# 92/92 [==============================] - 46s 499ms/step - loss: 0.0089 - mse: 0.0014 - FeatRecLoss: 0.0019 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0104 - val_mse: 0.0017 - val_FeatRecLoss: 0.0020 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00234: val_mse did not improve from 0.00134
# TargetLoss :  0.0019542111549526453
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 235/700
# 92/92 [==============================] - 46s 497ms/step - loss: 0.0095 - mse: 0.0015 - FeatRecLoss: 0.0019 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0088 - val_mse: 0.0014 - val_FeatRecLoss: 0.0019 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00235: val_mse did not improve from 0.00134
# TargetLoss :  0.0019471637206152081
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Epoch 236/700
# 42/92 [============>.................] - ETA: 24s - loss: 0.0089 - mse: 0.0014 - FeatRecLoss: 0.0019 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00
# KeyboardInterrupt
