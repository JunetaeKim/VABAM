# %%
import os
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.keras import backend as K
from tensorflow.keras.layers import Input, GRU, Dense, Masking, Reshape, Flatten, RepeatVector, TimeDistributed, Bidirectional, Activation, GaussianNoise, Lambda, LSTM
from tensorflow.keras import Model
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from Models.FeatExtModels_NoKaiser import *

os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="1"

# %% [markdown]
# ### Data

# %%
DATA = np.load('./Data/AsanTRSet.npy')

# %% [markdown]
# #### Env setting

# %%
save_path = './Results/'
if not os.path.exists(save_path):
    os.mkdir(save_path)
    
### Model checkpoint
ModelSaveSameName = save_path+'SigBandRepModel_ExtRec.hdf5'
ModelSave = ModelCheckpoint(filepath=ModelSaveSameName, monitor='val_mse', verbose=1, save_best_only=True )

### Model Early stop
EarlyStop = EarlyStopping(monitor='val_loss', patience=500)

LatDim = 3
SigDim = DATA.shape[1]
MaskingRate = 0.02
NoiseStd = 0.002
MaskStd = 0.1
ReparaStd = 0.1

# %%
'''
class RelLossWeight(tf.keras.callbacks.Callback):
    def __init__(self, LossName1, LossName2, BetaName1, BetaName2, verbose=1):
                
        self.LossName1 = LossName1
        self.LossName2 = LossName2
        self.BetaName1 = BetaName1
        self.BetaName2 = BetaName2
        self.verbose = verbose

    def on_epoch_end(self, epoch, logs={}):
        
        Loss1 = logs[self.LossName1] 
        Loss2 = logs[self.LossName2] 
        
        Beta1_idx = [num for num, i in enumerate(self.model.variables) if self.BetaName1 in i.name][0]
        Beta2_idx = [num for num, i in enumerate(self.model.variables) if self.BetaName2 in i.name][0]
        
        self.model.variables[Beta1_idx].assign(Loss1/Loss2)
        self.model.variables[Beta2_idx].assign(Loss2/Loss1)   

        if self.verbose==1:
            print(self.BetaName1+' : ', self.model.variables[Beta1_idx])
            print(self.BetaName2+' : ', self.model.variables[Beta2_idx])        
 

# Define the KL annealing callback function
class KLCallback(tf.keras.callbacks.Callback):
    def __init__(self, TargetLossName, Threshold, MaxBeta, BetaName, AnnealEpoch=100):
        self.TargetLossName = TargetLossName
        self.Threshold = Threshold
        self.BetaName = BetaName
        self.MaxBeta = MaxBeta
        self.AnnealStart = 0
        self.AnnealEpoch = AnnealEpoch

    def on_epoch_end(self, epoch, logs={}):
        
        TargetLoss = logs['val_'+self.TargetLossName]
        
        if TargetLoss > self.Threshold:
            
            self.AnnealStart = 0
            K.set_value(self.model.get_layer(self.BetaName).variables[0], 0.)
        else: 
            self.AnnealStart += 1
            Beta = (self.AnnealStart) / self.AnnealEpoch * self.MaxBeta
            K.set_value(self.model.get_layer(self.BetaName).variables[0], Beta)
        
        print(self.model.get_layer(self.BetaName).variables[0])
'''

# %%
def ParaFilters (layer, name=''):
    Fc = Dense(1, activation='sigmoid')(layer)
    Fc = tf.clip_by_value(Fc, 1e-7, 1-1e-7)
    
    # Reparameterization Trick for sampling from Uniformly distribution; ϵ∼U(0,1) 
    Epsilon = tf.random.uniform(shape=(tf.shape(Fc)[0], Fc.shape[1]))
    Epsilon = tf.clip_by_value(Epsilon, 1e-7, 1-1e-7)

    LogEps = tf.math.log(Epsilon)
    LogNegEps = tf.math.log(1 - Epsilon)
    
    LogTheta = tf.math.log(Fc)
    LogNegTheta = tf.math.log(1-Fc)

    Fc = tf.math.sigmoid(LogEps - LogNegEps + LogTheta - LogNegTheta)
    Fc = tf.clip_by_value(Fc, 1e-7, 1-1e-7)
    Fc = ReName(Fc, name)
    
    return Fc 


class Lossweight(tf.keras.layers.Layer):
    
    def __init__(self, name='Lossweight'):
        super(Lossweight, self).__init__(name=name)
        pass
    
    def build(self, input_shape):
        self.GenVec = tf.Variable(0., trainable=False)
    
    def call(self, input):

        return self.GenVec
    

class RandFCs(tf.keras.layers.Layer):
    
    def __init__(self, ):
        super(RandFCs, self).__init__(name='FCs')
        pass
    
    def build(self, input_shape):
        self.GenVec = tf.Variable(tf.random.uniform(shape=(1,6)), trainable=False)
    
    def call(self, input):
        return tf.tile(self.GenVec , (tf.shape(input)[0],1))
    


class KLAnneal(tf.keras.callbacks.Callback):
    def __init__(self, TargetLossName, Threshold,  BetaName, MaxBeta=0.1, MinBeta=1e-5, AnnealEpoch=100, verbose=1):
        
        if type(TargetLossName) != list:
            TargetLossName = [TargetLossName]
        
        self.TargetLossName = TargetLossName
        self.Threshold = Threshold
        self.BetaName = BetaName
        self.AnnealIdx = 0
        self.verbose = verbose 
        self.Beta =  np.concatenate([np.zeros(1), np.linspace(start=MinBeta, stop=MaxBeta, num=AnnealEpoch )])

    def on_epoch_end(self, epoch, logs={}):
        
        TargetLoss = max([logs[i] for i in self.TargetLossName]) 
        
        if TargetLoss > self.Threshold:
            
            self.AnnealIdx -= 1
            self.AnnealIdx = np.maximum(self.AnnealIdx, 0)
            K.set_value(self.model.get_layer(self.BetaName).variables[0], self.Beta[self.AnnealIdx])
        else: 
            self.AnnealIdx += 1
            self.AnnealIdx = np.minimum(self.AnnealIdx, len(self.Beta)-1)
            K.set_value(self.model.get_layer(self.BetaName).variables[0], self.Beta[self.AnnealIdx])
        
        if self.verbose==1:
            print(self.BetaName+' : ' ,self.model.get_layer(self.BetaName).variables[0].numpy())
        elif self.verbose==2:
            print('TargetLoss : ', TargetLoss)
            print(self.BetaName+' : ' ,self.model.get_layer(self.BetaName).variables[0].numpy())
            
            
       
class RelLossWeight(tf.keras.callbacks.Callback):
    def __init__(self, LossName1, LossName2, Beta1, Beta2, Weight =1., BetaName1 ='Beta1' , BetaName2 ='Beta2' , verbose=1):
                
        self.LossName1 = LossName1
        self.LossName2 = LossName2
        self.Beta1 = Beta1
        self.Beta2 = Beta2
        self.BetaName1 = BetaName1
        self.BetaName2 = BetaName2
        self.verbose = verbose
        self.Weight = Weight

    def on_epoch_end(self, epoch, logs={}):
        
        Loss1 = logs[self.LossName1] 
        Loss2 = logs[self.LossName2] 
        
        if Loss1>Loss2:
            Loss1 *= self.Weight
        elif Loss2>Loss1:
            Loss2 *= self.Weight
        
        self.Beta1.assign(Loss1/Loss2)
        self.Beta2.assign(Loss2/Loss1)   

        if self.verbose==1:
            print(self.BetaName1+' : ', self.Beta1.numpy())
            print(self.BetaName2+' : ', self.Beta2.numpy())   
            
        
def ReName (layer, name):
    return Lambda(lambda x: x, name=name)(layer)

# %%
def Encoder(SigDim, LatDim= 2, Type = '', MaskingRate = 0.025, NoiseStd = 0.002, MaskStd = 0.1, ReparaStd = 0.1 , Reparam = False):

    InpL = Input(shape=(SigDim,))
    InpFrame = tf.signal.frame(InpL, 100, 100)

    if Reparam:
        InpRegul = GaussianNoise(stddev=NoiseStd)(InpFrame, training=Reparam)
        MaskVec, NoisVec = MaskingGen(InpRegul, MaskingRate, MaskStd)
        EncInp = Masking(mask_value=0.)(InpRegul * MaskVec )
        EncOut = InpRegul + NoisVec
    else:
        EncInp, EncOut = InpFrame, InpFrame

    Encoder = Dense(50, activation='relu')(InpFrame)
    Encoder = Bidirectional(GRU(30, return_sequences=True))(Encoder)
    Encoder = Bidirectional(GRU(30, return_sequences=False))(Encoder)
    Encoder = Dense(50, activation='relu')(Encoder)
    Encoder = Dense(30, activation='relu')(Encoder)
    Encoder = Dense(15, activation='relu')(Encoder)

    Z_Mean = Dense(LatDim, activation='linear')(Encoder)
    Z_Log_Sigma = Dense(LatDim, activation='relu')(Encoder)
    Z_Log_Sigma = ReName(Z_Log_Sigma,'Z_Log_Sigma_'+Type)

    
    # Reparameterization Trick for sampling from Guassian distribution
    Epsilon = tf.random.normal(shape=(tf.shape(Z_Mean)[0], Z_Mean.shape[1]), mean=0., stddev=ReparaStd)

    if Reparam==False:
        Epsilon = Epsilon * 0

    Z_Mean = Z_Mean + tf.exp(0.5 * Z_Log_Sigma) * Epsilon
    Z_Mean = ReName(Z_Mean,'Z_Mean_'+Type)
    
    FCs =   Dense(6, activation='relu')(Z_Mean)
    FCs =   Dense(6, activation='sigmoid')(FCs)
    
    
    # Reparameterization Trick for sampling from Uniformly distribution; ϵ∼U(0,1) 
    FCs = tf.clip_by_value(FCs, 1e-7, 1-1e-7)
    Epsilon = tf.random.uniform(shape=(tf.shape(FCs)[0], FCs.shape[1]))
    Epsilon = tf.clip_by_value(Epsilon, 1e-7, 1-1e-7)
    
    LogEps = tf.math.log(Epsilon)
    LogNegEps = tf.math.log(1 - Epsilon)
    
    LogTheta = tf.math.log(FCs)
    LogNegTheta = tf.math.log(1-FCs)
    
    
    FCs = tf.math.sigmoid(LogEps - LogNegEps + LogTheta - LogNegTheta)
    FCs = tf.clip_by_value(FCs, 1e-7, 1-1e-7)
    FCs = ReName(FCs, 'FCs')
    
    return [InpL], [Flatten()(EncOut), Z_Mean, FCs]



def FeatExtractor(Inps, LatDim= 2, FiltLenList = [301, 301, 301, 301, 301, 301] ):
    
    EncReInp, InpZ, FCs = Inps
    
    H_F, L_F, HH_F, HL_F, LH_F, LL_F = tf.split(FCs, 6, axis=1)
    

    ### Filtering level 1 -------------------------------------------------------------------
    ## Filter generation
    To_H = GenHighFilter(H_F,  N=FiltLenList[0])
    To_L = GenLowFilter(L_F, N=FiltLenList[1])

    ## Perform signal filtering level 1
    InpFrame =  tf.signal.frame(EncReInp, To_H.shape[-1], 1)
    Sig_H = tf.reduce_sum(InpFrame*To_H[:,:,::-1], axis=-1, keepdims=True)
    Sig_H = ReName(Sig_H, 'Sig_H_Ext')

    InpFrame =  tf.signal.frame(EncReInp, To_L.shape[-1], 1)
    Sig_L = tf.reduce_sum(InpFrame*To_L[:,:,::-1], axis=-1, keepdims=True)
    Sig_L = ReName(Sig_L, 'Sig_L_Ext')



    ### Filtering level HH and HL (from Sig_H) -------------------------------------------------------------------
    ## Filter generation
    To_HH = GenHighFilter(HH_F, N=FiltLenList[2])
    To_HL = GenLowFilter(HL_F, N=FiltLenList[3])

    ## Perform signal filtering level 2
    Frame_H =  tf.signal.frame(Sig_H[:,:,0], To_HH.shape[-1], 1)
    Sig_HH = tf.reduce_sum(Frame_H*To_HH[:,:,::-1], axis=-1, keepdims=True)
    Sig_HH = ReName(Sig_HH, 'Sig_HH_Ext')

    Frame_H =  tf.signal.frame(Sig_H[:,:,0], To_HL.shape[-1], 1)
    Sig_HL = tf.reduce_sum(Frame_H*To_HL[:,:,::-1], axis=-1, keepdims=True)
    Sig_HL = ReName(Sig_HL, 'Sig_HL_Ext')


    ### Filtering level LH and LL (from Sig_L) -------------------------------------------------------------------
    ## Filter generation
    To_LH = GenHighFilter(LH_F,  N=FiltLenList[4])
    To_LL = GenLowFilter(LL_F,  N=FiltLenList[5])

    ## Perform signal filtering level 2
    Frame_L =  tf.signal.frame(Sig_L[:,:,0], To_LH.shape[-1], 1)
    Sig_LH = tf.reduce_sum(Frame_L*To_LH[:,:,::-1], axis=-1, keepdims=True)
    Sig_LH = ReName(Sig_LH, 'Sig_LH_Ext')

    Frame_L =  tf.signal.frame(Sig_L[:,:,0], To_LL.shape[-1], 1)
    Sig_LL = tf.reduce_sum(Frame_L*To_LL[:,:,::-1], axis=-1, keepdims=True)
    Sig_LL = ReName(Sig_LL, 'Sig_LL_Ext')

    
    return [Flatten()(Sig_HH), Flatten()(Sig_HL), Flatten()(Sig_LH), Flatten()(Sig_LL)]




def FeatGenerator (Inp_lat):
    
    Inp_lat = tf.concat(Inp_lat, axis=-1)
   
    Dec_Sig_HH = Dense(10, activation='relu')(Inp_lat)
    Dec_Sig_HH = Dense(20, activation='relu')(Dec_Sig_HH)
    Dec_Sig_HH = Dense(30, activation='relu')(Dec_Sig_HH)
    Dec_Sig_HH = Dense(50, activation='relu')(Dec_Sig_HH)

    Dec_Sig_HH = RepeatVector(10 )(Dec_Sig_HH)
    Dec_Sig_HH = Bidirectional(GRU(10, return_sequences=True))(Dec_Sig_HH)
    Dec_Sig_HH = Bidirectional(GRU(20, return_sequences=True))(Dec_Sig_HH)
    Dec_Sig_HH = Dense(40,'tanh')(Dec_Sig_HH)
    Sig_HH= Flatten(name='Sig_HH_Gen')(Dec_Sig_HH)
    
    # ---------------------------------------------------------------------- #
    
    Dec_Sig_HL = Dense(10, activation='relu')(Inp_lat)
    Dec_Sig_HL = Dense(20, activation='relu')(Dec_Sig_HL)
    Dec_Sig_HL = Dense(30, activation='relu')(Dec_Sig_HL)
    Dec_Sig_HL = Dense(50, activation='relu')(Dec_Sig_HL)

    Dec_Sig_HL = RepeatVector(10 )(Dec_Sig_HL)
    Dec_Sig_HL = Bidirectional(GRU(10, return_sequences=True))(Dec_Sig_HL)
    Dec_Sig_HL = Bidirectional(GRU(20, return_sequences=True))(Dec_Sig_HL)
    Dec_Sig_HL = Dense(40,'tanh')(Dec_Sig_HL)
    Sig_HL= Flatten(name='Sig_HL_Gen')(Dec_Sig_HL)
    
    # ---------------------------------------------------------------------- #
    
    Dec_Sig_LH = Dense(10, activation='relu')(Inp_lat)
    Dec_Sig_LH = Dense(20, activation='relu')(Dec_Sig_LH)
    Dec_Sig_LH = Dense(30, activation='relu')(Dec_Sig_LH)
    Dec_Sig_LH = Dense(50, activation='relu')(Dec_Sig_LH)

    Dec_Sig_LH = RepeatVector(10 )(Dec_Sig_LH)
    Dec_Sig_LH = Bidirectional(GRU(10, return_sequences=True))(Dec_Sig_LH)
    Dec_Sig_LH = Bidirectional(GRU(20, return_sequences=True))(Dec_Sig_LH)
    Dec_Sig_LH = Dense(40,'tanh')(Dec_Sig_LH)
    Sig_LH= Flatten(name='Sig_LH_Gen')(Dec_Sig_LH)
    
    # ---------------------------------------------------------------------- #
    
    Dec_Sig_LL = Dense(10, activation='relu')(Inp_lat)
    Dec_Sig_LL = Dense(20, activation='relu')(Dec_Sig_LL)
    Dec_Sig_LL = Dense(30, activation='relu')(Dec_Sig_LL)
    Dec_Sig_LL = Dense(50, activation='relu')(Dec_Sig_LL)

    Dec_Sig_LL = RepeatVector(10 )(Dec_Sig_LL)
    Dec_Sig_LL = Bidirectional(GRU(10, return_sequences=True))(Dec_Sig_LL)
    Dec_Sig_LL = Bidirectional(GRU(20, return_sequences=True))(Dec_Sig_LL)
    Dec_Sig_LL = Dense(40,'tanh')(Dec_Sig_LL)
    Sig_LL= Flatten(name='Sig_LL_Gen')(Dec_Sig_LL)
    
    return  Sig_HH, Sig_HL, Sig_LH, Sig_LL




def Reconstructor(Inps ):
    Sig_HH, Sig_HL, Sig_LH, Sig_LL = Inps

    ## GRU NET -------------------------------------------------------------------
    Dec_Sig_HH = Reshape((-1, 100))(Sig_HH)
    Dec_Sig_HL = Reshape((-1, 100))(Sig_HL)
    Dec_Sig_LH = Reshape((-1, 100))(Sig_LH)
    Dec_Sig_LL = Reshape((-1, 100))(Sig_LL)

    Dec_Sig_HH = Bidirectional(GRU(5), name='Dec_Sig_HH')(Dec_Sig_HH)
    Dec_Sig_HL = Bidirectional(GRU(5), name='Dec_Sig_HL')(Dec_Sig_HL)
    Dec_Sig_LH = Bidirectional(GRU(5), name='Dec_Sig_LH')(Dec_Sig_LH)
    Dec_Sig_LL = Bidirectional(GRU(5), name='Dec_Sig_LL')(Dec_Sig_LL)

    Decoder = tf.concat([ Dec_Sig_HH, Dec_Sig_HL, Dec_Sig_LH, Dec_Sig_LL], axis=1)
    Decoder = RepeatVector((SigDim//100) )(Decoder)
    Decoder = Bidirectional(GRU(50, return_sequences=True))(Decoder)
    Decoder = Dense(100, activation='relu')(Decoder)
    DecOut = Dense(100, activation='sigmoid')(Decoder)
    DecOut = Reshape((SigDim,),name='Out')(DecOut)

    
    return DecOut

# %%
### Encoder - FeatExtractor
EncInp, EncOut = Encoder(SigDim=SigDim, LatDim= LatDim, Type = 'Tr', MaskingRate = MaskingRate, NoiseStd = NoiseStd, MaskStd = MaskStd, ReparaStd = ReparaStd, Reparam=True)
FeatExtOut = FeatExtractor(EncOut)

### Encoder - FeatGenerator - Reconstruction
FeatGenOut = FeatGenerator(EncOut[1:])
FeatGenOut = ReName(FeatGenOut, 'FeatGenOut')

ReconOut = Reconstructor(FeatExtOut)
ReconOut = ReName(ReconOut, 'ReconOut')

### Define the total model
SigBandRepModel = Model(EncInp, ReconOut)

SigBandRepModel.add_weight(initializer=tf.constant_initializer(value=1.0), name='Beta_Rec', trainable=False)
SigBandRepModel.add_weight(initializer=tf.constant_initializer(value=1.0), name='Beta_Feat', trainable=False)
Beta_Rec = [i for i in SigBandRepModel.variables if 'Beta_Rec' in i.name][0]
Beta_Feat = [i for i in SigBandRepModel.variables if 'Beta_Feat' in i.name][0]


### Weight controller; Apply beta and capacity 
Capacity = 0.1 # 0.1 0.05
Beta_Z = Lossweight(name='Beta_Z')(FeatGenOut)
Beta_Fc = Lossweight(name='Beta_Fc')(FeatGenOut)


### Custom loss for Reconstruction
def RECMSE (y_true, y_pred):
    
    RecMSE = tf.losses.mse(y_true, y_pred)
    RecMSE *= Beta_Rec
    
    return RecMSE


### Adding the FeatRecLoss; It allows connection between the extractor and generator
MSE = tf.keras.losses.MeanSquaredError()
FeatRecLoss= MSE(tf.concat(FeatGenOut, axis=-1), tf.concat(FeatExtOut, axis=-1))

SigBandRepModel.add_loss(FeatRecLoss * Beta_Feat.numpy() )
SigBandRepModel.add_metric(FeatRecLoss, 'FeatRecLoss')

### KL Divergence for p(Z) vs q(Z)
Z_Sampled, Z_Log_Sigma = SigBandRepModel.get_layer('Z_Mean_Tr').output, SigBandRepModel.get_layer('Z_Log_Sigma_Tr').output
kl_Loss_Z = 0.5 * tf.reduce_sum( Z_Sampled**2  +  tf.exp(Z_Log_Sigma)- Z_Log_Sigma-1, axis=1)    
kl_Loss_Z = tf.reduce_mean(kl_Loss_Z )
kl_Loss_Z = Beta_Z * tf.abs(kl_Loss_Z - Capacity)

### KL Divergence for p(FCs) vs q(FCs)
BernP = 0.5 # hyperparameter
FCs = SigBandRepModel.get_layer('FCs').output
kl_Loss_FC = tf.math.log(FCs) - tf.math.log(BernP) + tf.math.log(1-FCs) - tf.math.log(1-BernP) 
kl_Loss_FC = tf.reduce_mean(-kl_Loss_FC )
kl_Loss_FC = Beta_Fc * tf.abs(kl_Loss_FC - 0.6)

SigBandRepModel.add_loss(kl_Loss_Z )
SigBandRepModel.add_metric(kl_Loss_Z, 'kl_Loss_Z')

SigBandRepModel.add_loss(kl_Loss_FC )
SigBandRepModel.add_metric(kl_Loss_FC, 'kl_Loss_FC')


## Model Compile
SigBandRepModel.compile(loss=RECMSE, optimizer='adam', metrics={"ReconOut":'mse'}) 

### Loss and KLD_Beta controller
KLD_Beta_Z = KLAnneal(TargetLossName=['val_FeatRecLoss', 'val_mse'], Threshold=0.001, BetaName='Beta_Z',  MaxBeta=0.1 , MinBeta=1e-6, AnnealEpoch=500, verbose=2)
KLD_Beta_Fc = KLAnneal(TargetLossName=['val_FeatRecLoss', 'val_mse'], Threshold=0.001, BetaName='Beta_Fc',  MaxBeta=0.1 , MinBeta=1e-6, AnnealEpoch=500, verbose=1)
RelLoss = RelLossWeight('val_mse', 'val_FeatRecLoss', Beta_Rec, Beta_Feat, verbose=1,Weight=6.)

# %%
SigBandRepModel.load_weights(ModelSaveSameName)
ModelSave = ModelCheckpoint(filepath=ModelSaveSameName, monitor='val_mse', verbose=1, save_best_only=True )

SigBandRepModel.fit(DATA[:], DATA[:], batch_size=3500, epochs=700, shuffle=True, validation_split=0.2, callbacks=[EarlyStop, ModelSave, KLD_Beta_Z, KLD_Beta_Fc, RelLoss])
# Out:
# Epoch 1/700
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x0000021D8DC32CA0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: unsupported operand type(s) for -: 'NoneType' and 'int'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x0000021D8DC32CA0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: unsupported operand type(s) for -: 'NoneType' and 'int'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
#  6/92 [>.............................] - ETA: 48s - loss: 0.0056 - mse: 0.0029 - FeatRecLoss: 0.0027 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.2334s vs `on_train_batch_end` time: 0.2793s). Check your callbacks.
# 92/92 [==============================] - ETA: 0s - loss: 0.0046 - mse: 0.0021 - FeatRecLoss: 0.0024 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x00000217ED2DD430> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: unsupported operand type(s) for -: 'NoneType' and 'int'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x00000217ED2DD430> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: unsupported operand type(s) for -: 'NoneType' and 'int'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 92/92 [==============================] - 91s 683ms/step - loss: 0.0046 - mse: 0.0021 - FeatRecLoss: 0.0024 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0039 - val_mse: 0.0016 - val_FeatRecLoss: 0.0023 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00001: val_mse improved from inf to 0.00163, saving model to ./Results\SigBandRepModel_ExtRec.hdf5
# TargetLoss :  0.00229690782725811
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Beta1 :  0.11799353
# Beta2 :  8.475041
# Epoch 2/700
# 92/92 [==============================] - 56s 610ms/step - loss: 0.0025 - mse: 0.0016 - FeatRecLoss: 0.0023 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0025 - val_mse: 0.0016 - val_FeatRecLoss: 0.0023 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00002: val_mse improved from 0.00163 to 0.00162, saving model to ./Results\SigBandRepModel_ExtRec.hdf5
# TargetLoss :  0.0022644666023552418
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Beta1 :  0.11939484
# Beta2 :  8.375571
# Epoch 3/700
# 92/92 [==============================] - 56s 612ms/step - loss: 0.0024 - mse: 0.0016 - FeatRecLoss: 0.0022 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0024 - val_mse: 0.0016 - val_FeatRecLoss: 0.0022 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00003: val_mse improved from 0.00162 to 0.00162, saving model to ./Results\SigBandRepModel_ExtRec.hdf5
# TargetLoss :  0.002238193992525339
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Beta1 :  0.1205866
# Beta2 :  8.292795
# Epoch 4/700
# 92/92 [==============================] - 56s 611ms/step - loss: 0.0024 - mse: 0.0016 - FeatRecLoss: 0.0022 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0024 - val_mse: 0.0016 - val_FeatRecLoss: 0.0022 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00004: val_mse improved from 0.00162 to 0.00162, saving model to ./Results\SigBandRepModel_ExtRec.hdf5
# TargetLoss :  0.0022209342569112778
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Beta1 :  0.121398374
# Beta2 :  8.237343
# Epoch 5/700
# 92/92 [==============================] - 56s 611ms/step - loss: 0.0024 - mse: 0.0016 - FeatRecLoss: 0.0022 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0024 - val_mse: 0.0016 - val_FeatRecLoss: 0.0022 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00005: val_mse improved from 0.00162 to 0.00162, saving model to ./Results\SigBandRepModel_ExtRec.hdf5
# TargetLoss :  0.002207624027505517
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Beta1 :  0.12200119
# Beta2 :  8.196641
# Epoch 6/700
# 92/92 [==============================] - 56s 607ms/step - loss: 0.0024 - mse: 0.0016 - FeatRecLoss: 0.0022 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0024 - val_mse: 0.0016 - val_FeatRecLoss: 0.0022 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00006: val_mse improved from 0.00162 to 0.00161, saving model to ./Results\SigBandRepModel_ExtRec.hdf5
# TargetLoss :  0.0021918409038335085
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Beta1 :  0.122783564
# Beta2 :  8.144413
# Epoch 7/700
# 92/92 [==============================] - 56s 611ms/step - loss: 0.0024 - mse: 0.0016 - FeatRecLoss: 0.0022 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0023 - val_mse: 0.0016 - val_FeatRecLoss: 0.0021 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00007: val_mse improved from 0.00161 to 0.00161, saving model to ./Results\SigBandRepModel_ExtRec.hdf5
# TargetLoss :  0.0021386556327342987
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Beta1 :  0.12577222
# Beta2 :  7.9508815
# Epoch 8/700
# 92/92 [==============================] - 56s 612ms/step - loss: 0.0023 - mse: 0.0016 - FeatRecLoss: 0.0021 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0022 - val_mse: 0.0016 - val_FeatRecLoss: 0.0020 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00008: val_mse improved from 0.00161 to 0.00161, saving model to ./Results\SigBandRepModel_ExtRec.hdf5
# TargetLoss :  0.0019906500820070505
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Beta1 :  0.13479161
# Beta2 :  7.418859
# Epoch 9/700
# 92/92 [==============================] - 56s 610ms/step - loss: 0.0022 - mse: 0.0016 - FeatRecLoss: 0.0020 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0021 - val_mse: 0.0016 - val_FeatRecLoss: 0.0019 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00009: val_mse improved from 0.00161 to 0.00161, saving model to ./Results\SigBandRepModel_ExtRec.hdf5
# TargetLoss :  0.0019179428927600384
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Beta1 :  0.13966998
# Beta2 :  7.1597347
# Epoch 10/700
# 92/92 [==============================] - 56s 611ms/step - loss: 0.0021 - mse: 0.0016 - FeatRecLoss: 0.0019 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0020 - val_mse: 0.0016 - val_FeatRecLoss: 0.0018 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00010: val_mse improved from 0.00161 to 0.00160, saving model to ./Results\SigBandRepModel_ExtRec.hdf5
# TargetLoss :  0.0018217054894194007
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Beta1 :  0.14671594
# Beta2 :  6.8158917
# Epoch 11/700
# 92/92 [==============================] - 56s 612ms/step - loss: 0.0020 - mse: 0.0016 - FeatRecLoss: 0.0018 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0020 - val_mse: 0.0016 - val_FeatRecLoss: 0.0017 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00011: val_mse improved from 0.00160 to 0.00160, saving model to ./Results\SigBandRepModel_ExtRec.hdf5
# TargetLoss :  0.0017265495844185352
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Beta1 :  0.154466
# Beta2 :  6.4739165
# Epoch 12/700
# 92/92 [==============================] - 56s 612ms/step - loss: 0.0020 - mse: 0.0016 - FeatRecLoss: 0.0017 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0019 - val_mse: 0.0016 - val_FeatRecLoss: 0.0016 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00012: val_mse improved from 0.00160 to 0.00160, saving model to ./Results\SigBandRepModel_ExtRec.hdf5
# TargetLoss :  0.001642241608351469
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Beta1 :  0.16216613
# Beta2 :  6.1665154
# Epoch 13/700
# 92/92 [==============================] - 56s 611ms/step - loss: 0.0019 - mse: 0.0016 - FeatRecLoss: 0.0016 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0018 - val_mse: 0.0016 - val_FeatRecLoss: 0.0016 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00013: val_mse improved from 0.00160 to 0.00159, saving model to ./Results\SigBandRepModel_ExtRec.hdf5
# TargetLoss :  0.0015941009623929858
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Beta1 :  6.0981474
# Beta2 :  0.16398424
# Epoch 14/700
# 92/92 [==============================] - 56s 612ms/step - loss: 0.0330 - mse: 0.0052 - FeatRecLoss: 0.0015 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0115 - val_mse: 0.0016 - val_FeatRecLoss: 0.0015 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00014: val_mse did not improve from 0.00159
# TargetLoss :  0.001645609620027244
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Beta1 :  6.586634
# Beta2 :  0.15182261
# Epoch 15/700
# 92/92 [==============================] - 56s 606ms/step - loss: 0.0122 - mse: 0.0016 - FeatRecLoss: 0.0015 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0120 - val_mse: 0.0016 - val_FeatRecLoss: 0.0015 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00015: val_mse did not improve from 0.00159
# TargetLoss :  0.0016002260381355882
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Beta1 :  6.5089936
# Beta2 :  0.15363358
# Epoch 16/700
# 92/92 [==============================] - 56s 611ms/step - loss: 0.0118 - mse: 0.0016 - FeatRecLoss: 0.0014 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0117 - val_mse: 0.0016 - val_FeatRecLoss: 0.0014 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00016: val_mse improved from 0.00159 to 0.00158, saving model to ./Results\SigBandRepModel_ExtRec.hdf5
# TargetLoss :  0.0015826713060960174
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Beta1 :  6.642311
# Beta2 :  0.15055001
# Epoch 17/700
# 92/92 [==============================] - 56s 614ms/step - loss: 0.0119 - mse: 0.0016 - FeatRecLoss: 0.0014 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0118 - val_mse: 0.0016 - val_FeatRecLoss: 0.0014 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00017: val_mse improved from 0.00158 to 0.00157, saving model to ./Results\SigBandRepModel_ExtRec.hdf5
# TargetLoss :  0.0015733597101643682
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Beta1 :  6.796274
# Beta2 :  0.14713944
# Epoch 18/700
# 92/92 [==============================] - 56s 611ms/step - loss: 0.0120 - mse: 0.0016 - FeatRecLoss: 0.0014 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0120 - val_mse: 0.0016 - val_FeatRecLoss: 0.0014 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00018: val_mse improved from 0.00157 to 0.00156, saving model to ./Results\SigBandRepModel_ExtRec.hdf5
# TargetLoss :  0.0015614362200722098
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Beta1 :  6.831221
# Beta2 :  0.14638671
# Epoch 19/700
# 92/92 [==============================] - 56s 607ms/step - loss: 0.0120 - mse: 0.0016 - FeatRecLoss: 0.0013 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0119 - val_mse: 0.0015 - val_FeatRecLoss: 0.0013 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00019: val_mse improved from 0.00156 to 0.00155, saving model to ./Results\SigBandRepModel_ExtRec.hdf5
# TargetLoss :  0.0015491900267079473
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Beta1 :  7.0885963
# Beta2 :  0.14107165
# Epoch 20/700
# 92/92 [==============================] - 56s 609ms/step - loss: 0.0123 - mse: 0.0015 - FeatRecLoss: 0.0013 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0122 - val_mse: 0.0015 - val_FeatRecLoss: 0.0013 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00020: val_mse improved from 0.00155 to 0.00155, saving model to ./Results\SigBandRepModel_ExtRec.hdf5
# TargetLoss :  0.0015455858083441854
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Beta1 :  7.3095946
# Beta2 :  0.13680649
# Epoch 21/700
# 92/92 [==============================] - 56s 606ms/step - loss: 0.0125 - mse: 0.0015 - FeatRecLoss: 0.0013 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0125 - val_mse: 0.0015 - val_FeatRecLoss: 0.0012 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00021: val_mse improved from 0.00155 to 0.00154, saving model to ./Results\SigBandRepModel_ExtRec.hdf5
# TargetLoss :  0.0015434741508215666
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Beta1 :  7.577182
# Beta2 :  0.13197519
# Epoch 22/700
# 92/92 [==============================] - 56s 609ms/step - loss: 0.0128 - mse: 0.0015 - FeatRecLoss: 0.0012 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0127 - val_mse: 0.0015 - val_FeatRecLoss: 0.0012 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00022: val_mse improved from 0.00154 to 0.00152, saving model to ./Results\SigBandRepModel_ExtRec.hdf5
# TargetLoss :  0.001520324032753706
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Beta1 :  7.7270384
# Beta2 :  0.12941569
# Epoch 23/700
# 92/92 [==============================] - 56s 612ms/step - loss: 0.0129 - mse: 0.0015 - FeatRecLoss: 0.0012 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0128 - val_mse: 0.0015 - val_FeatRecLoss: 0.0011 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00023: val_mse improved from 0.00152 to 0.00151, saving model to ./Results\SigBandRepModel_ExtRec.hdf5
# TargetLoss :  0.0015138437738642097
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Beta1 :  8.021066
# Beta2 :  0.124671705
# Epoch 24/700
# 92/92 [==============================] - 56s 607ms/step - loss: 0.0132 - mse: 0.0015 - FeatRecLoss: 0.0011 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0131 - val_mse: 0.0015 - val_FeatRecLoss: 0.0011 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00024: val_mse improved from 0.00151 to 0.00150, saving model to ./Results\SigBandRepModel_ExtRec.hdf5
# TargetLoss :  0.0014994406374171376
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Beta1 :  8.110856
# Beta2 :  0.12329155
# Epoch 25/700
# 92/92 [==============================] - 56s 609ms/step - loss: 0.0132 - mse: 0.0015 - FeatRecLoss: 0.0011 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0132 - val_mse: 0.0015 - val_FeatRecLoss: 0.0011 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00025: val_mse improved from 0.00150 to 0.00149, saving model to ./Results\SigBandRepModel_ExtRec.hdf5
# TargetLoss :  0.0014894942287355661
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Beta1 :  8.225371
# Beta2 :  0.121575065
# Epoch 26/700
# 92/92 [==============================] - 56s 611ms/step - loss: 0.0133 - mse: 0.0015 - FeatRecLoss: 0.0011 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0132 - val_mse: 0.0015 - val_FeatRecLoss: 0.0011 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00026: val_mse improved from 0.00149 to 0.00148, saving model to ./Results\SigBandRepModel_ExtRec.hdf5
# TargetLoss :  0.0014822370139881968
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Beta1 :  8.459169
# Beta2 :  0.11821491
# Epoch 27/700
# 92/92 [==============================] - 56s 610ms/step - loss: 0.0135 - mse: 0.0015 - FeatRecLoss: 0.0010 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0134 - val_mse: 0.0015 - val_FeatRecLoss: 9.9981e-04 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00027: val_mse improved from 0.00148 to 0.00147, saving model to ./Results\SigBandRepModel_ExtRec.hdf5
# TargetLoss :  0.0014676701975986362
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Beta1 :  8.807683
# Beta2 :  0.11353724
# Epoch 28/700
# 92/92 [==============================] - 56s 611ms/step - loss: 0.0139 - mse: 0.0015 - FeatRecLoss: 9.9115e-04 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0138 - val_mse: 0.0015 - val_FeatRecLoss: 9.7877e-04 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00028: val_mse improved from 0.00147 to 0.00146, saving model to ./Results\SigBandRepModel_ExtRec.hdf5
# TargetLoss :  0.001459444989450276
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Beta1 :  8.946642
# Beta2 :  0.11177378
# Epoch 29/700
# 92/92 [==============================] - 56s 613ms/step - loss: 0.0140 - mse: 0.0015 - FeatRecLoss: 9.5852e-04 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0140 - val_mse: 0.0015 - val_FeatRecLoss: 9.5704e-04 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00029: val_mse improved from 0.00146 to 0.00146, saving model to ./Results\SigBandRepModel_ExtRec.hdf5
# TargetLoss :  0.0014556876849383116
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Beta1 :  9.126232
# Beta2 :  0.10957424
# Epoch 30/700
# 92/92 [==============================] - 56s 609ms/step - loss: 0.0142 - mse: 0.0014 - FeatRecLoss: 9.3889e-04 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0141 - val_mse: 0.0014 - val_FeatRecLoss: 9.1380e-04 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00030: val_mse improved from 0.00146 to 0.00145, saving model to ./Results\SigBandRepModel_ExtRec.hdf5
# TargetLoss :  0.0014459261437878013
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Beta1 :  9.493935
# Beta2 :  0.10533041
# Epoch 31/700
# 92/92 [==============================] - 56s 612ms/step - loss: 0.0146 - mse: 0.0014 - FeatRecLoss: 8.9668e-04 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0145 - val_mse: 0.0014 - val_FeatRecLoss: 8.8102e-04 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00031: val_mse improved from 0.00145 to 0.00143, saving model to ./Results\SigBandRepModel_ExtRec.hdf5
# TargetLoss :  0.00143135292455554
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Beta1 :  9.747912
# Beta2 :  0.10258607
# Epoch 32/700
# 92/92 [==============================] - 56s 606ms/step - loss: 0.0148 - mse: 0.0014 - FeatRecLoss: 8.7761e-04 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0147 - val_mse: 0.0014 - val_FeatRecLoss: 8.6330e-04 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00032: val_mse improved from 0.00143 to 0.00142, saving model to ./Results\SigBandRepModel_ExtRec.hdf5
# TargetLoss :  0.0014179700519889593
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Beta1 :  9.85503
# Beta2 :  0.10147103
# Epoch 33/700
# 92/92 [==============================] - 56s 612ms/step - loss: 0.0148 - mse: 0.0014 - FeatRecLoss: 8.6038e-04 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0148 - val_mse: 0.0014 - val_FeatRecLoss: 8.4292e-04 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00033: val_mse improved from 0.00142 to 0.00141, saving model to ./Results\SigBandRepModel_ExtRec.hdf5
# TargetLoss :  0.0014125158777460456
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Beta1 :  10.054391
# Beta2 :  0.09945904
# Epoch 34/700
# 92/92 [==============================] - 56s 614ms/step - loss: 0.0150 - mse: 0.0014 - FeatRecLoss: 8.4950e-04 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0149 - val_mse: 0.0014 - val_FeatRecLoss: 8.5683e-04 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00034: val_mse improved from 0.00141 to 0.00140, saving model to ./Results\SigBandRepModel_ExtRec.hdf5
# TargetLoss :  0.0013997736386954784
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Beta1 :  9.801979
# Beta2 :  0.10202021
# Epoch 35/700
# 92/92 [==============================] - 56s 612ms/step - loss: 0.0146 - mse: 0.0014 - FeatRecLoss: 8.1917e-04 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0146 - val_mse: 0.0014 - val_FeatRecLoss: 8.0394e-04 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00035: val_mse did not improve from 0.00140
# TargetLoss :  0.0014065603027120233
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Beta1 :  10.497473
# Beta2 :  0.09526103
# Epoch 36/700
# 92/92 [==============================] - 56s 612ms/step - loss: 0.0156 - mse: 0.0014 - FeatRecLoss: 8.0627e-04 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0156 - val_mse: 0.0014 - val_FeatRecLoss: 8.2684e-04 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00036: val_mse did not improve from 0.00140
# TargetLoss :  0.0014032515464350581
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Beta1 :  10.182784
# Beta2 :  0.09820497
# Epoch 37/700
# 92/92 [==============================] - 56s 608ms/step - loss: 0.0149 - mse: 0.0014 - FeatRecLoss: 8.0005e-04 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0149 - val_mse: 0.0014 - val_FeatRecLoss: 8.3066e-04 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00037: val_mse improved from 0.00140 to 0.00138, saving model to ./Results\SigBandRepModel_ExtRec.hdf5
# TargetLoss :  0.0013815724523738027
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Beta1 :  9.979383
# Beta2 :  0.10020659
# Epoch 38/700
# 92/92 [==============================] - 56s 608ms/step - loss: 0.0145 - mse: 0.0014 - FeatRecLoss: 7.9610e-04 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0146 - val_mse: 0.0014 - val_FeatRecLoss: 7.7753e-04 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00038: val_mse did not improve from 0.00138
# TargetLoss :  0.0013895026640966535
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Beta1 :  10.722385
# Beta2 :  0.09326283
# Epoch 39/700
# 92/92 [==============================] - 56s 612ms/step - loss: 0.0155 - mse: 0.0014 - FeatRecLoss: 7.8082e-04 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0157 - val_mse: 0.0014 - val_FeatRecLoss: 7.5981e-04 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00039: val_mse did not improve from 0.00138
# TargetLoss :  0.0013970405561849475
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Beta1 :  11.031969
# Beta2 :  0.09064565
# Epoch 40/700
# 92/92 [==============================] - 56s 606ms/step - loss: 0.0159 - mse: 0.0014 - FeatRecLoss: 7.5931e-04 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0157 - val_mse: 0.0014 - val_FeatRecLoss: 7.7571e-04 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00040: val_mse improved from 0.00138 to 0.00136, saving model to ./Results\SigBandRepModel_ExtRec.hdf5
# TargetLoss :  0.0013569581788033247
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Beta1 :  10.495918
# Beta2 :  0.09527513
# Epoch 41/700
# 92/92 [==============================] - 56s 614ms/step - loss: 0.0149 - mse: 0.0014 - FeatRecLoss: 7.5340e-04 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0149 - val_mse: 0.0013 - val_FeatRecLoss: 7.4096e-04 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00041: val_mse improved from 0.00136 to 0.00135, saving model to ./Results\SigBandRepModel_ExtRec.hdf5
# TargetLoss :  0.0013468451797962189
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Beta1 :  10.906231
# Beta2 :  0.09169071
# Epoch 42/700
# 92/92 [==============================] - 56s 610ms/step - loss: 0.0154 - mse: 0.0013 - FeatRecLoss: 7.4086e-04 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0153 - val_mse: 0.0013 - val_FeatRecLoss: 7.2716e-04 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00042: val_mse improved from 0.00135 to 0.00134, saving model to ./Results\SigBandRepModel_ExtRec.hdf5
# TargetLoss :  0.0013369166990742087
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Beta1 :  11.031234
# Beta2 :  0.09065169
# Epoch 43/700
# 92/92 [==============================] - 56s 611ms/step - loss: 0.0155 - mse: 0.0013 - FeatRecLoss: 7.2559e-04 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0155 - val_mse: 0.0013 - val_FeatRecLoss: 7.0502e-04 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00043: val_mse did not improve from 0.00134
# TargetLoss :  0.0013382077449932694
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Beta1 :  11.388737
# Beta2 :  0.08780605
# Epoch 44/700
# 92/92 [==============================] - 56s 610ms/step - loss: 0.0159 - mse: 0.0013 - FeatRecLoss: 7.1886e-04 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0160 - val_mse: 0.0013 - val_FeatRecLoss: 7.3406e-04 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00044: val_mse did not improve from 0.00134
# TargetLoss :  0.0013390913372859359
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Beta1 :  10.945289
# Beta2 :  0.09136351
# Epoch 45/700
# 92/92 [==============================] - 56s 613ms/step - loss: 0.0152 - mse: 0.0013 - FeatRecLoss: 7.1381e-04 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0151 - val_mse: 0.0013 - val_FeatRecLoss: 6.9434e-04 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00045: val_mse improved from 0.00134 to 0.00132, saving model to ./Results\SigBandRepModel_ExtRec.hdf5
# TargetLoss :  0.0013173597399145365
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Beta1 :  11.383632
# Beta2 :  0.08784543
# Epoch 46/700
# 92/92 [==============================] - 56s 612ms/step - loss: 0.0156 - mse: 0.0013 - FeatRecLoss: 6.9439e-04 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0157 - val_mse: 0.0013 - val_FeatRecLoss: 7.0022e-04 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00046: val_mse did not improve from 0.00132
# TargetLoss :  0.0013173716142773628
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Beta1 :  11.2882
# Beta2 :  0.08858808
# Epoch 47/700
# 92/92 [==============================] - 56s 613ms/step - loss: 0.0155 - mse: 0.0013 - FeatRecLoss: 6.8728e-04 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0155 - val_mse: 0.0013 - val_FeatRecLoss: 6.7259e-04 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00047: val_mse did not improve from 0.00132
# TargetLoss :  0.0013174191117286682
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Beta1 :  11.752353
# Beta2 :  0.08508935
# Epoch 48/700
# 92/92 [==============================] - 56s 612ms/step - loss: 0.0160 - mse: 0.0013 - FeatRecLoss: 6.7202e-04 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0159 - val_mse: 0.0013 - val_FeatRecLoss: 6.7730e-04 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00048: val_mse improved from 0.00132 to 0.00130, saving model to ./Results\SigBandRepModel_ExtRec.hdf5
# TargetLoss :  0.001295719644986093
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Beta1 :  11.4784155
# Beta2 :  0.08712004
# Epoch 49/700
# 92/92 [==============================] - 56s 614ms/step - loss: 0.0156 - mse: 0.0013 - FeatRecLoss: 6.6866e-04 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0155 - val_mse: 0.0013 - val_FeatRecLoss: 6.6617e-04 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00049: val_mse improved from 0.00130 to 0.00129, saving model to ./Results\SigBandRepModel_ExtRec.hdf5
# TargetLoss :  0.0012910686200484633
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Beta1 :  11.62828
# Beta2 :  0.08599724
# Epoch 50/700
# 92/92 [==============================] - 56s 607ms/step - loss: 0.0156 - mse: 0.0013 - FeatRecLoss: 6.6617e-04 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0157 - val_mse: 0.0013 - val_FeatRecLoss: 6.3878e-04 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00050: val_mse did not improve from 0.00129
# TargetLoss :  0.001298624207265675
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Beta1 :  12.197918
# Beta2 :  0.081981204
# Epoch 51/700
# 92/92 [==============================] - 56s 604ms/step - loss: 0.0165 - mse: 0.0013 - FeatRecLoss: 6.8362e-04 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0163 - val_mse: 0.0013 - val_FeatRecLoss: 6.4566e-04 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00051: val_mse improved from 0.00129 to 0.00128, saving model to ./Results\SigBandRepModel_ExtRec.hdf5
# TargetLoss :  0.0012814983492717147
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Beta1 :  11.908667
# Beta2 :  0.08397246
# Epoch 52/700
# 92/92 [==============================] - 56s 610ms/step - loss: 0.0160 - mse: 0.0013 - FeatRecLoss: 6.3916e-04 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0158 - val_mse: 0.0013 - val_FeatRecLoss: 6.6769e-04 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00052: val_mse improved from 0.00128 to 0.00127, saving model to ./Results\SigBandRepModel_ExtRec.hdf5
# TargetLoss :  0.001271614688448608
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Beta1 :  11.427049
# Beta2 :  0.08751166
# Epoch 53/700
# 92/92 [==============================] - 56s 610ms/step - loss: 0.0151 - mse: 0.0013 - FeatRecLoss: 6.4998e-04 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0152 - val_mse: 0.0013 - val_FeatRecLoss: 6.2010e-04 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00053: val_mse did not improve from 0.00127
# TargetLoss :  0.0012770405737683177
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Beta1 :  12.356452
# Beta2 :  0.080929376
# Epoch 54/700
# 92/92 [==============================] - 56s 612ms/step - loss: 0.0164 - mse: 0.0013 - FeatRecLoss: 6.5343e-04 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0164 - val_mse: 0.0013 - val_FeatRecLoss: 6.7968e-04 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00054: val_mse did not improve from 0.00127
# TargetLoss :  0.0012716659111902118
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Beta1 :  11.225932
# Beta2 :  0.08907946
# Epoch 55/700
# 92/92 [==============================] - 56s 613ms/step - loss: 0.0148 - mse: 0.0013 - FeatRecLoss: 6.3707e-04 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0148 - val_mse: 0.0013 - val_FeatRecLoss: 6.3600e-04 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00055: val_mse improved from 0.00127 to 0.00126, saving model to ./Results\SigBandRepModel_ExtRec.hdf5
# TargetLoss :  0.0012617632746696472
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Beta1 :  11.903384
# Beta2 :  0.08400972
# Epoch 56/700
# 92/92 [==============================] - 56s 610ms/step - loss: 0.0156 - mse: 0.0013 - FeatRecLoss: 6.2371e-04 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0156 - val_mse: 0.0013 - val_FeatRecLoss: 6.1186e-04 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00056: val_mse did not improve from 0.00126
# TargetLoss :  0.001261822646483779
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Beta1 :  12.373625
# Beta2 :  0.08081706
# Epoch 57/700
# 92/92 [==============================] - 56s 611ms/step - loss: 0.0162 - mse: 0.0013 - FeatRecLoss: 6.1898e-04 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0161 - val_mse: 0.0013 - val_FeatRecLoss: 6.4424e-04 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00057: val_mse improved from 0.00126 to 0.00125, saving model to ./Results\SigBandRepModel_ExtRec.hdf5
# TargetLoss :  0.0012519127922132611
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Beta1 :  11.659408
# Beta2 :  0.08576765
# Epoch 58/700
# 92/92 [==============================] - 56s 611ms/step - loss: 0.0152 - mse: 0.0013 - FeatRecLoss: 6.4694e-04 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0152 - val_mse: 0.0013 - val_FeatRecLoss: 6.2584e-04 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00058: val_mse did not improve from 0.00125
# TargetLoss :  0.001253872411325574
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Beta1 :  12.021074
# Beta2 :  0.083187245
# Epoch 59/700
# 92/92 [==============================] - 56s 607ms/step - loss: 0.0156 - mse: 0.0012 - FeatRecLoss: 6.3803e-04 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0156 - val_mse: 0.0012 - val_FeatRecLoss: 6.2013e-04 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00059: val_mse improved from 0.00125 to 0.00125, saving model to ./Results\SigBandRepModel_ExtRec.hdf5
# TargetLoss :  0.0012456255499273539
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Beta1 :  12.051984
# Beta2 :  0.08297389
# Epoch 60/700
# 92/92 [==============================] - 56s 608ms/step - loss: 0.0155 - mse: 0.0012 - FeatRecLoss: 6.0568e-04 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0155 - val_mse: 0.0012 - val_FeatRecLoss: 6.3647e-04 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00060: val_mse improved from 0.00125 to 0.00124, saving model to ./Results\SigBandRepModel_ExtRec.hdf5
# TargetLoss :  0.0012358211679384112
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Beta1 :  11.6501
# Beta2 :  0.08583618
# Epoch 61/700
# 92/92 [==============================] - 56s 611ms/step - loss: 0.0150 - mse: 0.0012 - FeatRecLoss: 6.1762e-04 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0151 - val_mse: 0.0012 - val_FeatRecLoss: 6.0786e-04 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00061: val_mse did not improve from 0.00124
# TargetLoss :  0.0012402997817844152
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Beta1 :  12.242693
# Beta2 :  0.08168138
# Epoch 62/700
# 92/92 [==============================] - 56s 611ms/step - loss: 0.0157 - mse: 0.0012 - FeatRecLoss: 6.0060e-04 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0157 - val_mse: 0.0012 - val_FeatRecLoss: 6.5790e-04 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00062: val_mse improved from 0.00124 to 0.00123, saving model to ./Results\SigBandRepModel_ExtRec.hdf5
# TargetLoss :  0.0012285062111914158
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Beta1 :  11.203905
# Beta2 :  0.089254595
# Epoch 63/700
# 92/92 [==============================] - 56s 606ms/step - loss: 0.0144 - mse: 0.0012 - FeatRecLoss: 6.0044e-04 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0143 - val_mse: 0.0012 - val_FeatRecLoss: 5.7369e-04 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00063: val_mse improved from 0.00123 to 0.00122, saving model to ./Results\SigBandRepModel_ExtRec.hdf5
# TargetLoss :  0.001224248786456883
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Beta1 :  12.8039
# Beta2 :  0.07810121
# Epoch 64/700
# 92/92 [==============================] - 56s 611ms/step - loss: 0.0169 - mse: 0.0013 - FeatRecLoss: 5.9473e-04 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0163 - val_mse: 0.0012 - val_FeatRecLoss: 6.0611e-04 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00064: val_mse improved from 0.00122 to 0.00122, saving model to ./Results\SigBandRepModel_ExtRec.hdf5
# TargetLoss :  0.0012232160661369562
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Beta1 :  12.10895
# Beta2 :  0.08258355
# Epoch 65/700
# 92/92 [==============================] - 56s 607ms/step - loss: 0.0153 - mse: 0.0012 - FeatRecLoss: 5.7517e-04 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0152 - val_mse: 0.0012 - val_FeatRecLoss: 5.7655e-04 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00065: val_mse improved from 0.00122 to 0.00121, saving model to ./Results\SigBandRepModel_ExtRec.hdf5
# TargetLoss :  0.0012114152777940035
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Beta1 :  12.606872
# Beta2 :  0.07932182
# Epoch 66/700
# 92/92 [==============================] - 56s 612ms/step - loss: 0.0159 - mse: 0.0012 - FeatRecLoss: 5.9597e-04 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0160 - val_mse: 0.0012 - val_FeatRecLoss: 6.2181e-04 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00066: val_mse did not improve from 0.00121
# TargetLoss :  0.0012161185732111335
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Beta1 :  11.734706
# Beta2 :  0.085217305
# Epoch 67/700
# 92/92 [==============================] - 56s 608ms/step - loss: 0.0148 - mse: 0.0012 - FeatRecLoss: 5.8138e-04 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0148 - val_mse: 0.0012 - val_FeatRecLoss: 5.7574e-04 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00067: val_mse improved from 0.00121 to 0.00121, saving model to ./Results\SigBandRepModel_ExtRec.hdf5
# TargetLoss :  0.0012080312008038163
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Beta1 :  12.589445
# Beta2 :  0.079431616
# Epoch 68/700
# 92/92 [==============================] - 56s 606ms/step - loss: 0.0157 - mse: 0.0012 - FeatRecLoss: 5.8735e-04 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0158 - val_mse: 0.0012 - val_FeatRecLoss: 5.6647e-04 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00068: val_mse did not improve from 0.00121
# TargetLoss :  0.0012080754386261106
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Beta1 :  12.795909
# Beta2 :  0.07814998
# Epoch 69/700
# 92/92 [==============================] - 56s 611ms/step - loss: 0.0160 - mse: 0.0012 - FeatRecLoss: 5.6374e-04 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0160 - val_mse: 0.0012 - val_FeatRecLoss: 5.4982e-04 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00069: val_mse improved from 0.00121 to 0.00121, saving model to ./Results\SigBandRepModel_ExtRec.hdf5
# TargetLoss :  0.0012075479608029127
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Beta1 :  13.177634
# Beta2 :  0.07588616
# Epoch 70/700
# 92/92 [==============================] - 56s 610ms/step - loss: 0.0165 - mse: 0.0012 - FeatRecLoss: 5.6789e-04 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0165 - val_mse: 0.0012 - val_FeatRecLoss: 5.9464e-04 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00070: val_mse did not improve from 0.00121
# TargetLoss :  0.0012090607779100537
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Beta1 :  12.199616
# Beta2 :  0.08196979
# Epoch 71/700
# 92/92 [==============================] - 56s 609ms/step - loss: 0.0152 - mse: 0.0012 - FeatRecLoss: 5.8249e-04 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0151 - val_mse: 0.0012 - val_FeatRecLoss: 5.8523e-04 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00071: val_mse improved from 0.00121 to 0.00119, saving model to ./Results\SigBandRepModel_ExtRec.hdf5
# TargetLoss :  0.0011930334148928523
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Beta1 :  12.231431
# Beta2 :  0.081756584
# Epoch 72/700
# 92/92 [==============================] - 56s 611ms/step - loss: 0.0151 - mse: 0.0012 - FeatRecLoss: 5.5823e-04 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0151 - val_mse: 0.0012 - val_FeatRecLoss: 5.8455e-04 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00072: val_mse improved from 0.00119 to 0.00119, saving model to ./Results\SigBandRepModel_ExtRec.hdf5
# TargetLoss :  0.0011879238300025463
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Beta1 :  12.193313
# Beta2 :  0.08201217
# Epoch 73/700
# 92/92 [==============================] - 56s 614ms/step - loss: 0.0150 - mse: 0.0012 - FeatRecLoss: 5.5417e-04 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0151 - val_mse: 0.0012 - val_FeatRecLoss: 5.5096e-04 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00073: val_mse did not improve from 0.00119
# TargetLoss :  0.001190916751511395
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Beta1 :  12.969174
# Beta2 :  0.07710591
# Epoch 74/700
# 92/92 [==============================] - 56s 605ms/step - loss: 0.0159 - mse: 0.0012 - FeatRecLoss: 5.5713e-04 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0159 - val_mse: 0.0012 - val_FeatRecLoss: 5.4640e-04 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00074: val_mse improved from 0.00119 to 0.00119, saving model to ./Results\SigBandRepModel_ExtRec.hdf5
# TargetLoss :  0.0011864090338349342
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Beta1 :  13.027889
# Beta2 :  0.07675841
# Epoch 75/700
# 92/92 [==============================] - 56s 613ms/step - loss: 0.0161 - mse: 0.0012 - FeatRecLoss: 5.6563e-04 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0161 - val_mse: 0.0012 - val_FeatRecLoss: 5.6172e-04 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00075: val_mse did not improve from 0.00119
# TargetLoss :  0.0011888555018231273
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Beta1 :  12.698762
# Beta2 :  0.07874783
# Epoch 76/700
# 92/92 [==============================] - 56s 608ms/step - loss: 0.0155 - mse: 0.0012 - FeatRecLoss: 5.3990e-04 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0155 - val_mse: 0.0012 - val_FeatRecLoss: 5.4094e-04 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00076: val_mse improved from 0.00119 to 0.00118, saving model to ./Results\SigBandRepModel_ExtRec.hdf5
# TargetLoss :  0.001178310252726078
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Beta1 :  13.06949
# Beta2 :  0.07651408
# Epoch 77/700
# 92/92 [==============================] - 57s 615ms/step - loss: 0.0159 - mse: 0.0012 - FeatRecLoss: 5.4635e-04 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0161 - val_mse: 0.0012 - val_FeatRecLoss: 5.4316e-04 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00077: val_mse did not improve from 0.00118
# TargetLoss :  0.0011906421277672052
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Beta1 :  13.152351
# Beta2 :  0.076032035
# Epoch 78/700
# 92/92 [==============================] - 56s 611ms/step - loss: 0.0161 - mse: 0.0012 - FeatRecLoss: 5.4513e-04 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0161 - val_mse: 0.0012 - val_FeatRecLoss: 5.4148e-04 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00078: val_mse did not improve from 0.00118
# TargetLoss :  0.0011819892097264528
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Beta1 :  13.097243
# Beta2 :  0.07635195
# Epoch 79/700
# 92/92 [==============================] - 56s 611ms/step - loss: 0.0158 - mse: 0.0012 - FeatRecLoss: 5.3971e-04 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0158 - val_mse: 0.0012 - val_FeatRecLoss: 5.2400e-04 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00079: val_mse improved from 0.00118 to 0.00117, saving model to ./Results\SigBandRepModel_ExtRec.hdf5
# TargetLoss :  0.0011688320664688945
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Beta1 :  13.383486
# Beta2 :  0.074718945
# Epoch 80/700
# 92/92 [==============================] - 56s 612ms/step - loss: 0.0161 - mse: 0.0012 - FeatRecLoss: 5.4225e-04 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0163 - val_mse: 0.0012 - val_FeatRecLoss: 5.2481e-04 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00080: val_mse did not improve from 0.00117
# TargetLoss :  0.0011782384244725108
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Beta1 :  13.470462
# Beta2 :  0.074236505
# Epoch 81/700
# 92/92 [==============================] - 56s 612ms/step - loss: 0.0163 - mse: 0.0012 - FeatRecLoss: 5.3468e-04 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0163 - val_mse: 0.0012 - val_FeatRecLoss: 5.4075e-04 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00081: val_mse improved from 0.00117 to 0.00117, saving model to ./Results\SigBandRepModel_ExtRec.hdf5
# TargetLoss :  0.0011671556858345866
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Beta1 :  12.950479
# Beta2 :  0.07721722
# Epoch 82/700
# 92/92 [==============================] - 56s 610ms/step - loss: 0.0155 - mse: 0.0012 - FeatRecLoss: 5.3030e-04 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0156 - val_mse: 0.0012 - val_FeatRecLoss: 5.3457e-04 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00082: val_mse improved from 0.00117 to 0.00116, saving model to ./Results\SigBandRepModel_ExtRec.hdf5
# TargetLoss :  0.0011601560981944203
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Beta1 :  13.021558
# Beta2 :  0.07679573
# Epoch 83/700
# 92/92 [==============================] - 57s 615ms/step - loss: 0.0156 - mse: 0.0012 - FeatRecLoss: 5.1803e-04 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0155 - val_mse: 0.0012 - val_FeatRecLoss: 5.0973e-04 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00083: val_mse improved from 0.00116 to 0.00115, saving model to ./Results\SigBandRepModel_ExtRec.hdf5
# TargetLoss :  0.001151668606325984
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Beta1 :  13.556167
# Beta2 :  0.07376717
# Epoch 84/700
# 92/92 [==============================] - 56s 607ms/step - loss: 0.0162 - mse: 0.0012 - FeatRecLoss: 5.3258e-04 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0162 - val_mse: 0.0012 - val_FeatRecLoss: 5.1533e-04 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00084: val_mse did not improve from 0.00115
# TargetLoss :  0.0011536071542650461
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Beta1 :  13.431369
# Beta2 :  0.07445257
# Epoch 85/700
# 92/92 [==============================] - 57s 615ms/step - loss: 0.0160 - mse: 0.0012 - FeatRecLoss: 5.1653e-04 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0164 - val_mse: 0.0012 - val_FeatRecLoss: 5.0374e-04 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00085: val_mse did not improve from 0.00115
# TargetLoss :  0.0011845030821859837
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Beta1 :  14.108496
# Beta2 :  0.07087928
# Epoch 86/700
# 92/92 [==============================] - 56s 607ms/step - loss: 0.0169 - mse: 0.0012 - FeatRecLoss: 5.2092e-04 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0169 - val_mse: 0.0012 - val_FeatRecLoss: 5.1648e-04 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00086: val_mse did not improve from 0.00115
# TargetLoss :  0.0011579988058656454
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Beta1 :  13.452564
# Beta2 :  0.07433527
# Epoch 87/700
# 92/92 [==============================] - 56s 604ms/step - loss: 0.0158 - mse: 0.0011 - FeatRecLoss: 5.1298e-04 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0159 - val_mse: 0.0011 - val_FeatRecLoss: 5.0573e-04 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00087: val_mse improved from 0.00115 to 0.00114, saving model to ./Results\SigBandRepModel_ExtRec.hdf5
# TargetLoss :  0.0011433371109887958
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Beta1 :  13.5645685
# Beta2 :  0.073721476
# Epoch 88/700
# 92/92 [==============================] - 56s 610ms/step - loss: 0.0160 - mse: 0.0011 - FeatRecLoss: 5.1939e-04 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0160 - val_mse: 0.0011 - val_FeatRecLoss: 5.1592e-04 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00088: val_mse did not improve from 0.00114
# TargetLoss :  0.0011445792624726892
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Beta1 :  13.311202
# Beta2 :  0.075124696
# Epoch 89/700
# 92/92 [==============================] - 56s 613ms/step - loss: 0.0156 - mse: 0.0011 - FeatRecLoss: 5.0778e-04 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0157 - val_mse: 0.0011 - val_FeatRecLoss: 5.2443e-04 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00089: val_mse improved from 0.00114 to 0.00114, saving model to ./Results\SigBandRepModel_ExtRec.hdf5
# TargetLoss :  0.0011378381168469787
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Beta1 :  13.018073
# Beta2 :  0.07681628
# Epoch 90/700
# 92/92 [==============================] - 56s 605ms/step - loss: 0.0154 - mse: 0.0011 - FeatRecLoss: 5.1148e-04 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0153 - val_mse: 0.0011 - val_FeatRecLoss: 5.3828e-04 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00090: val_mse improved from 0.00114 to 0.00113, saving model to ./Results\SigBandRepModel_ExtRec.hdf5
# TargetLoss :  0.0011328407563269138
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Beta1 :  12.627256
# Beta2 :  0.07919376
# Epoch 91/700
# 92/92 [==============================] - 56s 611ms/step - loss: 0.0148 - mse: 0.0011 - FeatRecLoss: 5.0736e-04 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0148 - val_mse: 0.0011 - val_FeatRecLoss: 4.9318e-04 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00091: val_mse improved from 0.00113 to 0.00113, saving model to ./Results\SigBandRepModel_ExtRec.hdf5
# TargetLoss :  0.0011311192065477371
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Beta1 :  13.761264
# Beta2 :  0.07266775
# Epoch 92/700
# 92/92 [==============================] - 56s 612ms/step - loss: 0.0161 - mse: 0.0011 - FeatRecLoss: 4.9784e-04 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0161 - val_mse: 0.0011 - val_FeatRecLoss: 5.0964e-04 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00092: val_mse did not improve from 0.00113
# TargetLoss :  0.0011342732468619943
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Beta1 :  13.353934
# Beta2 :  0.0748843
# Epoch 93/700
# 92/92 [==============================] - 56s 610ms/step - loss: 0.0155 - mse: 0.0011 - FeatRecLoss: 5.0517e-04 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 0.0156 - val_mse: 0.0011 - val_FeatRecLoss: 5.0630e-04 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00093: val_mse improved from 0.00113 to 0.00113, saving model to ./Results\SigBandRepModel_ExtRec.hdf5
# TargetLoss :  0.0011297338642179966
# Beta_Z :  0.0
# Beta_Fc :  0.0
# Beta1 :  13.388016
# Beta2 :  0.074693665
# Epoch 94/700
# ...
# Epoch 331/700
# 92/92 [==============================] - 55s 602ms/step - loss: 0.0079 - mse: 0.0011 - FeatRecLoss: 8.5106e-04 - kl_Loss_Z: 1.8464e-04 - kl_Loss_FC: 2.6379e-05 - val_loss: 0.0073 - val_mse: 9.8114e-04 - val_FeatRecLoss: 8.5127e-04 - val_kl_Loss_Z: 2.0302e-04 - val_kl_Loss_FC: 4.3496e-05
#
# Epoch 00331: val_mse did not improve from 0.00097
# TargetLoss :  0.000981144024990499
# Beta_Z :  0.0004017976
# Beta_Fc :  0.0004017976
# Beta1 :  6.9154224
# Beta2 :  0.14460433
# Epoch 332/700
# 92/92 [==============================] - 55s 602ms/step - loss: 0.0080 - mse: 9.7085e-04 - FeatRecLoss: 9.1017e-04 - kl_Loss_Z: 2.8285e-04 - kl_Loss_FC: 9.2237e-05 - val_loss: 0.0081 - val_mse: 9.7418e-04 - val_FeatRecLoss: 9.5478e-04 - val_kl_Loss_Z: 2.5558e-04 - val_kl_Loss_FC: 1.0443e-04
#
# Epoch 00332: val_mse did not improve from 0.00097
# TargetLoss :  0.0009741822141222656
# Beta_Z :  0.0006021964
# Beta_Fc :  0.0006021964
# Beta1 :  6.1219378
# Beta2 :  0.16334698
# Epoch 333/700
# 92/92 [==============================] - 55s 601ms/step - loss: 0.0074 - mse: 9.6355e-04 - FeatRecLoss: 9.9518e-04 - kl_Loss_Z: 3.1064e-04 - kl_Loss_FC: 1.4765e-04 - val_loss: 0.0074 - val_mse: 9.6572e-04 - val_FeatRecLoss: 0.0010 - val_kl_Loss_Z: 2.9528e-04 - val_kl_Loss_FC: 1.4532e-04
#
# Epoch 00333: val_mse improved from 0.00097 to 0.00097, saving model to ./Results\SigBandRepModel_ExtRec.hdf5
# TargetLoss :  0.0010084914974868298
# Beta_Z :  0.0004017976
# Beta_Fc :  0.0004017976
# Beta1 :  0.1595987
# Beta2 :  6.2657156
# Epoch 334/700
# 92/92 [==============================] - 55s 602ms/step - loss: 0.0014 - mse: 0.0010 - FeatRecLoss: 9.4565e-04 - kl_Loss_Z: 2.4129e-04 - kl_Loss_FC: 7.9409e-05 - val_loss: 0.0014 - val_mse: 9.6731e-04 - val_FeatRecLoss: 9.3173e-04 - val_kl_Loss_Z: 2.5033e-04 - val_kl_Loss_FC: 6.5945e-05
#
# Epoch 00334: val_mse did not improve from 0.00097
# TargetLoss :  0.0009673095773905516
# Beta_Z :  0.0006021964
# Beta_Fc :  0.0006021964
# Beta1 :  6.2291107
# Beta2 :  0.16053656
# Epoch 335/700
# 92/92 [==============================] - 55s 602ms/step - loss: 0.0074 - mse: 9.7058e-04 - FeatRecLoss: 9.8386e-04 - kl_Loss_Z: 3.0716e-04 - kl_Loss_FC: 1.1381e-04 - val_loss: 0.0074 - val_mse: 9.6779e-04 - val_FeatRecLoss: 0.0010 - val_kl_Loss_Z: 2.8936e-04 - val_kl_Loss_FC: 1.2553e-04
#
# Epoch 00335: val_mse did not improve from 0.00097
# TargetLoss :  0.0010009537218138576
# Beta_Z :  0.0004017976
# Beta_Fc :  0.0004017976
# Beta1 :  0.161144
# Beta2 :  6.20563
# Epoch 336/700
# 92/92 [==============================] - 55s 603ms/step - loss: 0.0014 - mse: 0.0010 - FeatRecLoss: 9.4129e-04 - kl_Loss_Z: 2.4350e-04 - kl_Loss_FC: 7.0266e-05 - val_loss: 0.0014 - val_mse: 9.6968e-04 - val_FeatRecLoss: 9.5067e-04 - val_kl_Loss_Z: 2.5188e-04 - val_kl_Loss_FC: 5.8515e-05
#
# Epoch 00336: val_mse did not improve from 0.00097
# TargetLoss :  0.0009696761262603104
# Beta_Z :  0.0006021964
# Beta_Fc :  0.0006021964
# Beta1 :  6.119964
# Beta2 :  0.16339965
# Epoch 337/700
# 92/92 [==============================] - 55s 603ms/step - loss: 0.0074 - mse: 9.7298e-04 - FeatRecLoss: 0.0010 - kl_Loss_Z: 3.0602e-04 - kl_Loss_FC: 1.0171e-04 - val_loss: 0.0074 - val_mse: 9.7107e-04 - val_FeatRecLoss: 0.0010 - val_kl_Loss_Z: 2.8522e-04 - val_kl_Loss_FC: 1.1368e-04
#
# Epoch 00337: val_mse did not improve from 0.00097
# TargetLoss :  0.0010196929797530174
# Beta_Z :  0.0004017976
# Beta_Fc :  0.0004017976
# Beta1 :  0.15871918
# Beta2 :  6.3004355
# Epoch 338/700
# 92/92 [==============================] - 55s 602ms/step - loss: 0.0014 - mse: 0.0010 - FeatRecLoss: 9.4376e-04 - kl_Loss_Z: 2.4144e-04 - kl_Loss_FC: 6.5321e-05 - val_loss: 0.0014 - val_mse: 9.7302e-04 - val_FeatRecLoss: 9.3878e-04 - val_kl_Loss_Z: 2.4857e-04 - val_kl_Loss_FC: 5.4728e-05
#
# Epoch 00338: val_mse did not improve from 0.00097
# TargetLoss :  0.0009730214369483292
# Beta_Z :  0.0006021964
# Beta_Fc :  0.0006021964
# Beta1 :  6.2188616
# Beta2 :  0.16080113
# Epoch 339/700
# 92/92 [==============================] - 55s 601ms/step - loss: 0.0074 - mse: 9.7448e-04 - FeatRecLoss: 9.9790e-04 - kl_Loss_Z: 3.0218e-04 - kl_Loss_FC: 1.0031e-04 - val_loss: 0.0075 - val_mse: 9.8034e-04 - val_FeatRecLoss: 9.9699e-04 - val_kl_Loss_Z: 2.9423e-04 - val_kl_Loss_FC: 1.1891e-04
#
# Epoch 00339: val_mse did not improve from 0.00097
# TargetLoss :  0.0009969875682145357
# Beta_Z :  0.00080259517
# Beta_Fc :  0.00080259517
# Beta1 :  0.16388395
# Beta2 :  6.1018786
# Epoch 340/700
# 92/92 [==============================] - 55s 603ms/step - loss: 0.0017 - mse: 0.0011 - FeatRecLoss: 0.0011 - kl_Loss_Z: 3.2261e-04 - kl_Loss_FC: 1.1715e-04 - val_loss: 0.0016 - val_mse: 9.7719e-04 - val_FeatRecLoss: 0.0011 - val_kl_Loss_Z: 3.1155e-04 - val_kl_Loss_FC: 8.5236e-05
#
# Epoch 00340: val_mse did not improve from 0.00097
# TargetLoss :  0.0010871257400140166
# Beta_Z :  0.0006021964
# Beta_Fc :  0.0006021964
# Beta1 :  0.14981174
# Beta2 :  6.675044
# Epoch 341/700
# 92/92 [==============================] - 55s 604ms/step - loss: 0.0015 - mse: 9.7686e-04 - FeatRecLoss: 0.0010 - kl_Loss_Z: 2.7581e-04 - kl_Loss_FC: 5.4862e-05 - val_loss: 0.0015 - val_mse: 9.8714e-04 - val_FeatRecLoss: 9.9497e-04 - val_kl_Loss_Z: 2.8093e-04 - val_kl_Loss_FC: 4.7088e-05
#
# Epoch 00341: val_mse did not improve from 0.00097
# TargetLoss :  0.0009949695086106658
# Beta_Z :  0.00080259517
# Beta_Fc :  0.00080259517
# Beta1 :  0.16535574
# Beta2 :  6.047568
# Epoch 342/700
# 92/92 [==============================] - 55s 601ms/step - loss: 0.0016 - mse: 9.8430e-04 - FeatRecLoss: 0.0010 - kl_Loss_Z: 3.1735e-04 - kl_Loss_FC: 5.1969e-05 - val_loss: 0.0016 - val_mse: 9.9929e-04 - val_FeatRecLoss: 0.0011 - val_kl_Loss_Z: 3.0578e-04 - val_kl_Loss_FC: 4.2712e-05
#
# Epoch 00342: val_mse did not improve from 0.00097
# TargetLoss :  0.0010670002084225416
# Beta_Z :  0.0006021964
# Beta_Fc :  0.0006021964
# Beta1 :  0.1560896
# Beta2 :  6.4065766
# Epoch 343/700
# 92/92 [==============================] - 55s 603ms/step - loss: 0.0015 - mse: 9.9974e-04 - FeatRecLoss: 0.0010 - kl_Loss_Z: 2.7185e-04 - kl_Loss_FC: 2.9291e-05 - val_loss: 0.0015 - val_mse: 0.0010 - val_FeatRecLoss: 0.0010 - val_kl_Loss_Z: 2.6578e-04 - val_kl_Loss_FC: 2.7215e-05
#
# Epoch 00343: val_mse did not improve from 0.00097
# TargetLoss :  0.0010378481820225716
# Beta_Z :  0.0004017976
# Beta_Fc :  0.0004017976
# Beta1 :  0.16177987
# Beta2 :  6.1812387
# Epoch 344/700
# 92/92 [==============================] - 55s 601ms/step - loss: 0.0014 - mse: 0.0010 - FeatRecLoss: 9.4888e-04 - kl_Loss_Z: 2.3198e-04 - kl_Loss_FC: 1.6926e-05 - val_loss: 0.0014 - val_mse: 0.0010 - val_FeatRecLoss: 9.2834e-04 - val_kl_Loss_Z: 2.4195e-04 - val_kl_Loss_FC: 1.6825e-05
#
# Epoch 00344: val_mse did not improve from 0.00097
# TargetLoss :  0.0010126868728548288
# Beta_Z :  0.0002013988
# Beta_Fc :  0.0002013988
# Beta1 :  6.5451174
# Beta2 :  0.15278566
# Epoch 345/700
# 92/92 [==============================] - 55s 601ms/step - loss: 0.0089 - mse: 0.0012 - FeatRecLoss: 8.5121e-04 - kl_Loss_Z: 1.8661e-04 - kl_Loss_FC: 2.1046e-05 - val_loss: 0.0075 - val_mse: 9.7151e-04 - val_FeatRecLoss: 8.6130e-04 - val_kl_Loss_Z: 2.0506e-04 - val_kl_Loss_FC: 3.7938e-05
#
# Epoch 00345: val_mse did not improve from 0.00097
# TargetLoss :  0.0009715080377645791
# Beta_Z :  0.0004017976
# Beta_Fc :  0.0004017976
# Beta1 :  6.7677627
# Beta2 :  0.14775932
# Epoch 346/700
# 92/92 [==============================] - 55s 601ms/step - loss: 0.0078 - mse: 9.6890e-04 - FeatRecLoss: 9.1284e-04 - kl_Loss_Z: 2.7891e-04 - kl_Loss_FC: 8.1542e-05 - val_loss: 0.0078 - val_mse: 9.6313e-04 - val_FeatRecLoss: 9.1540e-04 - val_kl_Loss_Z: 2.5847e-04 - val_kl_Loss_FC: 9.3606e-05
#
# Epoch 00346: val_mse improved from 0.00097 to 0.00096, saving model to ./Results\SigBandRepModel_ExtRec.hdf5
# TargetLoss :  0.0009631332359276712
# Beta_Z :  0.0006021964
# Beta_Fc :  0.0006021964
# Beta1 :  6.312841
# Beta2 :  0.15840729
# Epoch 347/700
# 92/92 [==============================] - 55s 602ms/step - loss: 0.0075 - mse: 9.6325e-04 - FeatRecLoss: 9.8120e-04 - kl_Loss_Z: 3.0436e-04 - kl_Loss_FC: 1.3236e-04 - val_loss: 0.0075 - val_mse: 9.6080e-04 - val_FeatRecLoss: 9.9362e-04 - val_kl_Loss_Z: 2.9184e-04 - val_kl_Loss_FC: 1.3207e-04
#
# Epoch 00347: val_mse improved from 0.00096 to 0.00096, saving model to ./Results\SigBandRepModel_ExtRec.hdf5
# TargetLoss :  0.000993623398244381
# Beta_Z :  0.00080259517
# Beta_Fc :  0.00080259517
# Beta1 :  0.16116044
# Beta2 :  6.2049966
# Epoch 348/700
# 92/92 [==============================] - 55s 600ms/step - loss: 0.0017 - mse: 9.8517e-04 - FeatRecLoss: 0.0010 - kl_Loss_Z: 3.2671e-04 - kl_Loss_FC: 1.2389e-04 - val_loss: 0.0016 - val_mse: 9.7080e-04 - val_FeatRecLoss: 0.0010 - val_kl_Loss_Z: 3.2120e-04 - val_kl_Loss_FC: 9.3136e-05
#
# Epoch 00348: val_mse did not improve from 0.00096
# TargetLoss :  0.0010309939971193671
# Beta_Z :  0.0006021964
# Beta_Fc :  0.0006021964
# Beta1 :  0.15693653
# Beta2 :  6.372003
# Epoch 349/700
# 92/92 [==============================] - 55s 602ms/step - loss: 0.0015 - mse: 9.6990e-04 - FeatRecLoss: 9.9170e-04 - kl_Loss_Z: 2.7709e-04 - kl_Loss_FC: 6.0131e-05 - val_loss: 0.0015 - val_mse: 9.7999e-04 - val_FeatRecLoss: 9.9076e-04 - val_kl_Loss_Z: 2.8100e-04 - val_kl_Loss_FC: 5.2456e-05
#
# Epoch 00349: val_mse did not improve from 0.00096
# TargetLoss :  0.0009907592320814729
# Beta_Z :  0.00080259517
# Beta_Fc :  0.00080259517
# Beta1 :  0.16485527
# Beta2 :  6.065927
# Epoch 350/700
# 92/92 [==============================] - 55s 602ms/step - loss: 0.0016 - mse: 9.8207e-04 - FeatRecLoss: 0.0010 - kl_Loss_Z: 3.1653e-04 - kl_Loss_FC: 5.9175e-05 - val_loss: 0.0016 - val_mse: 9.9313e-04 - val_FeatRecLoss: 0.0011 - val_kl_Loss_Z: 3.0073e-04 - val_kl_Loss_FC: 5.1053e-05
#
# Epoch 00350: val_mse did not improve from 0.00096
# TargetLoss :  0.0010789405787363648
# Beta_Z :  0.0006021964
# Beta_Fc :  0.0006021964
# Beta1 :  0.15341069
# Beta2 :  6.5184507
# Epoch 351/700
# 92/92 [==============================] - 55s 602ms/step - loss: 0.0015 - mse: 9.8702e-04 - FeatRecLoss: 0.0010 - kl_Loss_Z: 2.7197e-04 - kl_Loss_FC: 3.4323e-05 - val_loss: 0.0015 - val_mse: 9.9512e-04 - val_FeatRecLoss: 0.0010 - val_kl_Loss_Z: 2.8010e-04 - val_kl_Loss_FC: 3.1713e-05
#
# Epoch 00351: val_mse did not improve from 0.00096
# TargetLoss :  0.0010026470990851521
# Beta_Z :  0.0004017976
# Beta_Fc :  0.0004017976
# Beta1 :  0.16541566
# Beta2 :  6.045377
# Epoch 352/700
# 92/92 [==============================] - 55s 601ms/step - loss: 0.0014 - mse: 9.9304e-04 - FeatRecLoss: 9.3413e-04 - kl_Loss_Z: 2.3387e-04 - kl_Loss_FC: 2.0352e-05 - val_loss: 0.0013 - val_mse: 0.0010 - val_FeatRecLoss: 8.9733e-04 - val_kl_Loss_Z: 2.5115e-04 - val_kl_Loss_FC: 1.9853e-05
#
# Epoch 00352: val_mse did not improve from 0.00096
# TargetLoss :  0.0010005357908084989
# Beta_Z :  0.0002013988
# Beta_Fc :  0.0002013988
# Beta1 :  6.6900578
# Beta2 :  0.14947554
# Epoch 353/700
# 92/92 [==============================] - 55s 600ms/step - loss: 0.0077 - mse: 9.9681e-04 - FeatRecLoss: 8.3083e-04 - kl_Loss_Z: 1.9965e-04 - kl_Loss_FC: 2.4300e-05 - val_loss: 0.0076 - val_mse: 9.7244e-04 - val_FeatRecLoss: 8.0880e-04 - val_kl_Loss_Z: 2.1777e-04 - val_kl_Loss_FC: 4.2000e-05
#
# Epoch 00353: val_mse did not improve from 0.00096
# TargetLoss :  0.0009724382543936372
# Beta_Z :  0.0004017976
# Beta_Fc :  0.0004017976
# Beta1 :  7.2139196
# Beta2 :  0.1386209
# Epoch 354/700
# 92/92 [==============================] - 55s 602ms/step - loss: 0.0083 - mse: 9.7621e-04 - FeatRecLoss: 9.0731e-04 - kl_Loss_Z: 2.8517e-04 - kl_Loss_FC: 8.3806e-05 - val_loss: 0.0082 - val_mse: 9.6633e-04 - val_FeatRecLoss: 9.1272e-04 - val_kl_Loss_Z: 2.6687e-04 - val_kl_Loss_FC: 9.4377e-05
#
# Epoch 00354: val_mse did not improve from 0.00096
# TargetLoss :  0.0009663321543484926
# Beta_Z :  0.0006021964
# Beta_Fc :  0.0006021964
# Beta1 :  6.35244
# Beta2 :  0.15741983
# Epoch 355/700
# 92/92 [==============================] - 55s 602ms/step - loss: 0.0075 - mse: 9.5592e-04 - FeatRecLoss: 9.7896e-04 - kl_Loss_Z: 3.1091e-04 - kl_Loss_FC: 1.3236e-04 - val_loss: 0.0075 - val_mse: 9.6308e-04 - val_FeatRecLoss: 9.8187e-04 - val_kl_Loss_Z: 3.0032e-04 - val_kl_Loss_FC: 1.3292e-04
#
# Epoch 00355: val_mse did not improve from 0.00096
# TargetLoss :  0.0009818676626309752
# Beta_Z :  0.00080259517
# Beta_Fc :  0.00080259517
# Beta1 :  0.16347742
# Beta2 :  6.1170526
# Epoch 356/700
# 92/92 [==============================] - 55s 603ms/step - loss: 0.0017 - mse: 0.0010 - FeatRecLoss: 0.0010 - kl_Loss_Z: 3.3163e-04 - kl_Loss_FC: 1.2259e-04 - val_loss: 0.0016 - val_mse: 9.6820e-04 - val_FeatRecLoss: 0.0010 - val_kl_Loss_Z: 3.1976e-04 - val_kl_Loss_FC: 9.1370e-05
#
# Epoch 00356: val_mse did not improve from 0.00096
# TargetLoss :  0.0010346005437895656
# Beta_Z :  0.0006021964
# Beta_Fc :  0.0006021964
# Beta1 :  0.15597041
# Beta2 :  6.4114723
# Epoch 357/700
# 92/92 [==============================] - 55s 602ms/step - loss: 0.0015 - mse: 9.6628e-04 - FeatRecLoss: 9.9071e-04 - kl_Loss_Z: 2.7808e-04 - kl_Loss_FC: 6.0884e-05 - val_loss: 0.0015 - val_mse: 9.7643e-04 - val_FeatRecLoss: 0.0010 - val_kl_Loss_Z: 2.8497e-04 - val_kl_Loss_FC: 5.4211e-05
#
# Epoch 00357: val_mse did not improve from 0.00096
# TargetLoss :  0.001002562465146184
# Beta_Z :  0.0004017976
# Beta_Fc :  0.0004017976
# Beta1 :  0.16232313
# Beta2 :  6.160551
# Epoch 358/700
# 92/92 [==============================] - 55s 599ms/step - loss: 0.0014 - mse: 9.7085e-04 - FeatRecLoss: 9.1577e-04 - kl_Loss_Z: 2.3632e-04 - kl_Loss_FC: 3.4443e-05 - val_loss: 0.0013 - val_mse: 9.8105e-04 - val_FeatRecLoss: 9.0844e-04 - val_kl_Loss_Z: 2.4242e-04 - val_kl_Loss_FC: 3.1444e-05
#
# Epoch 00358: val_mse did not improve from 0.00096
# TargetLoss :  0.0009810475166887045
# Beta_Z :  0.0006021964
# Beta_Fc :  0.0006021964
# Beta1 :  6.479552
# Beta2 :  0.15433165
# Epoch 359/700
# 92/92 [==============================] - 55s 601ms/step - loss: 0.0077 - mse: 9.8048e-04 - FeatRecLoss: 9.6296e-04 - kl_Loss_Z: 3.1257e-04 - kl_Loss_FC: 7.0017e-05 - val_loss: 0.0077 - val_mse: 9.7457e-04 - val_FeatRecLoss: 9.7190e-04 - val_kl_Loss_Z: 2.9838e-04 - val_kl_Loss_FC: 9.1233e-05
#
# Epoch 00359: val_mse did not improve from 0.00096
# TargetLoss :  0.0009745736024342477
# Beta_Z :  0.00080259517
# Beta_Fc :  0.00080259517
# Beta1 :  6.0164967
# Beta2 :  0.16620968
# Epoch 360/700
# 92/92 [==============================] - 55s 602ms/step - loss: 0.0073 - mse: 9.7069e-04 - FeatRecLoss: 0.0010 - kl_Loss_Z: 3.2858e-04 - kl_Loss_FC: 1.2405e-04 - val_loss: 0.0074 - val_mse: 9.7540e-04 - val_FeatRecLoss: 0.0011 - val_kl_Loss_Z: 3.1137e-04 - val_kl_Loss_FC: 1.2796e-04
#
# Epoch 00360: val_mse did not improve from 0.00096
# TargetLoss :  0.0010598241351544857
# Beta_Z :  0.0006021964
# Beta_Fc :  0.0006021964
# Beta1 :  0.15339038
# Beta2 :  6.519314
# Epoch 361/700
# 92/92 [==============================] - 55s 602ms/step - loss: 0.0015 - mse: 0.0011 - FeatRecLoss: 9.8776e-04 - kl_Loss_Z: 2.7905e-04 - kl_Loss_FC: 7.8736e-05 - val_loss: 0.0015 - val_mse: 9.6921e-04 - val_FeatRecLoss: 9.9419e-04 - val_kl_Loss_Z: 2.8526e-04 - val_kl_Loss_FC: 6.3260e-05
#
# Epoch 00361: val_mse did not improve from 0.00096
# TargetLoss :  0.0009941913885995746
# Beta_Z :  0.00080259517
# Beta_Fc :  0.00080259517
# Beta1 :  0.16247925
# Beta2 :  6.154632
# Epoch 362/700
# 92/92 [==============================] - 55s 602ms/step - loss: 0.0016 - mse: 9.6601e-04 - FeatRecLoss: 0.0010 - kl_Loss_Z: 3.2198e-04 - kl_Loss_FC: 7.0028e-05 - val_loss: 0.0016 - val_mse: 9.7939e-04 - val_FeatRecLoss: 0.0010 - val_kl_Loss_Z: 3.1453e-04 - val_kl_Loss_FC: 5.7028e-05
#
# Epoch 00362: val_mse did not improve from 0.00096
# TargetLoss :  0.0010416312143206596
# Beta_Z :  0.0006021964
# Beta_Fc :  0.0006021964
# Beta1 :  0.15670739
# Beta2 :  6.3813195
# Epoch 363/700
# 92/92 [==============================] - 55s 601ms/step - loss: 0.0015 - mse: 9.7277e-04 - FeatRecLoss: 9.7877e-04 - kl_Loss_Z: 2.7749e-04 - kl_Loss_FC: 4.0081e-05 - val_loss: 0.0015 - val_mse: 9.8459e-04 - val_FeatRecLoss: 9.7244e-04 - val_kl_Loss_Z: 2.9047e-04 - val_kl_Loss_FC: 3.5954e-05
#
# Epoch 00363: val_mse did not improve from 0.00096
# TargetLoss :  0.0009845852619037032
# Beta_Z :  0.00080259517
# Beta_Fc :  0.00080259517
# Beta1 :  6.074962
# Beta2 :  0.16461007
# Epoch 364/700
# 87/92 [===========================>..] - ETA: 2s - loss: 0.0074 - mse: 9.9229e-04 - FeatRecLoss: 0.0010 - kl_Loss_Z: 3.3223e-04 - kl_Loss_FC: 6.8886e-05

# %%
SigBandRepModel.load_weights(ModelSaveSameName)
