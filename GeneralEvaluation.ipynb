# %% [markdown]
# ## FreqPulse-VAE: A Frequency-Conditioned Variational Autoencoder for Pulsatile Signal Generation

# %%
import os
import numpy as np
import pandas as pd


import tensorflow as tf
from tensorflow.keras import backend as K
from tensorflow.keras.layers import Input, GRU, Dense, Masking, Reshape, Flatten, RepeatVector, TimeDistributed, Bidirectional, Activation, GaussianNoise, Lambda, LSTM
from tensorflow.keras import Model
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from Models.FPVAE_T20 import *
from Utilities.Utilities import *
from Utilities.EvaluationModules import *

import matplotlib.cm as cm
from mpl_toolkits.axes_grid1 import make_axes_locatable
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="4"

# %% [markdown]
# #### Env setting

# %%
LatDim = 10
MaskingRate = 0.02
NoiseStd = 0.002
MaskStd = 0.1
ReparaStd = 0.1
Capacity_Z = 0.1
Capacity_Fc = 0.1
FcLimit = 0.05
DecayH = 0. 
DecayL = 0.
SlidingSize = 50
SigType ='ART'

### Other parameters
Patience = 300
TrRate = 0.8

SavePath = './Results/'
ModelName = 'TCMIL_'+str(SigType)+'_Z'+str(LatDim)+'.hdf5'

if not os.path.exists(SavePath):
    os.mkdir(SavePath)

### Model checkpoint
ModelSaveName = SavePath+ModelName

# %% [markdown]
# ### Data

# %%
ValData = np.load('./Data/ProcessedData/ValART.npy')
SigDim = ValData.shape[1]

# %%
# Out:
# <KerasTensor: shape=(None, 1000) dtype=float32 (created by layer 'ReconModel')>

# %% [markdown]
# ### Post model

# %%
# Defining BioSigBandVAE
EncModel = Encoder(SigDim=SigDim, LatDim= LatDim, Type = '', MaskingRate = MaskingRate, NoiseStd = NoiseStd, MaskStd = MaskStd, ReparaStd = ReparaStd, Reparam=True, FcLimit=FcLimit)
FeatExtModel = FeatExtractor(SigDim=SigDim, DecayH=DecayH, DecayL=DecayL)
FeatGenModel = FeatGenerator(SigDim=SigDim, LatDim= LatDim)
ReconModel = Reconstructor(SigDim=SigDim, FeatDim=400)

## Model core parts
EncInp =EncModel.input
InpZ = EncModel.output[2]
InpFCCommon = EncModel.output[1][:, :2]
InpFCEach = EncModel.output[1][:, 2:]

## Each output of each model
FeatExtOut = FeatExtModel(EncModel.output[:2])
FeatGenOut = FeatGenModel([InpFCCommon, InpFCEach, InpZ])
ReconExtOut = ReconModel(FeatExtOut)
ReconGenOut = ReconModel(FeatGenOut)

### Define the total model
SigBandRepModel = Model(EncInp, [FeatGenOut, ReconExtOut, ReconGenOut])

### Weight controller; Apply beta and capacity 
Beta_Z = Lossweight(name='Beta_Z', InitVal=0.05)(FeatGenOut)
Beta_Fc = Lossweight(name='Beta_Fc', InitVal=0.05)(FeatGenOut)
Beta_TC = Lossweight(name='Beta_TC', InitVal=0.05)(FeatGenOut)
Beta_MI = Lossweight(name='Beta_MI', InitVal=0.05)(FeatGenOut)
Beta_Rec_ext = Lossweight(name='Beta_Rec_ext', InitVal=500.)(FeatGenOut)
Beta_Rec_gen = Lossweight(name='Beta_Rec_gen', InitVal=500.)(FeatGenOut)
Beta_Feat = Lossweight(name='Beta_Feat', InitVal=500.)(FeatGenOut)

### Adding the RecLoss; 
MSE = tf.keras.losses.MeanSquaredError()

ReconOut_ext = Beta_Rec_ext * MSE(ReconExtOut, EncInp)
SigBandRepModel.add_loss(ReconOut_ext)
SigBandRepModel.add_metric(ReconOut_ext, 'ReconOut_ext')

#ReconOut_gen = Beta_Rec_gen * MSE(ReconGenOut, EncInp)
#SigBandRepModel.add_loss(ReconOut_gen)
#SigBandRepModel.add_metric(ReconOut_gen, 'ReconOut_gen')


### Adding the FeatRecLoss; It allows connection between the extractor and generator
FeatRecLoss= Beta_Feat * MSE(tf.concat(FeatGenOut, axis=-1), tf.concat(FeatExtOut, axis=-1))
SigBandRepModel.add_loss(FeatRecLoss)
SigBandRepModel.add_metric(FeatRecLoss, 'FeatRecLoss')

### KL Divergence for p(Z) vs q(Z)
Z_Mu, Z_Log_Sigma, Zs = SigBandRepModel.get_layer('Z_Mu').output, SigBandRepModel.get_layer('Z_Log_Sigma').output, SigBandRepModel.get_layer('Zs').output
kl_Loss_Z = 0.5 * tf.reduce_sum( Z_Mu**2  +  tf.exp(Z_Log_Sigma)- Z_Log_Sigma-1, axis=1)    
kl_Loss_Z = tf.reduce_mean(kl_Loss_Z )
kl_Loss_Z = Beta_Z * tf.abs(kl_Loss_Z - Capacity_Z)

### KL Divergence for p(FCs) vs q(FCs)
BernP = 0.5 # hyperparameter
FCs = SigBandRepModel.get_layer('FC_Mu').output 
kl_Loss_FC = tf.math.log(FCs) - tf.math.log(BernP) + tf.math.log(1-FCs) - tf.math.log(1-BernP) 
kl_Loss_FC = tf.reduce_mean(-kl_Loss_FC )
kl_Loss_FC = Beta_Fc * tf.abs(kl_Loss_FC - Capacity_Fc)


### KL Divergence for q(Z) vs q(Z)_Prod
LogProb_QZ = LogNormalDensity(Zs[:, None], Z_Mu[None], Z_Log_Sigma[None])
Log_QZ_Prod = tf.reduce_sum( tf.reduce_logsumexp(LogProb_QZ, axis=1, keepdims=False),   axis=1,  keepdims=False)
Log_QZ = tf.reduce_logsumexp(tf.reduce_sum(LogProb_QZ, axis=2, keepdims=False),   axis=1,   keepdims=False)
kl_Loss_TC = -tf.reduce_mean(Log_QZ - Log_QZ_Prod)
kl_Loss_TC = Beta_TC * kl_Loss_TC

### MI Loss ; I[z;x] = KL[q(z,x)||q(x)q(z)] = E_x[KL[q(z|x)||q(z)]]
Log_QZX = tf.reduce_sum(LogNormalDensity(Zs, Z_Mu, Z_Log_Sigma), axis=1)
kl_Loss_MI = -tf.reduce_mean((Log_QZX - Log_QZ))
kl_Loss_MI = Beta_MI * kl_Loss_MI



SigBandRepModel.add_loss(kl_Loss_Z )
SigBandRepModel.add_metric(kl_Loss_Z , 'kl_Loss_Z')

SigBandRepModel.add_loss(kl_Loss_FC )
SigBandRepModel.add_metric(kl_Loss_FC , 'kl_Loss_FC')

SigBandRepModel.add_loss(kl_Loss_TC )
SigBandRepModel.add_metric(kl_Loss_TC , 'kl_Loss_TC')

SigBandRepModel.add_loss(kl_Loss_MI )
SigBandRepModel.add_metric(kl_Loss_MI , 'kl_Loss_MI')

### Load weights
SigBandRepModel.load_weights(ModelSaveName)

### Regularizer resetting
for i in SigBandRepModel.weights:
    if i.name.split('/')[0] in ['Beta_Z','Beta_Fc','Beta_Rec_ext','Beta_Rec_gen', 'Beta_Feat']:
        i.assign(1.)
        
## Model Compile
SigBandRepModel.compile(optimizer='adam')

# %%
SigBandRepModel.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Inp_Enc (InputLayer)            [(None, 1000)]       0
# __________________________________________________________________________________________________
# tf.signal.frame_14 (TFOpLambda) (None, 20, 50)       0           Inp_Enc[0][0]
# __________________________________________________________________________________________________
# dense_64 (Dense)                (None, 20, 50)       2550        tf.signal.frame_14[0][0]
# __________________________________________________________________________________________________
# bidirectional_36 (Bidirectional (None, 20, 50)       11550       dense_64[0][0]
# __________________________________________________________________________________________________
# bidirectional_37 (Bidirectional (None, 20, 50)       11550       bidirectional_36[0][0]
# __________________________________________________________________________________________________
# bidirectional_38 (Bidirectional (None, 100)          30600       bidirectional_37[0][0]
# __________________________________________________________________________________________________
# dense_65 (Dense)                (None, 50)           5050        bidirectional_38[0][0]
# __________________________________________________________________________________________________
# dense_66 (Dense)                (None, 30)           1530        dense_65[0][0]
# __________________________________________________________________________________________________
# gaussian_noise_2 (GaussianNoise (None, 20, 50)       0           tf.signal.frame_14[0][0]
# __________________________________________________________________________________________________
# dense_67 (Dense)                (None, 20)           620         dense_66[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.shape_10 (TFOpLamb (3,)                 0           gaussian_noise_2[0][0]
# __________________________________________________________________________________________________
# dense_69 (Dense)                (None, 6)            126         dense_67[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_54 (Sl ()                   0           tf.compat.v1.shape_10[0][0]
# __________________________________________________________________________________________________
# dense_70 (Dense)                (None, 6)            42          dense_69[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_112 (TFOpLambd ()                   0           tf.__operators__.getitem_54[0][0]
# __________________________________________________________________________________________________
# tf.clip_by_value_6 (TFOpLambda) (None, 6)            0           dense_70[0][0]
# __________________________________________________________________________________________________
# tf.range_16 (TFOpLambda)        (None,)              0           tf.math.multiply_112[0][0]
# __________________________________________________________________________________________________
# FC_Mu (Lambda)                  (None, 6)            0           tf.clip_by_value_6[0][0]
# __________________________________________________________________________________________________
# tf.random.shuffle_2 (TFOpLambda (None,)              0           tf.range_16[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.shape_14 (TFOpLamb (2,)                 0           FC_Mu[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.shape_11 (TFOpLamb (1,)                 0           tf.random.shuffle_2[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_59 (Sl ()                   0           tf.compat.v1.shape_14[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_55 (Sl ()                   0           tf.compat.v1.shape_11[0][0]
# __________________________________________________________________________________________________
# tf.random.uniform_2 (TFOpLambda (None, 6)            0           tf.__operators__.getitem_59[0][0]
# __________________________________________________________________________________________________
# tf.cast_24 (TFOpLambda)         ()                   0           tf.__operators__.getitem_55[0][0]
# __________________________________________________________________________________________________
# tf.clip_by_value_7 (TFOpLambda) (None, 6)            0           tf.random.uniform_2[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_113 (TFOpLambd ()                   0           tf.cast_24[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_26 (TFOpLambda (None, 6)            0           tf.clip_by_value_7[0][0]
# __________________________________________________________________________________________________
# tf.cast_25 (TFOpLambda)         ()                   0           tf.math.multiply_113[0][0]
# __________________________________________________________________________________________________
# tf.math.log_12 (TFOpLambda)     (None, 6)            0           tf.clip_by_value_7[0][0]
# __________________________________________________________________________________________________
# tf.math.log_13 (TFOpLambda)     (None, 6)            0           tf.math.subtract_26[0][0]
# __________________________________________________________________________________________________
# tf.math.less_2 (TFOpLambda)     (None,)              0           tf.random.shuffle_2[0][0]
#                                                                  tf.cast_25[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_28 (TFOpLambda (None, 6)            0           tf.math.log_12[0][0]
#                                                                  tf.math.log_13[0][0]
# __________________________________________________________________________________________________
# tf.math.log_14 (TFOpLambda)     (None, 6)            0           FC_Mu[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_27 (TFOpLambda (None, 6)            0           FC_Mu[0][0]
# __________________________________________________________________________________________________
# tf.cast_26 (TFOpLambda)         (None,)              0           tf.math.less_2[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_24 (TFOpLa (None, 6)            0           tf.math.subtract_28[0][0]
#                                                                  tf.math.log_14[0][0]
# __________________________________________________________________________________________________
# tf.math.log_15 (TFOpLambda)     (None, 6)            0           tf.math.subtract_27[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.eq_14 (TFOpLam (None,)              0           tf.cast_26[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_29 (TFOpLambda (None, 6)            0           tf.__operators__.add_24[0][0]
#                                                                  tf.math.log_15[0][0]
# __________________________________________________________________________________________________
# tf.cast_27 (TFOpLambda)         (None,)              0           tf.__operators__.eq_14[0][0]
# __________________________________________________________________________________________________
# tf.math.sigmoid_2 (TFOpLambda)  (None, 6)            0           tf.math.subtract_29[0][0]
# __________________________________________________________________________________________________
# Z_Mu (Dense)                    (None, 10)           210         dense_67[0][0]
# __________________________________________________________________________________________________
# dense_68 (Dense)                (None, 10)           210         dense_67[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.shape_12 (TFOpLamb (1,)                 0           tf.cast_27[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_118 (TFOpLambd (None, 6)            0           tf.math.sigmoid_2[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_119 (TFOpLambd (None, 6)            0           FC_Mu[0][0]
# __________________________________________________________________________________________________
# Z_Log_Sigma (Lambda)            (None, 10)           0           dense_68[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.shape_13 (TFOpLamb (2,)                 0           Z_Mu[0][0]
# __________________________________________________________________________________________________
# tf.random.normal_4 (TFOpLambda) (None,)              0           tf.compat.v1.shape_12[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_25 (TFOpLa (None, 6)            0           tf.math.multiply_118[0][0]
#                                                                  tf.math.multiply_119[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_116 (TFOpLambd (None, 10)           0           Z_Log_Sigma[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_58 (Sl ()                   0           tf.compat.v1.shape_13[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_114 (TFOpLambd (None,)              0           tf.cast_27[0][0]
#                                                                  tf.random.normal_4[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_120 (TFOpLambd (None, 6)            0           tf.__operators__.add_25[0][0]
# __________________________________________________________________________________________________
# tf.math.exp_6 (TFOpLambda)      (None, 10)           0           tf.math.multiply_116[0][0]
# __________________________________________________________________________________________________
# tf.random.normal_5 (TFOpLambda) (None, 10)           0           tf.__operators__.getitem_58[0][0]
# __________________________________________________________________________________________________
# tf.reshape_5 (TFOpLambda)       (None, None)         0           tf.math.multiply_114[0][0]
#                                                                  tf.__operators__.getitem_54[0][0]
# __________________________________________________________________________________________________
# tf.clip_by_value_8 (TFOpLambda) (None, 6)            0           tf.math.multiply_120[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_117 (TFOpLambd (None, 10)           0           tf.math.exp_6[0][0]
#                                                                  tf.random.normal_5[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_57 (Sl (None, None, 1)      0           tf.reshape_5[0][0]
# __________________________________________________________________________________________________
# FCs (Lambda)                    (None, 6)            0           tf.clip_by_value_8[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_23 (TFOpLa (None, 10)           0           Z_Mu[0][0]
#                                                                  tf.math.multiply_117[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_22 (TFOpLa (None, 20, 50)       0           gaussian_noise_2[0][0]
#                                                                  tf.__operators__.getitem_57[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_76 (Sl (None, 2)            0           FCs[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_77 (Sl (None, 4)            0           FCs[0][0]
# __________________________________________________________________________________________________
# Zs (Lambda)                     (None, 10)           0           tf.__operators__.add_23[0][0]
# __________________________________________________________________________________________________
# SigOut (Flatten)                (None, 1000)         0           tf.__operators__.add_22[0][0]
# __________________________________________________________________________________________________
# FeatGenModel (Functional)       [(None, 400), (None, 48720       tf.__operators__.getitem_76[0][0]
#                                                                  tf.__operators__.getitem_77[0][0]
#                                                                  Zs[0][0]
# __________________________________________________________________________________________________
# FeatExtModel (Functional)       [(None, 400), (None, 0           SigOut[0][0]
#                                                                  FCs[0][0]
# __________________________________________________________________________________________________
# ReconModel (Functional)         (None, 1000)         82500       FeatExtModel[0][0]
#                                                                  FeatExtModel[0][1]
#                                                                  FeatExtModel[0][2]
#                                                                  FeatExtModel[0][3]
#                                                                  FeatGenModel[0][0]
#                                                                  FeatGenModel[0][1]
#                                                                  FeatGenModel[0][2]
#                                                                  FeatGenModel[0][3]
# __________________________________________________________________________________________________
# tf.convert_to_tensor_12 (TFOpLa (None, 1000)         0           Inp_Enc[0][0]
# __________________________________________________________________________________________________
# tf.convert_to_tensor_13 (TFOpLa (None, 1000)         0           ReconModel[0][0]
# __________________________________________________________________________________________________
# tf.convert_to_tensor_14 (TFOpLa (None, 1000)         0           tf.convert_to_tensor_12[0][0]
# __________________________________________________________________________________________________
# tf.cast_28 (TFOpLambda)         (None, 1000)         0           tf.convert_to_tensor_13[0][0]
# __________________________________________________________________________________________________
# tf.math.squared_difference_4 (T (None, 1000)         0           tf.convert_to_tensor_14[0][0]
#                                                                  tf.cast_28[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_mean_10 (TFOpLam (None,)              0           tf.math.squared_difference_4[0][0
# __________________________________________________________________________________________________
# tf.cast_29 (TFOpLambda)         (None,)              0           tf.math.reduce_mean_10[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_157 (TFOpLambd (None,)              0           tf.cast_29[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_sum_50 (TFOpLamb ()                   0           tf.math.multiply_157[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.size_4 (TFOpLambda ()                   0           tf.math.multiply_157[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_sum_51 (TFOpLamb ()                   0           tf.math.reduce_sum_50[0][0]
# __________________________________________________________________________________________________
# tf.cast_30 (TFOpLambda)         ()                   0           tf.compat.v1.size_4[0][0]
# __________________________________________________________________________________________________
# tf.math.divide_no_nan_4 (TFOpLa ()                   0           tf.math.reduce_sum_51[0][0]
#                                                                  tf.cast_30[0][0]
# __________________________________________________________________________________________________
# Beta_Rec_ext (Lossweight)       ()                   1           FeatGenModel[0][0]
#                                                                  FeatGenModel[0][1]
#                                                                  FeatGenModel[0][2]
#                                                                  FeatGenModel[0][3]
# __________________________________________________________________________________________________
# tf.cast_31 (TFOpLambda)         ()                   0           tf.math.divide_no_nan_4[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_158 (TFOpLambd ()                   0           Beta_Rec_ext[0][0]
#                                                                  tf.cast_31[0][0]
# __________________________________________________________________________________________________
# add_loss_10 (AddLoss)           ()                   0           tf.math.multiply_158[0][0]
# __________________________________________________________________________________________________
# add_metric_10 (AddMetric)       ()                   0           tf.math.multiply_158[0][0]
# __________________________________________________________________________________________________
# tf.concat_20 (TFOpLambda)       (None, 1600)         0           FeatExtModel[0][0]
#                                                                  FeatExtModel[0][1]
#                                                                  FeatExtModel[0][2]
#                                                                  FeatExtModel[0][3]
# __________________________________________________________________________________________________
# tf.concat_19 (TFOpLambda)       (None, 1600)         0           FeatGenModel[0][0]
#                                                                  FeatGenModel[0][1]
#                                                                  FeatGenModel[0][2]
#                                                                  FeatGenModel[0][3]
# __________________________________________________________________________________________________
# tf.convert_to_tensor_15 (TFOpLa (None, 1600)         0           tf.concat_20[0][0]
# __________________________________________________________________________________________________
# tf.convert_to_tensor_16 (TFOpLa (None, 1600)         0           tf.concat_19[0][0]
# __________________________________________________________________________________________________
# tf.convert_to_tensor_17 (TFOpLa (None, 1600)         0           tf.convert_to_tensor_15[0][0]
# __________________________________________________________________________________________________
# tf.cast_32 (TFOpLambda)         (None, 1600)         0           tf.convert_to_tensor_16[0][0]
# __________________________________________________________________________________________________
# tf.math.squared_difference_5 (T (None, 1600)         0           tf.convert_to_tensor_17[0][0]
#                                                                  tf.cast_32[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_mean_11 (TFOpLam (None,)              0           tf.math.squared_difference_5[0][0
# __________________________________________________________________________________________________
# tf.cast_33 (TFOpLambda)         (None,)              0           tf.math.reduce_mean_11[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_159 (TFOpLambd (None,)              0           tf.cast_33[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_sum_52 (TFOpLamb ()                   0           tf.math.multiply_159[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.size_5 (TFOpLambda ()                   0           tf.math.multiply_159[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_sum_53 (TFOpLamb ()                   0           tf.math.reduce_sum_52[0][0]
# __________________________________________________________________________________________________
# tf.cast_34 (TFOpLambda)         ()                   0           tf.compat.v1.size_5[0][0]
# __________________________________________________________________________________________________
# tf.math.divide_no_nan_5 (TFOpLa ()                   0           tf.math.reduce_sum_53[0][0]
#                                                                  tf.cast_34[0][0]
# __________________________________________________________________________________________________
# Beta_Feat (Lossweight)          ()                   1           FeatGenModel[0][0]
#                                                                  FeatGenModel[0][1]
#                                                                  FeatGenModel[0][2]
#                                                                  FeatGenModel[0][3]
# __________________________________________________________________________________________________
# tf.cast_35 (TFOpLambda)         ()                   0           tf.math.divide_no_nan_5[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_160 (TFOpLambd ()                   0           Beta_Feat[0][0]
#                                                                  tf.cast_35[0][0]
# __________________________________________________________________________________________________
# add_loss_11 (AddLoss)           ()                   0           tf.math.multiply_160[0][0]
# __________________________________________________________________________________________________
# add_metric_11 (AddMetric)       ()                   0           tf.math.multiply_160[0][0]
# __________________________________________________________________________________________________
# tf.math.pow_2 (TFOpLambda)      (None, 10)           0           Z_Mu[0][0]
# __________________________________________________________________________________________________
# tf.math.exp_7 (TFOpLambda)      (None, 10)           0           Z_Log_Sigma[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_29 (TFOpLa (None, 10)           0           tf.math.pow_2[0][0]
#                                                                  tf.math.exp_7[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_30 (TFOpLambda (None, 10)           0           tf.__operators__.add_29[0][0]
#                                                                  Z_Log_Sigma[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_31 (TFOpLambda (None, 10)           0           tf.math.subtract_30[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_sum_54 (TFOpLamb (None,)              0           tf.math.subtract_31[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_161 (TFOpLambd (None,)              0           tf.math.reduce_sum_54[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_mean_12 (TFOpLam ()                   0           tf.math.multiply_161[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_32 (TFOpLambda ()                   0           tf.math.reduce_mean_12[0][0]
# __________________________________________________________________________________________________
# Beta_Z (Lossweight)             ()                   1           FeatGenModel[0][0]
#                                                                  FeatGenModel[0][1]
#                                                                  FeatGenModel[0][2]
#                                                                  FeatGenModel[0][3]
# __________________________________________________________________________________________________
# tf.math.abs_4 (TFOpLambda)      ()                   0           tf.math.subtract_32[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_162 (TFOpLambd ()                   0           Beta_Z[0][0]
#                                                                  tf.math.abs_4[0][0]
# __________________________________________________________________________________________________
# add_loss_12 (AddLoss)           ()                   0           tf.math.multiply_162[0][0]
# __________________________________________________________________________________________________
# add_metric_12 (AddMetric)       ()                   0           tf.math.multiply_162[0][0]
# __________________________________________________________________________________________________
# tf.math.log_16 (TFOpLambda)     (None, 6)            0           FC_Mu[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_34 (TFOpLambda (None, 6)            0           FC_Mu[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_33 (TFOpLambda (None, 6)            0           tf.math.log_16[0][0]
# __________________________________________________________________________________________________
# tf.math.log_17 (TFOpLambda)     (None, 6)            0           tf.math.subtract_34[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_30 (TFOpLa (None, 6)            0           tf.math.subtract_33[0][0]
#                                                                  tf.math.log_17[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_35 (TFOpLambda (None, 6)            0           tf.__operators__.add_30[0][0]
# __________________________________________________________________________________________________
# tf.math.negative_15 (TFOpLambda (None, 6)            0           tf.math.subtract_35[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_mean_13 (TFOpLam ()                   0           tf.math.negative_15[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_36 (TFOpLambda ()                   0           tf.math.reduce_mean_13[0][0]
# __________________________________________________________________________________________________
# Beta_Fc (Lossweight)            ()                   1           FeatGenModel[0][0]
#                                                                  FeatGenModel[0][1]
#                                                                  FeatGenModel[0][2]
#                                                                  FeatGenModel[0][3]
# __________________________________________________________________________________________________
# tf.math.abs_5 (TFOpLambda)      ()                   0           tf.math.subtract_36[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_163 (TFOpLambd ()                   0           Beta_Fc[0][0]
#                                                                  tf.math.abs_5[0][0]
# __________________________________________________________________________________________________
# add_loss_13 (AddLoss)           ()                   0           tf.math.multiply_163[0][0]
# __________________________________________________________________________________________________
# add_metric_13 (AddMetric)       ()                   0           tf.math.multiply_163[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_78 (Sl (None, 1, 10)        0           Zs[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_79 (Sl (1, None, 10)        0           Z_Mu[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_80 (Sl (1, None, 10)        0           Z_Log_Sigma[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_37 (TFOpLambda (None, None, 10)     0           tf.__operators__.getitem_78[0][0]
#                                                                  tf.__operators__.getitem_79[0][0]
# __________________________________________________________________________________________________
# tf.math.negative_16 (TFOpLambda (1, None, 10)        0           tf.__operators__.getitem_80[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_164 (TFOpLambd (None, None, 10)     0           tf.math.subtract_37[0][0]
#                                                                  tf.math.subtract_37[0][0]
# __________________________________________________________________________________________________
# tf.math.exp_8 (TFOpLambda)      (1, None, 10)        0           tf.math.negative_16[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_165 (TFOpLambd (None, None, 10)     0           tf.math.multiply_164[0][0]
#                                                                  tf.math.exp_8[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_31 (TFOpLa (None, None, 10)     0           tf.math.multiply_165[0][0]
#                                                                  tf.__operators__.getitem_80[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_32 (TFOpLa (None, None, 10)     0           tf.__operators__.add_31[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_166 (TFOpLambd (None, None, 10)     0           tf.__operators__.add_32[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_sum_56 (TFOpLamb (None, None)         0           tf.math.multiply_166[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_logsumexp_4 (TFO (None, 10)           0           tf.math.multiply_166[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_logsumexp_5 (TFO (None,)              0           tf.math.reduce_sum_56[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_sum_55 (TFOpLamb (None,)              0           tf.math.reduce_logsumexp_4[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_38 (TFOpLambda (None,)              0           tf.math.reduce_logsumexp_5[0][0]
#                                                                  tf.math.reduce_sum_55[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_mean_14 (TFOpLam ()                   0           tf.math.subtract_38[0][0]
# __________________________________________________________________________________________________
# Beta_TC (Lossweight)            ()                   1           FeatGenModel[0][0]
#                                                                  FeatGenModel[0][1]
#                                                                  FeatGenModel[0][2]
#                                                                  FeatGenModel[0][3]
# __________________________________________________________________________________________________
# tf.math.negative_17 (TFOpLambda ()                   0           tf.math.reduce_mean_14[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_167 (TFOpLambd ()                   0           Beta_TC[0][0]
#                                                                  tf.math.negative_17[0][0]
# __________________________________________________________________________________________________
# add_loss_14 (AddLoss)           ()                   0           tf.math.multiply_167[0][0]
# __________________________________________________________________________________________________
# add_metric_14 (AddMetric)       ()                   0           tf.math.multiply_167[0][0]
# ==================================================================================================
# Total params: 195,263
# Trainable params: 195,258
# Non-trainable params: 5
# __________________________________________________________________________________________________

# %%
if 5:
    print('true')
# Out:
# true

# %% [markdown]
# ### Reconstruction; MSE

# %%
RecPred = SigBandRepModel.predict(ValData,  batch_size=3500, verbose=1)[-1]
# Out:
# 23/23 [==============================] - 14s 203ms/step

# %%
SigBandRepModel.evaluate(ValData,  batch_size=3500, verbose=1)
# Out:
# 23/23 [==============================] - 4s 162ms/step - loss: 18.7876 - ReconOutGen: 0.0036 - FeatRecLoss: 5.6729e-04 - kl_Loss_Z: 0.4808 - kl_Loss_FC: 0.0589 - kl_Loss_TC: 18.2436
# [18.78759765625,
#  0.003648278769105673,
#  0.000567288079764694,
#  0.48082607984542847,
#  0.05892202630639076,
#  18.243633270263672]

# %%
EvalMSE = tf.keras.losses.MeanSquaredError()
EvalMSE(ValData, RecPred)

# %%
plt.plot(ValData[0])

# %% [markdown]
# ### From extractor to reconstruction validation
# #### It ultimately evaluates the performance of the reconstructor

# %%
idx = 51
N_Gen = 200
'''
FC_Comm = np.tile(np.linspace(0.,0.05, N_Gen )[:, None], (1,2))
FC_Each = np.tile(np.linspace(0.,0.05, N_Gen )[:, None], (1,4))

'''
FC_Comm = np.tile(np.random.uniform(0, 0.05, N_Gen)[:, None], (1,2))
FC_Comm = np.sort(FC_Comm)
FC_Each = np.tile(np.random.uniform(0, 0.05, N_Gen)[:, None], (1,4))
FC_Each = np.sort(FC_Each)


RecPred, HH,HL,LH, LL = VisReconExtract (ValData, idx, FeatExtModel, ReconModel, FC_Comm, FC_Each, N_Gen=N_Gen)
# Out:
# (200, 1000)

# %% [markdown]
# #### From extractor to reconstruction LL

# %%
plt.figure(figsize=(15, 5))
for i in range(N_Gen):
    plt.plot(LL.numpy()[i])

# %% [markdown]
# #### From extractor to reconstruction HH

# %%
plt.figure(figsize=(15, 5))
for i in range(N_Gen):
    plt.plot(HH.numpy()[i])

# %%
# Out:
# (0.5, 0.17999999999999994)

# %% [markdown]
# ### Permutation Local Correlation Monotonicity Index (PLCMI)

# %%
PLCMI_Res = PLMI(FeatGenModel,  ReconModel, LatDim=10, N_Gen=300, N_Interval=20, MonoWinSize=300, MinZval = -5., MaxZval = 5., N_FreqSel =1,  MinFreq=1, MaxFreq=51, Weight='Amplitude', Type='Cor')
# Out:
# [0, -5.0, 1.3833]
# [0, -4.47, 1.8616]
# [0, -3.95, 2.4575]
# [0, -3.42, 1.0785]
# [0, -2.89, 3.3146]
# [0, -2.37, 3.228]
# [0, -1.84, 2.959]
# [0, -1.32, 2.8263]
# [0, -0.79, 2.3061]
# [0, -0.26, 1.1041]
# [0, 0.26, 1.8779]
# [0, 0.79, 1.2393]
# [0, 1.32, 3.0246]
# [0, 1.84, 2.9526]
# [0, 2.37, 1.3242]
# [0, 2.89, 2.1125]
# [0, 3.42, 2.8764]
# [0, 3.95, 2.7048]
# [0, 4.47, 3.1548]
# [0, 5.0, 2.9899]
# [1, -5.0, 2.1588]
# [1, -4.47, 2.9899]
# [1, -3.95, 2.9564]
# [1, -3.42, 2.94]
# [1, -2.89, 2.524]
# [1, -2.37, 3.4425]
# [1, -1.84, 3.3281]
# [1, -1.32, 2.2534]
# [1, -0.79, 3.3054]
# [1, -0.26, 2.7522]
# [1, 0.26, 3.1807]
# [1, 0.79, 2.9271]
# [1, 1.32, 0.6996]
# [1, 1.84, 1.0104]
# [1, 2.37, 1.7578]
# [1, 2.89, 3.1051]
# [1, 3.42, 3.1377]
# [1, 3.95, 3.1316]
# [1, 4.47, 3.0705]
# [1, 5.0, 3.223]
# [2, -5.0, 3.3158]
# [2, -4.47, 3.2318]
# [2, -3.95, 3.3476]
# [2, -3.42, 3.0992]
# [2, -2.89, 2.9619]
# [2, -2.37, 3.0829]
# [2, -1.84, 2.7264]
# [2, -1.32, 1.8913]
# [2, -0.79, 3.3215]
# [2, -0.26, 3.2872]
# [2, 0.26, 3.1526]
# [2, 0.79, 2.6444]
# [2, 1.32, 2.1394]
# [2, 1.84, 1.8923]
# [2, 2.37, 3.1498]
# [2, 2.89, 3.209]
# [2, 3.42, 3.2544]
# [2, 3.95, 3.0351]
# [2, 4.47, 2.9005]
# [2, 5.0, 1.9609]
# [3, -5.0, 3.636]
# [3, -4.47, 3.56]
# [3, -3.95, 3.4966]
# [3, -3.42, 3.0784]
# [3, -2.89, 3.3878]
# [3, -2.37, 3.1163]
# [3, -1.84, 3.2299]
# [3, -1.32, 2.4905]
# [3, -0.79, 3.1287]
# [3, -0.26, 1.3194]
# [3, 0.26, 2.6088]
# [3, 0.79, 2.7443]
# [3, 1.32, 3.0021]
# [3, 1.84, 3.1762]
# [3, 2.37, 3.4633]
# [3, 2.89, 3.6007]
# [3, 3.42, 3.5328]
# [3, 3.95, 3.5287]
# [3, 4.47, 3.5255]
# [3, 5.0, 3.148]
# [4, -5.0, 2.8424]
# [4, -4.47, 2.8335]
# [4, -3.95, 2.8457]
# [4, -3.42, 2.8191]
# [4, -2.89, 2.9374]
# [4, -2.37, 3.2057]
# [4, -1.84, 3.0072]
# [4, -1.32, 3.3031]
# [4, -0.79, 3.0048]
# [4, -0.26, 2.9509]
# [4, 0.26, 3.3728]
# [4, 0.79, 3.545]
# [4, 1.32, 3.4865]
# [4, 1.84, 3.3671]
# [4, 2.37, 3.262]
# [4, 2.89, 3.1509]
# [4, 3.42, 2.7088]
# [4, 3.95, 2.3564]
# [4, 4.47, 2.2961]
# [4, 5.0, 2.0642]
# [5, -5.0, 3.4423]
# [5, -4.47, 3.0557]
# [5, -3.95, 1.962]
# [5, -3.42, 3.1281]
# [5, -2.89, 3.2118]
# [5, -2.37, 3.4183]
# [5, -1.84, 3.3309]
# [5, -1.32, 2.7051]
# [5, -0.79, 2.8576]
# [5, -0.26, 1.6337]
# [5, 0.26, 2.1963]
# [5, 0.79, 2.8116]
# [5, 1.32, 2.5594]
# [5, 1.84, 1.2014]
# [5, 2.37, 1.8243]
# [5, 2.89, 1.6217]
# [5, 3.42, 2.1408]
# [5, 3.95, 2.5642]
# [5, 4.47, 2.8526]
# [5, 5.0, 2.9528]
# [6, -5.0, 3.565]
# [6, -4.47, 3.4541]
# [6, -3.95, 3.3597]
# [6, -3.42, 2.9691]
# [6, -2.89, 3.1434]
# [6, -2.37, 3.2124]
# [6, -1.84, 3.0945]
# [6, -1.32, 3.1534]
# [6, -0.79, 3.092]
# [6, -0.26, 3.0227]
# [6, 0.26, 2.8392]
# [6, 0.79, 2.4022]
# [6, 1.32, 1.9324]
# [6, 1.84, 1.9722]
# [6, 2.37, 2.2008]
# [6, 2.89, 2.1872]
# [6, 3.42, 1.0707]
# [6, 3.95, 2.5727]
# [6, 4.47, 2.6052]
# [6, 5.0, 2.4368]
# [7, -5.0, 1.3142]
# [7, -4.47, 0.7748]
# [7, -3.95, 2.4675]
# [7, -3.42, 2.7268]
# [7, -2.89, 2.6869]
# [7, -2.37, 2.7566]
# [7, -1.84, 2.8277]
# [7, -1.32, 2.7878]
# [7, -0.79, 2.7143]
# [7, -0.26, 2.5437]
# [7, 0.26, 2.3088]
# [7, 0.79, 2.2225]
# [7, 1.32, 2.4739]
# [7, 1.84, 2.5439]
# [7, 2.37, 2.5755]
# [7, 2.89, 2.2246]
# [7, 3.42, 1.4513]
# [7, 3.95, 3.1648]
# [7, 4.47, 3.6737]
# [7, 5.0, 1.5138]
# [8, -5.0, 0.5634]
# [8, -4.47, 2.072]
# [8, -3.95, 2.0237]
# [8, -3.42, 2.6943]
# [8, -2.89, 2.9031]
# [8, -2.37, 2.7935]
# [8, -1.84, 1.7373]
# [8, -1.32, 2.3703]
# [8, -0.79, 1.383]
# [8, -0.26, 1.8466]
# [8, 0.26, 1.7263]
# [8, 0.79, 1.2224]
# [8, 1.32, 2.0781]
# [8, 1.84, 2.085]
# [8, 2.37, 2.9393]
# [8, 2.89, 2.8525]
# [8, 3.42, 2.7079]
# [8, 3.95, 2.6241]
# [8, 4.47, 2.5818]
# [8, 5.0, 2.6951]
# [9, -5.0, 1.5782]
# [9, -4.47, 2.6328]
# [9, -3.95, 3.1933]
# [9, -3.42, 3.0061]
# [9, -2.89, 3.052]
# [9, -2.37, 1.8185]
# [9, -1.84, 2.7624]
# [9, -1.32, 2.2897]
# [9, -0.79, 2.6609]
# [9, -0.26, 2.4665]
# [9, 0.26, 2.184]
# [9, 0.79, 1.9695]
# [9, 1.32, 2.6496]
# [9, 1.84, 2.2475]
# [9, 2.37, 1.3102]
# [9, 2.89, 2.0502]
# [9, 3.42, 1.9399]
# [9, 3.95, 2.0622]
# [9, 4.47, 2.721]
# [9, 5.0, 2.927]

# %%
plt.imshow(np.array(PLCMI_Res)[:, -1].reshape(-1, 20) > 3.0)

# %% [markdown]
# ### Qualitative evaluation of the amplitude relationship between the input frequency for signal generation (y-axis) and the frequency of the generated signal (x-axis).

# %%
ZFix = {9:-1.84}
#ZFix = {2:1.32, 9:3.32}
#zVal[:,0] = -3
#Val[:,1] = 2.33
#zVal[:,2] = 0.4
#zVal[:,3] = -1.67
#zVal[:,4] = 0.33
#zVal[:,5] = 3
#zVal[:,6] = -1.67
#zVal[:,7] = 3
#zVal[:,8] = 3
#zVal[:,9] = -1

HeatMapFrequency(FeatGenModel,  ReconModel, LatDim, ZFix, N_Gen=300)

# %% [markdown]
# ### Visualizing the reconstruction conditioned on a specific z-value when frequencies are given at regular intervals
# #### Objective: This qualitatively evaluates the impact of changes in input frequencies on signal generation when a specific z-value is given.

# %%
RecPred, HH,HL,LH, LL = VisReconGivenZ (FeatGenModel,  ReconModel, LatDim, ZFix, Mode='Origin', N_Gen=300, MinFreqR=0, MaxFreqR=0.05)

# %%
#ZFix = {6:-3.}
RecPred, HH,HL,LH, LL = VisReconGivenZ (FeatGenModel,  ReconModel, LatDim, ZFix, Mode='LL', N_Gen=300, MinFreqR=0, MaxFreqR=0.05)

# %% [markdown]
# ### Visualizing the reconstruction conditioned on a specific frequency value when z-values are given at regular intervals
# #### Objective: This qualitatively evaluates the impact of changes in input z-values on signal generation when a specific frequency is given.

# %%
FcCommFix = {0:0.05, 1:0.05}
FcEachFix = {0:0.05, 1:0.05, 2:0.05, 3:0.05}
RecPred, HH,HL,LH, LL = VisReconGivenFreq (FeatGenModel,  ReconModel, LatDim, FcCommFix, FcEachFix,  Mode='Origin', N_Gen=200, MinZval = -3., MaxZval = 3., CutLower=-2., CutUpper = 1.)

# %% [markdown]
# ### From generator to reconstruction validation

# %%
idx = 175
plt.plot(RecPred[idx])

# %% [markdown]
# ### Visualizing amplitude by frequency given a specific ID

# %%
# GenSig_zVar
N_Gen= 300
SigGen5, Amplitude5 = GenSig_zVar(FeatGenModel, ReconModel, 0.05, N_Gen=N_Gen)
SigGen4, Amplitude4 = GenSig_zVar(FeatGenModel, ReconModel,  0.04, N_Gen=N_Gen)
SigGen3, Amplitude3 = GenSig_zVar(FeatGenModel, ReconModel,  0.03, N_Gen=N_Gen)
SigGen2, Amplitude2 = GenSig_zVar(FeatGenModel, ReconModel,  0.02, N_Gen=N_Gen)
SigGen1, Amplitude1 = GenSig_zVar(FeatGenModel, ReconModel,  0.01, N_Gen=N_Gen)

plt.figure(figsize=(12, 5))
idx = 20
plt.plot(Amplitude5[idx, 1:51])
plt.plot(Amplitude4[idx, 1:51])
plt.plot(Amplitude3[idx, 1:51])
plt.plot(Amplitude2[idx, 1:51])
plt.plot(Amplitude1[idx, 1:51])

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

N_Gen = 300
MinFreq=1
MaxFreq=50


# GenSig_FcVar
zVal = np.tile(np.zeros(LatDim), (N_Gen,1))
SigGen_FcVar, Amplitude_FcVar = GenSig_FcVar(FeatGenModel,  ReconModel,zVal, N_Gen=N_Gen, zType='Fixed')

# Axes generation
FreqX = np.arange(0, N_Gen)
GenY = np.arange(MinFreq, MaxFreq+1)
FreqX, GenY = np.meshgrid(GenY, FreqX)

# 3D plot
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111, projection='3d')
surf = ax.plot_surface(FreqX, GenY, Amplitude_FcVar[:, MinFreq:MaxFreq+1], cmap='viridis', linewidth=1, antialiased=True, alpha = 0.9)

# Axis labels
ax.set_xlabel('Frequency', fontsize=14, labelpad=5.5)
ax.set_xticks(ax.get_xticks())
ax.tick_params(axis='x', labelsize=12)
ax.set_xlim(left=MinFreq, right=MaxFreq+1)

ax.set_ylabel('Gneration', fontsize=14, labelpad=6.5)
ax.set_yticks(ax.get_yticks())
ax.tick_params(axis='y', labelsize=12)
ax.set_ylim(bottom=0, top=N_Gen)

ax.set_zlabel('Amplitude', fontsize=14, labelpad=11.)
ax.set_zticks(ax.get_zticks())
ax.tick_params(axis='z', labelsize=12, pad=5)  
ax.set_zlim(bottom=0, top=Amplitude_FcVar[:, MinFreq:MaxFreq+1].max())

ax.view_init(azim=300, elev=45)
plt.show()
