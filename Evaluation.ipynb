# %% [markdown]
# # BioSig-BandVAE: Bandpass-Driven Variational Autoencoder for Interpretable and Compressed Biosignal Feature Generation

# %%
import os
import numpy as np
import pandas as pd


import tensorflow as tf
from tensorflow.keras import backend as K
from tensorflow.keras.layers import Input, GRU, Dense, Masking, Reshape, Flatten, RepeatVector, TimeDistributed, Bidirectional, Activation, GaussianNoise, Lambda, LSTM
from tensorflow.keras import Model
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from Models.BioSigBandVAE_MultiM_Exp_deep_TCL import *
from Utilities.Utilities import *
from Utilities.EvaluationModules import *

import matplotlib.cm as cm
from mpl_toolkits.axes_grid1 import make_axes_locatable
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="4"

# %% [markdown]
# #### Env setting

# %%
LatDim = 10
MaskingRate = 0.02
NoiseStd = 0.002
MaskStd = 0.1
ReparaStd = 0.1
Capacity_Z = 0.1
Capacity_Fc = 0.1
FcLimit = 0.05
DecayH = 0. 
DecayL = 0.
N_Gen = 300

### Other parameters
Patience = 300
TrRate = 0.8

SavePath = './Results/'
ModelName = 'SigBandRep_MultMod_Ext_Z'+str(LatDim)+'_ExpDeep_TCL.hdf5'

if not os.path.exists(SavePath):
    os.mkdir(SavePath)

### Model checkpoint
ModelSaveName = SavePath+ModelName

# %% [markdown]
# ### Data

# %%
DATA = np.load('./Data/AsanTRSet.npy')
SigDim = DATA.shape[1]

np.random.seed(7)
PermutedDATA = np.random.permutation(DATA)
TrLen = int(PermutedDATA.shape[0] * TrRate)

TrData = PermutedDATA[:TrLen]
ValData = PermutedDATA[TrLen:]

# %% [markdown]
# ### Post model

# %%
# Defining BioSigBandVAE
EncModel = Encoder(SigDim=SigDim, LatDim= LatDim, Type = '', MaskingRate = MaskingRate, NoiseStd = NoiseStd, MaskStd = MaskStd, ReparaStd = ReparaStd, Reparam=True, FcLimit=FcLimit)
FeatExtModel = FeatExtractor(SigDim=SigDim, DecayH=DecayH, DecayL=DecayL)
FeatGenModel = FeatGenerator(LatDim= LatDim)
ReconModel = Reconstructor(SigDim=SigDim, FeatDim=400)

## Model core parts
EncInp =EncModel.input
InpZ = EncModel.output[2]
InpFCCommon = EncModel.output[1][:, :2]
InpFCEach = EncModel.output[1][:, 2:]

## Each output of each model
FeatExtOut = FeatExtModel(EncModel.output[:2])
FeatGenOut = FeatGenModel([InpFCCommon, InpFCEach, InpZ])
ReconOut_ext = ReconModel(FeatExtOut)
ReconOut_gen = ReconModel(FeatGenOut)

### Define the total model
SigBandRepModel = Model(EncInp, [FeatGenOut, ReconOut_ext, ReconOut_gen])

### Weight controller; Apply beta and capacity 
Beta_Z = Lossweight(name='Beta_Z', InitVal=0.05)(FeatGenOut)
Beta_Fc = Lossweight(name='Beta_Fc', InitVal=0.05)(FeatGenOut)
Beta_TC = Lossweight(name='Beta_TC', InitVal=0.05)(FeatGenOut)
Beta_Rec_ext = Lossweight(name='Beta_Rec_ext', InitVal=500.)(FeatGenOut)
Beta_Rec_gen = Lossweight(name='Beta_Rec_gen', InitVal=500.)(FeatGenOut)
Beta_Feat = Lossweight(name='Beta_Feat', InitVal=500.)(FeatGenOut)

### Adding the RecLoss; 
MSE = tf.keras.losses.MeanSquaredError()

ReconOut_ext = Beta_Rec_ext * MSE(ReconOut_ext, EncInp)
SigBandRepModel.add_loss(ReconOut_ext)
SigBandRepModel.add_metric(ReconOut_ext, 'ReconOut_ext')


### Adding the FeatRecLoss; It allows connection between the extractor and generator
FeatRecLoss= Beta_Feat * MSE(tf.concat(FeatGenOut, axis=-1), tf.concat(FeatExtOut, axis=-1))
SigBandRepModel.add_loss(FeatRecLoss)
SigBandRepModel.add_metric(FeatRecLoss, 'FeatRecLoss')

### KL Divergence for p(Z) vs q(Z)
Z_Mu, Z_Log_Sigma, Zs = SigBandRepModel.get_layer('Z_Mu').output, SigBandRepModel.get_layer('Z_Log_Sigma').output, SigBandRepModel.get_layer('Zs').output
kl_Loss_Z = 0.5 * tf.reduce_sum( Z_Mu**2  +  tf.exp(Z_Log_Sigma)- Z_Log_Sigma-1, axis=1)    
kl_Loss_Z = tf.reduce_mean(kl_Loss_Z )
kl_Loss_Z = Beta_Z * tf.abs(kl_Loss_Z - Capacity_Z)

### KL Divergence for p(FCs) vs q(FCs)
BernP = 0.5 # hyperparameter
FCs = SigBandRepModel.get_layer('FC_Mu').output 
kl_Loss_FC = tf.math.log(FCs) - tf.math.log(BernP) + tf.math.log(1-FCs) - tf.math.log(1-BernP) 
kl_Loss_FC = tf.reduce_mean(-kl_Loss_FC )
kl_Loss_FC = Beta_Fc * tf.abs(kl_Loss_FC - Capacity_Fc)


### KL Divergence for q(Z) vs q(Z)_Prod
LogProb_QZ = LogNormalDensity(Zs[:, None], Z_Mu[None], Z_Log_Sigma[None])
Log_QZ_Prod = tf.math.reduce_sum( tf.math.reduce_logsumexp(LogProb_QZ, axis=1, keepdims=False),   axis=1,  keepdims=False)
Log_QZ = tf.math.reduce_logsumexp(tf.math.reduce_sum(LogProb_QZ, axis=2, keepdims=False),   axis=1,   keepdims=False)
kl_Loss_TC = -tf.math.reduce_mean(Log_QZ - Log_QZ_Prod)
kl_Loss_TC = Beta_TC * kl_Loss_TC


SigBandRepModel.add_loss(kl_Loss_Z )
SigBandRepModel.add_metric(kl_Loss_Z , 'kl_Loss_Z')

SigBandRepModel.add_loss(kl_Loss_FC )
SigBandRepModel.add_metric(kl_Loss_FC , 'kl_Loss_FC')

SigBandRepModel.add_loss(kl_Loss_TC )
SigBandRepModel.add_metric(kl_Loss_TC , 'kl_Loss_TC')
    
### Load weights
SigBandRepModel.load_weights(ModelSaveName)

### Regularizer resetting
for i in SigBandRepModel.weights:
    if i.name.split('/')[0] in ['Beta_Z','Beta_Fc','Beta_Rec_ext','Beta_Rec_gen', 'Beta_Feat']:
        i.assign(1.)
        
## Model Compile
SigBandRepModel.compile(optimizer='adam')

# %%
SigBandRepModel.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Inp_Enc (InputLayer)            [(None, 1000)]       0
# __________________________________________________________________________________________________
# tf.signal.frame (TFOpLambda)    (None, 10, 100)      0           Inp_Enc[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 10, 50)       5050        tf.signal.frame[0][0]
# __________________________________________________________________________________________________
# bidirectional (Bidirectional)   (None, 10, 60)       14760       dense[0][0]
# __________________________________________________________________________________________________
# bidirectional_1 (Bidirectional) (None, 60)           16560       bidirectional[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 50)           3050        bidirectional_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 30)           1530        dense_1[0][0]
# __________________________________________________________________________________________________
# gaussian_noise (GaussianNoise)  (None, 10, 100)      0           tf.signal.frame[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 15)           465         dense_2[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.shape (TFOpLambda) (3,)                 0           gaussian_noise[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 6)            96          dense_3[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem (Slici ()                   0           tf.compat.v1.shape[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 6)            42          dense_5[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply (TFOpLambda)   ()                   0           tf.__operators__.getitem[0][0]
# __________________________________________________________________________________________________
# tf.clip_by_value (TFOpLambda)   (None, 6)            0           dense_6[0][0]
# __________________________________________________________________________________________________
# tf.range (TFOpLambda)           (None,)              0           tf.math.multiply[0][0]
# __________________________________________________________________________________________________
# FC_Mu (Lambda)                  (None, 6)            0           tf.clip_by_value[0][0]
# __________________________________________________________________________________________________
# tf.random.shuffle (TFOpLambda)  (None,)              0           tf.range[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.shape_4 (TFOpLambd (2,)                 0           FC_Mu[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.shape_1 (TFOpLambd (1,)                 0           tf.random.shuffle[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_5 (Sli ()                   0           tf.compat.v1.shape_4[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1 (Sli ()                   0           tf.compat.v1.shape_1[0][0]
# __________________________________________________________________________________________________
# tf.random.uniform (TFOpLambda)  (None, 6)            0           tf.__operators__.getitem_5[0][0]
# __________________________________________________________________________________________________
# tf.cast (TFOpLambda)            ()                   0           tf.__operators__.getitem_1[0][0]
# __________________________________________________________________________________________________
# tf.clip_by_value_1 (TFOpLambda) (None, 6)            0           tf.random.uniform[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_1 (TFOpLambda) ()                   0           tf.cast[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract (TFOpLambda)   (None, 6)            0           tf.clip_by_value_1[0][0]
# __________________________________________________________________________________________________
# tf.cast_1 (TFOpLambda)          ()                   0           tf.math.multiply_1[0][0]
# __________________________________________________________________________________________________
# tf.math.log (TFOpLambda)        (None, 6)            0           tf.clip_by_value_1[0][0]
# __________________________________________________________________________________________________
# tf.math.log_1 (TFOpLambda)      (None, 6)            0           tf.math.subtract[0][0]
# __________________________________________________________________________________________________
# tf.math.less (TFOpLambda)       (None,)              0           tf.random.shuffle[0][0]
#                                                                  tf.cast_1[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_2 (TFOpLambda) (None, 6)            0           tf.math.log[0][0]
#                                                                  tf.math.log_1[0][0]
# __________________________________________________________________________________________________
# tf.math.log_2 (TFOpLambda)      (None, 6)            0           FC_Mu[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_1 (TFOpLambda) (None, 6)            0           FC_Mu[0][0]
# __________________________________________________________________________________________________
# tf.cast_2 (TFOpLambda)          (None,)              0           tf.math.less[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_2 (TFOpLam (None, 6)            0           tf.math.subtract_2[0][0]
#                                                                  tf.math.log_2[0][0]
# __________________________________________________________________________________________________
# tf.math.log_3 (TFOpLambda)      (None, 6)            0           tf.math.subtract_1[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.eq (TFOpLambda (None,)              0           tf.cast_2[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_3 (TFOpLambda) (None, 6)            0           tf.__operators__.add_2[0][0]
#                                                                  tf.math.log_3[0][0]
# __________________________________________________________________________________________________
# tf.cast_3 (TFOpLambda)          (None,)              0           tf.__operators__.eq[0][0]
# __________________________________________________________________________________________________
# tf.math.sigmoid (TFOpLambda)    (None, 6)            0           tf.math.subtract_3[0][0]
# __________________________________________________________________________________________________
# Z_Mu (Dense)                    (None, 10)           160         dense_3[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 10)           160         dense_3[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.shape_2 (TFOpLambd (1,)                 0           tf.cast_3[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_6 (TFOpLambda) (None, 6)            0           tf.math.sigmoid[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_7 (TFOpLambda) (None, 6)            0           FC_Mu[0][0]
# __________________________________________________________________________________________________
# Z_Log_Sigma (Lambda)            (None, 10)           0           dense_4[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.shape_3 (TFOpLambd (2,)                 0           Z_Mu[0][0]
# __________________________________________________________________________________________________
# tf.random.normal (TFOpLambda)   (None,)              0           tf.compat.v1.shape_2[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_3 (TFOpLam (None, 6)            0           tf.math.multiply_6[0][0]
#                                                                  tf.math.multiply_7[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_4 (TFOpLambda) (None, 10)           0           Z_Log_Sigma[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_4 (Sli ()                   0           tf.compat.v1.shape_3[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_2 (TFOpLambda) (None,)              0           tf.cast_3[0][0]
#                                                                  tf.random.normal[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_8 (TFOpLambda) (None, 6)            0           tf.__operators__.add_3[0][0]
# __________________________________________________________________________________________________
# tf.math.exp (TFOpLambda)        (None, 10)           0           tf.math.multiply_4[0][0]
# __________________________________________________________________________________________________
# tf.random.normal_1 (TFOpLambda) (None, 10)           0           tf.__operators__.getitem_4[0][0]
# __________________________________________________________________________________________________
# tf.reshape_1 (TFOpLambda)       (None, None)         0           tf.math.multiply_2[0][0]
#                                                                  tf.__operators__.getitem[0][0]
# __________________________________________________________________________________________________
# tf.clip_by_value_2 (TFOpLambda) (None, 6)            0           tf.math.multiply_8[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_5 (TFOpLambda) (None, 10)           0           tf.math.exp[0][0]
#                                                                  tf.random.normal_1[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_3 (Sli (None, None, 1)      0           tf.reshape_1[0][0]
# __________________________________________________________________________________________________
# FCs (Lambda)                    (None, 6)            0           tf.clip_by_value_2[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_1 (TFOpLam (None, 10)           0           Z_Mu[0][0]
#                                                                  tf.math.multiply_5[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add (TFOpLambd (None, 10, 100)      0           gaussian_noise[0][0]
#                                                                  tf.__operators__.getitem_3[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_22 (Sl (None, 2)            0           FCs[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_23 (Sl (None, 4)            0           FCs[0][0]
# __________________________________________________________________________________________________
# Zs (Lambda)                     (None, 10)           0           tf.__operators__.add_1[0][0]
# __________________________________________________________________________________________________
# SigOut (Flatten)                (None, 1000)         0           tf.__operators__.add[0][0]
# __________________________________________________________________________________________________
# FeatGenModel (Functional)       [(None, 400), (None, 58400       tf.__operators__.getitem_22[0][0]
#                                                                  tf.__operators__.getitem_23[0][0]
#                                                                  Zs[0][0]
# __________________________________________________________________________________________________
# FeatExtModel (Functional)       [(None, 400), (None, 0           SigOut[0][0]
#                                                                  FCs[0][0]
# __________________________________________________________________________________________________
# ReconModel (Functional)         (None, 1000)         70150       FeatExtModel[0][0]
#                                                                  FeatExtModel[0][1]
#                                                                  FeatExtModel[0][2]
#                                                                  FeatExtModel[0][3]
#                                                                  FeatGenModel[0][0]
#                                                                  FeatGenModel[0][1]
#                                                                  FeatGenModel[0][2]
#                                                                  FeatGenModel[0][3]
# __________________________________________________________________________________________________
# tf.convert_to_tensor (TFOpLambd (None, 1000)         0           Inp_Enc[0][0]
# __________________________________________________________________________________________________
# tf.convert_to_tensor_1 (TFOpLam (None, 1000)         0           ReconModel[0][0]
# __________________________________________________________________________________________________
# tf.convert_to_tensor_2 (TFOpLam (None, 1000)         0           tf.convert_to_tensor[0][0]
# __________________________________________________________________________________________________
# tf.cast_4 (TFOpLambda)          (None, 1000)         0           tf.convert_to_tensor_1[0][0]
# __________________________________________________________________________________________________
# tf.math.squared_difference (TFO (None, 1000)         0           tf.convert_to_tensor_2[0][0]
#                                                                  tf.cast_4[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_mean (TFOpLambda (None,)              0           tf.math.squared_difference[0][0]
# __________________________________________________________________________________________________
# tf.cast_5 (TFOpLambda)          (None,)              0           tf.math.reduce_mean[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_45 (TFOpLambda (None,)              0           tf.cast_5[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_sum_12 (TFOpLamb ()                   0           tf.math.multiply_45[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.size (TFOpLambda)  ()                   0           tf.math.multiply_45[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_sum_13 (TFOpLamb ()                   0           tf.math.reduce_sum_12[0][0]
# __________________________________________________________________________________________________
# tf.cast_6 (TFOpLambda)          ()                   0           tf.compat.v1.size[0][0]
# __________________________________________________________________________________________________
# tf.math.divide_no_nan (TFOpLamb ()                   0           tf.math.reduce_sum_13[0][0]
#                                                                  tf.cast_6[0][0]
# __________________________________________________________________________________________________
# Beta_Rec_ext (Lossweight)       ()                   1           FeatGenModel[0][0]
#                                                                  FeatGenModel[0][1]
#                                                                  FeatGenModel[0][2]
#                                                                  FeatGenModel[0][3]
# __________________________________________________________________________________________________
# tf.cast_7 (TFOpLambda)          ()                   0           tf.math.divide_no_nan[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_46 (TFOpLambda ()                   0           Beta_Rec_ext[0][0]
#                                                                  tf.cast_7[0][0]
# __________________________________________________________________________________________________
# add_loss (AddLoss)              ()                   0           tf.math.multiply_46[0][0]
# __________________________________________________________________________________________________
# add_metric (AddMetric)          ()                   0           tf.math.multiply_46[0][0]
# __________________________________________________________________________________________________
# tf.concat_6 (TFOpLambda)        (None, 1600)         0           FeatExtModel[0][0]
#                                                                  FeatExtModel[0][1]
#                                                                  FeatExtModel[0][2]
#                                                                  FeatExtModel[0][3]
# __________________________________________________________________________________________________
# tf.concat_5 (TFOpLambda)        (None, 1600)         0           FeatGenModel[0][0]
#                                                                  FeatGenModel[0][1]
#                                                                  FeatGenModel[0][2]
#                                                                  FeatGenModel[0][3]
# __________________________________________________________________________________________________
# tf.convert_to_tensor_3 (TFOpLam (None, 1600)         0           tf.concat_6[0][0]
# __________________________________________________________________________________________________
# tf.convert_to_tensor_4 (TFOpLam (None, 1600)         0           tf.concat_5[0][0]
# __________________________________________________________________________________________________
# tf.convert_to_tensor_5 (TFOpLam (None, 1600)         0           tf.convert_to_tensor_3[0][0]
# __________________________________________________________________________________________________
# tf.cast_8 (TFOpLambda)          (None, 1600)         0           tf.convert_to_tensor_4[0][0]
# __________________________________________________________________________________________________
# tf.math.squared_difference_1 (T (None, 1600)         0           tf.convert_to_tensor_5[0][0]
#                                                                  tf.cast_8[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_mean_1 (TFOpLamb (None,)              0           tf.math.squared_difference_1[0][0
# __________________________________________________________________________________________________
# tf.cast_9 (TFOpLambda)          (None,)              0           tf.math.reduce_mean_1[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_47 (TFOpLambda (None,)              0           tf.cast_9[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_sum_14 (TFOpLamb ()                   0           tf.math.multiply_47[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.size_1 (TFOpLambda ()                   0           tf.math.multiply_47[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_sum_15 (TFOpLamb ()                   0           tf.math.reduce_sum_14[0][0]
# __________________________________________________________________________________________________
# tf.cast_10 (TFOpLambda)         ()                   0           tf.compat.v1.size_1[0][0]
# __________________________________________________________________________________________________
# tf.math.divide_no_nan_1 (TFOpLa ()                   0           tf.math.reduce_sum_15[0][0]
#                                                                  tf.cast_10[0][0]
# __________________________________________________________________________________________________
# Beta_Feat (Lossweight)          ()                   1           FeatGenModel[0][0]
#                                                                  FeatGenModel[0][1]
#                                                                  FeatGenModel[0][2]
#                                                                  FeatGenModel[0][3]
# __________________________________________________________________________________________________
# tf.cast_11 (TFOpLambda)         ()                   0           tf.math.divide_no_nan_1[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_48 (TFOpLambda ()                   0           Beta_Feat[0][0]
#                                                                  tf.cast_11[0][0]
# __________________________________________________________________________________________________
# add_loss_1 (AddLoss)            ()                   0           tf.math.multiply_48[0][0]
# __________________________________________________________________________________________________
# add_metric_1 (AddMetric)        ()                   0           tf.math.multiply_48[0][0]
# __________________________________________________________________________________________________
# tf.math.pow (TFOpLambda)        (None, 10)           0           Z_Mu[0][0]
# __________________________________________________________________________________________________
# tf.math.exp_1 (TFOpLambda)      (None, 10)           0           Z_Log_Sigma[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_7 (TFOpLam (None, 10)           0           tf.math.pow[0][0]
#                                                                  tf.math.exp_1[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_4 (TFOpLambda) (None, 10)           0           tf.__operators__.add_7[0][0]
#                                                                  Z_Log_Sigma[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_5 (TFOpLambda) (None, 10)           0           tf.math.subtract_4[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_sum_16 (TFOpLamb (None,)              0           tf.math.subtract_5[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_49 (TFOpLambda (None,)              0           tf.math.reduce_sum_16[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_mean_2 (TFOpLamb ()                   0           tf.math.multiply_49[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_6 (TFOpLambda) ()                   0           tf.math.reduce_mean_2[0][0]
# __________________________________________________________________________________________________
# Beta_Z (Lossweight)             ()                   1           FeatGenModel[0][0]
#                                                                  FeatGenModel[0][1]
#                                                                  FeatGenModel[0][2]
#                                                                  FeatGenModel[0][3]
# __________________________________________________________________________________________________
# tf.math.abs (TFOpLambda)        ()                   0           tf.math.subtract_6[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_50 (TFOpLambda ()                   0           Beta_Z[0][0]
#                                                                  tf.math.abs[0][0]
# __________________________________________________________________________________________________
# add_loss_2 (AddLoss)            ()                   0           tf.math.multiply_50[0][0]
# __________________________________________________________________________________________________
# add_metric_2 (AddMetric)        ()                   0           tf.math.multiply_50[0][0]
# __________________________________________________________________________________________________
# tf.math.log_4 (TFOpLambda)      (None, 6)            0           FC_Mu[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_8 (TFOpLambda) (None, 6)            0           FC_Mu[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_7 (TFOpLambda) (None, 6)            0           tf.math.log_4[0][0]
# __________________________________________________________________________________________________
# tf.math.log_5 (TFOpLambda)      (None, 6)            0           tf.math.subtract_8[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_8 (TFOpLam (None, 6)            0           tf.math.subtract_7[0][0]
#                                                                  tf.math.log_5[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_9 (TFOpLambda) (None, 6)            0           tf.__operators__.add_8[0][0]
# __________________________________________________________________________________________________
# tf.math.negative_3 (TFOpLambda) (None, 6)            0           tf.math.subtract_9[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_mean_3 (TFOpLamb ()                   0           tf.math.negative_3[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_10 (TFOpLambda ()                   0           tf.math.reduce_mean_3[0][0]
# __________________________________________________________________________________________________
# Beta_Fc (Lossweight)            ()                   1           FeatGenModel[0][0]
#                                                                  FeatGenModel[0][1]
#                                                                  FeatGenModel[0][2]
#                                                                  FeatGenModel[0][3]
# __________________________________________________________________________________________________
# tf.math.abs_1 (TFOpLambda)      ()                   0           tf.math.subtract_10[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_51 (TFOpLambda ()                   0           Beta_Fc[0][0]
#                                                                  tf.math.abs_1[0][0]
# __________________________________________________________________________________________________
# add_loss_3 (AddLoss)            ()                   0           tf.math.multiply_51[0][0]
# __________________________________________________________________________________________________
# add_metric_3 (AddMetric)        ()                   0           tf.math.multiply_51[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_24 (Sl (None, 1, 10)        0           Zs[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_25 (Sl (1, None, 10)        0           Z_Mu[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_26 (Sl (1, None, 10)        0           Z_Log_Sigma[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_11 (TFOpLambda (None, None, 10)     0           tf.__operators__.getitem_24[0][0]
#                                                                  tf.__operators__.getitem_25[0][0]
# __________________________________________________________________________________________________
# tf.math.negative_4 (TFOpLambda) (1, None, 10)        0           tf.__operators__.getitem_26[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_52 (TFOpLambda (None, None, 10)     0           tf.math.subtract_11[0][0]
#                                                                  tf.math.subtract_11[0][0]
# __________________________________________________________________________________________________
# tf.math.exp_2 (TFOpLambda)      (1, None, 10)        0           tf.math.negative_4[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_53 (TFOpLambda (None, None, 10)     0           tf.math.multiply_52[0][0]
#                                                                  tf.math.exp_2[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_9 (TFOpLam (None, None, 10)     0           tf.math.multiply_53[0][0]
#                                                                  tf.__operators__.getitem_26[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_10 (TFOpLa (None, None, 10)     0           tf.__operators__.add_9[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_54 (TFOpLambda (None, None, 10)     0           tf.__operators__.add_10[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_sum_18 (TFOpLamb (None, None)         0           tf.math.multiply_54[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_logsumexp (TFOpL (None, 10)           0           tf.math.multiply_54[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_logsumexp_1 (TFO (None,)              0           tf.math.reduce_sum_18[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_sum_17 (TFOpLamb (None,)              0           tf.math.reduce_logsumexp[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_12 (TFOpLambda (None,)              0           tf.math.reduce_logsumexp_1[0][0]
#                                                                  tf.math.reduce_sum_17[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_mean_4 (TFOpLamb ()                   0           tf.math.subtract_12[0][0]
# __________________________________________________________________________________________________
# Beta_TC (Lossweight)            ()                   1           FeatGenModel[0][0]
#                                                                  FeatGenModel[0][1]
#                                                                  FeatGenModel[0][2]
#                                                                  FeatGenModel[0][3]
# __________________________________________________________________________________________________
# tf.math.negative_5 (TFOpLambda) ()                   0           tf.math.reduce_mean_4[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_55 (TFOpLambda ()                   0           Beta_TC[0][0]
#                                                                  tf.math.negative_5[0][0]
# __________________________________________________________________________________________________
# add_loss_4 (AddLoss)            ()                   0           tf.math.multiply_55[0][0]
# __________________________________________________________________________________________________
# add_metric_4 (AddMetric)        ()                   0           tf.math.multiply_55[0][0]
# ==================================================================================================
# Total params: 170,428
# Trainable params: 170,423
# Non-trainable params: 5
# __________________________________________________________________________________________________

# %% [markdown]
# ### Model evaluation

# %%
SigBandRepModel.evaluate(TrData,  batch_size=3500, verbose=1)

# %% [markdown]
# ### From extractor to reconstruction validation
# #### It ultimately evaluates the performance of the reconstructor

# %%
idx = 51
N_Gen = 200
'''
FC_Comm = np.tile(np.linspace(0.,0.05, N_Gen )[:, None], (1,2))
FC_Each = np.tile(np.linspace(0.,0.05, N_Gen )[:, None], (1,4))

'''
FC_Comm = np.tile(np.random.uniform(0, 0.05, N_Gen)[:, None], (1,2))
FC_Comm = np.sort(FC_Comm)
FC_Each = np.tile(np.random.uniform(0, 0.05, N_Gen)[:, None], (1,4))
FC_Each = np.sort(FC_Each)


RecPred, HH,HL,LH, LL = VisReconExtract (ValData, idx, FeatExtModel, ReconModel, FC_Comm, FC_Each, N_Gen=N_Gen)
# Out:
# (200, 1000)

# %% [markdown]
# #### From extractor to reconstruction LL

# %%
plt.figure(figsize=(15, 5))
for i in range(N_Gen):
    plt.plot(LL.numpy()[i])

# %% [markdown]
# #### From extractor to reconstruction HH

# %%
plt.figure(figsize=(15, 5))
for i in range(N_Gen):
    plt.plot(HH.numpy()[i])

# %% [markdown]
# ### Permutation Local Correlation Monotonicity Index (PLCMI)

# %%
PLCMI_Res = PLCMI(FeatGenModel,  ReconModel, LatDim=10, N_Gen=300, N_Interval=10, MonoWinSize=20, MinZval = -3., MaxZval = 3., MinFreq=1, MaxFreq=51, Weight='Continuity')
# Out:
# [0, -3.0, 19.2302]
# [0, -2.33, 17.82]
# [0, -1.67, 18.9765]
# [0, -1.0, 19.4748]
# [0, -0.33, 18.5489]
# [0, 0.33, 18.954]
# [0, 1.0, 18.9421]
# [0, 1.67, 17.1773]
# [0, 2.33, 17.3308]
# [0, 3.0, 17.3002]
# [1, -3.0, 18.254]
# [1, -2.33, 17.5816]
# [1, -1.67, 17.4346]
# [1, -1.0, 17.487]
# [1, -0.33, 18.2055]
# [1, 0.33, 18.3508]
# [1, 1.0, 17.2211]
# [1, 1.67, 17.4412]
# [1, 2.33, 19.4971]
# [1, 3.0, 19.5276]
# [2, -3.0, 18.1447]
# [2, -2.33, 16.2282]
# [2, -1.67, 18.1826]
# [2, -1.0, 19.2344]
# [2, -0.33, 19.4828]
# [2, 0.33, 19.7533]
# [2, 1.0, 18.2255]
# [2, 1.67, 17.991]
# [2, 2.33, 17.7187]
# [2, 3.0, 19.4195]
# [3, -3.0, 18.7007]
# [3, -2.33, 17.63]
# [3, -1.67, 18.7655]
# [3, -1.0, 18.6935]
# [3, -0.33, 18.1499]
# [3, 0.33, 19.3965]
# [3, 1.0, 18.6627]
# [3, 1.67, 19.2384]
# [3, 2.33, 19.212]
# [3, 3.0, 18.4631]
# [4, -3.0, 15.134]
# [4, -2.33, 15.7444]
# [4, -1.67, 15.245]
# [4, -1.0, 16.3303]
# [4, -0.33, 19.2057]
# [4, 0.33, 18.2216]
# [4, 1.0, 17.1333]
# [4, 1.67, 18.047]
# [4, 2.33, 18.2037]
# [4, 3.0, 18.1364]
# [5, -3.0, 18.0992]
# [5, -2.33, 18.7999]
# [5, -1.67, 18.5092]
# [5, -1.0, 16.9831]
# [5, -0.33, 18.0918]
# [5, 0.33, 18.6695]
# [5, 1.0, 18.3424]
# [5, 1.67, 15.8689]
# [5, 2.33, 17.5878]
# [5, 3.0, 18.6562]
# [6, -3.0, 19.1647]
# [6, -2.33, 19.2068]
# [6, -1.67, 18.9924]
# [6, -1.0, 18.672]
# [6, -0.33, 18.4333]
# [6, 0.33, 18.5492]
# [6, 1.0, 18.5993]
# [6, 1.67, 18.2425]
# [6, 2.33, 18.3524]
# [6, 3.0, 18.4426]
# [7, -3.0, 17.7742]
# [7, -2.33, 16.9951]
# [7, -1.67, 17.1029]
# [7, -1.0, 18.1008]
# [7, -0.33, 17.9626]
# [7, 0.33, 18.9813]
# [7, 1.0, 18.7108]
# [7, 1.67, 18.4547]
# [7, 2.33, 18.3745]
# [7, 3.0, 19.4069]
# [8, -3.0, 18.7146]
# [8, -2.33, 18.519]
# [8, -1.67, 18.2443]
# [8, -1.0, 19.3668]
# [8, -0.33, 19.2543]
# [8, 0.33, 19.1935]
# [8, 1.0, 18.3343]
# [8, 1.67, 18.6828]
# [8, 2.33, 18.628]
# [8, 3.0, 19.0133]
# [9, -3.0, 18.486]
# [9, -2.33, 19.0482]
# [9, -1.67, 18.3644]
# [9, -1.0, 18.9113]
# [9, -0.33, 17.3687]
# [9, 0.33, 17.9203]
# [9, 1.0, 18.0513]
# [9, 1.67, 17.3427]
# [9, 2.33, 17.5833]
# [9, 3.0, 18.652]

# %% [markdown]
# ### Qualitative evaluation of the amplitude relationship between the input frequency for signal generation (y-axis) and the frequency of the generated signal (x-axis).

# %%
ZFix = {1:3.0}
#zVal[:,0] = -3
#Val[:,1] = 2.33
#zVal[:,2] = 0.4
#zVal[:,3] = -1.67
#zVal[:,4] = 0.33
#zVal[:,5] = 3
#zVal[:,6] = -1.67
#zVal[:,7] = 3
#zVal[:,8] = 3
#zVal[:,9] = -1

HeatMapFrequency(FeatGenModel,  ReconModel, LatDim, ZFix, N_Gen)

# %% [markdown]
# ### Visualizing the reconstruction conditioned on a specific z-value when frequencies are given at regular intervals
# #### Objective: This qualitatively evaluates the impact of changes in input frequencies on signal generation when a specific z-value is given.

# %%
ZFix = {0:1.}
RecPred, HH,HL,LH, LL = VisReconGivenZ (FeatGenModel,  ReconModel, LatDim, ZFix, Mode='Origin', N_Gen=300, MinFreqR=0, MaxFreqR=0.05)

# %% [markdown]
# ### Visualizing the reconstruction conditioned on a specific frequency value when z-values are given at regular intervals
# #### Objective: This qualitatively evaluates the impact of changes in input z-values on signal generation when a specific frequency is given.

# %%
FcCommFix = {0:0.05, 1:0.05}
FcEachFix = {0:0.05, 1:0.05, 2:0.05, 3:0.05}
RecPred, HH,HL,LH, LL = VisReconGivenFreq (FeatGenModel,  ReconModel, LatDim, FcCommFix, FcEachFix,  Mode='Origin', N_Gen=200, MinZval = -3., MaxZval = 3., CutLower=-2., CutUpper = 1.)

# %% [markdown]
# ### From generator to reconstruction validation

# %%
idx = 175
plt.plot(RecPred[idx])

# %% [markdown]
# ### Visualizing amplitude by frequency given a specific ID

# %%
# GenSig_zVar
N_Gen= 300
SigGen5, Amplitude5 = GenSig_zVar(FeatGenModel, ReconModel, 0.05, N_Gen=N_Gen)
SigGen4, Amplitude4 = GenSig_zVar(FeatGenModel, ReconModel,  0.04, N_Gen=N_Gen)
SigGen3, Amplitude3 = GenSig_zVar(FeatGenModel, ReconModel,  0.03, N_Gen=N_Gen)
SigGen2, Amplitude2 = GenSig_zVar(FeatGenModel, ReconModel,  0.02, N_Gen=N_Gen)
SigGen1, Amplitude1 = GenSig_zVar(FeatGenModel, ReconModel,  0.01, N_Gen=N_Gen)

plt.figure(figsize=(12, 5))
idx = 20
plt.plot(Amplitude5[idx, 1:51])
plt.plot(Amplitude4[idx, 1:51])
plt.plot(Amplitude3[idx, 1:51])
plt.plot(Amplitude2[idx, 1:51])
plt.plot(Amplitude1[idx, 1:51])

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

N_Gen = 300
MinFreq=1
MaxFreq=50


# GenSig_FcVar
zVal = np.tile(np.zeros(LatDim), (N_Gen,1))
SigGen_FcVar, Amplitude_FcVar = GenSig_FcVar(FeatGenModel,  ReconModel,zVal, N_Gen=N_Gen, zType='Fixed')

# Axes generation
FreqX = np.arange(0, N_Gen)
GenY = np.arange(MinFreq, MaxFreq+1)
FreqX, GenY = np.meshgrid(GenY, FreqX)

# 3D plot
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111, projection='3d')
surf = ax.plot_surface(FreqX, GenY, Amplitude_FcVar[:, MinFreq:MaxFreq+1], cmap='viridis', linewidth=1, antialiased=True, alpha = 0.9)

# Axis labels
ax.set_xlabel('Frequency', fontsize=14, labelpad=5.5)
ax.set_xticks(ax.get_xticks())
ax.tick_params(axis='x', labelsize=12)
ax.set_xlim(left=MinFreq, right=MaxFreq+1)

ax.set_ylabel('Gneration', fontsize=14, labelpad=6.5)
ax.set_yticks(ax.get_yticks())
ax.tick_params(axis='y', labelsize=12)
ax.set_ylim(bottom=0, top=N_Gen)

ax.set_zlabel('Amplitude', fontsize=14, labelpad=11.)
ax.set_zticks(ax.get_zticks())
ax.tick_params(axis='z', labelsize=12, pad=5)  
ax.set_zlim(bottom=0, top=Amplitude_FcVar[:, MinFreq:MaxFreq+1].max())

ax.view_init(azim=300, elev=45)
plt.show()
