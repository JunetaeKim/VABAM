# %%
import os
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.keras import backend as K
from tensorflow.keras.layers import Input, GRU, Dense, Masking, Reshape, Flatten, RepeatVector, TimeDistributed, Bidirectional, Activation, GaussianNoise, Lambda, LSTM
from tensorflow.keras import Model
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from Models.FeatExtModels_NoKaiser import *

os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %% [markdown]
# ### Data

# %%
DATA = np.load('./Data/AsanTRSet.npy')

# %% [markdown]
# #### Env setting

# %%
save_path = './Results/'
if not os.path.exists(save_path):
    os.mkdir(save_path)
    
### Model checkpoint
ModelSaveSameName = save_path+'SigBandRepModel_ExtRec_2.hdf5'
ModelSave = ModelCheckpoint(filepath=ModelSaveSameName, monitor='val_mse', verbose=1, save_best_only=True )

### Model Early stop
EarlyStop = EarlyStopping(monitor='val_loss', patience=500)

LatDim = 3
SigDim = DATA.shape[1]
MaskingRate = 0.02
NoiseStd = 0.002
MaskStd = 0.1
ReparaStd = 0.1

# %%
'''
class RelLossWeight(tf.keras.callbacks.Callback):
    def __init__(self, LossName1, LossName2, BetaName1, BetaName2, verbose=1):
                
        self.LossName1 = LossName1
        self.LossName2 = LossName2
        self.BetaName1 = BetaName1
        self.BetaName2 = BetaName2
        self.verbose = verbose

    def on_epoch_end(self, epoch, logs={}):
        
        Loss1 = logs[self.LossName1] 
        Loss2 = logs[self.LossName2] 
        
        Beta1_idx = [num for num, i in enumerate(self.model.variables) if self.BetaName1 in i.name][0]
        Beta2_idx = [num for num, i in enumerate(self.model.variables) if self.BetaName2 in i.name][0]
        
        self.model.variables[Beta1_idx].assign(Loss1/Loss2)
        self.model.variables[Beta2_idx].assign(Loss2/Loss1)   

        if self.verbose==1:
            print(self.BetaName1+' : ', self.model.variables[Beta1_idx])
            print(self.BetaName2+' : ', self.model.variables[Beta2_idx])        
 

# Define the KL annealing callback function
class KLCallback(tf.keras.callbacks.Callback):
    def __init__(self, TargetLossName, Threshold, MaxBeta, BetaName, AnnealEpoch=100):
        self.TargetLossName = TargetLossName
        self.Threshold = Threshold
        self.BetaName = BetaName
        self.MaxBeta = MaxBeta
        self.AnnealStart = 0
        self.AnnealEpoch = AnnealEpoch

    def on_epoch_end(self, epoch, logs={}):
        
        TargetLoss = logs['val_'+self.TargetLossName]
        
        if TargetLoss > self.Threshold:
            
            self.AnnealStart = 0
            K.set_value(self.model.get_layer(self.BetaName).variables[0], 0.)
        else: 
            self.AnnealStart += 1
            Beta = (self.AnnealStart) / self.AnnealEpoch * self.MaxBeta
            K.set_value(self.model.get_layer(self.BetaName).variables[0], Beta)
        
        print(self.model.get_layer(self.BetaName).variables[0])
'''

'''
class KLAnneal(tf.keras.callbacks.Callback):
    def __init__(self, TargetLossName, Threshold,  BetaName, MaxBeta=0.1, MinBeta=1e-5, AnnealEpoch=100, UnderLimit=0., verbose=1):
        
        if type(TargetLossName) != list:
            TargetLossName = [TargetLossName]
        
        self.TargetLossName = TargetLossName
        self.Threshold = Threshold
        self.BetaName = BetaName
        self.AnnealIdx = 0
        self.verbose = verbose 
        self.Beta =  np.concatenate([np.array([UnderLimit]), np.linspace(start=MinBeta, stop=MaxBeta, num=AnnealEpoch )])

    def on_epoch_end(self, epoch, logs={}):
        
        TargetLoss = max([logs[i] for i in self.TargetLossName]) 
        
        if TargetLoss > self.Threshold:
            
            #self.AnnealIdx -= 1
            #self.AnnealIdx = np.maximum(self.AnnealIdx, 0)
            K.set_value(self.model.get_layer(self.BetaName).variables[0], self.Beta[self.AnnealIdx])
        else: 
            self.AnnealIdx += 1
            self.AnnealIdx = np.minimum(self.AnnealIdx, len(self.Beta)-1)
            K.set_value(self.model.get_layer(self.BetaName).variables[0], self.Beta[self.AnnealIdx])
        
        if self.verbose==1:
            print(self.BetaName+' : ' ,self.model.get_layer(self.BetaName).variables[0].numpy())
        elif self.verbose==2:
            print('TargetLoss : ', TargetLoss)
            print(self.BetaName+' : ' ,self.model.get_layer(self.BetaName).variables[0].numpy())
'''

'''
class RelLossWeight(tf.keras.callbacks.Callback):
    def __init__(self, LossName1, LossName2, Beta1, Beta2, WeightB1 =1., WeightB2 =1., BetaName1 ='Beta1' , BetaName2 ='Beta2' , verbose=1):
                
        self.LossName1 = LossName1
        self.LossName2 = LossName2
        self.Beta1 = Beta1
        self.Beta2 = Beta2
        self.BetaName1 = BetaName1
        self.BetaName2 = BetaName2
        self.verbose = verbose
        self.WeightB1 = WeightB1
        self.WeightB2 = WeightB2

    def on_epoch_end(self, epoch, logs={}):
        
        Loss1 = logs[self.LossName1] 
        Loss2 = logs[self.LossName2] 
        
        Beta1 = tf.maximum(Loss1/Loss2, 1.) * self.WeightB1
        Beta2 = tf.maximum(Loss2/Loss1, 1.) * self.WeightB2
        
        self.Beta1.assign(Beta1)
        self.Beta2.assign(Beta2)   

        if self.verbose==1:
            print(self.BetaName1+' : ', self.Beta1.numpy())
            print(self.BetaName2+' : ', self.Beta2.numpy())   
'''

# %%
'''
class KLAnneal(tf.keras.callbacks.Callback):
    def __init__(self, TargetLossName, Threshold,  Beta, BetaName ='Beta', MaxBeta=0.1, MinBeta=1e-5, AnnealEpoch=100, UnderLimit=0., verbose=1):
        
        if type(TargetLossName) != list:
            TargetLossName = [TargetLossName]
        
        self.TargetLossName = TargetLossName
        self.Threshold = Threshold
        self.Beta = Beta
        self.BetaName = BetaName
        self.AnnealIdx = 0
        self.verbose = verbose 
        self.BetaValue =  np.concatenate([np.array([UnderLimit]), np.linspace(start=MinBeta, stop=MaxBeta, num=AnnealEpoch )])

    def on_epoch_end(self, epoch, logs={}):
        
        TargetLoss = max([logs[i] for i in self.TargetLossName]) 
        
        if TargetLoss > self.Threshold:
            
            #self.AnnealIdx -= 1
            #self.AnnealIdx = np.maximum(self.AnnealIdx, 0)
            self.Beta.assign(self.BetaValue[self.AnnealIdx])
        else: 
            self.AnnealIdx += 1
            self.AnnealIdx = np.minimum(self.AnnealIdx, len(self.BetaValue)-1)
            self.Beta.assign(self.BetaValue[self.AnnealIdx])
        
        if self.verbose==1:
            print(self.BetaName+' : ' ,self.Beta.numpy())
        elif self.verbose==2:
            print('TargetLoss : ', TargetLoss)
            print(self.BetaName+' : ' ,self.Beta.numpy())
            
            
       
class RelLossWeight(tf.keras.callbacks.Callback):
    def __init__(self, BetaList, BetaWeight, MinLimit , MaxLimit , verbose=1):
                
        self.BetaList = BetaList
        self.BetaWeight = BetaWeight
        self.MinLimit = MinLimit
        self.MaxLimit = MaxLimit
        self.verbose = verbose

        
    def on_epoch_end(self, epoch, logs={}):
        
        Losses = np.array([logs[i] for i in self.BetaList.keys()])
        Losses = np.maximum(1e-7, Losses)
        RelWeights = Losses / np.min(Losses)
        RelWeights = {LossName:RelWeights[num] for num, LossName in enumerate (self.BetaList.keys())}

        for name, beta in self.BetaList.items():
            
            Value = np.clip(RelWeights[name] * self.BetaWeight[name], self.MinLimit[name], self.MaxLimit[name])
            beta.assign(Value)

        if self.verbose==1:
            print(RelWeights)
            for key, beta in self.BetaList.items():
                print(key, ': ', beta.numpy())
                
RelLossDic = {'val_mse':'Beta_Rec', 'val_FeatRecLoss':'Beta_Feat', 'val_kl_Loss_Z':'Beta_Z', 'val_kl_Loss_FC':'Beta_Fc'}
WeightDic = {'val_mse':10., 'val_FeatRecLoss':100., 'val_kl_Loss_Z':1., 'val_kl_Loss_FC':1.}
MinLimit = {'val_mse':1., 'val_FeatRecLoss':1., 'val_kl_Loss_Z':0.01, 'val_kl_Loss_FC':0.01}
MaxLimit = {'val_mse':200., 'val_FeatRecLoss':200., 'val_kl_Loss_Z':0.1, 'val_kl_Loss_FC':0.1}
RelLoss = RelLossWeight(BetaList=RelLossDic, BetaWeight= WeightDic, MinLimit= MinLimit, MaxLimit = MaxLimit )


class RelLossWeight(tf.keras.callbacks.Callback):
    def __init__(self, BetaList, LossScaling, MinLimit , MaxLimit , verbose=1):
                
        self.BetaList = BetaList
        self.LossScaling = LossScaling
        self.MinLimit = MinLimit
        self.MaxLimit = MaxLimit
        self.verbose = verbose

        
    def on_epoch_end(self, epoch, logs={}):
        
        Losses = np.array([logs[i] for i in self.BetaList.keys()])
        Losses = np.maximum(1e-7, Losses)
        RelWeights = Losses / np.min(Losses)
        RelWeights = {loss:RelWeights[num] * self.LossScaling[loss] for num, loss in enumerate (self.BetaList.keys())}

        for loss, beta in self.BetaList.items():
            
            Value = np.clip(RelWeights[loss] , self.MinLimit[beta], self.MaxLimit[beta])
            K.set_value(self.model.get_layer(beta).variables[0], Value)

        if self.verbose==1:
            print('RelWeights')
            print(RelWeights)
                       
            for key, beta in self.BetaList.items():
                print(beta, ': ', self.model.get_layer(beta).variables[0].numpy())

'''

# %%
        
def ReName (layer, name):
    return Lambda(lambda x: x, name=name)(layer)

def ParaFilters (layer, name=''):
    Fc = Dense(1, activation='sigmoid')(layer)
    Fc = tf.clip_by_value(Fc, 1e-7, 1-1e-7)
    
    # Reparameterization Trick for sampling from Uniformly distribution; ϵ∼U(0,1) 
    Epsilon = tf.random.uniform(shape=(tf.shape(Fc)[0], Fc.shape[1]))
    Epsilon = tf.clip_by_value(Epsilon, 1e-7, 1-1e-7)

    LogEps = tf.math.log(Epsilon)
    LogNegEps = tf.math.log(1 - Epsilon)
    
    LogTheta = tf.math.log(Fc)
    LogNegTheta = tf.math.log(1-Fc)

    Fc = tf.math.sigmoid(LogEps - LogNegEps + LogTheta - LogNegTheta)
    Fc = tf.clip_by_value(Fc, 1e-7, 1-1e-7)
    Fc = ReName(Fc, name)
    
    return Fc 


class Lossweight(tf.keras.layers.Layer):
    
    def __init__(self, InitVal = 0., name='Lossweight'):
        super(Lossweight, self).__init__(name=name)
        self.InitVal = InitVal
    
    def build(self, input_shape):
        self.GenVec = tf.Variable(self.InitVal, trainable=False)
    
    def call(self, input):

        return self.GenVec
    
    def get_config(self):
        config = super(Lossweight, self).get_config()
        config.update({ 'InitVal': self.InitVal })
        return config
    

class RandFCs(tf.keras.layers.Layer):
    
    def __init__(self, ):
        super(RandFCs, self).__init__(name='FCs')
        pass
    
    def build(self, input_shape):
        self.GenVec = tf.Variable(tf.random.uniform(shape=(1,6)), trainable=False)
    
    def call(self, input):
        return tf.tile(self.GenVec , (tf.shape(input)[0],1))
    


class KLAnneal(tf.keras.callbacks.Callback):
    def __init__(self, TargetLossName, Threshold,  BetaName, MaxBeta=0.1, MinBeta=1e-5, AnnealEpoch=100, UnderLimit=0., verbose=1):
        
        if type(TargetLossName) != list:
            TargetLossName = [TargetLossName]
        
        self.TargetLossName = TargetLossName
        self.Threshold = Threshold
        self.BetaName = BetaName
        self.AnnealIdx = 0
        self.verbose = verbose 
        self.Beta =  np.concatenate([np.array([UnderLimit]), np.linspace(start=MinBeta, stop=MaxBeta, num=AnnealEpoch )])

    def on_epoch_end(self, epoch, logs={}):
        
        TargetLoss = max([logs[i] for i in self.TargetLossName]) 
        
        if TargetLoss > self.Threshold:
            
            self.AnnealIdx -= 1
            self.AnnealIdx = np.maximum(self.AnnealIdx, 0)
            K.set_value(self.model.get_layer(self.BetaName).variables[0], self.Beta[self.AnnealIdx])
        else: 
            self.AnnealIdx += 1
            self.AnnealIdx = np.minimum(self.AnnealIdx, len(self.Beta)-1)
            K.set_value(self.model.get_layer(self.BetaName).variables[0], self.Beta[self.AnnealIdx])
        
        if self.verbose==1:
            print(self.BetaName+' : ' ,self.model.get_layer(self.BetaName).variables[0].numpy())
        elif self.verbose==2:
            print('TargetLoss : ', TargetLoss)
            print(self.BetaName+' : ' ,self.model.get_layer(self.BetaName).variables[0].numpy())
            
          

class RelLossWeight(tf.keras.callbacks.Callback):
    def __init__(self, BetaList, LossScaling, MinLimit , MaxLimit , verbose=1):
                
        self.BetaList = BetaList
        self.LossScaling = LossScaling
        self.MinLimit = MinLimit
        self.MaxLimit = MaxLimit
        self.verbose = verbose

        
    def on_epoch_end(self, epoch, logs={}):
        
        Losses = {key:logs[key]/np.maximum(1e-7,self.model.get_layer(beta).variables[0].numpy()) for key, beta in self.BetaList.items()}
        '''
        WeigLosses = np.array([logs[i] for i in self.BetaList.keys()])
        WeigLosses = np.maximum(1e-7, WeigLosses)
        RelWeights = WeigLosses / np.min(WeigLosses)
        '''
        
        WeigLosses = np.maximum(1e-7, np.array(list(Losses.values())))
        #print(WeigLosses)
        RelWeights = WeigLosses / np.min(WeigLosses)
        #print(RelWeights)
        RelWeights = {loss:RelWeights[num] * self.LossScaling[loss] for num, loss in enumerate (self.BetaList.keys())}
        #print(RelWeights)

        for loss, beta in self.BetaList.items():
            
            Value = np.clip(RelWeights[loss] , self.MinLimit[beta], self.MaxLimit[beta])
            K.set_value(self.model.get_layer(beta).variables[0], Value)

        if self.verbose==1:

            print('Losses')
            for key, value in Losses.items():
                print("%s: %.7f" % (key, value))
            
            print('RelWeights')
            for key, value in RelWeights.items():
                print("%s: %.7f" % (key, value))
                       
            for key, beta in self.BetaList.items():
                print(beta, ': ', self.model.get_layer(beta).variables[0].numpy())

# %%
def Encoder(SigDim, LatDim= 2, Type = '', MaskingRate = 0.025, NoiseStd = 0.002, MaskStd = 0.1, ReparaStd = 0.1 , Reparam = False):

    InpL = Input(shape=(SigDim,))
    InpFrame = tf.signal.frame(InpL, 100, 100)

    if Reparam:
        InpRegul = GaussianNoise(stddev=NoiseStd)(InpFrame, training=Reparam)
        MaskVec, NoisVec = MaskingGen(InpRegul, MaskingRate, MaskStd)
        EncInp = Masking(mask_value=0.)(InpRegul * MaskVec )
        EncOut = InpRegul + NoisVec
    else:
        EncInp, EncOut = InpFrame, InpFrame

    Encoder = Dense(50, activation='relu')(InpFrame)
    Encoder = Bidirectional(GRU(30, return_sequences=True))(Encoder)
    Encoder = Bidirectional(GRU(30, return_sequences=False))(Encoder)
    Encoder = Dense(50, activation='relu')(Encoder)
    Encoder = Dense(30, activation='relu')(Encoder)
    Encoder = Dense(15, activation='relu')(Encoder)

    Z_Mean = Dense(LatDim, activation='linear')(Encoder)
    Z_Log_Sigma = Dense(LatDim, activation='relu')(Encoder)
    Z_Log_Sigma = ReName(Z_Log_Sigma,'Z_Log_Sigma_'+Type)

    
    # Reparameterization Trick for sampling from Guassian distribution
    Epsilon = tf.random.normal(shape=(tf.shape(Z_Mean)[0], Z_Mean.shape[1]), mean=0., stddev=ReparaStd)

    if Reparam==False:
        Epsilon = Epsilon * 0

    Z_Mean = Z_Mean + tf.exp(0.5 * Z_Log_Sigma) * Epsilon
    Z_Mean = ReName(Z_Mean,'Z_Mean_'+Type)
    
    FCs =   Dense(6, activation='relu')(Encoder)
    FCs =   Dense(6, activation='sigmoid')(FCs)
    
    
    # Reparameterization Trick for sampling from Uniformly distribution; ϵ∼U(0,1) 
    FCs = tf.clip_by_value(FCs, 1e-7, 1-1e-7)
    Epsilon = tf.random.uniform(shape=(tf.shape(FCs)[0], FCs.shape[1]))
    Epsilon = tf.clip_by_value(Epsilon, 1e-7, 1-1e-7)
    
    LogEps = tf.math.log(Epsilon)
    LogNegEps = tf.math.log(1 - Epsilon)
    
    LogTheta = tf.math.log(FCs)
    LogNegTheta = tf.math.log(1-FCs)
    
    
    FCs = tf.math.sigmoid(LogEps - LogNegEps + LogTheta - LogNegTheta)
    FCs = tf.clip_by_value(FCs, 1e-7, 1-1e-7)
    FCs = ReName(FCs, 'FCs')
    
    return [InpL], [Flatten()(EncOut), Z_Mean, FCs]



def FeatExtractor(Inps, LatDim= 2, FiltLenList = [301, 301, 301, 301, 301, 301] ):
    
    EncReInp, InpZ, FCs = Inps
    
    H_F, L_F, HH_F, HL_F, LH_F, LL_F = tf.split(FCs, 6, axis=1)
    

    ### Filtering level 1 -------------------------------------------------------------------
    ## Filter generation
    To_H = GenHighFilter(H_F,  N=FiltLenList[0])
    To_L = GenLowFilter(L_F, N=FiltLenList[1])

    ## Perform signal filtering level 1
    InpFrame =  tf.signal.frame(EncReInp, To_H.shape[-1], 1)
    Sig_H = tf.reduce_sum(InpFrame*To_H[:,:,::-1], axis=-1, keepdims=True)
    Sig_H = ReName(Sig_H, 'Sig_H_Ext')

    InpFrame =  tf.signal.frame(EncReInp, To_L.shape[-1], 1)
    Sig_L = tf.reduce_sum(InpFrame*To_L[:,:,::-1], axis=-1, keepdims=True)
    Sig_L = ReName(Sig_L, 'Sig_L_Ext')



    ### Filtering level HH and HL (from Sig_H) -------------------------------------------------------------------
    ## Filter generation
    To_HH = GenHighFilter(HH_F, N=FiltLenList[2])
    To_HL = GenLowFilter(HL_F, N=FiltLenList[3])

    ## Perform signal filtering level 2
    Frame_H =  tf.signal.frame(Sig_H[:,:,0], To_HH.shape[-1], 1)
    Sig_HH = tf.reduce_sum(Frame_H*To_HH[:,:,::-1], axis=-1, keepdims=True)
    Sig_HH = ReName(Sig_HH, 'Sig_HH_Ext')

    Frame_H =  tf.signal.frame(Sig_H[:,:,0], To_HL.shape[-1], 1)
    Sig_HL = tf.reduce_sum(Frame_H*To_HL[:,:,::-1], axis=-1, keepdims=True)
    Sig_HL = ReName(Sig_HL, 'Sig_HL_Ext')


    ### Filtering level LH and LL (from Sig_L) -------------------------------------------------------------------
    ## Filter generation
    To_LH = GenHighFilter(LH_F,  N=FiltLenList[4])
    To_LL = GenLowFilter(LL_F,  N=FiltLenList[5])

    ## Perform signal filtering level 2
    Frame_L =  tf.signal.frame(Sig_L[:,:,0], To_LH.shape[-1], 1)
    Sig_LH = tf.reduce_sum(Frame_L*To_LH[:,:,::-1], axis=-1, keepdims=True)
    Sig_LH = ReName(Sig_LH, 'Sig_LH_Ext')

    Frame_L =  tf.signal.frame(Sig_L[:,:,0], To_LL.shape[-1], 1)
    Sig_LL = tf.reduce_sum(Frame_L*To_LL[:,:,::-1], axis=-1, keepdims=True)
    Sig_LL = ReName(Sig_LL, 'Sig_LL_Ext')

    
    return [Flatten()(Sig_HH), Flatten()(Sig_HL), Flatten()(Sig_LH), Flatten()(Sig_LL)]




def FeatGenerator (Inp_lat):
    
    #Inp_lat = tf.concat(Inp_lat, axis=-1)
    InpZ, FCCommon, FCEach = Inp_lat
    HH_F, HL_F, LH_F, LL_F = tf.split(FCEach, 4, axis=1)
    
   
    Dec_Sig_HH = Dense(10, activation='relu')(tf.concat([InpZ, FCCommon, HH_F], axis=-1))
    Dec_Sig_HH = Dense(20, activation='relu')(Dec_Sig_HH)
    Dec_Sig_HH = Dense(30, activation='relu')(Dec_Sig_HH)
    Dec_Sig_HH = Dense(50, activation='relu')(Dec_Sig_HH)

    Dec_Sig_HH = RepeatVector(10 )(Dec_Sig_HH)
    Dec_Sig_HH = Bidirectional(GRU(10, return_sequences=True))(Dec_Sig_HH)
    Dec_Sig_HH = Bidirectional(GRU(20, return_sequences=True))(Dec_Sig_HH)
    Dec_Sig_HH = Dense(40,'tanh')(Dec_Sig_HH)
    Sig_HH= Flatten(name='Sig_HH_Gen')(Dec_Sig_HH)
    
    # ---------------------------------------------------------------------- #
    
    Dec_Sig_HL = Dense(10, activation='relu')(tf.concat([InpZ, FCCommon, HL_F], axis=-1))
    Dec_Sig_HL = Dense(20, activation='relu')(Dec_Sig_HL)
    Dec_Sig_HL = Dense(30, activation='relu')(Dec_Sig_HL)
    Dec_Sig_HL = Dense(50, activation='relu')(Dec_Sig_HL)

    Dec_Sig_HL = RepeatVector(10 )(Dec_Sig_HL)
    Dec_Sig_HL = Bidirectional(GRU(10, return_sequences=True))(Dec_Sig_HL)
    Dec_Sig_HL = Bidirectional(GRU(20, return_sequences=True))(Dec_Sig_HL)
    Dec_Sig_HL = Dense(40,'tanh')(Dec_Sig_HL)
    Sig_HL= Flatten(name='Sig_HL_Gen')(Dec_Sig_HL)
    
    # ---------------------------------------------------------------------- #
    
    Dec_Sig_LH = Dense(10, activation='relu')(tf.concat([InpZ, FCCommon, LH_F], axis=-1))
    Dec_Sig_LH = Dense(20, activation='relu')(Dec_Sig_LH)
    Dec_Sig_LH = Dense(30, activation='relu')(Dec_Sig_LH)
    Dec_Sig_LH = Dense(50, activation='relu')(Dec_Sig_LH)

    Dec_Sig_LH = RepeatVector(10 )(Dec_Sig_LH)
    Dec_Sig_LH = Bidirectional(GRU(10, return_sequences=True))(Dec_Sig_LH)
    Dec_Sig_LH = Bidirectional(GRU(20, return_sequences=True))(Dec_Sig_LH)
    Dec_Sig_LH = Dense(40,'tanh')(Dec_Sig_LH)
    Sig_LH= Flatten(name='Sig_LH_Gen')(Dec_Sig_LH)
    
    # ---------------------------------------------------------------------- #
    
    Dec_Sig_LL = Dense(10, activation='relu')(tf.concat([InpZ, FCCommon, LL_F], axis=-1))
    Dec_Sig_LL = Dense(20, activation='relu')(Dec_Sig_LL)
    Dec_Sig_LL = Dense(30, activation='relu')(Dec_Sig_LL)
    Dec_Sig_LL = Dense(50, activation='relu')(Dec_Sig_LL)

    Dec_Sig_LL = RepeatVector(10 )(Dec_Sig_LL)
    Dec_Sig_LL = Bidirectional(GRU(10, return_sequences=True))(Dec_Sig_LL)
    Dec_Sig_LL = Bidirectional(GRU(20, return_sequences=True))(Dec_Sig_LL)
    Dec_Sig_LL = Dense(40,'tanh')(Dec_Sig_LL)
    Sig_LL= Flatten(name='Sig_LL_Gen')(Dec_Sig_LL)
    
    return  Sig_HH, Sig_HL, Sig_LH, Sig_LL




def Reconstructor(Inps ):
    Sig_HH, Sig_HL, Sig_LH, Sig_LL = Inps

    ## GRU NET -------------------------------------------------------------------
    Dec_Sig_HH = Reshape((-1, 100))(Sig_HH)
    Dec_Sig_HL = Reshape((-1, 100))(Sig_HL)
    Dec_Sig_LH = Reshape((-1, 100))(Sig_LH)
    Dec_Sig_LL = Reshape((-1, 100))(Sig_LL)

    Dec_Sig_HH = Bidirectional(GRU(5), name='Dec_Sig_HH')(Dec_Sig_HH)
    Dec_Sig_HL = Bidirectional(GRU(5), name='Dec_Sig_HL')(Dec_Sig_HL)
    Dec_Sig_LH = Bidirectional(GRU(5), name='Dec_Sig_LH')(Dec_Sig_LH)
    Dec_Sig_LL = Bidirectional(GRU(5), name='Dec_Sig_LL')(Dec_Sig_LL)

    Decoder = tf.concat([ Dec_Sig_HH, Dec_Sig_HL, Dec_Sig_LH, Dec_Sig_LL], axis=1)
    Decoder = RepeatVector((SigDim//100) )(Decoder)
    Decoder = Bidirectional(GRU(50, return_sequences=True))(Decoder)
    Decoder = Dense(100, activation='relu')(Decoder)
    DecOut = Dense(100, activation='sigmoid')(Decoder)
    DecOut = Reshape((SigDim,),name='Out')(DecOut)

    
    return DecOut

# %%
### Encoder - FeatExtractor
EncInp, EncOut = Encoder(SigDim=SigDim, LatDim= LatDim, Type = 'Tr', MaskingRate = MaskingRate, NoiseStd = NoiseStd, MaskStd = MaskStd, ReparaStd = ReparaStd, Reparam=True)
FeatExtOut = FeatExtractor(EncOut)

### Encoder - FeatGenerator - Reconstruction
FeatGenOut = FeatGenerator([EncOut[1],EncOut[2][:, :2], EncOut[2][:, 2:]])
FeatGenOut = ReName(FeatGenOut, 'FeatGenOut')

ReconOut = Reconstructor(FeatExtOut)
ReconOut = ReName(ReconOut, 'ReconOut')

### Define the total model
SigBandRepModel = Model(EncInp, ReconOut)

### Weight controller; Apply beta and capacity 
Capacity_Z = 0.1 # 0.1 0.05
Capacity_Fc = 0.6
Beta_Z = Lossweight(name='Beta_Z')(FeatGenOut)
Beta_Fc = Lossweight(name='Beta_Fc')(FeatGenOut)
Beta_Rec = Lossweight(name='Beta_Rec', InitVal=500.)(FeatGenOut)
Beta_Feat = Lossweight(name='Beta_Feat', InitVal=500.)(FeatGenOut)


### Adding the RecLoss; 
MSE = tf.keras.losses.MeanSquaredError()
RecLoss = Beta_Rec * MSE(ReconOut, EncInp)
SigBandRepModel.add_loss(RecLoss)
SigBandRepModel.add_metric(RecLoss, 'RecLoss')


### Adding the FeatRecLoss; It allows connection between the extractor and generator
FeatRecLoss= Beta_Feat * MSE(tf.concat(FeatGenOut, axis=-1), tf.concat(FeatExtOut, axis=-1))
SigBandRepModel.add_loss(FeatRecLoss)
SigBandRepModel.add_metric(FeatRecLoss, 'FeatRecLoss')

### KL Divergence for p(Z) vs q(Z)
Z_Sampled, Z_Log_Sigma = SigBandRepModel.get_layer('Z_Mean_Tr').output, SigBandRepModel.get_layer('Z_Log_Sigma_Tr').output
kl_Loss_Z = 0.5 * tf.reduce_sum( Z_Sampled**2  +  tf.exp(Z_Log_Sigma)- Z_Log_Sigma-1, axis=1)    
kl_Loss_Z = tf.reduce_mean(kl_Loss_Z )
kl_Loss_Z = Beta_Z * tf.abs(kl_Loss_Z - Capacity_Z)

### KL Divergence for p(FCs) vs q(FCs)
BernP = 0.5 # hyperparameter
FCs = SigBandRepModel.get_layer('FCs').output
kl_Loss_FC = tf.math.log(FCs) - tf.math.log(BernP) + tf.math.log(1-FCs) - tf.math.log(1-BernP) 
kl_Loss_FC = tf.reduce_mean(-kl_Loss_FC )
kl_Loss_FC = Beta_Fc * tf.abs(kl_Loss_FC - Capacity_Fc)

SigBandRepModel.add_loss(kl_Loss_Z )
SigBandRepModel.add_metric(kl_Loss_Z , 'kl_Loss_Z')

SigBandRepModel.add_loss(kl_Loss_FC )
SigBandRepModel.add_metric(kl_Loss_FC , 'kl_Loss_FC')

## Model Compile
SigBandRepModel.compile(optimizer='adam') 

### Loss and KLD_Beta controller
KLD_Beta_Z = KLAnneal(TargetLossName=['val_FeatRecLoss', 'val_RecLoss'], Threshold=0.001, BetaName='Beta_Z',  MaxBeta=0.1 , MinBeta=0.1, AnnealEpoch=1, UnderLimit=1e-7, verbose=2)
KLD_Beta_Fc = KLAnneal(TargetLossName=['val_FeatRecLoss', 'val_RecLoss'], Threshold=0.001, BetaName='Beta_Fc',  MaxBeta=0.005 , MinBeta=0.005, AnnealEpoch=1, UnderLimit=1e-7, verbose=1)

RelLossDic = {'val_RecLoss':'Beta_Rec', 'val_FeatRecLoss':'Beta_Feat', 'val_kl_Loss_Z':'Beta_Z', 'val_kl_Loss_FC':'Beta_Fc'}
ScalingDic = {'val_RecLoss':100., 'val_FeatRecLoss':100., 'val_kl_Loss_Z':0.1, 'val_kl_Loss_FC':0.1}
MinLimit = {'Beta_Rec':1., 'Beta_Feat':1., 'Beta_Z':0.01, 'Beta_Fc':0.01}
MaxLimit = {'Beta_Rec':500., 'Beta_Feat':500., 'Beta_Z':0.1, 'Beta_Fc':0.05}
RelLoss = RelLossWeight(BetaList=RelLossDic, LossScaling= ScalingDic, MinLimit= MinLimit, MaxLimit = MaxLimit )

# %%
SigBandRepModel.load_weights(ModelSaveSameName)
ModelSave = ModelCheckpoint(filepath=ModelSaveSameName, monitor='val_FeatRecLoss', verbose=1, save_best_only=True )

SigBandRepModel.fit(DATA[:], batch_size=3500, epochs=700, shuffle=True, validation_split=0.2, callbacks=[EarlyStop, ModelSave, RelLoss])
# Out:
# Epoch 1/700
#  6/92 [>.............................] - ETA: 40s - loss: 36.6216 - RecLoss: 20.2146 - FeatRecLoss: 14.9286 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1372s vs `on_train_batch_end` time: 0.2812s). Check your callbacks.
# 92/92 [==============================] - 70s 543ms/step - loss: 20.3571 - RecLoss: 8.1631 - FeatRecLoss: 4.2127 - kl_Loss_Z: 0.0000e+00 - kl_Loss_FC: 0.0000e+00 - val_loss: 5.7645 - val_RecLoss: 4.3449 - val_FeatRecLoss: 1.4196 - val_kl_Loss_Z: 0.0000e+00 - val_kl_Loss_FC: 0.0000e+00
#
# Epoch 00001: val_FeatRecLoss improved from inf to 1.41960, saving model to ./Results\SigBandRepModel_ExtRec_2.hdf5
# Losses
# val_RecLoss: 0.0086898
# val_FeatRecLoss: 0.0028392
# val_kl_Loss_Z: 0.0000000
# val_kl_Loss_FC: 0.0000000
# RelWeights
# val_RecLoss: 8689764.9765015
# val_FeatRecLoss: 2839190.7215118
# val_kl_Loss_Z: 0.1000000
# val_kl_Loss_FC: 0.1000000
# Beta_Rec :  500.0
# Beta_Feat :  500.0
# Beta_Z :  0.1
# Beta_Fc :  0.05
# Epoch 2/700
# 92/92 [==============================] - 46s 498ms/step - loss: 5.6977 - RecLoss: 4.1410 - FeatRecLoss: 1.3434 - kl_Loss_Z: 0.0560 - kl_Loss_FC: 0.0025 - val_loss: 5.3232 - val_RecLoss: 4.0286 - val_FeatRecLoss: 1.2564 - val_kl_Loss_Z: 0.0342 - val_kl_Loss_FC: 0.0040
#
# Epoch 00002: val_FeatRecLoss improved from 1.41960 to 1.25640, saving model to ./Results\SigBandRepModel_ExtRec_2.hdf5
# Losses
# val_RecLoss: 0.0080571
# val_FeatRecLoss: 0.0025128
# val_kl_Loss_Z: 0.3416213
# val_kl_Loss_FC: 0.0809772
# RelWeights
# val_RecLoss: 320.6421039
# val_FeatRecLoss: 100.0000000
# val_kl_Loss_Z: 13.5952058
# val_kl_Loss_FC: 3.2225805
# Beta_Rec :  320.6421
# Beta_Feat :  100.0
# Beta_Z :  0.1
# Beta_Fc :  0.05
# Epoch 3/700
# 92/92 [==============================] - 46s 497ms/step - loss: 2.8300 - RecLoss: 2.5396 - FeatRecLoss: 0.2567 - kl_Loss_Z: 0.0070 - kl_Loss_FC: 0.0024 - val_loss: 2.7636 - val_RecLoss: 2.5045 - val_FeatRecLoss: 0.2547 - val_kl_Loss_Z: 0.0021 - val_kl_Loss_FC: 0.0023
#
# Epoch 00003: val_FeatRecLoss improved from 1.25640 to 0.25472, saving model to ./Results\SigBandRepModel_ExtRec_2.hdf5
# Losses
# val_RecLoss: 0.0078110
# val_FeatRecLoss: 0.0025472
# val_kl_Loss_Z: 0.0207462
# val_kl_Loss_FC: 0.0450650
# RelWeights
# val_RecLoss: 306.6469272
# val_FeatRecLoss: 100.0000000
# val_kl_Loss_Z: 0.8144608
# val_kl_Loss_FC: 1.7691768
# Beta_Rec :  306.64694
# Beta_Feat :  100.0
# Beta_Z :  0.1
# Beta_Fc :  0.05
# Epoch 4/700
# 92/92 [==============================] - 46s 505ms/step - loss: 2.6222 - RecLoss: 2.3343 - FeatRecLoss: 0.2497 - kl_Loss_Z: 8.7717e-04 - kl_Loss_FC: 0.0025 - val_loss: 2.5045 - val_RecLoss: 2.2539 - val_FeatRecLoss: 0.2469 - val_kl_Loss_Z: 6.4399e-04 - val_kl_Loss_FC: 0.0030
#
# Epoch 00004: val_FeatRecLoss improved from 0.25472 to 0.24688, saving model to ./Results\SigBandRepModel_ExtRec_2.hdf5
# Losses
# val_RecLoss: 0.0073502
# val_FeatRecLoss: 0.0024688
# val_kl_Loss_Z: 0.0064399
# val_kl_Loss_FC: 0.0606039
# RelWeights
# val_RecLoss: 297.7275164
# val_FeatRecLoss: 100.0000000
# val_kl_Loss_Z: 0.2608548
# val_kl_Loss_FC: 2.4548190
# Beta_Rec :  297.7275
# Beta_Feat :  100.0
# Beta_Z :  0.1
# Beta_Fc :  0.05
# Epoch 5/700
# 92/92 [==============================] - 46s 502ms/step - loss: 2.3835 - RecLoss: 2.0700 - FeatRecLoss: 0.2436 - kl_Loss_Z: 6.3989e-04 - kl_Loss_FC: 0.0038 - val_loss: 2.1902 - val_RecLoss: 1.9428 - val_FeatRecLoss: 0.2426 - val_kl_Loss_Z: 4.6434e-04 - val_kl_Loss_FC: 0.0043
#
# Epoch 00005: val_FeatRecLoss improved from 0.24688 to 0.24264, saving model to ./Results\SigBandRepModel_ExtRec_2.hdf5
# Losses
# val_RecLoss: 0.0065253
# val_FeatRecLoss: 0.0024264
# val_kl_Loss_Z: 0.0046434
# val_kl_Loss_FC: 0.0863516
# RelWeights
# val_RecLoss: 268.9265460
# val_FeatRecLoss: 100.0000000
# val_kl_Loss_Z: 0.1913658
# val_kl_Loss_FC: 3.5587751
# Beta_Rec :  268.92654
# Beta_Feat :  100.0
# Beta_Z :  0.1
# Beta_Fc :  0.05
# Epoch 6/700
# 92/92 [==============================] - 46s 497ms/step - loss: 1.9462 - RecLoss: 1.6573 - FeatRecLoss: 0.2408 - kl_Loss_Z: 5.8125e-04 - kl_Loss_FC: 0.0044 - val_loss: 1.8251 - val_RecLoss: 1.5800 - val_FeatRecLoss: 0.2402 - val_kl_Loss_Z: 4.5535e-04 - val_kl_Loss_FC: 0.0045
#
# Epoch 00006: val_FeatRecLoss improved from 0.24264 to 0.24015, saving model to ./Results\SigBandRepModel_ExtRec_2.hdf5
# Losses
# val_RecLoss: 0.0058753
# val_FeatRecLoss: 0.0024015
# val_kl_Loss_Z: 0.0045535
# val_kl_Loss_FC: 0.0896831
# RelWeights
# val_RecLoss: 244.6492015
# val_FeatRecLoss: 100.0000000
# val_kl_Loss_Z: 0.1896113
# val_kl_Loss_FC: 3.7344507
# Beta_Rec :  244.6492
# Beta_Feat :  100.0
# Beta_Z :  0.1
# Beta_Fc :  0.05
# Epoch 7/700
# 92/92 [==============================] - 46s 497ms/step - loss: 1.6530 - RecLoss: 1.3848 - FeatRecLoss: 0.2386 - kl_Loss_Z: 4.7346e-04 - kl_Loss_FC: 0.0049 - val_loss: 1.5731 - val_RecLoss: 1.3296 - val_FeatRecLoss: 0.2379 - val_kl_Loss_Z: 4.8035e-04 - val_kl_Loss_FC: 0.0052
#
# Epoch 00007: val_FeatRecLoss improved from 0.24015 to 0.23786, saving model to ./Results\SigBandRepModel_ExtRec_2.hdf5
# Losses
# val_RecLoss: 0.0054346
# val_FeatRecLoss: 0.0023786
# val_kl_Loss_Z: 0.0048035
# val_kl_Loss_FC: 0.1039964
# RelWeights
# val_RecLoss: 228.4764723
# val_FeatRecLoss: 100.0000000
# val_kl_Loss_Z: 0.2019410
# val_kl_Loss_FC: 4.3720819
# Beta_Rec :  228.47647
# Beta_Feat :  100.0
# Beta_Z :  0.1
# Beta_Fc :  0.05
# Epoch 8/700
# 92/92 [==============================] - 47s 506ms/step - loss: 1.4625 - RecLoss: 1.1970 - FeatRecLoss: 0.2365 - kl_Loss_Z: 5.3812e-04 - kl_Loss_FC: 0.0055 - val_loss: 1.3916 - val_RecLoss: 1.1489 - val_FeatRecLoss: 0.2363 - val_kl_Loss_Z: 4.5080e-04 - val_kl_Loss_FC: 0.0058
#
# Epoch 00008: val_FeatRecLoss improved from 0.23786 to 0.23635, saving model to ./Results\SigBandRepModel_ExtRec_2.hdf5
# Losses
# val_RecLoss: 0.0050286
# val_FeatRecLoss: 0.0023635
# val_kl_Loss_Z: 0.0045080
# val_kl_Loss_FC: 0.1169260
# RelWeights
# val_RecLoss: 212.7615509
# val_FeatRecLoss: 100.0000000
# val_kl_Loss_Z: 0.1907358
# val_kl_Loss_FC: 4.9471874
# Beta_Rec :  212.76155
# Beta_Feat :  100.0
# Beta_Z :  0.1
# Beta_Fc :  0.05
# Epoch 9/700
# 92/92 [==============================] - 47s 513ms/step - loss: 1.2912 - RecLoss: 1.0298 - FeatRecLoss: 0.2351 - kl_Loss_Z: 5.0244e-04 - kl_Loss_FC: 0.0060 - val_loss: 1.2303 - val_RecLoss: 0.9878 - val_FeatRecLoss: 0.2357 - val_kl_Loss_Z: 5.4757e-04 - val_kl_Loss_FC: 0.0062
#
# Epoch 00009: val_FeatRecLoss improved from 0.23635 to 0.23573, saving model to ./Results\SigBandRepModel_ExtRec_2.hdf5
# Losses
# val_RecLoss: 0.0046429
# val_FeatRecLoss: 0.0023573
# val_kl_Loss_Z: 0.0054757
# val_kl_Loss_FC: 0.1239312
# RelWeights
# val_RecLoss: 196.9640650
# val_FeatRecLoss: 100.0000000
# val_kl_Loss_Z: 0.2322926
# val_kl_Loss_FC: 5.2574323
# Beta_Rec :  196.96407
# Beta_Feat :  100.0
# Beta_Z :  0.1
# Beta_Fc :  0.05
# Epoch 10/700
# 92/92 [==============================] - 46s 498ms/step - loss: 1.1419 - RecLoss: 0.8850 - FeatRecLoss: 0.2343 - kl_Loss_Z: 4.3151e-04 - kl_Loss_FC: 0.0065 - val_loss: 1.0955 - val_RecLoss: 0.8542 - val_FeatRecLoss: 0.2339 - val_kl_Loss_Z: 7.1019e-04 - val_kl_Loss_FC: 0.0067
#
# Epoch 00010: val_FeatRecLoss improved from 0.23573 to 0.23390, saving model to ./Results\SigBandRepModel_ExtRec_2.hdf5
# Losses
# val_RecLoss: 0.0043369
# val_FeatRecLoss: 0.0023390
# val_kl_Loss_Z: 0.0071019
# val_kl_Loss_FC: 0.1345974
# RelWeights
# val_RecLoss: 185.4194446
# val_FeatRecLoss: 100.0000000
# val_kl_Loss_Z: 0.3036353
# val_kl_Loss_FC: 5.7545698
# Beta_Rec :  185.41945
# Beta_Feat :  100.0
# Beta_Z :  0.1
# Beta_Fc :  0.05
# Epoch 11/700
# 92/92 [==============================] - 46s 499ms/step - loss: 1.0314 - RecLoss: 0.7812 - FeatRecLoss: 0.2336 - kl_Loss_Z: 4.8619e-04 - kl_Loss_FC: 0.0070 - val_loss: 0.9964 - val_RecLoss: 0.7549 - val_FeatRecLoss: 0.2336 - val_kl_Loss_Z: 8.9816e-04 - val_kl_Loss_FC: 0.0070
#
# Epoch 00011: val_FeatRecLoss improved from 0.23390 to 0.23356, saving model to ./Results\SigBandRepModel_ExtRec_2.hdf5
# Losses
# val_RecLoss: 0.0040712
# val_FeatRecLoss: 0.0023356
# val_kl_Loss_Z: 0.0089816
# val_kl_Loss_FC: 0.1403004
# RelWeights
# val_RecLoss: 174.3128227
# val_FeatRecLoss: 100.0000000
# val_kl_Loss_Z: 0.3845529
# val_kl_Loss_FC: 6.0070523
# Beta_Rec :  174.31282
# Beta_Feat :  100.0
# Beta_Z :  0.1
# Beta_Fc :  0.05
# Epoch 12/700
# 92/92 [==============================] - 46s 501ms/step - loss: 0.9403 - RecLoss: 0.6889 - FeatRecLoss: 0.2329 - kl_Loss_Z: 5.0967e-04 - kl_Loss_FC: 0.0073 - val_loss: 0.9079 - val_RecLoss: 0.6665 - val_FeatRecLoss: 0.2331 - val_kl_Loss_Z: 8.0434e-04 - val_kl_Loss_FC: 0.0075
#
# Epoch 00012: val_FeatRecLoss improved from 0.23356 to 0.23308, saving model to ./Results\SigBandRepModel_ExtRec_2.hdf5
# Losses
# val_RecLoss: 0.0038238
# val_FeatRecLoss: 0.0023308
# val_kl_Loss_Z: 0.0080434
# val_kl_Loss_FC: 0.1496717
# RelWeights
# val_RecLoss: 164.0538862
# val_FeatRecLoss: 100.0000000
# val_kl_Loss_Z: 0.3450843
# val_kl_Loss_FC: 6.4213396
# Beta_Rec :  164.05388
# Beta_Feat :  100.0
# Beta_Z :  0.1
# Beta_Fc :  0.05
# Epoch 13/700
# 92/92 [==============================] - 46s 496ms/step - loss: 0.8607 - RecLoss: 0.6109 - FeatRecLoss: 0.2325 - kl_Loss_Z: 5.1622e-04 - kl_Loss_FC: 0.0076 - val_loss: 0.8329 - val_RecLoss: 0.5919 - val_FeatRecLoss: 0.2333 - val_kl_Loss_Z: 3.3617e-04 - val_kl_Loss_FC: 0.0074
#
# Epoch 00013: val_FeatRecLoss did not improve from 0.23308
# Losses
# val_RecLoss: 0.0036082
# val_FeatRecLoss: 0.0023329
# val_kl_Loss_Z: 0.0033617
# val_kl_Loss_FC: 0.1473116
# RelWeights
# val_RecLoss: 154.6617444
# val_FeatRecLoss: 100.0000000
# val_kl_Loss_Z: 0.1440990
# val_kl_Loss_FC: 6.3144338
# Beta_Rec :  154.66174
# Beta_Feat :  100.0
# Beta_Z :  0.1
# Beta_Fc :  0.05
# Epoch 14/700
# 92/92 [==============================] - 46s 496ms/step - loss: 0.7926 - RecLoss: 0.5470 - FeatRecLoss: 0.2314 - kl_Loss_Z: 4.1422e-04 - kl_Loss_FC: 0.0082 - val_loss: 0.7747 - val_RecLoss: 0.5334 - val_FeatRecLoss: 0.2326 - val_kl_Loss_Z: 3.0760e-04 - val_kl_Loss_FC: 0.0084
#
# Epoch 00014: val_FeatRecLoss improved from 0.23308 to 0.23257, saving model to ./Results\SigBandRepModel_ExtRec_2.hdf5
# Losses
# val_RecLoss: 0.0034488
# val_FeatRecLoss: 0.0023257
# val_kl_Loss_Z: 0.0030760
# val_kl_Loss_FC: 0.1684238
# RelWeights
# val_RecLoss: 148.2890088
# val_FeatRecLoss: 100.0000000
# val_kl_Loss_Z: 0.1322587
# val_kl_Loss_FC: 7.2418106
# Beta_Rec :  148.289
# Beta_Feat :  100.0
# Beta_Z :  0.1
# Beta_Fc :  0.05
# Epoch 15/700
# 92/92 [==============================] - 46s 496ms/step - loss: 0.7454 - RecLoss: 0.5019 - FeatRecLoss: 0.2312 - kl_Loss_Z: 4.5691e-04 - kl_Loss_FC: 0.0083 - val_loss: 0.7308 - val_RecLoss: 0.4909 - val_FeatRecLoss: 0.2310 - val_kl_Loss_Z: 4.0830e-04 - val_kl_Loss_FC: 0.0085
#
# Epoch 00015: val_FeatRecLoss improved from 0.23257 to 0.23100, saving model to ./Results\SigBandRepModel_ExtRec_2.hdf5
# Losses
# val_RecLoss: 0.0033107
# val_FeatRecLoss: 0.0023100
# val_kl_Loss_Z: 0.0040830
# val_kl_Loss_FC: 0.1695548
# RelWeights
# val_RecLoss: 143.3214695
# val_FeatRecLoss: 100.0000000
# val_kl_Loss_Z: 0.1767551
# val_kl_Loss_FC: 7.3400985
# Beta_Rec :  143.32147
# Beta_Feat :  100.0
# Beta_Z :  0.1
# Beta_Fc :  0.05
# Epoch 16/700
# 92/92 [==============================] - 46s 501ms/step - loss: 0.7091 - RecLoss: 0.4658 - FeatRecLoss: 0.2305 - kl_Loss_Z: 4.5461e-04 - kl_Loss_FC: 0.0086 - val_loss: 0.6976 - val_RecLoss: 0.4574 - val_FeatRecLoss: 0.2314 - val_kl_Loss_Z: 4.8557e-04 - val_kl_Loss_FC: 0.0083
#
# Epoch 00016: val_FeatRecLoss did not improve from 0.23100
# Losses
# val_RecLoss: 0.0031915
# val_FeatRecLoss: 0.0023143
# val_kl_Loss_Z: 0.0048557
# val_kl_Loss_FC: 0.1653499
# RelWeights
# val_RecLoss: 137.9037110
# val_FeatRecLoss: 100.0000000
# val_kl_Loss_Z: 0.2098104
# val_kl_Loss_FC: 7.1446538
# Beta_Rec :  137.90372
# Beta_Feat :  100.0
# Beta_Z :  0.1
# Beta_Fc :  0.05
# Epoch 17/700
# 92/92 [==============================] - 46s 506ms/step - loss: 0.6752 - RecLoss: 0.4315 - FeatRecLoss: 0.2302 - kl_Loss_Z: 4.2939e-04 - kl_Loss_FC: 0.0088 - val_loss: 0.6625 - val_RecLoss: 0.4222 - val_FeatRecLoss: 0.2304 - val_kl_Loss_Z: 6.5894e-04 - val_kl_Loss_FC: 0.0092
#
# Epoch 00017: val_FeatRecLoss improved from 0.23100 to 0.23039, saving model to ./Results\SigBandRepModel_ExtRec_2.hdf5
# Losses
# val_RecLoss: 0.0030614
# val_FeatRecLoss: 0.0023039
# val_kl_Loss_Z: 0.0065894
# val_kl_Loss_FC: 0.1848674
# RelWeights
# val_RecLoss: 132.8767335
# val_FeatRecLoss: 100.0000000
# val_kl_Loss_Z: 0.2860081
# val_kl_Loss_FC: 8.0240676
# Beta_Rec :  132.87674
# Beta_Feat :  100.0
# Beta_Z :  0.1
# Beta_Fc :  0.05
# Epoch 18/700
# 92/92 [==============================] - 46s 504ms/step - loss: 0.6435 - RecLoss: 0.4009 - FeatRecLoss: 0.2299 - kl_Loss_Z: 4.5297e-04 - kl_Loss_FC: 0.0090 - val_loss: 0.6323 - val_RecLoss: 0.3924 - val_FeatRecLoss: 0.2302 - val_kl_Loss_Z: 4.5782e-04 - val_kl_Loss_FC: 0.0092
#
# Epoch 00018: val_FeatRecLoss improved from 0.23039 to 0.23022, saving model to ./Results\SigBandRepModel_ExtRec_2.hdf5
# Losses
# val_RecLoss: 0.0029533
# val_FeatRecLoss: 0.0023022
# val_kl_Loss_Z: 0.0045782
# val_kl_Loss_FC: 0.1844485
# RelWeights
# val_RecLoss: 128.2843540
# val_FeatRecLoss: 100.0000000
# val_kl_Loss_Z: 0.1988648
# val_kl_Loss_FC: 8.0120078
# Beta_Rec :  128.28435
# Beta_Feat :  100.0
# Beta_Z :  0.1
# Beta_Fc :  0.05
# Epoch 19/700
# 92/92 [==============================] - 46s 504ms/step - loss: 0.6155 - RecLoss: 0.3735 - FeatRecLoss: 0.2296 - kl_Loss_Z: 4.8342e-04 - kl_Loss_FC: 0.0093 - val_loss: 0.6066 - val_RecLoss: 0.3668 - val_FeatRecLoss: 0.2296 - val_kl_Loss_Z: 5.7144e-04 - val_kl_Loss_FC: 0.0096
#
# Epoch 00019: val_FeatRecLoss improved from 0.23022 to 0.22960, saving model to ./Results\SigBandRepModel_ExtRec_2.hdf5
# Losses
# val_RecLoss: 0.0028593
# val_FeatRecLoss: 0.0022960
# val_kl_Loss_Z: 0.0057144
# val_kl_Loss_FC: 0.1925688
# RelWeights
# val_RecLoss: 124.5348908
# val_FeatRecLoss: 100.0000000
# val_kl_Loss_Z: 0.2488819
# val_kl_Loss_FC: 8.3870658
# Beta_Rec :  124.53489
# Beta_Feat :  100.0
# Beta_Z :  0.1
# Beta_Fc :  0.05
# Epoch 20/700
# 92/92 [==============================] - 46s 497ms/step - loss: 0.5946 - RecLoss: 0.3515 - FeatRecLoss: 0.2293 - kl_Loss_Z: 4.4407e-04 - kl_Loss_FC: 0.0094 - val_loss: 0.5857 - val_RecLoss: 0.3463 - val_FeatRecLoss: 0.2295 - val_kl_Loss_Z: 2.4639e-04 - val_kl_Loss_FC: 0.0098
#
# Epoch 00020: val_FeatRecLoss improved from 0.22960 to 0.22947, saving model to ./Results\SigBandRepModel_ExtRec_2.hdf5
# Losses
# val_RecLoss: 0.0027805
# val_FeatRecLoss: 0.0022947
# val_kl_Loss_Z: 0.0024639
# val_kl_Loss_FC: 0.1952796
# RelWeights
# val_RecLoss: 121.1709434
# val_FeatRecLoss: 100.0000000
# val_kl_Loss_Z: 0.1073765
# val_kl_Loss_FC: 8.5101298
# Beta_Rec :  121.170944
# Beta_Feat :  100.0
# Beta_Z :  0.1
# Beta_Fc :  0.05
# Epoch 21/700
# 92/92 [==============================] - 46s 498ms/step - loss: 0.5737 - RecLoss: 0.3325 - FeatRecLoss: 0.2284 - kl_Loss_Z: 4.2203e-04 - kl_Loss_FC: 0.0096 - val_loss: 0.5661 - val_RecLoss: 0.3268 - val_FeatRecLoss: 0.2292 - val_kl_Loss_Z: 6.5148e-04 - val_kl_Loss_FC: 0.0095
#
# Epoch 00021: val_FeatRecLoss improved from 0.22947 to 0.22916, saving model to ./Results\SigBandRepModel_ExtRec_2.hdf5
# Losses
# val_RecLoss: 0.0026973
# val_FeatRecLoss: 0.0022916
# val_kl_Loss_Z: 0.0065148
# val_kl_Loss_FC: 0.1899249
# RelWeights
# val_RecLoss: 117.7031390
# val_FeatRecLoss: 100.0000000
# val_kl_Loss_Z: 0.2842906
# val_kl_Loss_FC: 8.2879278
# Beta_Rec :  117.70314
# Beta_Feat :  100.0
# Beta_Z :  0.1
# Beta_Fc :  0.05
# Epoch 22/700
# 92/92 [==============================] - 46s 498ms/step - loss: 0.5547 - RecLoss: 0.3145 - FeatRecLoss: 0.2285 - kl_Loss_Z: 4.3460e-04 - kl_Loss_FC: 0.0098 - val_loss: 0.5493 - val_RecLoss: 0.3103 - val_FeatRecLoss: 0.2288 - val_kl_Loss_Z: 2.4471e-04 - val_kl_Loss_FC: 0.0100
#
# Epoch 00022: val_FeatRecLoss improved from 0.22916 to 0.22876, saving model to ./Results\SigBandRepModel_ExtRec_2.hdf5
# Losses
# val_RecLoss: 0.0026364
# val_FeatRecLoss: 0.0022876
# val_kl_Loss_Z: 0.0024471
# val_kl_Loss_FC: 0.2006258
# RelWeights
# val_RecLoss: 115.2474522
# val_FeatRecLoss: 100.0000000
# val_kl_Loss_Z: 0.1069714
# val_kl_Loss_FC: 8.7701608
# Beta_Rec :  115.24745
# Beta_Feat :  100.0
# Beta_Z :  0.1
# Beta_Fc :  0.05
# Epoch 23/700
# 92/92 [==============================] - 46s 500ms/step - loss: 0.5415 - RecLoss: 0.3005 - FeatRecLoss: 0.2281 - kl_Loss_Z: 3.8742e-04 - kl_Loss_FC: 0.0100 - val_loss: 0.5370 - val_RecLoss: 0.2975 - val_FeatRecLoss: 0.2279 - val_kl_Loss_Z: 0.0012 - val_kl_Loss_FC: 0.0104
#
# Epoch 00023: val_FeatRecLoss improved from 0.22876 to 0.22789, saving model to ./Results\SigBandRepModel_ExtRec_2.hdf5
# Losses
# val_RecLoss: 0.0025815
# val_FeatRecLoss: 0.0022789
# val_kl_Loss_Z: 0.0117842
# val_kl_Loss_FC: 0.2086871
# RelWeights
# val_RecLoss: 113.2809351
# val_FeatRecLoss: 100.0000000
# val_kl_Loss_Z: 0.5171063
# val_kl_Loss_FC: 9.1574500
# Beta_Rec :  113.28094
# Beta_Feat :  100.0
# Beta_Z :  0.1
# Beta_Fc :  0.05
# Epoch 24/700
# 92/92 [==============================] - 46s 504ms/step - loss: 0.5289 - RecLoss: 0.2892 - FeatRecLoss: 0.2279 - kl_Loss_Z: 4.9271e-04 - kl_Loss_FC: 0.0099 - val_loss: 0.5251 - val_RecLoss: 0.2858 - val_FeatRecLoss: 0.2288 - val_kl_Loss_Z: 2.4866e-04 - val_kl_Loss_FC: 0.0102
#
# Epoch 00024: val_FeatRecLoss did not improve from 0.22789
# Losses
# val_RecLoss: 0.0025233
# val_FeatRecLoss: 0.0022883
# val_kl_Loss_Z: 0.0024866
# val_kl_Loss_FC: 0.2034944
# RelWeights
# val_RecLoss: 110.2735282
# val_FeatRecLoss: 100.0000000
# val_kl_Loss_Z: 0.1086674
# val_kl_Loss_FC: 8.8929964
# Beta_Rec :  110.27353
# Beta_Feat :  100.0
# Beta_Z :  0.1
# Beta_Fc :  0.05
# Epoch 25/700
# 92/92 [==============================] - 46s 504ms/step - loss: 0.5159 - RecLoss: 0.2753 - FeatRecLoss: 0.2278 - kl_Loss_Z: 4.5617e-04 - kl_Loss_FC: 0.0099 - val_loss: 0.5112 - val_RecLoss: 0.2716 - val_FeatRecLoss: 0.2290 - val_kl_Loss_Z: 2.7261e-04 - val_kl_Loss_FC: 0.0103
#
# Epoch 00025: val_FeatRecLoss did not improve from 0.22789
# Losses
# val_RecLoss: 0.0024630
# val_FeatRecLoss: 0.0022899
# val_kl_Loss_Z: 0.0027261
# val_kl_Loss_FC: 0.2065118
# RelWeights
# val_RecLoss: 107.5553925
# val_FeatRecLoss: 100.0000000
# val_kl_Loss_Z: 0.1190479
# val_kl_Loss_FC: 9.0182313
# Beta_Rec :  107.55539
# Beta_Feat :  100.0
# Beta_Z :  0.1
# Beta_Fc :  0.05
# Epoch 26/700
# 92/92 [==============================] - 46s 497ms/step - loss: 0.5013 - RecLoss: 0.2629 - FeatRecLoss: 0.2269 - kl_Loss_Z: 4.6954e-04 - kl_Loss_FC: 0.0102 - val_loss: 0.4988 - val_RecLoss: 0.2603 - val_FeatRecLoss: 0.2262 - val_kl_Loss_Z: 0.0013 - val_kl_Loss_FC: 0.0110
#
# Epoch 00026: val_FeatRecLoss improved from 0.22789 to 0.22623, saving model to ./Results\SigBandRepModel_ExtRec_2.hdf5
# Losses
# val_RecLoss: 0.0024200
# val_FeatRecLoss: 0.0022623
# val_kl_Loss_Z: 0.0126604
# val_kl_Loss_FC: 0.2206490
# RelWeights
# val_RecLoss: 106.9704712
# val_FeatRecLoss: 100.0000000
# val_kl_Loss_Z: 0.5596264
# val_kl_Loss_FC: 9.7533175
# Beta_Rec :  106.970474
# Beta_Feat :  100.0
# Beta_Z :  0.1
# Beta_Fc :  0.05
# Epoch 27/700
# 92/92 [==============================] - 46s 497ms/step - loss: 0.4961 - RecLoss: 0.2570 - FeatRecLoss: 0.2264 - kl_Loss_Z: 4.7450e-04 - kl_Loss_FC: 0.0105 - val_loss: 0.4916 - val_RecLoss: 0.2539 - val_FeatRecLoss: 0.2259 - val_kl_Loss_Z: 6.9736e-04 - val_kl_Loss_FC: 0.0110
#
# Epoch 00027: val_FeatRecLoss improved from 0.22623 to 0.22594, saving model to ./Results\SigBandRepModel_ExtRec_2.hdf5
# Losses
# val_RecLoss: 0.0023740
# val_FeatRecLoss: 0.0022594
# val_kl_Loss_Z: 0.0069736
# val_kl_Loss_FC: 0.2200760
# RelWeights
# val_RecLoss: 105.0737854
# val_FeatRecLoss: 100.0000000
# val_kl_Loss_Z: 0.3086517
# val_kl_Loss_FC: 9.7406014
# Beta_Rec :  105.073784
# Beta_Feat :  100.0
# Beta_Z :  0.1
# Beta_Fc :  0.05
# Epoch 28/700
# 92/92 [==============================] - 46s 498ms/step - loss: 0.4863 - RecLoss: 0.2475 - FeatRecLoss: 0.2260 - kl_Loss_Z: 4.6878e-04 - kl_Loss_FC: 0.0105 - val_loss: 0.4822 - val_RecLoss: 0.2450 - val_FeatRecLoss: 0.2266 - val_kl_Loss_Z: 3.7137e-04 - val_kl_Loss_FC: 0.0102
#
# Epoch 00028: val_FeatRecLoss did not improve from 0.22594
# Losses
# val_RecLoss: 0.0023318
# val_FeatRecLoss: 0.0022657
# val_kl_Loss_Z: 0.0037137
# val_kl_Loss_FC: 0.2047681
# RelWeights
# val_RecLoss: 102.9166504
# val_FeatRecLoss: 100.0000000
# val_kl_Loss_Z: 0.1639110
# val_kl_Loss_FC: 9.0378356
# Beta_Rec :  102.91665
# Beta_Feat :  100.0
# Beta_Z :  0.1
# Beta_Fc :  0.05
# Epoch 29/700
# 92/92 [==============================] - 46s 497ms/step - loss: 0.4758 - RecLoss: 0.2386 - FeatRecLoss: 0.2253 - kl_Loss_Z: 4.4524e-04 - kl_Loss_FC: 0.0107 - val_loss: 0.4733 - val_RecLoss: 0.2368 - val_FeatRecLoss: 0.2254 - val_kl_Loss_Z: 4.1403e-04 - val_kl_Loss_FC: 0.0107
#
# Epoch 00029: val_FeatRecLoss improved from 0.22594 to 0.22543, saving model to ./Results\SigBandRepModel_ExtRec_2.hdf5
# Losses
# val_RecLoss: 0.0023006
# val_FeatRecLoss: 0.0022543
# val_kl_Loss_Z: 0.0041403
# val_kl_Loss_FC: 0.2138251
# RelWeights
# val_RecLoss: 102.0548464
# val_FeatRecLoss: 100.0000000
# val_kl_Loss_Z: 0.1836602
# val_kl_Loss_FC: 9.4851502
# Beta_Rec :  102.05485
# Beta_Feat :  100.0
# Beta_Z :  0.1
# Beta_Fc :  0.05
# Epoch 30/700
# 92/92 [==============================] - 46s 496ms/step - loss: 0.4698 - RecLoss: 0.2329 - FeatRecLoss: 0.2245 - kl_Loss_Z: 4.3716e-04 - kl_Loss_FC: 0.0110 - val_loss: 0.4671 - val_RecLoss: 0.2304 - val_FeatRecLoss: 0.2259 - val_kl_Loss_Z: 2.3185e-04 - val_kl_Loss_FC: 0.0105
#
# Epoch 00030: val_FeatRecLoss did not improve from 0.22543
# Losses
# val_RecLoss: 0.0022579
# val_FeatRecLoss: 0.0022588
# val_kl_Loss_Z: 0.0023185
# val_kl_Loss_FC: 0.2107681
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 100.0391048
# val_kl_Loss_Z: 0.1026841
# val_kl_Loss_FC: 9.3346867
# Beta_Rec :  100.0
# Beta_Feat :  100.03911
# Beta_Z :  0.1
# Beta_Fc :  0.05
# Epoch 31/700
# 92/92 [==============================] - 46s 497ms/step - loss: 0.4603 - RecLoss: 0.2245 - FeatRecLoss: 0.2242 - kl_Loss_Z: 4.6202e-04 - kl_Loss_FC: 0.0110 - val_loss: 0.4587 - val_RecLoss: 0.2228 - val_FeatRecLoss: 0.2238 - val_kl_Loss_Z: 2.3858e-04 - val_kl_Loss_FC: 0.0119
#
# Epoch 00031: val_FeatRecLoss improved from 0.22543 to 0.22379, saving model to ./Results\SigBandRepModel_ExtRec_2.hdf5
# Losses
# val_RecLoss: 0.0022279
# val_FeatRecLoss: 0.0022370
# val_kl_Loss_Z: 0.0023858
# val_kl_Loss_FC: 0.2385038
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 100.4076998
# val_kl_Loss_Z: 0.1070873
# val_kl_Loss_FC: 10.7051473
# Beta_Rec :  100.0
# Beta_Feat :  100.4077
# Beta_Z :  0.1
# Beta_Fc :  0.05
# Epoch 32/700
# 92/92 [==============================] - 46s 496ms/step - loss: 0.4581 - RecLoss: 0.2218 - FeatRecLoss: 0.2241 - kl_Loss_Z: 4.7639e-04 - kl_Loss_FC: 0.0113 - val_loss: 0.4549 - val_RecLoss: 0.2189 - val_FeatRecLoss: 0.2245 - val_kl_Loss_Z: 4.6509e-04 - val_kl_Loss_FC: 0.0110
#
# Epoch 00032: val_FeatRecLoss did not improve from 0.22379
# Losses
# val_RecLoss: 0.0021886
# val_FeatRecLoss: 0.0022361
# val_kl_Loss_Z: 0.0046509
# val_kl_Loss_FC: 0.2209504
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 102.1706926
# val_kl_Loss_Z: 0.2125030
# val_kl_Loss_FC: 10.0954024
# Beta_Rec :  100.0
# Beta_Feat :  102.17069
# Beta_Z :  0.1
# Beta_Fc :  0.05
# Epoch 33/700
# 92/92 [==============================] - 46s 496ms/step - loss: 0.4585 - RecLoss: 0.2176 - FeatRecLoss: 0.2277 - kl_Loss_Z: 4.2051e-04 - kl_Loss_FC: 0.0113 - val_loss: 0.4557 - val_RecLoss: 0.2158 - val_FeatRecLoss: 0.2284 - val_kl_Loss_Z: 2.2667e-04 - val_kl_Loss_FC: 0.0113
#
# Epoch 00033: val_FeatRecLoss did not improve from 0.22379
# Losses
# val_RecLoss: 0.0021584
# val_FeatRecLoss: 0.0022355
# val_kl_Loss_Z: 0.0022667
# val_kl_Loss_FC: 0.2250529
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 103.5690625
# val_kl_Loss_Z: 0.1050191
# val_kl_Loss_FC: 10.4267589
# Beta_Rec :  100.0
# Beta_Feat :  103.56906
# Beta_Z :  0.1
# Beta_Fc :  0.05
# Epoch 34/700
# 92/92 [==============================] - 46s 496ms/step - loss: 0.4589 - RecLoss: 0.2147 - FeatRecLoss: 0.2306 - kl_Loss_Z: 5.1714e-04 - kl_Loss_FC: 0.0116 - val_loss: 0.4577 - val_RecLoss: 0.2138 - val_FeatRecLoss: 0.2326 - val_kl_Loss_Z: 4.2765e-04 - val_kl_Loss_FC: 0.0109
#
# Epoch 00034: val_FeatRecLoss did not improve from 0.22379
# Losses
# val_RecLoss: 0.0021380
# val_FeatRecLoss: 0.0022456
# val_kl_Loss_Z: 0.0042765
# val_kl_Loss_FC: 0.2185932
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 105.0307401
# val_kl_Loss_Z: 0.2000221
# val_kl_Loss_FC: 10.2241875
# Beta_Rec :  100.0
# Beta_Feat :  105.03074
# Beta_Z :  0.1
# Beta_Fc :  0.05
# Epoch 35/700
# 92/92 [==============================] - 46s 496ms/step - loss: 0.4573 - RecLoss: 0.2111 - FeatRecLoss: 0.2328 - kl_Loss_Z: 4.3532e-04 - kl_Loss_FC: 0.0120 - val_loss: 0.4552 - val_RecLoss: 0.2094 - val_FeatRecLoss: 0.2342 - val_kl_Loss_Z: 3.0362e-04 - val_kl_Loss_FC: 0.0114
#
# Epoch 00035: val_FeatRecLoss did not improve from 0.22379
# Losses
# val_RecLoss: 0.0020936
# val_FeatRecLoss: 0.0022295
# val_kl_Loss_Z: 0.0030362
# val_kl_Loss_FC: 0.2281745
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 106.4929518
# val_kl_Loss_Z: 0.1450280
# val_kl_Loss_FC: 10.8989207
# Beta_Rec :  100.0
# Beta_Feat :  106.49295
# Beta_Z :  0.1
# Beta_Fc :  0.05
# Epoch 36/700
# 92/92 [==============================] - 46s 496ms/step - loss: 0.4570 - RecLoss: 0.2086 - FeatRecLoss: 0.2351 - kl_Loss_Z: 4.0913e-04 - kl_Loss_FC: 0.0125 - val_loss: 0.4558 - val_RecLoss: 0.2064 - val_FeatRecLoss: 0.2362 - val_kl_Loss_Z: 3.7608e-04 - val_kl_Loss_FC: 0.0127
#
# Epoch 00036: val_FeatRecLoss did not improve from 0.22379
# Losses
# val_RecLoss: 0.0020644
# val_FeatRecLoss: 0.0022183
# val_kl_Loss_Z: 0.0037608
# val_kl_Loss_FC: 0.2540588
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 107.4591462
# val_kl_Loss_Z: 0.1821784
# val_kl_Loss_FC: 12.3069512
# Beta_Rec :  100.0
# Beta_Feat :  107.459145
# Beta_Z :  0.1
# Beta_Fc :  0.05
# Epoch 37/700
# 92/92 [==============================] - 46s 497ms/step - loss: 0.4551 - RecLoss: 0.2058 - FeatRecLoss: 0.2367 - kl_Loss_Z: 4.2693e-04 - kl_Loss_FC: 0.0126 - val_loss: 0.4550 - val_RecLoss: 0.2050 - val_FeatRecLoss: 0.2356 - val_kl_Loss_Z: 7.3786e-04 - val_kl_Loss_FC: 0.0136
#
# Epoch 00037: val_FeatRecLoss did not improve from 0.22379
# Losses
# val_RecLoss: 0.0020501
# val_FeatRecLoss: 0.0021927
# val_kl_Loss_Z: 0.0073786
# val_kl_Loss_FC: 0.2726395
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 106.9543252
# val_kl_Loss_Z: 0.3599156
# val_kl_Loss_FC: 13.2988577
# Beta_Rec :  100.0
# Beta_Feat :  106.95432
# Beta_Z :  0.1
# Beta_Fc :  0.05
# Epoch 38/700
# 92/92 [==============================] - 46s 497ms/step - loss: 0.4522 - RecLoss: 0.2030 - FeatRecLoss: 0.2353 - kl_Loss_Z: 4.8993e-04 - kl_Loss_FC: 0.0125 - val_loss: 0.4508 - val_RecLoss: 0.2019 - val_FeatRecLoss: 0.2344 - val_kl_Loss_Z: 2.5443e-04 - val_kl_Loss_FC: 0.0143
#
# Epoch 00038: val_FeatRecLoss did not improve from 0.22379
# Losses
# val_RecLoss: 0.0020187
# val_FeatRecLoss: 0.0021913
# val_kl_Loss_Z: 0.0025443
# val_kl_Loss_FC: 0.2865595
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 108.5518649
# val_kl_Loss_Z: 0.1260378
# val_kl_Loss_FC: 14.1951814
# Beta_Rec :  100.0
# Beta_Feat :  108.551865
# Beta_Z :  0.1
# Beta_Fc :  0.05
# Epoch 39/700
# 92/92 [==============================] - 46s 496ms/step - loss: 0.4527 - RecLoss: 0.2005 - FeatRecLoss: 0.2383 - kl_Loss_Z: 5.3420e-04 - kl_Loss_FC: 0.0128 - val_loss: 0.4513 - val_RecLoss: 0.1999 - val_FeatRecLoss: 0.2378 - val_kl_Loss_Z: 2.6056e-04 - val_kl_Loss_FC: 0.0135
#
# Epoch 00039: val_FeatRecLoss did not improve from 0.22379
# Losses
# val_RecLoss: 0.0019985
# val_FeatRecLoss: 0.0021902
# val_kl_Loss_Z: 0.0026056
# val_kl_Loss_FC: 0.2693035
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 109.5913805
# val_kl_Loss_Z: 0.1303747
# val_kl_Loss_FC: 13.4751344
# Beta_Rec :  100.0
# Beta_Feat :  109.59138
# Beta_Z :  0.1
# Beta_Fc :  0.05
# Epoch 40/700
# 92/92 [==============================] - 46s 497ms/step - loss: 0.4516 - RecLoss: 0.1981 - FeatRecLoss: 0.2396 - kl_Loss_Z: 4.2022e-04 - kl_Loss_FC: 0.0132 - val_loss: 0.4507 - val_RecLoss: 0.1970 - val_FeatRecLoss: 0.2393 - val_kl_Loss_Z: 4.2406e-04 - val_kl_Loss_FC: 0.0140
#
# Epoch 00040: val_FeatRecLoss did not improve from 0.22379
# Losses
# val_RecLoss: 0.0019699
# val_FeatRecLoss: 0.0021839
# val_kl_Loss_Z: 0.0042406
# val_kl_Loss_FC: 0.2790702
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 110.8667912
# val_kl_Loss_Z: 0.2152756
# val_kl_Loss_FC: 14.1669651
# Beta_Rec :  100.0
# Beta_Feat :  110.86679
# Beta_Z :  0.1
# Beta_Fc :  0.05
# Epoch 41/700
# 92/92 [==============================] - 46s 496ms/step - loss: 0.4523 - RecLoss: 0.1956 - FeatRecLoss: 0.2422 - kl_Loss_Z: 4.8905e-04 - kl_Loss_FC: 0.0133 - val_loss: 0.4500 - val_RecLoss: 0.1938 - val_FeatRecLoss: 0.2418 - val_kl_Loss_Z: 8.4590e-04 - val_kl_Loss_FC: 0.0135
#
# Epoch 00041: val_FeatRecLoss did not improve from 0.22379
# Losses
# val_RecLoss: 0.0019384
# val_FeatRecLoss: 0.0021808
# val_kl_Loss_Z: 0.0084590
# val_kl_Loss_FC: 0.2702795
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 112.5016359
# val_kl_Loss_Z: 0.4363854
# val_kl_Loss_FC: 13.9432163
# Beta_Rec :  100.0
# Beta_Feat :  112.50163
# Beta_Z :  0.1
# Beta_Fc :  0.05
# Epoch 42/700
# 92/92 [==============================] - 46s 497ms/step - loss: 0.4535 - RecLoss: 0.1935 - FeatRecLoss: 0.2452 - kl_Loss_Z: 4.4890e-04 - kl_Loss_FC: 0.0137 - val_loss: 0.4521 - val_RecLoss: 0.1921 - val_FeatRecLoss: 0.2462 - val_kl_Loss_Z: 6.9297e-04 - val_kl_Loss_FC: 0.0131
#
# Epoch 00042: val_FeatRecLoss did not improve from 0.22379
# Losses
# val_RecLoss: 0.0019212
# val_FeatRecLoss: 0.0021887
# val_kl_Loss_Z: 0.0069297
# val_kl_Loss_FC: 0.2611236
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 113.9230434
# val_kl_Loss_Z: 0.3606888
# val_kl_Loss_FC: 13.5914453
# Beta_Rec :  100.0
# Beta_Feat :  113.92304
# Beta_Z :  0.1
# Beta_Fc :  0.05
# Epoch 43/700
# 92/92 [==============================] - 46s 497ms/step - loss: 0.4545 - RecLoss: 0.1913 - FeatRecLoss: 0.2477 - kl_Loss_Z: 3.9447e-04 - kl_Loss_FC: 0.0139 - val_loss: 0.4530 - val_RecLoss: 0.1902 - val_FeatRecLoss: 0.2486 - val_kl_Loss_Z: 8.3742e-04 - val_kl_Loss_FC: 0.0135
#
# Epoch 00043: val_FeatRecLoss did not improve from 0.22379
# Losses
# val_RecLoss: 0.0019017
# val_FeatRecLoss: 0.0021818
# val_kl_Loss_Z: 0.0083742
# val_kl_Loss_FC: 0.2690683
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 114.7297401
# val_kl_Loss_Z: 0.4403601
# val_kl_Loss_FC: 14.1490820
# Beta_Rec :  100.0
# Beta_Feat :  114.72974
# Beta_Z :  0.1
# Beta_Fc :  0.05
# Epoch 44/700
# 92/92 [==============================] - 46s 497ms/step - loss: 0.4537 - RecLoss: 0.1892 - FeatRecLoss: 0.2491 - kl_Loss_Z: 5.5735e-04 - kl_Loss_FC: 0.0141 - val_loss: 0.4539 - val_RecLoss: 0.1896 - val_FeatRecLoss: 0.2503 - val_kl_Loss_Z: 2.1726e-04 - val_kl_Loss_FC: 0.0138
#
# Epoch 00044: val_FeatRecLoss did not improve from 0.22379
# Losses
# val_RecLoss: 0.0018958
# val_FeatRecLoss: 0.0021819
# val_kl_Loss_Z: 0.0021726
# val_kl_Loss_FC: 0.2755240
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 115.0905095
# val_kl_Loss_Z: 0.1146029
# val_kl_Loss_FC: 14.5333725
# Beta_Rec :  100.0
# Beta_Feat :  115.09051
# Beta_Z :  0.1
# Beta_Fc :  0.05
# Epoch 45/700
# 92/92 [==============================] - 46s 496ms/step - loss: 0.4524 - RecLoss: 0.1874 - FeatRecLoss: 0.2497 - kl_Loss_Z: 3.9556e-04 - kl_Loss_FC: 0.0142 - val_loss: 0.4513 - val_RecLoss: 0.1862 - val_FeatRecLoss: 0.2493 - val_kl_Loss_Z: 1.8970e-04 - val_kl_Loss_FC: 0.0156
#
# Epoch 00045: val_FeatRecLoss did not improve from 0.22379
# Losses
# val_RecLoss: 0.0018619
# val_FeatRecLoss: 0.0021659
# val_kl_Loss_Z: 0.0018970
# val_kl_Loss_FC: 0.3123289
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 116.3300624
# val_kl_Loss_Z: 0.1018856
# val_kl_Loss_FC: 16.7748621
# Beta_Rec :  100.0
# Beta_Feat :  116.33006
# Beta_Z :  0.1
# Beta_Fc :  0.05
# Epoch 46/700
# 92/92 [==============================] - 46s 497ms/step - loss: 0.4530 - RecLoss: 0.1854 - FeatRecLoss: 0.2517 - kl_Loss_Z: 4.8070e-04 - kl_Loss_FC: 0.0145 - val_loss: 0.4514 - val_RecLoss: 0.1837 - val_FeatRecLoss: 0.2523 - val_kl_Loss_Z: 0.0013 - val_kl_Loss_FC: 0.0141
#
# Epoch 00046: val_FeatRecLoss did not improve from 0.22379
# Losses
# val_RecLoss: 0.0018366
# val_FeatRecLoss: 0.0021691
# val_kl_Loss_Z: 0.0132025
# val_kl_Loss_FC: 0.2820659
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 118.1050792
# val_kl_Loss_Z: 0.7188476
# val_kl_Loss_FC: 15.3579050
# Beta_Rec :  100.0
# Beta_Feat :  118.10508
# Beta_Z :  0.1
# Beta_Fc :  0.05
# Epoch 47/700
# 92/92 [==============================] - 46s 496ms/step - loss: 0.4560 - RecLoss: 0.1836 - FeatRecLoss: 0.2560 - kl_Loss_Z: 5.2767e-04 - kl_Loss_FC: 0.0145 - val_loss: 0.4541 - val_RecLoss: 0.1826 - val_FeatRecLoss: 0.2557 - val_kl_Loss_Z: 4.5346e-04 - val_kl_Loss_FC: 0.0152
#
# Epoch 00047: val_FeatRecLoss did not improve from 0.22379
# Losses
# val_RecLoss: 0.0018264
# val_FeatRecLoss: 0.0021654
# val_kl_Loss_Z: 0.0045346
# val_kl_Loss_FC: 0.3044834
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 118.5619396
# val_kl_Loss_Z: 0.2482861
# val_kl_Loss_FC: 16.6714210
# Beta_Rec :  100.0
# Beta_Feat :  118.56194
# Beta_Z :  0.1
# Beta_Fc :  0.05
# Epoch 48/700
# 92/92 [==============================] - 46s 496ms/step - loss: 0.4539 - RecLoss: 0.1822 - FeatRecLoss: 0.2560 - kl_Loss_Z: 4.5701e-04 - kl_Loss_FC: 0.0149 - val_loss: 0.4525 - val_RecLoss: 0.1809 - val_FeatRecLoss: 0.2551 - val_kl_Loss_Z: 4.2644e-04 - val_kl_Loss_FC: 0.0162
#
# Epoch 00048: val_FeatRecLoss did not improve from 0.22379
# Losses
# val_RecLoss: 0.0018088
# val_FeatRecLoss: 0.0021513
# val_kl_Loss_Z: 0.0042644
# val_kl_Loss_FC: 0.3232774
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 118.9379869
# val_kl_Loss_Z: 0.2357596
# val_kl_Loss_FC: 17.8725609
# Beta_Rec :  100.0
# Beta_Feat :  118.93799
# Beta_Z :  0.1
# Beta_Fc :  0.05
# Epoch 49/700
# 92/92 [==============================] - 46s 496ms/step - loss: 0.4538 - RecLoss: 0.1804 - FeatRecLoss: 0.2563 - kl_Loss_Z: 4.4962e-04 - kl_Loss_FC: 0.0151 - val_loss: 0.4513 - val_RecLoss: 0.1792 - val_FeatRecLoss: 0.2547 - val_kl_Loss_Z: 3.8636e-04 - val_kl_Loss_FC: 0.0170
#
# Epoch 00049: val_FeatRecLoss did not improve from 0.22379
# Losses
# val_RecLoss: 0.0017919
# val_FeatRecLoss: 0.0021416
# val_kl_Loss_Z: 0.0038636
# val_kl_Loss_FC: 0.3394911
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 119.5148419
# val_kl_Loss_Z: 0.2156131
# val_kl_Loss_FC: 18.9459667
# Beta_Rec :  100.0
# Beta_Feat :  119.51484
# Beta_Z :  0.1
# Beta_Fc :  0.05
# Epoch 50/700
# 92/92 [==============================] - 46s 495ms/step - loss: 0.4529 - RecLoss: 0.1791 - FeatRecLoss: 0.2579 - kl_Loss_Z: 4.8680e-04 - kl_Loss_FC: 0.0150 - val_loss: 0.4506 - val_RecLoss: 0.1776 - val_FeatRecLoss: 0.2570 - val_kl_Loss_Z: 1.8719e-04 - val_kl_Loss_FC: 0.0159
#
# Epoch 00050: val_FeatRecLoss did not improve from 0.22379
# Losses
# val_RecLoss: 0.0017755
# val_FeatRecLoss: 0.0021502
# val_kl_Loss_Z: 0.0018719
# val_kl_Loss_FC: 0.3185969
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 121.1002691
# val_kl_Loss_Z: 0.1054297
# val_kl_Loss_FC: 17.9437750
# Beta_Rec :  100.0
# Beta_Feat :  121.100266
# Beta_Z :  0.1
# Beta_Fc :  0.05
# Epoch 51/700
# 92/92 [==============================] - 46s 495ms/step - loss: 0.4543 - RecLoss: 0.1771 - FeatRecLoss: 0.2607 - kl_Loss_Z: 5.6954e-04 - kl_Loss_FC: 0.0151 - val_loss: 0.4533 - val_RecLoss: 0.1764 - val_FeatRecLoss: 0.2586 - val_kl_Loss_Z: 2.1113e-04 - val_kl_Loss_FC: 0.0181
#
# Epoch 00051: val_FeatRecLoss did not improve from 0.22379
# Losses
# val_RecLoss: 0.0017642
# val_FeatRecLoss: 0.0021352
# val_kl_Loss_Z: 0.0021113
# val_kl_Loss_FC: 0.3611870
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 121.0295952
# val_kl_Loss_Z: 0.1196753
# val_kl_Loss_FC: 20.4731388
# Beta_Rec :  100.0
# Beta_Feat :  121.029594
# Beta_Z :  0.1
# Beta_Fc :  0.05
# Epoch 52/700
# 92/92 [==============================] - 46s 496ms/step - loss: 0.4526 - RecLoss: 0.1760 - FeatRecLoss: 0.2599 - kl_Loss_Z: 5.6773e-04 - kl_Loss_FC: 0.0155 - val_loss: 0.4522 - val_RecLoss: 0.1748 - val_FeatRecLoss: 0.2604 - val_kl_Loss_Z: 9.1701e-04 - val_kl_Loss_FC: 0.0161
#
# Epoch 00052: val_FeatRecLoss did not improve from 0.22379
# Losses
# val_RecLoss: 0.0017483
# val_FeatRecLoss: 0.0021516
# val_kl_Loss_Z: 0.0091701
# val_kl_Loss_FC: 0.3214704
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 123.0702169
# val_kl_Loss_Z: 0.5245167
# val_kl_Loss_FC: 18.3876465
# Beta_Rec :  100.0
# Beta_Feat :  123.07021
# Beta_Z :  0.1
# Beta_Fc :  0.05
# Epoch 53/700
# 92/92 [==============================] - 46s 496ms/step - loss: 0.4555 - RecLoss: 0.1746 - FeatRecLoss: 0.2642 - kl_Loss_Z: 4.7194e-04 - kl_Loss_FC: 0.0157 - val_loss: 0.4544 - val_RecLoss: 0.1735 - val_FeatRecLoss: 0.2644 - val_kl_Loss_Z: 2.6562e-04 - val_kl_Loss_FC: 0.0162
#
# Epoch 00053: val_FeatRecLoss did not improve from 0.22379
# Losses
# val_RecLoss: 0.0017355
# val_FeatRecLoss: 0.0021481
# val_kl_Loss_Z: 0.0026562
# val_kl_Loss_FC: 0.3238467
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 123.7785291
# val_kl_Loss_Z: 0.1530518
# val_kl_Loss_FC: 18.6605617
# Beta_Rec :  100.0
# Beta_Feat :  123.77853
# Beta_Z :  0.1
# Beta_Fc :  0.05
# Epoch 54/700
# 92/92 [==============================] - 46s 497ms/step - loss: 0.4550 - RecLoss: 0.1730 - FeatRecLoss: 0.2658 - kl_Loss_Z: 3.8159e-04 - kl_Loss_FC: 0.0157 - val_loss: 0.4555 - val_RecLoss: 0.1728 - val_FeatRecLoss: 0.2652 - val_kl_Loss_Z: 3.4062e-04 - val_kl_Loss_FC: 0.0171
#
# Epoch 00054: val_FeatRecLoss did not improve from 0.22379
# Losses
# val_RecLoss: 0.0017283
# val_FeatRecLoss: 0.0021428
# val_kl_Loss_Z: 0.0034062
# val_kl_Loss_FC: 0.3410781
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 123.9831184
# val_kl_Loss_Z: 0.1970839
# val_kl_Loss_FC: 19.7347820
# Beta_Rec :  100.0
# Beta_Feat :  123.983116
# Beta_Z :  0.1
# Beta_Fc :  0.05
# Epoch 55/700
# 92/92 [==============================] - 46s 498ms/step - loss: 0.4539 - RecLoss: 0.1714 - FeatRecLoss: 0.2664 - kl_Loss_Z: 4.1587e-04 - kl_Loss_FC: 0.0158 - val_loss: 0.4535 - val_RecLoss: 0.1705 - val_FeatRecLoss: 0.2663 - val_kl_Loss_Z: 1.8780e-04 - val_kl_Loss_FC: 0.0165
#
# Epoch 00055: val_FeatRecLoss did not improve from 0.22379
# Losses
# val_RecLoss: 0.0017048
# val_FeatRecLoss: 0.0021477
# val_kl_Loss_Z: 0.0018780
# val_kl_Loss_FC: 0.3305673
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 125.9751776
# val_kl_Loss_Z: 0.1101602
# val_kl_Loss_FC: 19.3900580
# Beta_Rec :  100.0
# Beta_Feat :  125.975174
# Beta_Z :  0.1
# Beta_Fc :  0.05
# Epoch 56/700
# 92/92 [==============================] - 46s 497ms/step - loss: 0.4569 - RecLoss: 0.1703 - FeatRecLoss: 0.2695 - kl_Loss_Z: 4.3431e-04 - kl_Loss_FC: 0.0163 - val_loss: 0.4577 - val_RecLoss: 0.1708 - val_FeatRecLoss: 0.2694 - val_kl_Loss_Z: 7.1525e-04 - val_kl_Loss_FC: 0.0168
#
# Epoch 00056: val_FeatRecLoss did not improve from 0.22379
# Losses
# val_RecLoss: 0.0017080
# val_FeatRecLoss: 0.0021384
# val_kl_Loss_Z: 0.0071525
# val_kl_Loss_FC: 0.3366074
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 125.1959595
# val_kl_Loss_Z: 0.4187661
# val_kl_Loss_FC: 19.7076536
# Beta_Rec :  100.0
# Beta_Feat :  125.19596
# Beta_Z :  0.1
# Beta_Fc :  0.05
# Epoch 57/700
# 92/92 [==============================] - 46s 497ms/step - loss: 0.4543 - RecLoss: 0.1693 - FeatRecLoss: 0.2682 - kl_Loss_Z: 4.5703e-04 - kl_Loss_FC: 0.0162 - val_loss: 0.4531 - val_RecLoss: 0.1680 - val_FeatRecLoss: 0.2696 - val_kl_Loss_Z: 2.8468e-04 - val_kl_Loss_FC: 0.0152
#
# Epoch 00057: val_FeatRecLoss did not improve from 0.22379
# Losses
# val_RecLoss: 0.0016795
# val_FeatRecLoss: 0.0021538
# val_kl_Loss_Z: 0.0028468
# val_kl_Loss_FC: 0.3034880
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 128.2402075
# val_kl_Loss_Z: 0.1695044
# val_kl_Loss_FC: 18.0700147
# Beta_Rec :  100.0
# Beta_Feat :  128.2402
# Beta_Z :  0.1
# Beta_Fc :  0.05
# Epoch 58/700
# 92/92 [==============================] - 46s 496ms/step - loss: 0.4586 - RecLoss: 0.1676 - FeatRecLoss: 0.2742 - kl_Loss_Z: 4.9104e-04 - kl_Loss_FC: 0.0164 - val_loss: 0.4588 - val_RecLoss: 0.1669 - val_FeatRecLoss: 0.2753 - val_kl_Loss_Z: 1.9478e-04 - val_kl_Loss_FC: 0.0164
#
# Epoch 00058: val_FeatRecLoss did not improve from 0.22379
# Losses
# val_RecLoss: 0.0016685
# val_FeatRecLoss: 0.0021471
# val_kl_Loss_Z: 0.0019478
# val_kl_Loss_FC: 0.3284112
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 128.6850321
# val_kl_Loss_Z: 0.1167411
# val_kl_Loss_FC: 19.6828621
# Beta_Rec :  100.0
# Beta_Feat :  128.68503
# Beta_Z :  0.1
# Beta_Fc :  0.05
# Epoch 59/700
# 92/92 [==============================] - 46s 497ms/step - loss: 0.4593 - RecLoss: 0.1665 - FeatRecLoss: 0.2750 - kl_Loss_Z: 4.3717e-04 - kl_Loss_FC: 0.0165 - val_loss: 0.4590 - val_RecLoss: 0.1658 - val_FeatRecLoss: 0.2768 - val_kl_Loss_Z: 3.3196e-04 - val_kl_Loss_FC: 0.0161
#
# Epoch 00059: val_FeatRecLoss did not improve from 0.22379
# Losses
# val_RecLoss: 0.0016581
# val_FeatRecLoss: 0.0021510
# val_kl_Loss_Z: 0.0033196
# val_kl_Loss_FC: 0.3211015
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 129.7298430
# val_kl_Loss_Z: 0.2002038
# val_kl_Loss_FC: 19.3656465
# Beta_Rec :  100.0
# Beta_Feat :  129.72984
# Beta_Z :  0.1
# Beta_Fc :  0.05
# Epoch 60/700
# 92/92 [==============================] - 46s 497ms/step - loss: 0.4593 - RecLoss: 0.1654 - FeatRecLoss: 0.2770 - kl_Loss_Z: 5.7252e-04 - kl_Loss_FC: 0.0165 - val_loss: 0.4613 - val_RecLoss: 0.1662 - val_FeatRecLoss: 0.2781 - val_kl_Loss_Z: 3.8592e-04 - val_kl_Loss_FC: 0.0166
#
# Epoch 00060: val_FeatRecLoss did not improve from 0.22379
# Losses
# val_RecLoss: 0.0016623
# val_FeatRecLoss: 0.0021436
# val_kl_Loss_Z: 0.0038592
# val_kl_Loss_FC: 0.3315631
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 128.9542265
# val_kl_Loss_Z: 0.2321575
# val_kl_Loss_FC: 19.9457627
# Beta_Rec :  100.0
# Beta_Feat :  128.95422
# Beta_Z :  0.1
# Beta_Fc :  0.05
# Epoch 61/700
# 92/92 [==============================] - 46s 497ms/step - loss: 0.4583 - RecLoss: 0.1646 - FeatRecLoss: 0.2757 - kl_Loss_Z: 4.4919e-04 - kl_Loss_FC: 0.0167 - val_loss: 0.4565 - val_RecLoss: 0.1630 - val_FeatRecLoss: 0.2747 - val_kl_Loss_Z: 4.0672e-04 - val_kl_Loss_FC: 0.0184
#
# Epoch 00061: val_FeatRecLoss did not improve from 0.22379
# Losses
# val_RecLoss: 0.0016304
# val_FeatRecLoss: 0.0021303
# val_kl_Loss_Z: 0.0040672
# val_kl_Loss_FC: 0.3671277
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 130.6602905
# val_kl_Loss_Z: 0.2494633
# val_kl_Loss_FC: 22.5179320
# Beta_Rec :  100.0
# Beta_Feat :  130.6603
# Beta_Z :  0.1
# Beta_Fc :  0.05
# Epoch 62/700
# 92/92 [==============================] - 46s 496ms/step - loss: 0.4594 - RecLoss: 0.1625 - FeatRecLoss: 0.2788 - kl_Loss_Z: 4.5634e-04 - kl_Loss_FC: 0.0170 - val_loss: 0.4608 - val_RecLoss: 0.1633 - val_FeatRecLoss: 0.2799 - val_kl_Loss_Z: 3.7765e-04 - val_kl_Loss_FC: 0.0173
#
# Epoch 00062: val_FeatRecLoss did not improve from 0.22379
# Losses
# val_RecLoss: 0.0016328
# val_FeatRecLoss: 0.0021419
# val_kl_Loss_Z: 0.0037765
# val_kl_Loss_FC: 0.3453179
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 131.1806903
# val_kl_Loss_Z: 0.2312970
# val_kl_Loss_FC: 21.1492430
# Beta_Rec :  100.0
# Beta_Feat :  131.1807
# Beta_Z :  0.1
# Beta_Fc :  0.05
# Epoch 63/700
# 92/92 [==============================] - 46s 497ms/step - loss: 0.4584 - RecLoss: 0.1617 - FeatRecLoss: 0.2798 - kl_Loss_Z: 4.1384e-04 - kl_Loss_FC: 0.0170 - val_loss: 0.4582 - val_RecLoss: 0.1607 - val_FeatRecLoss: 0.2814 - val_kl_Loss_Z: 3.1643e-04 - val_kl_Loss_FC: 0.0158
#
# Epoch 00063: val_FeatRecLoss did not improve from 0.22379
# Losses
# val_RecLoss: 0.0016069
# val_FeatRecLoss: 0.0021454
# val_kl_Loss_Z: 0.0031643
# val_kl_Loss_FC: 0.3157825
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 133.5120260
# val_kl_Loss_Z: 0.1969139
# val_kl_Loss_FC: 19.6512867
# Beta_Rec :  100.0
# Beta_Feat :  133.51202
# Beta_Z :  0.1
# Beta_Fc :  0.05
# Epoch 64/700
# 92/92 [==============================] - 46s 497ms/step - loss: 0.4637 - RecLoss: 0.1607 - FeatRecLoss: 0.2844 - kl_Loss_Z: 3.9703e-04 - kl_Loss_FC: 0.0173 - val_loss: 0.4626 - val_RecLoss: 0.1603 - val_FeatRecLoss: 0.2851 - val_kl_Loss_Z: 3.0560e-04 - val_kl_Loss_FC: 0.0169
#
# Epoch 00064: val_FeatRecLoss did not improve from 0.22379
# Losses
# val_RecLoss: 0.0016030
# val_FeatRecLoss: 0.0021354
# val_kl_Loss_Z: 0.0030560
# val_kl_Loss_FC: 0.3385191
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 133.2095441
# val_kl_Loss_Z: 0.1906375
# val_kl_Loss_FC: 21.1173709
# Beta_Rec :  100.0
# Beta_Feat :  133.20955
# Beta_Z :  0.1
# Beta_Fc :  0.05
# Epoch 65/700
# 92/92 [==============================] - 46s 497ms/step - loss: 0.4613 - RecLoss: 0.1598 - FeatRecLoss: 0.2836 - kl_Loss_Z: 3.9282e-04 - kl_Loss_FC: 0.0174 - val_loss: 0.4628 - val_RecLoss: 0.1604 - val_FeatRecLoss: 0.2846 - val_kl_Loss_Z: 8.0790e-04 - val_kl_Loss_FC: 0.0170
#
# Epoch 00065: val_FeatRecLoss did not improve from 0.22379
# Losses
# val_RecLoss: 0.0016044
# val_FeatRecLoss: 0.0021366
# val_kl_Loss_Z: 0.0080790
# val_kl_Loss_FC: 0.3392107
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 133.1725237
# val_kl_Loss_Z: 0.5035590
# val_kl_Loss_FC: 21.1427646
# Beta_Rec :  100.0
# Beta_Feat :  133.17253
# Beta_Z :  0.1
# Beta_Fc :  0.05
# Epoch 66/700
# 92/92 [==============================] - 46s 497ms/step - loss: 0.4615 - RecLoss: 0.1588 - FeatRecLoss: 0.2835 - kl_Loss_Z: 5.5265e-04 - kl_Loss_FC: 0.0174 - val_loss: 0.4594 - val_RecLoss: 0.1579 - val_FeatRecLoss: 0.2838 - val_kl_Loss_Z: 1.9736e-04 - val_kl_Loss_FC: 0.0175
#
# Epoch 00066: val_FeatRecLoss did not improve from 0.22379
# Losses
# val_RecLoss: 0.0015789
# val_FeatRecLoss: 0.0021312
# val_kl_Loss_Z: 0.0019736
# val_kl_Loss_FC: 0.3505553
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 134.9799536
# val_kl_Loss_Z: 0.1249997
# val_kl_Loss_FC: 22.2023366
# Beta_Rec :  100.0
# Beta_Feat :  134.97995
# Beta_Z :  0.1
# Beta_Fc :  0.05
# Epoch 67/700
# 92/92 [==============================] - 46s 496ms/step - loss: 0.4635 - RecLoss: 0.1576 - FeatRecLoss: 0.2871 - kl_Loss_Z: 4.1155e-04 - kl_Loss_FC: 0.0175 - val_loss: 0.4617 - val_RecLoss: 0.1567 - val_FeatRecLoss: 0.2873 - val_kl_Loss_Z: 1.8401e-04 - val_kl_Loss_FC: 0.0175
#
# Epoch 00067: val_FeatRecLoss did not improve from 0.22379
# Losses
# val_RecLoss: 0.0015669
# val_FeatRecLoss: 0.0021285
# val_kl_Loss_Z: 0.0018401
# val_kl_Loss_FC: 0.3503923
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 135.8421211
# val_kl_Loss_Z: 0.1174382
# val_kl_Loss_FC: 22.3623826
# Beta_Rec :  100.0
# Beta_Feat :  135.84212
# Beta_Z :  0.1
# Beta_Fc :  0.05
# Epoch 68/700
# 92/92 [==============================] - 46s 496ms/step - loss: 0.4631 - RecLoss: 0.1566 - FeatRecLoss: 0.2887 - kl_Loss_Z: 4.3974e-04 - kl_Loss_FC: 0.0176 - val_loss: 0.4639 - val_RecLoss: 0.1561 - val_FeatRecLoss: 0.2910 - val_kl_Loss_Z: 4.3288e-04 - val_kl_Loss_FC: 0.0163
#
# Epoch 00068: val_FeatRecLoss did not improve from 0.22379
# Losses
# val_RecLoss: 0.0015608
# val_FeatRecLoss: 0.0021423
# val_kl_Loss_Z: 0.0043288
# val_kl_Loss_FC: 0.3269849
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 137.2606693
# val_kl_Loss_Z: 0.2773518
# val_kl_Loss_FC: 20.9503536
# Beta_Rec :  100.0
# Beta_Feat :  137.26067
# Beta_Z :  0.1
# Beta_Fc :  0.05
# Epoch 69/700
# 92/92 [==============================] - 46s 495ms/step - loss: 0.4655 - RecLoss: 0.1557 - FeatRecLoss: 0.2916 - kl_Loss_Z: 4.5785e-04 - kl_Loss_FC: 0.0178 - val_loss: 0.4650 - val_RecLoss: 0.1547 - val_FeatRecLoss: 0.2927 - val_kl_Loss_Z: 5.4015e-04 - val_kl_Loss_FC: 0.0171
#
# Epoch 00069: val_FeatRecLoss did not improve from 0.22379
# Losses
# val_RecLoss: 0.0015471
# val_FeatRecLoss: 0.0021322
# val_kl_Loss_Z: 0.0054015
# val_kl_Loss_FC: 0.3410991
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 137.8176880
# val_kl_Loss_Z: 0.3491349
# val_kl_Loss_FC: 22.0473638
# Beta_Rec :  100.0
# Beta_Feat :  137.81769
# Beta_Z :  0.1
# Beta_Fc :  0.05
# Epoch 70/700
# 92/92 [==============================] - 46s 497ms/step - loss: 0.4664 - RecLoss: 0.1549 - FeatRecLoss: 0.2933 - kl_Loss_Z: 5.1005e-04 - kl_Loss_FC: 0.0178 - val_loss: 0.4654 - val_RecLoss: 0.1541 - val_FeatRecLoss: 0.2936 - val_kl_Loss_Z: 2.0706e-04 - val_kl_Loss_FC: 0.0176
#
# Epoch 00070: val_FeatRecLoss did not improve from 0.22379
# Losses
# val_RecLoss: 0.0015410
# val_FeatRecLoss: 0.0021301
# val_kl_Loss_Z: 0.0020706
# val_kl_Loss_FC: 0.3511187
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 138.2284801
# val_kl_Loss_Z: 0.1343710
# val_kl_Loss_FC: 22.7851969
# Beta_Rec :  100.0
# Beta_Feat :  138.22849
# Beta_Z :  0.1
# Beta_Fc :  0.05
# Epoch 71/700
# 92/92 [==============================] - 46s 496ms/step - loss: 0.4660 - RecLoss: 0.1539 - FeatRecLoss: 0.2933 - kl_Loss_Z: 4.6147e-04 - kl_Loss_FC: 0.0180 - val_loss: 0.4666 - val_RecLoss: 0.1534 - val_FeatRecLoss: 0.2958 - val_kl_Loss_Z: 3.1158e-04 - val_kl_Loss_FC: 0.0170
#
# Epoch 00071: val_FeatRecLoss did not improve from 0.22379
# Losses
# val_RecLoss: 0.0015344
# val_FeatRecLoss: 0.0021399
# val_kl_Loss_Z: 0.0031158
# val_kl_Loss_FC: 0.3409717
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 139.4596077
# val_kl_Loss_Z: 0.2030618
# val_kl_Loss_FC: 22.2215729
# Beta_Rec :  100.0
# Beta_Feat :  139.45961
# Beta_Z :  0.1
# Beta_Fc :  0.05
# Epoch 72/700
# 92/92 [==============================] - 46s 497ms/step - loss: 0.4673 - RecLoss: 0.1528 - FeatRecLoss: 0.2956 - kl_Loss_Z: 4.4231e-04 - kl_Loss_FC: 0.0181 - val_loss: 0.4672 - val_RecLoss: 0.1521 - val_FeatRecLoss: 0.2977 - val_kl_Loss_Z: 4.4782e-04 - val_kl_Loss_FC: 0.0170
#
# Epoch 00072: val_FeatRecLoss did not improve from 0.22379
# Losses
# val_RecLoss: 0.0015213
# val_FeatRecLoss: 0.0021344
# val_kl_Loss_Z: 0.0044782
# val_kl_Loss_FC: 0.3401769
# RelWeights
# ...
# val_kl_Loss_FC: 0.2689112
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 101.3447533
# val_kl_Loss_Z: 26.0413104
# val_kl_Loss_FC: 28.2570174
# Beta_Rec :  100.0
# Beta_Feat :  101.34476
# Beta_Z :  0.1
# Beta_Fc :  0.05
# Epoch 396/700
# 92/92 [==============================] - 46s 497ms/step - loss: 0.2296 - RecLoss: 0.0946 - FeatRecLoss: 0.0974 - kl_Loss_Z: 0.0237 - kl_Loss_FC: 0.0135 - val_loss: 0.2291 - val_RecLoss: 0.0945 - val_FeatRecLoss: 0.0969 - val_kl_Loss_Z: 0.0239 - val_kl_Loss_FC: 0.0138
#
# Epoch 00396: val_FeatRecLoss did not improve from 0.09646
# Losses
# val_RecLoss: 0.0009453
# val_FeatRecLoss: 0.0009558
# val_kl_Loss_Z: 0.2391108
# val_kl_Loss_FC: 0.2766200
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 101.1046717
# val_kl_Loss_Z: 25.2933670
# val_kl_Loss_FC: 29.2611242
# Beta_Rec :  100.0
# Beta_Feat :  101.104675
# Beta_Z :  0.1
# Beta_Fc :  0.05
# Epoch 397/700
# 92/92 [==============================] - 46s 497ms/step - loss: 0.2294 - RecLoss: 0.0948 - FeatRecLoss: 0.0974 - kl_Loss_Z: 0.0240 - kl_Loss_FC: 0.0132 - val_loss: 0.2306 - val_RecLoss: 0.0949 - val_FeatRecLoss: 0.0977 - val_kl_Loss_Z: 0.0244 - val_kl_Loss_FC: 0.0136
#
# Epoch 00397: val_FeatRecLoss did not improve from 0.09646
# Losses
# val_RecLoss: 0.0009490
# val_FeatRecLoss: 0.0009659
# val_kl_Loss_Z: 0.2441609
# val_kl_Loss_FC: 0.2720192
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 101.7810579
# val_kl_Loss_Z: 25.7293744
# val_kl_Loss_FC: 28.6650454
# Beta_Rec :  100.0
# Beta_Feat :  101.78106
# Beta_Z :  0.1
# Beta_Fc :  0.05
# Epoch 398/700
# 92/92 [==============================] - 46s 497ms/step - loss: 0.2295 - RecLoss: 0.0945 - FeatRecLoss: 0.0977 - kl_Loss_Z: 0.0240 - kl_Loss_FC: 0.0133 - val_loss: 0.2303 - val_RecLoss: 0.0955 - val_FeatRecLoss: 0.0968 - val_kl_Loss_Z: 0.0239 - val_kl_Loss_FC: 0.0140
#
# Epoch 00398: val_FeatRecLoss did not improve from 0.09646
# Losses
# val_RecLoss: 0.0009554
# val_FeatRecLoss: 0.0009512
# val_kl_Loss_Z: 0.2387944
# val_kl_Loss_FC: 0.2808416
# RelWeights
# val_RecLoss: 100.4402865
# val_FeatRecLoss: 100.0000000
# val_kl_Loss_Z: 25.1049328
# val_kl_Loss_FC: 29.5254330
# Beta_Rec :  100.440285
# Beta_Feat :  100.0
# Beta_Z :  0.1
# Beta_Fc :  0.05
# Epoch 399/700
# 92/92 [==============================] - 46s 498ms/step - loss: 0.2287 - RecLoss: 0.0949 - FeatRecLoss: 0.0964 - kl_Loss_Z: 0.0239 - kl_Loss_FC: 0.0132 - val_loss: 0.2302 - val_RecLoss: 0.0968 - val_FeatRecLoss: 0.0959 - val_kl_Loss_Z: 0.0238 - val_kl_Loss_FC: 0.0137
#
# Epoch 00399: val_FeatRecLoss improved from 0.09646 to 0.09591, saving model to ./Results\SigBandRepModel_ExtRec_2.hdf5
# Losses
# val_RecLoss: 0.0009638
# val_FeatRecLoss: 0.0009591
# val_kl_Loss_Z: 0.2379223
# val_kl_Loss_FC: 0.2745243
# RelWeights
# val_RecLoss: 100.4888414
# val_FeatRecLoss: 100.0000000
# val_kl_Loss_Z: 24.8059581
# val_kl_Loss_FC: 28.6221187
# Beta_Rec :  100.48884
# Beta_Feat :  100.0
# Beta_Z :  0.1
# Beta_Fc :  0.05
# Epoch 400/700
# 92/92 [==============================] - 46s 497ms/step - loss: 0.2292 - RecLoss: 0.0952 - FeatRecLoss: 0.0963 - kl_Loss_Z: 0.0235 - kl_Loss_FC: 0.0133 - val_loss: 0.2277 - val_RecLoss: 0.0951 - val_FeatRecLoss: 0.0955 - val_kl_Loss_Z: 0.0234 - val_kl_Loss_FC: 0.0137
#
# Epoch 00400: val_FeatRecLoss improved from 0.09591 to 0.09552, saving model to ./Results\SigBandRepModel_ExtRec_2.hdf5
# Losses
# val_RecLoss: 0.0009462
# val_FeatRecLoss: 0.0009552
# val_kl_Loss_Z: 0.2338771
# val_kl_Loss_FC: 0.2736337
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 100.9511032
# val_kl_Loss_Z: 24.7180176
# val_kl_Loss_FC: 28.9198104
# Beta_Rec :  100.0
# Beta_Feat :  100.9511
# Beta_Z :  0.1
# Beta_Fc :  0.05
# Epoch 401/700
# 92/92 [==============================] - 46s 498ms/step - loss: 0.2282 - RecLoss: 0.0943 - FeatRecLoss: 0.0972 - kl_Loss_Z: 0.0238 - kl_Loss_FC: 0.0132 - val_loss: 0.2296 - val_RecLoss: 0.0942 - val_FeatRecLoss: 0.0965 - val_kl_Loss_Z: 0.0243 - val_kl_Loss_FC: 0.0146
#
# Epoch 00401: val_FeatRecLoss did not improve from 0.09552
# Losses
# val_RecLoss: 0.0009422
# val_FeatRecLoss: 0.0009554
# val_kl_Loss_Z: 0.2431385
# val_kl_Loss_FC: 0.2914216
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 101.4057409
# val_kl_Loss_Z: 25.8060151
# val_kl_Loss_FC: 30.9306413
# Beta_Rec :  100.0
# Beta_Feat :  101.40574
# Beta_Z :  0.1
# Beta_Fc :  0.05
# Epoch 402/700
# 92/92 [==============================] - 46s 497ms/step - loss: 0.2290 - RecLoss: 0.0943 - FeatRecLoss: 0.0972 - kl_Loss_Z: 0.0240 - kl_Loss_FC: 0.0134 - val_loss: 0.2308 - val_RecLoss: 0.0955 - val_FeatRecLoss: 0.0981 - val_kl_Loss_Z: 0.0241 - val_kl_Loss_FC: 0.0131
#
# Epoch 00402: val_FeatRecLoss did not improve from 0.09552
# Losses
# val_RecLoss: 0.0009549
# val_FeatRecLoss: 0.0009677
# val_kl_Loss_Z: 0.2407148
# val_kl_Loss_FC: 0.2627253
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 101.3461380
# val_kl_Loss_Z: 25.2089566
# val_kl_Loss_FC: 27.5140202
# Beta_Rec :  100.0
# Beta_Feat :  101.34614
# Beta_Z :  0.1
# Beta_Fc :  0.05
# Epoch 403/700
# 92/92 [==============================] - 46s 498ms/step - loss: 0.2292 - RecLoss: 0.0945 - FeatRecLoss: 0.0973 - kl_Loss_Z: 0.0241 - kl_Loss_FC: 0.0132 - val_loss: 0.2286 - val_RecLoss: 0.0947 - val_FeatRecLoss: 0.0972 - val_kl_Loss_Z: 0.0234 - val_kl_Loss_FC: 0.0134
#
# Epoch 00403: val_FeatRecLoss did not improve from 0.09552
# Losses
# val_RecLoss: 0.0009469
# val_FeatRecLoss: 0.0009589
# val_kl_Loss_Z: 0.2335249
# val_kl_Loss_FC: 0.2675391
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 101.2672960
# val_kl_Loss_Z: 24.6616349
# val_kl_Loss_FC: 28.2537381
# Beta_Rec :  100.0
# Beta_Feat :  101.267296
# Beta_Z :  0.1
# Beta_Fc :  0.05
# Epoch 404/700
# 92/92 [==============================] - 46s 498ms/step - loss: 0.2287 - RecLoss: 0.0944 - FeatRecLoss: 0.0974 - kl_Loss_Z: 0.0236 - kl_Loss_FC: 0.0133 - val_loss: 0.2307 - val_RecLoss: 0.0947 - val_FeatRecLoss: 0.0976 - val_kl_Loss_Z: 0.0242 - val_kl_Loss_FC: 0.0141
#
# Epoch 00404: val_FeatRecLoss did not improve from 0.09552
# Losses
# val_RecLoss: 0.0009474
# val_FeatRecLoss: 0.0009642
# val_kl_Loss_Z: 0.2424491
# val_kl_Loss_FC: 0.2812240
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 101.7674248
# val_kl_Loss_Z: 25.5907839
# val_kl_Loss_FC: 29.6835204
# Beta_Rec :  100.0
# Beta_Feat :  101.767426
# Beta_Z :  0.1
# Beta_Fc :  0.05
# Epoch 405/700
# 92/92 [==============================] - 46s 497ms/step - loss: 0.2292 - RecLoss: 0.0942 - FeatRecLoss: 0.0977 - kl_Loss_Z: 0.0238 - kl_Loss_FC: 0.0135 - val_loss: 0.2305 - val_RecLoss: 0.0955 - val_FeatRecLoss: 0.0979 - val_kl_Loss_Z: 0.0233 - val_kl_Loss_FC: 0.0138
#
# Epoch 00405: val_FeatRecLoss did not improve from 0.09552
# Losses
# val_RecLoss: 0.0009553
# val_FeatRecLoss: 0.0009621
# val_kl_Loss_Z: 0.2333854
# val_kl_Loss_FC: 0.2751345
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 100.7122917
# val_kl_Loss_Z: 24.4312733
# val_kl_Loss_FC: 28.8016580
# Beta_Rec :  100.0
# Beta_Feat :  100.71229
# Beta_Z :  0.1
# Beta_Fc :  0.05
# Epoch 406/700
# 92/92 [==============================] - 46s 497ms/step - loss: 0.2278 - RecLoss: 0.0943 - FeatRecLoss: 0.0968 - kl_Loss_Z: 0.0237 - kl_Loss_FC: 0.0134 - val_loss: 0.2287 - val_RecLoss: 0.0956 - val_FeatRecLoss: 0.0953 - val_kl_Loss_Z: 0.0240 - val_kl_Loss_FC: 0.0138
#
# Epoch 00406: val_FeatRecLoss improved from 0.09552 to 0.09535, saving model to ./Results\SigBandRepModel_ExtRec_2.hdf5
# Losses
# val_RecLoss: 0.0009562
# val_FeatRecLoss: 0.0009467
# val_kl_Loss_Z: 0.2399000
# val_kl_Loss_FC: 0.2756337
# RelWeights
# val_RecLoss: 101.0036955
# val_FeatRecLoss: 100.0000000
# val_kl_Loss_Z: 25.3402393
# val_kl_Loss_FC: 29.1147336
# Beta_Rec :  101.00369
# Beta_Feat :  100.0
# Beta_Z :  0.1
# Beta_Fc :  0.05
# Epoch 407/700
# 92/92 [==============================] - 46s 497ms/step - loss: 0.2273 - RecLoss: 0.0953 - FeatRecLoss: 0.0955 - kl_Loss_Z: 0.0236 - kl_Loss_FC: 0.0134 - val_loss: 0.2290 - val_RecLoss: 0.0961 - val_FeatRecLoss: 0.0948 - val_kl_Loss_Z: 0.0245 - val_kl_Loss_FC: 0.0135
#
# Epoch 00407: val_FeatRecLoss improved from 0.09535 to 0.09481, saving model to ./Results\SigBandRepModel_ExtRec_2.hdf5
# Losses
# val_RecLoss: 0.0009513
# val_FeatRecLoss: 0.0009481
# val_kl_Loss_Z: 0.2450957
# val_kl_Loss_FC: 0.2709927
# RelWeights
# val_RecLoss: 100.3311643
# val_FeatRecLoss: 100.0000000
# val_kl_Loss_Z: 25.8504809
# val_kl_Loss_FC: 28.5818616
# Beta_Rec :  100.33116
# Beta_Feat :  100.0
# Beta_Z :  0.1
# Beta_Fc :  0.05
# Epoch 408/700
# 92/92 [==============================] - 46s 497ms/step - loss: 0.2272 - RecLoss: 0.0945 - FeatRecLoss: 0.0959 - kl_Loss_Z: 0.0238 - kl_Loss_FC: 0.0133 - val_loss: 0.2272 - val_RecLoss: 0.0951 - val_FeatRecLoss: 0.0944 - val_kl_Loss_Z: 0.0241 - val_kl_Loss_FC: 0.0136
#
# Epoch 00408: val_FeatRecLoss improved from 0.09481 to 0.09443, saving model to ./Results\SigBandRepModel_ExtRec_2.hdf5
# Losses
# val_RecLoss: 0.0009475
# val_FeatRecLoss: 0.0009443
# val_kl_Loss_Z: 0.2410590
# val_kl_Loss_FC: 0.2715057
# RelWeights
# val_RecLoss: 100.3449766
# val_FeatRecLoss: 100.0000000
# val_kl_Loss_Z: 25.5280266
# val_kl_Loss_FC: 28.7523127
# Beta_Rec :  100.34498
# Beta_Feat :  100.0
# Beta_Z :  0.1
# Beta_Fc :  0.05
# Epoch 409/700
# 92/92 [==============================] - 46s 497ms/step - loss: 0.2272 - RecLoss: 0.0944 - FeatRecLoss: 0.0962 - kl_Loss_Z: 0.0238 - kl_Loss_FC: 0.0132 - val_loss: 0.2293 - val_RecLoss: 0.0946 - val_FeatRecLoss: 0.0976 - val_kl_Loss_Z: 0.0236 - val_kl_Loss_FC: 0.0136
#
# Epoch 00409: val_FeatRecLoss did not improve from 0.09443
# Losses
# val_RecLoss: 0.0009425
# val_FeatRecLoss: 0.0009755
# val_kl_Loss_Z: 0.2355560
# val_kl_Loss_FC: 0.2715866
# RelWeights
# val_RecLoss: 100.0000000
# val_FeatRecLoss: 103.5100387
# val_kl_Loss_Z: 24.9936597
# val_kl_Loss_FC: 28.8166895
# Beta_Rec :  100.0
# Beta_Feat :  103.51004
# Beta_Z :  0.1
# Beta_Fc :  0.05
# Epoch 410/700
# 92/92 [==============================] - 46s 496ms/step - loss: 0.2311 - RecLoss: 0.0941 - FeatRecLoss: 0.0991 - kl_Loss_Z: 0.0241 - kl_Loss_FC: 0.0136 - val_loss: 0.2316 - val_RecLoss: 0.0956 - val_FeatRecLoss: 0.0988 - val_kl_Loss_Z: 0.0239 - val_kl_Loss_FC: 0.0134
#
# Epoch 00410: val_FeatRecLoss did not improve from 0.09443
# Losses
# val_RecLoss: 0.0009557
# val_FeatRecLoss: 0.0009546
# val_kl_Loss_Z: 0.2390905
# val_kl_Loss_FC: 0.2671339
# RelWeights
# val_RecLoss: 100.1078518
# val_FeatRecLoss: 100.0000000
# val_kl_Loss_Z: 25.0449306
# val_kl_Loss_FC: 27.9824930
# Beta_Rec :  100.10785
# Beta_Feat :  100.0
# Beta_Z :  0.1
# Beta_Fc :  0.05
# Epoch 411/700
# 56/92 [=================>............] - ETA: 17s - loss: 0.2269 - RecLoss: 0.0940 - FeatRecLoss: 0.0963 - kl_Loss_Z: 0.0236 - kl_Loss_FC: 0.0134
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [44], in <cell line: 4>()
#       1 #SigBandRepModel.load_weights(ModelSaveSameName)
#       2 ModelSave = ModelCheckpoint(filepath=ModelSaveSameName, monitor='val_FeatRecLoss', verbose=1, save_best_only=True )
# ----> 4 SigBandRepModel.fit(DATA[:], batch_size=3500, epochs=700, shuffle=True, validation_split=0.2, callbacks=[EarlyStop, ModelSave, RelLoss])
#
# File ~\anaconda3\envs\ai\lib\site-packages\tensorflow\python\keras\engine\training.py:1105, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1103 logs = tmp_logs  # No error, now safe to assign to logs.
#    1104 end_step = step + data_handler.step_increment
# -> 1105 callbacks.on_train_batch_end(end_step, logs)
#    1106 if self.stop_training:
#    1107   break
#
# File ~\anaconda3\envs\ai\lib\site-packages\tensorflow\python\keras\callbacks.py:454, in CallbackList.on_train_batch_end(self, batch, logs)
#     447 """Calls the `on_train_batch_end` methods of its callbacks.
#     448
#     449 Arguments:
#     450     batch: Integer, index of batch within the current epoch.
#     451     logs: Dict. Aggregated metric results up until this batch.
#     452 """
#     453 if self._should_call_train_batch_hooks:
# --> 454   self._call_batch_hook(ModeKeys.TRAIN, 'end', batch, logs=logs)
#
# File ~\anaconda3\envs\ai\lib\site-packages\tensorflow\python\keras\callbacks.py:296, in CallbackList._call_batch_hook(self, mode, hook, batch, logs)
#     294   self._call_batch_begin_hook(mode, batch, logs)
#     295 elif hook == 'end':
# --> 296   self._call_batch_end_hook(mode, batch, logs)
#     297 else:
#     298   raise ValueError('Unrecognized hook: {}'.format(hook))
#
# File ~\anaconda3\envs\ai\lib\site-packages\tensorflow\python\keras\callbacks.py:316, in CallbackList._call_batch_end_hook(self, mode, batch, logs)
#     313   batch_time = time.time() - self._batch_start_time
#     314   self._batch_times.append(batch_time)
# --> 316 self._call_batch_hook_helper(hook_name, batch, logs)
#     318 if len(self._batch_times) >= self._num_batches_for_timing_check:
#     319   end_hook_name = hook_name
#
# File ~\anaconda3\envs\ai\lib\site-packages\tensorflow\python\keras\callbacks.py:356, in CallbackList._call_batch_hook_helper(self, hook_name, batch, logs)
#     354 hook = getattr(callback, hook_name)
#     355 if getattr(callback, '_supports_tf_logs', False):
# --> 356   hook(batch, logs)
#     357 else:
#     358   if numpy_logs is None:  # Only convert once.
#
# File ~\anaconda3\envs\ai\lib\site-packages\tensorflow\python\keras\callbacks.py:1020, in ProgbarLogger.on_train_batch_end(self, batch, logs)
#    1019 def on_train_batch_end(self, batch, logs=None):
# -> 1020   self._batch_update_progbar(batch, logs)
#
# File ~\anaconda3\envs\ai\lib\site-packages\tensorflow\python\keras\callbacks.py:1084, in ProgbarLogger._batch_update_progbar(self, batch, logs)
#    1080   self.seen += add_seen
#    1082 if self.verbose == 1:
#    1083   # Only block async when verbose = 1.
# -> 1084   logs = tf_utils.to_numpy_or_python_type(logs)
#    1085   self.progbar.update(self.seen, list(logs.items()), finalize=False)
#
# File ~\anaconda3\envs\ai\lib\site-packages\tensorflow\python\keras\utils\tf_utils.py:514, in to_numpy_or_python_type(tensors)
#     511     return x.item() if np.ndim(x) == 0 else x
#     512   return t  # Don't turn ragged or sparse tensors to NumPy.
# --> 514 return nest.map_structure(_to_single_numpy_or_python_type, tensors)
#
# File ~\anaconda3\envs\ai\lib\site-packages\tensorflow\python\util\nest.py:659, in map_structure(func, *structure, **kwargs)
#     655 flat_structure = (flatten(s, expand_composites) for s in structure)
#     656 entries = zip(*flat_structure)
#     658 return pack_sequence_as(
# --> 659     structure[0], [func(*x) for x in entries],
#     660     expand_composites=expand_composites)
#
# File ~\anaconda3\envs\ai\lib\site-packages\tensorflow\python\util\nest.py:659, in <listcomp>(.0)
#     655 flat_structure = (flatten(s, expand_composites) for s in structure)
#     656 entries = zip(*flat_structure)
#     658 return pack_sequence_as(
# --> 659     structure[0], [func(*x) for x in entries],
#     660     expand_composites=expand_composites)
#
# File ~\anaconda3\envs\ai\lib\site-packages\tensorflow\python\keras\utils\tf_utils.py:510, in to_numpy_or_python_type.<locals>._to_single_numpy_or_python_type(t)
#     508 def _to_single_numpy_or_python_type(t):
#     509   if isinstance(t, ops.Tensor):
# --> 510     x = t.numpy()
#     511     return x.item() if np.ndim(x) == 0 else x
#     512   return t
#
# File ~\anaconda3\envs\ai\lib\site-packages\tensorflow\python\framework\ops.py:1071, in _EagerTensorBase.numpy(self)
#    1048 """Copy of the contents of this Tensor into a NumPy array or scalar.
#    1049
#    1050 Unlike NumPy arrays, Tensors are immutable, so this method has to copy
#    (...)
#    1068     NumPy dtype.
#    1069 """
#    1070 # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1071 maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1072 return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#
# File ~\anaconda3\envs\ai\lib\site-packages\tensorflow\python\framework\ops.py:1037, in _EagerTensorBase._numpy(self)
#    1035 def _numpy(self):
#    1036   try:
# -> 1037     return self._numpy_internal()
#    1038   except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1039     six.raise_from(core._status_to_exception(e.code, e.message), None)
#
# KeyboardInterrupt:

# %%
res = []
for i in range (5000):

    FCs = 0.9
    FCs = tf.clip_by_value(FCs, 1e-7, 1-1e-7)
    Epsilon = tf.random.uniform(shape=(1, 1))
    Epsilon = tf.clip_by_value(Epsilon, 1e-7, 1-1e-7)

    LogEps = tf.math.log(Epsilon)
    LogNegEps = tf.math.log(1 - Epsilon)

    LogTheta = tf.math.log(FCs)
    LogNegTheta = tf.math.log(1-FCs)


    res.append(tf.math.sigmoid(LogEps - LogNegEps + LogTheta - LogNegTheta).numpy())
    
plt.hist(np.concatenate(res))
